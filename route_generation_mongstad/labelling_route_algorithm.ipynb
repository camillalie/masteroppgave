# %%
import pandas as pd
from itertools import combinations
import math
import os
import csv
import time

# %%
cargo_capacity_psv = 100
psv_speed = 10 #7 for strøm, 10 på resten
max_platforms_in_one_voyage = 6

# %% [markdown]
# ## Reads input data

# %%
demand = pd.read_csv('clustering/output_platforms_demand.csv', header=0, delimiter=';')
distances = pd.read_csv('clustering/output_distance_matrix_kmeans.csv', header=0, delimiter=';', index_col='from/to')

platforms_demand = dict(zip(demand['platform'], demand['avg_q'].replace(',', '.').astype(float)))
platforms_d = ['MON'] + demand['platform'].tolist() + ['MON']  # Add 'Mon' as start and end platforms

# %% [markdown]
# ## Algorithm for generating the shortest routes

# %%
shortest_routes_dict = {}

def generate_routes(demand, distances):
    cargo_capacity = cargo_capacity_psv
    max_platforms = max_platforms_in_one_voyage + 2 

    def dp(platform, cargo_remaining, route, visited):
        if cargo_remaining < 0:
            return
        if len(route) > max_platforms:
            return
        if platform == 'MON' and len(route) > 2:
            total_demand = sum(platforms_demand[p] for p in route[1:-1])
            if total_demand <= cargo_capacity:
                key = tuple(sorted(set(route)))
                total_distance = sum(distances.loc[route[i], route[i+1]] for i in range(len(route)-1))
                if key not in shortest_routes_dict or total_distance < shortest_routes_dict[key][1]:
                    duration_sailing = round((total_distance / psv_speed), 2)
                    duration_lossing = round(((total_demand * 1.389) / psv_speed), 2)
                    duration_sailing = round(duration_sailing, 2)
                    duration_lossing = round(duration_lossing, 2)
                    shortest_routes_dict[key] = (route, total_distance, total_demand, duration_sailing, duration_lossing)
            return

        # Check if the current route is dominated
        current_distance = sum(distances.loc[route[i], route[i+1]] for i in range(len(route)-1))
        current_demand = sum(platforms_demand[p] for p in route[1:-1])
        
        # Check for dominance in existing routes
        for key, (existing_route, existing_distance, existing_demand, _, _) in shortest_routes_dict.items():
            if set(existing_route[1:-1]) == set(route[1:-1]) and existing_demand >= current_demand and existing_distance <= current_distance:
                return
        
        # Check for dominance in subsequent routes starting with the same platforms
        for existing_route in dominated_routes:
            if set(existing_route[1:-1]) == set(route[1:-1]) and existing_demand >= current_demand and existing_distance <= current_distance:
                return

        for next_platform in platforms_demand.keys():
            if next_platform != platform and next_platform not in visited:
                try:
                    distance_to_next = distances.loc[platform, next_platform]
                    new_cargo_remaining = cargo_remaining - platforms_demand[next_platform]
                    dp(next_platform, new_cargo_remaining, route + [next_platform], visited.union({next_platform}))
                except KeyError:
                    print("KeyError occurred for platform:", next_platform)
                    continue

    for r in range(3, min(len(platforms_demand) + 3, max_platforms + 3)):
        for route_combination in combinations(platforms_demand.keys(), r - 2):
            route = ['MON'] + list(route_combination) + ['MON']
            dp('MON', cargo_capacity, route, {'MON'})

            # Add the current route to the dominated routes set
            dominated_routes.add(tuple(route))

    return shortest_routes_dict

# Keep track of dominated routes to skip future routes starting with them
dominated_routes = set()
shortest_routes_dict = generate_routes(demand, distances)

for route, distance, demand, duration_sailing, duration_lossing in shortest_routes_dict.values():
    print(f"Shortest Route: {route}, Total Distance: {round(distance,2)}, Total Demand: {demand}, Duration sailing: {duration_sailing}, Duration lossing: {duration_lossing}")

print(len(shortest_routes_dict))
# Out:
# Shortest Route: ['MON', 'APT', 'MON'], Total Distance: 134.2, Total Demand: 18.0, Duration sailing: 13.42, Duration lossing: 2.5
# Shortest Route: ['MON', 'ASL', 'MON'], Total Distance: 159.8, Total Demand: 25.0, Duration sailing: 15.98, Duration lossing: 3.47
# Shortest Route: ['MON', 'DAB', 'MON'], Total Distance: 92.0, Total Demand: 40.0, Duration sailing: 9.2, Duration lossing: 5.56
# Shortest Route: ['MON', 'DSA', 'MON'], Total Distance: 175.0, Total Demand: 29.0, Duration sailing: 17.5, Duration lossing: 4.03
# Shortest Route: ['MON', 'DSS', 'MON'], Total Distance: 170.6, Total Demand: 29.0, Duration sailing: 17.06, Duration lossing: 4.03
# Shortest Route: ['MON', 'GF', 'MON'], Total Distance: 156.2, Total Demand: 68.0, Duration sailing: 15.62, Duration lossing: 9.45
# Shortest Route: ['MON', 'KVB', 'MON'], Total Distance: 131.4, Total Demand: 14.0, Duration sailing: 13.14, Duration lossing: 1.94
# Shortest Route: ['MON', 'MID', 'MON'], Total Distance: 164.2, Total Demand: 14.0, Duration sailing: 16.42, Duration lossing: 1.94
# Shortest Route: ['MON', 'NLNVAL', 'MON'], Total Distance: 142.0, Total Demand: 29.0, Duration sailing: 14.2, Duration lossing: 4.03
# Shortest Route: ['MON', 'OSC', 'MON'], Total Distance: 117.2, Total Demand: 18.0, Duration sailing: 11.72, Duration lossing: 2.5
# Shortest Route: ['MON', 'OSE', 'MON'], Total Distance: 119.2, Total Demand: 36.0, Duration sailing: 11.92, Duration lossing: 5.0
# Shortest Route: ['MON', 'OSO', 'MON'], Total Distance: 106.0, Total Demand: 14.0, Duration sailing: 10.6, Duration lossing: 1.94
# Shortest Route: ['MON', 'OSS', 'MON'], Total Distance: 127.0, Total Demand: 18.0, Duration sailing: 12.7, Duration lossing: 2.5
# Shortest Route: ['MON', 'ST', 'MON'], Total Distance: 191.0, Total Demand: 68.0, Duration sailing: 19.1, Duration lossing: 9.45
# Shortest Route: ['MON', 'TENTRB', 'MON'], Total Distance: 79.8, Total Demand: 23.0, Duration sailing: 7.98, Duration lossing: 3.19
# Shortest Route: ['MON', 'TEQTRC', 'MON'], Total Distance: 70.4, Total Demand: 27.0, Duration sailing: 7.04, Duration lossing: 3.75
# Shortest Route: ['MON', 'TRO', 'MON'], Total Distance: 63.8, Total Demand: 11.0, Duration sailing: 6.38, Duration lossing: 1.53
# Shortest Route: ['MON', 'VFB', 'MON'], Total Distance: 106.4, Total Demand: 18.0, Duration sailing: 10.64, Duration lossing: 2.5
# Shortest Route: ['MON', 'APT', 'ASL', 'MON'], Total Distance: 200.3, Total Demand: 43.0, Duration sailing: 20.03, Duration lossing: 5.97
# Shortest Route: ['MON', 'APT', 'DAB', 'MON'], Total Distance: 175.5, Total Demand: 58.0, Duration sailing: 17.55, Duration lossing: 8.06
# Shortest Route: ['MON', 'APT', 'DSA', 'MON'], Total Distance: 228.9, Total Demand: 47.0, Duration sailing: 22.89, Duration lossing: 6.53
# Shortest Route: ['MON', 'APT', 'DSS', 'MON'], Total Distance: 232.6, Total Demand: 47.0, Duration sailing: 23.26, Duration lossing: 6.53
# Shortest Route: ['MON', 'APT', 'GF', 'MON'], Total Distance: 205.9, Total Demand: 86.0, Duration sailing: 20.59, Duration lossing: 11.95
# Shortest Route: ['MON', 'APT', 'KVB', 'MON'], Total Distance: 182.3, Total Demand: 32.0, Duration sailing: 18.23, Duration lossing: 4.44
# Shortest Route: ['MON', 'APT', 'MID', 'MON'], Total Distance: 175.9, Total Demand: 32.0, Duration sailing: 17.59, Duration lossing: 4.44
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'MON'], Total Distance: 186.7, Total Demand: 47.0, Duration sailing: 18.67, Duration lossing: 6.53
# Shortest Route: ['MON', 'APT', 'OSC', 'MON'], Total Distance: 146.3, Total Demand: 36.0, Duration sailing: 14.63, Duration lossing: 5.0
# Shortest Route: ['MON', 'APT', 'OSE', 'MON'], Total Distance: 140.2, Total Demand: 54.0, Duration sailing: 14.02, Duration lossing: 7.5
# Shortest Route: ['MON', 'APT', 'OSO', 'MON'], Total Distance: 146.5, Total Demand: 32.0, Duration sailing: 14.65, Duration lossing: 4.44
# Shortest Route: ['MON', 'APT', 'OSS', 'MON'], Total Distance: 137.4, Total Demand: 36.0, Duration sailing: 13.74, Duration lossing: 5.0
# Shortest Route: ['MON', 'APT', 'ST', 'MON'], Total Distance: 230.7, Total Demand: 86.0, Duration sailing: 23.07, Duration lossing: 11.95
# Shortest Route: ['MON', 'APT', 'TENTRB', 'MON'], Total Distance: 144.7, Total Demand: 41.0, Duration sailing: 14.47, Duration lossing: 5.69
# Shortest Route: ['MON', 'APT', 'TEQTRC', 'MON'], Total Distance: 146.8, Total Demand: 45.0, Duration sailing: 14.68, Duration lossing: 6.25
# Shortest Route: ['MON', 'APT', 'TRO', 'MON'], Total Distance: 134.7, Total Demand: 29.0, Duration sailing: 13.47, Duration lossing: 4.03
# Shortest Route: ['MON', 'APT', 'VFB', 'MON'], Total Distance: 151.3, Total Demand: 36.0, Duration sailing: 15.13, Duration lossing: 5.0
# Shortest Route: ['MON', 'ASL', 'DAB', 'MON'], Total Distance: 167.3, Total Demand: 65.0, Duration sailing: 16.73, Duration lossing: 9.03
# Shortest Route: ['MON', 'ASL', 'DSA', 'MON'], Total Distance: 189.5, Total Demand: 54.0, Duration sailing: 18.95, Duration lossing: 7.5
# Shortest Route: ['MON', 'ASL', 'DSS', 'MON'], Total Distance: 195.5, Total Demand: 54.0, Duration sailing: 19.55, Duration lossing: 7.5
# Shortest Route: ['MON', 'ASL', 'GF', 'MON'], Total Distance: 170.6, Total Demand: 93.0, Duration sailing: 17.06, Duration lossing: 12.92
# Shortest Route: ['MON', 'ASL', 'KVB', 'MON'], Total Distance: 160.1, Total Demand: 39.0, Duration sailing: 16.01, Duration lossing: 5.42
# Shortest Route: ['MON', 'ASL', 'MID', 'MON'], Total Distance: 196.0, Total Demand: 39.0, Duration sailing: 19.6, Duration lossing: 5.42
# Shortest Route: ['MON', 'ASL', 'NLNVAL', 'MON'], Total Distance: 162.5, Total Demand: 54.0, Duration sailing: 16.25, Duration lossing: 7.5
# Shortest Route: ['MON', 'ASL', 'OSC', 'MON'], Total Distance: 174.2, Total Demand: 43.0, Duration sailing: 17.42, Duration lossing: 5.97
# Shortest Route: ['MON', 'ASL', 'OSE', 'MON'], Total Distance: 181.8, Total Demand: 61.0, Duration sailing: 18.18, Duration lossing: 8.47
# Shortest Route: ['MON', 'ASL', 'OSO', 'MON'], Total Distance: 167.9, Total Demand: 39.0, Duration sailing: 16.79, Duration lossing: 5.42
# Shortest Route: ['MON', 'ASL', 'OSS', 'MON'], Total Distance: 190.7, Total Demand: 43.0, Duration sailing: 19.07, Duration lossing: 5.97
# Shortest Route: ['MON', 'ASL', 'ST', 'MON'], Total Distance: 190.4, Total Demand: 93.0, Duration sailing: 19.04, Duration lossing: 12.92
# Shortest Route: ['MON', 'ASL', 'TENTRB', 'MON'], Total Distance: 169.9, Total Demand: 48.0, Duration sailing: 16.99, Duration lossing: 6.67
# Shortest Route: ['MON', 'ASL', 'TEQTRC', 'MON'], Total Distance: 163.7, Total Demand: 52.0, Duration sailing: 16.37, Duration lossing: 7.22
# Shortest Route: ['MON', 'ASL', 'TRO', 'MON'], Total Distance: 168.2, Total Demand: 36.0, Duration sailing: 16.82, Duration lossing: 5.0
# Shortest Route: ['MON', 'ASL', 'VFB', 'MON'], Total Distance: 164.5, Total Demand: 43.0, Duration sailing: 16.45, Duration lossing: 5.97
# Shortest Route: ['MON', 'DAB', 'DSA', 'MON'], Total Distance: 176.0, Total Demand: 69.0, Duration sailing: 17.6, Duration lossing: 9.58
# Shortest Route: ['MON', 'DAB', 'DSS', 'MON'], Total Distance: 170.6, Total Demand: 69.0, Duration sailing: 17.06, Duration lossing: 9.58
# Shortest Route: ['MON', 'DAB', 'KVB', 'MON'], Total Distance: 139.2, Total Demand: 54.0, Duration sailing: 13.92, Duration lossing: 7.5
# Shortest Route: ['MON', 'DAB', 'MID', 'MON'], Total Distance: 188.7, Total Demand: 54.0, Duration sailing: 18.87, Duration lossing: 7.5
# Shortest Route: ['MON', 'DAB', 'NLNVAL', 'MON'], Total Distance: 150.6, Total Demand: 69.0, Duration sailing: 15.06, Duration lossing: 9.58
# Shortest Route: ['MON', 'DAB', 'OSC', 'MON'], Total Distance: 147.6, Total Demand: 58.0, Duration sailing: 14.76, Duration lossing: 8.06
# Shortest Route: ['MON', 'DAB', 'OSE', 'MON'], Total Distance: 154.8, Total Demand: 76.0, Duration sailing: 15.48, Duration lossing: 10.56
# Shortest Route: ['MON', 'DAB', 'OSO', 'MON'], Total Distance: 135.3, Total Demand: 54.0, Duration sailing: 13.53, Duration lossing: 7.5
# Shortest Route: ['MON', 'DAB', 'OSS', 'MON'], Total Distance: 165.3, Total Demand: 58.0, Duration sailing: 16.53, Duration lossing: 8.06
# Shortest Route: ['MON', 'DAB', 'TENTRB', 'MON'], Total Distance: 119.6, Total Demand: 63.0, Duration sailing: 11.96, Duration lossing: 8.75
# Shortest Route: ['MON', 'DAB', 'TEQTRC', 'MON'], Total Distance: 106.9, Total Demand: 67.0, Duration sailing: 10.69, Duration lossing: 9.31
# Shortest Route: ['MON', 'DAB', 'TRO', 'MON'], Total Distance: 116.9, Total Demand: 51.0, Duration sailing: 11.69, Duration lossing: 7.08
# Shortest Route: ['MON', 'DAB', 'VFB', 'MON'], Total Distance: 131.4, Total Demand: 58.0, Duration sailing: 13.14, Duration lossing: 8.06
# Shortest Route: ['MON', 'DSA', 'DSS', 'MON'], Total Distance: 182.9, Total Demand: 58.0, Duration sailing: 18.29, Duration lossing: 8.06
# Shortest Route: ['MON', 'DSA', 'GF', 'MON'], Total Distance: 185.3, Total Demand: 97.0, Duration sailing: 18.53, Duration lossing: 13.47
# Shortest Route: ['MON', 'DSA', 'KVB', 'MON'], Total Distance: 180.0, Total Demand: 43.0, Duration sailing: 18.0, Duration lossing: 5.97
# Shortest Route: ['MON', 'DSA', 'MID', 'MON'], Total Distance: 225.7, Total Demand: 43.0, Duration sailing: 22.57, Duration lossing: 5.97
# Shortest Route: ['MON', 'DSA', 'NLNVAL', 'MON'], Total Distance: 186.2, Total Demand: 58.0, Duration sailing: 18.62, Duration lossing: 8.06
# Shortest Route: ['MON', 'DSA', 'OSC', 'MON'], Total Distance: 201.3, Total Demand: 47.0, Duration sailing: 20.13, Duration lossing: 6.53
# Shortest Route: ['MON', 'DSA', 'OSE', 'MON'], Total Distance: 209.5, Total Demand: 65.0, Duration sailing: 20.95, Duration lossing: 9.03
# Shortest Route: ['MON', 'DSA', 'OSO', 'MON'], Total Distance: 193.2, Total Demand: 43.0, Duration sailing: 19.32, Duration lossing: 5.97
# Shortest Route: ['MON', 'DSA', 'OSS', 'MON'], Total Distance: 219.0, Total Demand: 47.0, Duration sailing: 21.9, Duration lossing: 6.53
# Shortest Route: ['MON', 'DSA', 'ST', 'MON'], Total Distance: 197.7, Total Demand: 97.0, Duration sailing: 19.77, Duration lossing: 13.47
# Shortest Route: ['MON', 'DSA', 'TENTRB', 'MON'], Total Distance: 190.9, Total Demand: 52.0, Duration sailing: 19.09, Duration lossing: 7.22
# Shortest Route: ['MON', 'DSA', 'TEQTRC', 'MON'], Total Distance: 182.1, Total Demand: 56.0, Duration sailing: 18.21, Duration lossing: 7.78
# Shortest Route: ['MON', 'DSA', 'TRO', 'MON'], Total Distance: 189.9, Total Demand: 40.0, Duration sailing: 18.99, Duration lossing: 5.56
# Shortest Route: ['MON', 'DSA', 'VFB', 'MON'], Total Distance: 188.9, Total Demand: 47.0, Duration sailing: 18.89, Duration lossing: 6.53
# Shortest Route: ['MON', 'DSS', 'GF', 'MON'], Total Distance: 189.4, Total Demand: 97.0, Duration sailing: 18.94, Duration lossing: 13.47
# Shortest Route: ['MON', 'DSS', 'KVB', 'MON'], Total Distance: 181.9, Total Demand: 43.0, Duration sailing: 18.19, Duration lossing: 5.97
# Shortest Route: ['MON', 'DSS', 'MID', 'MON'], Total Distance: 231.6, Total Demand: 43.0, Duration sailing: 23.16, Duration lossing: 5.97
# Shortest Route: ['MON', 'DSS', 'NLNVAL', 'MON'], Total Distance: 190.0, Total Demand: 58.0, Duration sailing: 19.0, Duration lossing: 8.06
# Shortest Route: ['MON', 'DSS', 'OSC', 'MON'], Total Distance: 204.2, Total Demand: 47.0, Duration sailing: 20.42, Duration lossing: 6.53
# Shortest Route: ['MON', 'DSS', 'OSE', 'MON'], Total Distance: 212.5, Total Demand: 65.0, Duration sailing: 21.25, Duration lossing: 9.03
# Shortest Route: ['MON', 'DSS', 'OSO', 'MON'], Total Distance: 195.0, Total Demand: 43.0, Duration sailing: 19.5, Duration lossing: 5.97
# Shortest Route: ['MON', 'DSS', 'OSS', 'MON'], Total Distance: 222.4, Total Demand: 47.0, Duration sailing: 22.24, Duration lossing: 6.53
# Shortest Route: ['MON', 'DSS', 'ST', 'MON'], Total Distance: 205.5, Total Demand: 97.0, Duration sailing: 20.55, Duration lossing: 13.47
# Shortest Route: ['MON', 'DSS', 'TENTRB', 'MON'], Total Distance: 190.4, Total Demand: 52.0, Duration sailing: 19.04, Duration lossing: 7.22
# Shortest Route: ['MON', 'DSS', 'TEQTRC', 'MON'], Total Distance: 180.4, Total Demand: 56.0, Duration sailing: 18.04, Duration lossing: 7.78
# Shortest Route: ['MON', 'DSS', 'TRO', 'MON'], Total Distance: 189.1, Total Demand: 40.0, Duration sailing: 18.91, Duration lossing: 5.56
# Shortest Route: ['MON', 'DSS', 'VFB', 'MON'], Total Distance: 190.5, Total Demand: 47.0, Duration sailing: 19.05, Duration lossing: 6.53
# Shortest Route: ['MON', 'GF', 'KVB', 'MON'], Total Distance: 157.4, Total Demand: 82.0, Duration sailing: 15.74, Duration lossing: 11.39
# Shortest Route: ['MON', 'GF', 'MID', 'MON'], Total Distance: 205.1, Total Demand: 82.0, Duration sailing: 20.51, Duration lossing: 11.39
# Shortest Route: ['MON', 'GF', 'NLNVAL', 'MON'], Total Distance: 163.3, Total Demand: 97.0, Duration sailing: 16.33, Duration lossing: 13.47
# Shortest Route: ['MON', 'GF', 'OSC', 'MON'], Total Distance: 178.3, Total Demand: 86.0, Duration sailing: 17.83, Duration lossing: 11.95
# Shortest Route: ['MON', 'GF', 'OSO', 'MON'], Total Distance: 170.2, Total Demand: 82.0, Duration sailing: 17.02, Duration lossing: 11.39
# Shortest Route: ['MON', 'GF', 'OSS', 'MON'], Total Distance: 196.1, Total Demand: 86.0, Duration sailing: 19.61, Duration lossing: 11.95
# Shortest Route: ['MON', 'GF', 'TENTRB', 'MON'], Total Distance: 169.2, Total Demand: 91.0, Duration sailing: 16.92, Duration lossing: 12.64
# Shortest Route: ['MON', 'GF', 'TEQTRC', 'MON'], Total Distance: 161.4, Total Demand: 95.0, Duration sailing: 16.14, Duration lossing: 13.2
# Shortest Route: ['MON', 'GF', 'TRO', 'MON'], Total Distance: 168.0, Total Demand: 79.0, Duration sailing: 16.8, Duration lossing: 10.97
# Shortest Route: ['MON', 'GF', 'VFB', 'MON'], Total Distance: 166.0, Total Demand: 86.0, Duration sailing: 16.6, Duration lossing: 11.95
# Shortest Route: ['MON', 'KVB', 'MID', 'MON'], Total Distance: 185.4, Total Demand: 28.0, Duration sailing: 18.54, Duration lossing: 3.89
# Shortest Route: ['MON', 'KVB', 'NLNVAL', 'MON'], Total Distance: 142.7, Total Demand: 43.0, Duration sailing: 14.27, Duration lossing: 5.97
# Shortest Route: ['MON', 'KVB', 'OSC', 'MON'], Total Distance: 153.7, Total Demand: 32.0, Duration sailing: 15.37, Duration lossing: 4.44
# Shortest Route: ['MON', 'KVB', 'OSE', 'MON'], Total Distance: 162.0, Total Demand: 50.0, Duration sailing: 16.2, Duration lossing: 6.95
# Shortest Route: ['MON', 'KVB', 'OSO', 'MON'], Total Distance: 144.7, Total Demand: 28.0, Duration sailing: 14.47, Duration lossing: 3.89
# Shortest Route: ['MON', 'KVB', 'OSS', 'MON'], Total Distance: 172.1, Total Demand: 32.0, Duration sailing: 17.21, Duration lossing: 4.44
# Shortest Route: ['MON', 'KVB', 'ST', 'MON'], Total Distance: 185.9, Total Demand: 82.0, Duration sailing: 18.59, Duration lossing: 11.39
# Shortest Route: ['MON', 'KVB', 'TENTRB', 'MON'], Total Distance: 143.2, Total Demand: 37.0, Duration sailing: 14.32, Duration lossing: 5.14
# Shortest Route: ['MON', 'KVB', 'TEQTRC', 'MON'], Total Distance: 135.8, Total Demand: 41.0, Duration sailing: 13.58, Duration lossing: 5.69
# Shortest Route: ['MON', 'KVB', 'TRO', 'MON'], Total Distance: 101.8, Total Demand: 25.0, Duration sailing: 10.18, Duration lossing: 3.47
# Shortest Route: ['MON', 'KVB', 'VFB', 'MON'], Total Distance: 140.4, Total Demand: 32.0, Duration sailing: 14.04, Duration lossing: 4.44
# Shortest Route: ['MON', 'MID', 'NLNVAL', 'MON'], Total Distance: 187.7, Total Demand: 43.0, Duration sailing: 18.77, Duration lossing: 5.97
# Shortest Route: ['MON', 'MID', 'OSC', 'MON'], Total Distance: 164.2, Total Demand: 32.0, Duration sailing: 16.42, Duration lossing: 4.44
# Shortest Route: ['MON', 'MID', 'OSE', 'MON'], Total Distance: 165.8, Total Demand: 50.0, Duration sailing: 16.58, Duration lossing: 6.95
# Shortest Route: ['MON', 'MID', 'OSO', 'MON'], Total Distance: 164.6, Total Demand: 28.0, Duration sailing: 16.46, Duration lossing: 3.89
# Shortest Route: ['MON', 'MID', 'OSS', 'MON'], Total Distance: 169.6, Total Demand: 32.0, Duration sailing: 16.96, Duration lossing: 4.44
# Shortest Route: ['MON', 'MID', 'ST', 'MON'], Total Distance: 226.2, Total Demand: 82.0, Duration sailing: 22.62, Duration lossing: 11.39
# Shortest Route: ['MON', 'MID', 'TENTRB', 'MON'], Total Distance: 170.2, Total Demand: 37.0, Duration sailing: 17.02, Duration lossing: 5.14
# Shortest Route: ['MON', 'MID', 'TEQTRC', 'MON'], Total Distance: 169.5, Total Demand: 41.0, Duration sailing: 16.95, Duration lossing: 5.69
# Shortest Route: ['MON', 'MID', 'TRO', 'MON'], Total Distance: 148.1, Total Demand: 25.0, Duration sailing: 14.81, Duration lossing: 3.47
# Shortest Route: ['MON', 'MID', 'VFB', 'MON'], Total Distance: 166.3, Total Demand: 32.0, Duration sailing: 16.63, Duration lossing: 4.44
# Shortest Route: ['MON', 'NLNVAL', 'OSC', 'MON'], Total Distance: 159.0, Total Demand: 47.0, Duration sailing: 15.9, Duration lossing: 6.53
# Shortest Route: ['MON', 'NLNVAL', 'OSE', 'MON'], Total Distance: 167.2, Total Demand: 65.0, Duration sailing: 16.72, Duration lossing: 9.03
# Shortest Route: ['MON', 'NLNVAL', 'OSO', 'MON'], Total Distance: 151.2, Total Demand: 43.0, Duration sailing: 15.12, Duration lossing: 5.97
# Shortest Route: ['MON', 'NLNVAL', 'OSS', 'MON'], Total Distance: 176.9, Total Demand: 47.0, Duration sailing: 17.69, Duration lossing: 6.53
# Shortest Route: ['MON', 'NLNVAL', 'ST', 'MON'], Total Distance: 190.3, Total Demand: 97.0, Duration sailing: 19.03, Duration lossing: 13.47
# Shortest Route: ['MON', 'NLNVAL', 'TENTRB', 'MON'], Total Distance: 151.8, Total Demand: 52.0, Duration sailing: 15.18, Duration lossing: 7.22
# Shortest Route: ['MON', 'NLNVAL', 'TEQTRC', 'MON'], Total Distance: 145.3, Total Demand: 56.0, Duration sailing: 14.53, Duration lossing: 7.78
# Shortest Route: ['MON', 'NLNVAL', 'TRO', 'MON'], Total Distance: 150.4, Total Demand: 40.0, Duration sailing: 15.04, Duration lossing: 5.56
# Shortest Route: ['MON', 'NLNVAL', 'VFB', 'MON'], Total Distance: 147.3, Total Demand: 47.0, Duration sailing: 14.73, Duration lossing: 6.53
# Shortest Route: ['MON', 'OSC', 'OSE', 'MON'], Total Distance: 125.6, Total Demand: 54.0, Duration sailing: 12.56, Duration lossing: 7.5
# Shortest Route: ['MON', 'OSC', 'OSO', 'MON'], Total Distance: 118.6, Total Demand: 32.0, Duration sailing: 11.86, Duration lossing: 4.44
# Shortest Route: ['MON', 'OSC', 'OSS', 'MON'], Total Distance: 135.9, Total Demand: 36.0, Duration sailing: 13.59, Duration lossing: 5.0
# Shortest Route: ['MON', 'OSC', 'ST', 'MON'], Total Distance: 204.4, Total Demand: 86.0, Duration sailing: 20.44, Duration lossing: 11.95
# Shortest Route: ['MON', 'OSC', 'TENTRB', 'MON'], Total Distance: 123.4, Total Demand: 41.0, Duration sailing: 12.34, Duration lossing: 5.69
# Shortest Route: ['MON', 'OSC', 'TEQTRC', 'MON'], Total Distance: 123.3, Total Demand: 45.0, Duration sailing: 12.33, Duration lossing: 6.25
# Shortest Route: ['MON', 'OSC', 'TRO', 'MON'], Total Distance: 118.8, Total Demand: 29.0, Duration sailing: 11.88, Duration lossing: 4.03
# Shortest Route: ['MON', 'OSC', 'VFB', 'MON'], Total Distance: 122.6, Total Demand: 36.0, Duration sailing: 12.26, Duration lossing: 5.0
# Shortest Route: ['MON', 'OSE', 'OSO', 'MON'], Total Distance: 125.5, Total Demand: 50.0, Duration sailing: 12.55, Duration lossing: 6.95
# Shortest Route: ['MON', 'OSE', 'OSS', 'MON'], Total Distance: 129.8, Total Demand: 54.0, Duration sailing: 12.98, Duration lossing: 7.5
# Shortest Route: ['MON', 'OSE', 'TENTRB', 'MON'], Total Distance: 126.6, Total Demand: 59.0, Duration sailing: 12.66, Duration lossing: 8.2
# Shortest Route: ['MON', 'OSE', 'TEQTRC', 'MON'], Total Distance: 127.9, Total Demand: 63.0, Duration sailing: 12.79, Duration lossing: 8.75
# Shortest Route: ['MON', 'OSE', 'TRO', 'MON'], Total Distance: 127.1, Total Demand: 47.0, Duration sailing: 12.71, Duration lossing: 6.53
# Shortest Route: ['MON', 'OSE', 'VFB', 'MON'], Total Distance: 130.3, Total Demand: 54.0, Duration sailing: 13.03, Duration lossing: 7.5
# Shortest Route: ['MON', 'OSO', 'OSS', 'MON'], Total Distance: 136.2, Total Demand: 32.0, Duration sailing: 13.62, Duration lossing: 4.44
# Shortest Route: ['MON', 'OSO', 'ST', 'MON'], Total Distance: 197.4, Total Demand: 82.0, Duration sailing: 19.74, Duration lossing: 11.39
# Shortest Route: ['MON', 'OSO', 'TENTRB', 'MON'], Total Distance: 112.1, Total Demand: 37.0, Duration sailing: 11.21, Duration lossing: 5.14
# Shortest Route: ['MON', 'OSO', 'TEQTRC', 'MON'], Total Distance: 111.0, Total Demand: 41.0, Duration sailing: 11.1, Duration lossing: 5.69
# Shortest Route: ['MON', 'OSO', 'TRO', 'MON'], Total Distance: 110.9, Total Demand: 25.0, Duration sailing: 11.09, Duration lossing: 3.47
# Shortest Route: ['MON', 'OSO', 'VFB', 'MON'], Total Distance: 111.1, Total Demand: 32.0, Duration sailing: 11.11, Duration lossing: 4.44
# Shortest Route: ['MON', 'OSS', 'ST', 'MON'], Total Distance: 221.3, Total Demand: 86.0, Duration sailing: 22.13, Duration lossing: 11.95
# Shortest Route: ['MON', 'OSS', 'TENTRB', 'MON'], Total Distance: 135.9, Total Demand: 41.0, Duration sailing: 13.59, Duration lossing: 5.69
# Shortest Route: ['MON', 'OSS', 'TEQTRC', 'MON'], Total Distance: 137.6, Total Demand: 45.0, Duration sailing: 13.76, Duration lossing: 6.25
# Shortest Route: ['MON', 'OSS', 'TRO', 'MON'], Total Distance: 136.8, Total Demand: 29.0, Duration sailing: 13.68, Duration lossing: 4.03
# Shortest Route: ['MON', 'OSS', 'VFB', 'MON'], Total Distance: 140.9, Total Demand: 36.0, Duration sailing: 14.09, Duration lossing: 5.0
# Shortest Route: ['MON', 'ST', 'TENTRB', 'MON'], Total Distance: 197.6, Total Demand: 91.0, Duration sailing: 19.76, Duration lossing: 12.64
# Shortest Route: ['MON', 'ST', 'TEQTRC', 'MON'], Total Distance: 190.1, Total Demand: 95.0, Duration sailing: 19.01, Duration lossing: 13.2
# Shortest Route: ['MON', 'ST', 'TRO', 'MON'], Total Distance: 196.4, Total Demand: 79.0, Duration sailing: 19.64, Duration lossing: 10.97
# Shortest Route: ['MON', 'ST', 'VFB', 'MON'], Total Distance: 193.6, Total Demand: 86.0, Duration sailing: 19.36, Duration lossing: 11.95
# Shortest Route: ['MON', 'TENTRB', 'TEQTRC', 'MON'], Total Distance: 86.3, Total Demand: 50.0, Duration sailing: 8.63, Duration lossing: 6.95
# Shortest Route: ['MON', 'TENTRB', 'TRO', 'MON'], Total Distance: 82.6, Total Demand: 34.0, Duration sailing: 8.26, Duration lossing: 4.72
# Shortest Route: ['MON', 'TENTRB', 'VFB', 'MON'], Total Distance: 113.0, Total Demand: 41.0, Duration sailing: 11.3, Duration lossing: 5.69
# Shortest Route: ['MON', 'TEQTRC', 'TRO', 'MON'], Total Distance: 83.1, Total Demand: 38.0, Duration sailing: 8.31, Duration lossing: 5.28
# Shortest Route: ['MON', 'TEQTRC', 'VFB', 'MON'], Total Distance: 110.2, Total Demand: 45.0, Duration sailing: 11.02, Duration lossing: 6.25
# Shortest Route: ['MON', 'TRO', 'VFB', 'MON'], Total Distance: 110.6, Total Demand: 29.0, Duration sailing: 11.06, Duration lossing: 4.03
# Shortest Route: ['MON', 'APT', 'ASL', 'DAB', 'MON'], Total Distance: 207.8, Total Demand: 83.0, Duration sailing: 20.78, Duration lossing: 11.53
# Shortest Route: ['MON', 'APT', 'ASL', 'DSA', 'MON'], Total Distance: 230.0, Total Demand: 72.0, Duration sailing: 23.0, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'ASL', 'DSS', 'MON'], Total Distance: 236.0, Total Demand: 72.0, Duration sailing: 23.6, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'ASL', 'KVB', 'MON'], Total Distance: 200.6, Total Demand: 57.0, Duration sailing: 20.06, Duration lossing: 7.92
# Shortest Route: ['MON', 'APT', 'ASL', 'MID', 'MON'], Total Distance: 236.5, Total Demand: 57.0, Duration sailing: 23.65, Duration lossing: 7.92
# Shortest Route: ['MON', 'APT', 'ASL', 'NLNVAL', 'MON'], Total Distance: 203.0, Total Demand: 72.0, Duration sailing: 20.3, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'ASL', 'OSC', 'MON'], Total Distance: 214.7, Total Demand: 61.0, Duration sailing: 21.47, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'ASL', 'OSE', 'MON'], Total Distance: 222.3, Total Demand: 79.0, Duration sailing: 22.23, Duration lossing: 10.97
# Shortest Route: ['MON', 'APT', 'ASL', 'OSO', 'MON'], Total Distance: 208.4, Total Demand: 57.0, Duration sailing: 20.84, Duration lossing: 7.92
# Shortest Route: ['MON', 'APT', 'ASL', 'OSS', 'MON'], Total Distance: 231.2, Total Demand: 61.0, Duration sailing: 23.12, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'ASL', 'TENTRB', 'MON'], Total Distance: 210.4, Total Demand: 66.0, Duration sailing: 21.04, Duration lossing: 9.17
# Shortest Route: ['MON', 'APT', 'ASL', 'TEQTRC', 'MON'], Total Distance: 204.2, Total Demand: 70.0, Duration sailing: 20.42, Duration lossing: 9.72
# Shortest Route: ['MON', 'APT', 'ASL', 'TRO', 'MON'], Total Distance: 208.7, Total Demand: 54.0, Duration sailing: 20.87, Duration lossing: 7.5
# Shortest Route: ['MON', 'APT', 'ASL', 'VFB', 'MON'], Total Distance: 205.0, Total Demand: 61.0, Duration sailing: 20.5, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'DAB', 'DSA', 'MON'], Total Distance: 259.5, Total Demand: 87.0, Duration sailing: 25.95, Duration lossing: 12.08
# Shortest Route: ['MON', 'APT', 'DAB', 'DSS', 'MON'], Total Distance: 254.1, Total Demand: 87.0, Duration sailing: 25.41, Duration lossing: 12.08
# Shortest Route: ['MON', 'APT', 'DAB', 'KVB', 'MON'], Total Distance: 222.7, Total Demand: 72.0, Duration sailing: 22.27, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'DAB', 'MID', 'MON'], Total Distance: 272.2, Total Demand: 72.0, Duration sailing: 27.22, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'DAB', 'NLNVAL', 'MON'], Total Distance: 234.1, Total Demand: 87.0, Duration sailing: 23.41, Duration lossing: 12.08
# Shortest Route: ['MON', 'APT', 'DAB', 'OSC', 'MON'], Total Distance: 231.1, Total Demand: 76.0, Duration sailing: 23.11, Duration lossing: 10.56
# Shortest Route: ['MON', 'APT', 'DAB', 'OSE', 'MON'], Total Distance: 238.3, Total Demand: 94.0, Duration sailing: 23.83, Duration lossing: 13.06
# Shortest Route: ['MON', 'APT', 'DAB', 'OSO', 'MON'], Total Distance: 218.8, Total Demand: 72.0, Duration sailing: 21.88, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'DAB', 'OSS', 'MON'], Total Distance: 248.8, Total Demand: 76.0, Duration sailing: 24.88, Duration lossing: 10.56
# Shortest Route: ['MON', 'APT', 'DAB', 'TENTRB', 'MON'], Total Distance: 203.1, Total Demand: 81.0, Duration sailing: 20.31, Duration lossing: 11.25
# Shortest Route: ['MON', 'APT', 'DAB', 'TEQTRC', 'MON'], Total Distance: 190.4, Total Demand: 85.0, Duration sailing: 19.04, Duration lossing: 11.81
# Shortest Route: ['MON', 'APT', 'DAB', 'TRO', 'MON'], Total Distance: 200.4, Total Demand: 69.0, Duration sailing: 20.04, Duration lossing: 9.58
# Shortest Route: ['MON', 'APT', 'DAB', 'VFB', 'MON'], Total Distance: 214.9, Total Demand: 76.0, Duration sailing: 21.49, Duration lossing: 10.56
# Shortest Route: ['MON', 'APT', 'DSA', 'DSS', 'MON'], Total Distance: 236.8, Total Demand: 76.0, Duration sailing: 23.68, Duration lossing: 10.56
# Shortest Route: ['MON', 'APT', 'DSA', 'KVB', 'MON'], Total Distance: 233.9, Total Demand: 61.0, Duration sailing: 23.39, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'DSA', 'MID', 'MON'], Total Distance: 279.6, Total Demand: 61.0, Duration sailing: 27.96, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'DSA', 'NLNVAL', 'MON'], Total Distance: 240.1, Total Demand: 76.0, Duration sailing: 24.01, Duration lossing: 10.56
# Shortest Route: ['MON', 'APT', 'DSA', 'OSC', 'MON'], Total Distance: 255.2, Total Demand: 65.0, Duration sailing: 25.52, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'DSA', 'OSE', 'MON'], Total Distance: 263.4, Total Demand: 83.0, Duration sailing: 26.34, Duration lossing: 11.53
# Shortest Route: ['MON', 'APT', 'DSA', 'OSO', 'MON'], Total Distance: 247.1, Total Demand: 61.0, Duration sailing: 24.71, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'DSA', 'OSS', 'MON'], Total Distance: 272.9, Total Demand: 65.0, Duration sailing: 27.29, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'DSA', 'TENTRB', 'MON'], Total Distance: 244.8, Total Demand: 70.0, Duration sailing: 24.48, Duration lossing: 9.72
# Shortest Route: ['MON', 'APT', 'DSA', 'TEQTRC', 'MON'], Total Distance: 236.0, Total Demand: 74.0, Duration sailing: 23.6, Duration lossing: 10.28
# Shortest Route: ['MON', 'APT', 'DSA', 'TRO', 'MON'], Total Distance: 243.8, Total Demand: 58.0, Duration sailing: 24.38, Duration lossing: 8.06
# Shortest Route: ['MON', 'APT', 'DSA', 'VFB', 'MON'], Total Distance: 242.8, Total Demand: 65.0, Duration sailing: 24.28, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'DSS', 'KVB', 'MON'], Total Distance: 243.9, Total Demand: 61.0, Duration sailing: 24.39, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'DSS', 'MID', 'MON'], Total Distance: 293.6, Total Demand: 61.0, Duration sailing: 29.36, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'DSS', 'NLNVAL', 'MON'], Total Distance: 252.0, Total Demand: 76.0, Duration sailing: 25.2, Duration lossing: 10.56
# Shortest Route: ['MON', 'APT', 'DSS', 'OSC', 'MON'], Total Distance: 266.2, Total Demand: 65.0, Duration sailing: 26.62, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'DSS', 'OSE', 'MON'], Total Distance: 274.5, Total Demand: 83.0, Duration sailing: 27.45, Duration lossing: 11.53
# Shortest Route: ['MON', 'APT', 'DSS', 'OSO', 'MON'], Total Distance: 257.0, Total Demand: 61.0, Duration sailing: 25.7, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'DSS', 'OSS', 'MON'], Total Distance: 284.4, Total Demand: 65.0, Duration sailing: 28.44, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'DSS', 'TENTRB', 'MON'], Total Distance: 252.4, Total Demand: 70.0, Duration sailing: 25.24, Duration lossing: 9.72
# Shortest Route: ['MON', 'APT', 'DSS', 'TEQTRC', 'MON'], Total Distance: 242.4, Total Demand: 74.0, Duration sailing: 24.24, Duration lossing: 10.28
# Shortest Route: ['MON', 'APT', 'DSS', 'TRO', 'MON'], Total Distance: 251.1, Total Demand: 58.0, Duration sailing: 25.11, Duration lossing: 8.06
# Shortest Route: ['MON', 'APT', 'DSS', 'VFB', 'MON'], Total Distance: 252.5, Total Demand: 65.0, Duration sailing: 25.25, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'GF', 'KVB', 'MON'], Total Distance: 207.1, Total Demand: 100.0, Duration sailing: 20.71, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'GF', 'MID', 'MON'], Total Distance: 254.8, Total Demand: 100.0, Duration sailing: 25.48, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'GF', 'OSO', 'MON'], Total Distance: 219.9, Total Demand: 100.0, Duration sailing: 21.99, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'GF', 'TRO', 'MON'], Total Distance: 217.7, Total Demand: 97.0, Duration sailing: 21.77, Duration lossing: 13.47
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'MON'], Total Distance: 236.3, Total Demand: 46.0, Duration sailing: 23.63, Duration lossing: 6.39
# Shortest Route: ['MON', 'APT', 'KVB', 'NLNVAL', 'MON'], Total Distance: 193.6, Total Demand: 61.0, Duration sailing: 19.36, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'KVB', 'OSC', 'MON'], Total Distance: 204.6, Total Demand: 50.0, Duration sailing: 20.46, Duration lossing: 6.95
# Shortest Route: ['MON', 'APT', 'KVB', 'OSE', 'MON'], Total Distance: 212.9, Total Demand: 68.0, Duration sailing: 21.29, Duration lossing: 9.45
# Shortest Route: ['MON', 'APT', 'KVB', 'OSO', 'MON'], Total Distance: 195.6, Total Demand: 46.0, Duration sailing: 19.56, Duration lossing: 6.39
# Shortest Route: ['MON', 'APT', 'KVB', 'OSS', 'MON'], Total Distance: 223.0, Total Demand: 50.0, Duration sailing: 22.3, Duration lossing: 6.95
# Shortest Route: ['MON', 'APT', 'KVB', 'ST', 'MON'], Total Distance: 236.8, Total Demand: 100.0, Duration sailing: 23.68, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'KVB', 'TENTRB', 'MON'], Total Distance: 194.1, Total Demand: 55.0, Duration sailing: 19.41, Duration lossing: 7.64
# Shortest Route: ['MON', 'APT', 'KVB', 'TEQTRC', 'MON'], Total Distance: 186.7, Total Demand: 59.0, Duration sailing: 18.67, Duration lossing: 8.2
# Shortest Route: ['MON', 'APT', 'KVB', 'TRO', 'MON'], Total Distance: 152.7, Total Demand: 43.0, Duration sailing: 15.27, Duration lossing: 5.97
# Shortest Route: ['MON', 'APT', 'KVB', 'VFB', 'MON'], Total Distance: 191.3, Total Demand: 50.0, Duration sailing: 19.13, Duration lossing: 6.95
# Shortest Route: ['MON', 'APT', 'MID', 'NLNVAL', 'MON'], Total Distance: 199.4, Total Demand: 61.0, Duration sailing: 19.94, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'MID', 'OSC', 'MON'], Total Distance: 175.9, Total Demand: 50.0, Duration sailing: 17.59, Duration lossing: 6.95
# Shortest Route: ['MON', 'APT', 'MID', 'OSE', 'MON'], Total Distance: 177.5, Total Demand: 68.0, Duration sailing: 17.75, Duration lossing: 9.45
# Shortest Route: ['MON', 'APT', 'MID', 'OSO', 'MON'], Total Distance: 176.3, Total Demand: 46.0, Duration sailing: 17.63, Duration lossing: 6.39
# Shortest Route: ['MON', 'APT', 'MID', 'OSS', 'MON'], Total Distance: 181.3, Total Demand: 50.0, Duration sailing: 18.13, Duration lossing: 6.95
# Shortest Route: ['MON', 'APT', 'MID', 'ST', 'MON'], Total Distance: 237.9, Total Demand: 100.0, Duration sailing: 23.79, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'MID', 'TENTRB', 'MON'], Total Distance: 181.9, Total Demand: 55.0, Duration sailing: 18.19, Duration lossing: 7.64
# Shortest Route: ['MON', 'APT', 'MID', 'TEQTRC', 'MON'], Total Distance: 181.2, Total Demand: 59.0, Duration sailing: 18.12, Duration lossing: 8.2
# Shortest Route: ['MON', 'APT', 'MID', 'TRO', 'MON'], Total Distance: 159.8, Total Demand: 43.0, Duration sailing: 15.98, Duration lossing: 5.97
# Shortest Route: ['MON', 'APT', 'MID', 'VFB', 'MON'], Total Distance: 178.0, Total Demand: 50.0, Duration sailing: 17.8, Duration lossing: 6.95
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'OSC', 'MON'], Total Distance: 203.7, Total Demand: 65.0, Duration sailing: 20.37, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'OSE', 'MON'], Total Distance: 211.9, Total Demand: 83.0, Duration sailing: 21.19, Duration lossing: 11.53
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'OSO', 'MON'], Total Distance: 195.9, Total Demand: 61.0, Duration sailing: 19.59, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'OSS', 'MON'], Total Distance: 221.6, Total Demand: 65.0, Duration sailing: 22.16, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'TENTRB', 'MON'], Total Distance: 196.5, Total Demand: 70.0, Duration sailing: 19.65, Duration lossing: 9.72
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'TEQTRC', 'MON'], Total Distance: 190.0, Total Demand: 74.0, Duration sailing: 19.0, Duration lossing: 10.28
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'TRO', 'MON'], Total Distance: 195.1, Total Demand: 58.0, Duration sailing: 19.51, Duration lossing: 8.06
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'VFB', 'MON'], Total Distance: 192.0, Total Demand: 65.0, Duration sailing: 19.2, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'OSC', 'OSE', 'MON'], Total Distance: 154.7, Total Demand: 72.0, Duration sailing: 15.47, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'OSC', 'OSO', 'MON'], Total Distance: 147.7, Total Demand: 50.0, Duration sailing: 14.77, Duration lossing: 6.95
# Shortest Route: ['MON', 'APT', 'OSC', 'OSS', 'MON'], Total Distance: 165.0, Total Demand: 54.0, Duration sailing: 16.5, Duration lossing: 7.5
# Shortest Route: ['MON', 'APT', 'OSC', 'TENTRB', 'MON'], Total Distance: 152.5, Total Demand: 59.0, Duration sailing: 15.25, Duration lossing: 8.2
# Shortest Route: ['MON', 'APT', 'OSC', 'TEQTRC', 'MON'], Total Distance: 152.4, Total Demand: 63.0, Duration sailing: 15.24, Duration lossing: 8.75
# Shortest Route: ['MON', 'APT', 'OSC', 'TRO', 'MON'], Total Distance: 147.9, Total Demand: 47.0, Duration sailing: 14.79, Duration lossing: 6.53
# Shortest Route: ['MON', 'APT', 'OSC', 'VFB', 'MON'], Total Distance: 151.7, Total Demand: 54.0, Duration sailing: 15.17, Duration lossing: 7.5
# Shortest Route: ['MON', 'APT', 'OSE', 'OSO', 'MON'], Total Distance: 146.5, Total Demand: 68.0, Duration sailing: 14.65, Duration lossing: 9.45
# Shortest Route: ['MON', 'APT', 'OSE', 'OSS', 'MON'], Total Distance: 150.8, Total Demand: 72.0, Duration sailing: 15.08, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'OSE', 'TENTRB', 'MON'], Total Distance: 147.6, Total Demand: 77.0, Duration sailing: 14.76, Duration lossing: 10.7
# Shortest Route: ['MON', 'APT', 'OSE', 'TEQTRC', 'MON'], Total Distance: 148.9, Total Demand: 81.0, Duration sailing: 14.89, Duration lossing: 11.25
# Shortest Route: ['MON', 'APT', 'OSE', 'TRO', 'MON'], Total Distance: 148.1, Total Demand: 65.0, Duration sailing: 14.81, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'OSE', 'VFB', 'MON'], Total Distance: 151.3, Total Demand: 72.0, Duration sailing: 15.13, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'OSO', 'OSS', 'MON'], Total Distance: 176.7, Total Demand: 50.0, Duration sailing: 17.67, Duration lossing: 6.95
# Shortest Route: ['MON', 'APT', 'OSO', 'ST', 'MON'], Total Distance: 237.9, Total Demand: 100.0, Duration sailing: 23.79, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'OSO', 'TENTRB', 'MON'], Total Distance: 152.6, Total Demand: 55.0, Duration sailing: 15.26, Duration lossing: 7.64
# Shortest Route: ['MON', 'APT', 'OSO', 'TEQTRC', 'MON'], Total Distance: 151.5, Total Demand: 59.0, Duration sailing: 15.15, Duration lossing: 8.2
# Shortest Route: ['MON', 'APT', 'OSO', 'TRO', 'MON'], Total Distance: 151.4, Total Demand: 43.0, Duration sailing: 15.14, Duration lossing: 5.97
# Shortest Route: ['MON', 'APT', 'OSO', 'VFB', 'MON'], Total Distance: 151.6, Total Demand: 50.0, Duration sailing: 15.16, Duration lossing: 6.95
# Shortest Route: ['MON', 'APT', 'OSS', 'TENTRB', 'MON'], Total Distance: 146.3, Total Demand: 59.0, Duration sailing: 14.63, Duration lossing: 8.2
# Shortest Route: ['MON', 'APT', 'OSS', 'TEQTRC', 'MON'], Total Distance: 148.0, Total Demand: 63.0, Duration sailing: 14.8, Duration lossing: 8.75
# Shortest Route: ['MON', 'APT', 'OSS', 'TRO', 'MON'], Total Distance: 147.2, Total Demand: 47.0, Duration sailing: 14.72, Duration lossing: 6.53
# Shortest Route: ['MON', 'APT', 'OSS', 'VFB', 'MON'], Total Distance: 151.3, Total Demand: 54.0, Duration sailing: 15.13, Duration lossing: 7.5
# Shortest Route: ['MON', 'APT', 'ST', 'TRO', 'MON'], Total Distance: 236.1, Total Demand: 97.0, Duration sailing: 23.61, Duration lossing: 13.47
# Shortest Route: ['MON', 'APT', 'TENTRB', 'TEQTRC', 'MON'], Total Distance: 151.2, Total Demand: 68.0, Duration sailing: 15.12, Duration lossing: 9.45
# Shortest Route: ['MON', 'APT', 'TENTRB', 'TRO', 'MON'], Total Distance: 147.5, Total Demand: 52.0, Duration sailing: 14.75, Duration lossing: 7.22
# Shortest Route: ['MON', 'APT', 'TENTRB', 'VFB', 'MON'], Total Distance: 177.9, Total Demand: 59.0, Duration sailing: 17.79, Duration lossing: 8.2
# Shortest Route: ['MON', 'APT', 'TEQTRC', 'TRO', 'MON'], Total Distance: 159.5, Total Demand: 56.0, Duration sailing: 15.95, Duration lossing: 7.78
# Shortest Route: ['MON', 'APT', 'TEQTRC', 'VFB', 'MON'], Total Distance: 186.6, Total Demand: 63.0, Duration sailing: 18.66, Duration lossing: 8.75
# Shortest Route: ['MON', 'APT', 'TRO', 'VFB', 'MON'], Total Distance: 181.5, Total Demand: 47.0, Duration sailing: 18.15, Duration lossing: 6.53
# Shortest Route: ['MON', 'ASL', 'DAB', 'DSA', 'MON'], Total Distance: 251.3, Total Demand: 94.0, Duration sailing: 25.13, Duration lossing: 13.06
# Shortest Route: ['MON', 'ASL', 'DAB', 'DSS', 'MON'], Total Distance: 245.9, Total Demand: 94.0, Duration sailing: 24.59, Duration lossing: 13.06
# Shortest Route: ['MON', 'ASL', 'DAB', 'KVB', 'MON'], Total Distance: 214.5, Total Demand: 79.0, Duration sailing: 21.45, Duration lossing: 10.97
# Shortest Route: ['MON', 'ASL', 'DAB', 'MID', 'MON'], Total Distance: 264.0, Total Demand: 79.0, Duration sailing: 26.4, Duration lossing: 10.97
# Shortest Route: ['MON', 'ASL', 'DAB', 'NLNVAL', 'MON'], Total Distance: 225.9, Total Demand: 94.0, Duration sailing: 22.59, Duration lossing: 13.06
# Shortest Route: ['MON', 'ASL', 'DAB', 'OSC', 'MON'], Total Distance: 222.9, Total Demand: 83.0, Duration sailing: 22.29, Duration lossing: 11.53
# Shortest Route: ['MON', 'ASL', 'DAB', 'OSO', 'MON'], Total Distance: 210.6, Total Demand: 79.0, Duration sailing: 21.06, Duration lossing: 10.97
# Shortest Route: ['MON', 'ASL', 'DAB', 'OSS', 'MON'], Total Distance: 240.6, Total Demand: 83.0, Duration sailing: 24.06, Duration lossing: 11.53
# Shortest Route: ['MON', 'ASL', 'DAB', 'TENTRB', 'MON'], Total Distance: 194.9, Total Demand: 88.0, Duration sailing: 19.49, Duration lossing: 12.22
# Shortest Route: ['MON', 'ASL', 'DAB', 'TEQTRC', 'MON'], Total Distance: 182.2, Total Demand: 92.0, Duration sailing: 18.22, Duration lossing: 12.78
# Shortest Route: ['MON', 'ASL', 'DAB', 'TRO', 'MON'], Total Distance: 192.2, Total Demand: 76.0, Duration sailing: 19.22, Duration lossing: 10.56
# Shortest Route: ['MON', 'ASL', 'DAB', 'VFB', 'MON'], Total Distance: 206.7, Total Demand: 83.0, Duration sailing: 20.67, Duration lossing: 11.53
# Shortest Route: ['MON', 'ASL', 'DSA', 'DSS', 'MON'], Total Distance: 197.4, Total Demand: 83.0, Duration sailing: 19.74, Duration lossing: 11.53
# Shortest Route: ['MON', 'ASL', 'DSA', 'KVB', 'MON'], Total Distance: 194.5, Total Demand: 68.0, Duration sailing: 19.45, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'DSA', 'MID', 'MON'], Total Distance: 240.2, Total Demand: 68.0, Duration sailing: 24.02, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'DSA', 'NLNVAL', 'MON'], Total Distance: 200.7, Total Demand: 83.0, Duration sailing: 20.07, Duration lossing: 11.53
# Shortest Route: ['MON', 'ASL', 'DSA', 'OSC', 'MON'], Total Distance: 215.8, Total Demand: 72.0, Duration sailing: 21.58, Duration lossing: 10.0
# Shortest Route: ['MON', 'ASL', 'DSA', 'OSE', 'MON'], Total Distance: 224.0, Total Demand: 90.0, Duration sailing: 22.4, Duration lossing: 12.5
# Shortest Route: ['MON', 'ASL', 'DSA', 'OSO', 'MON'], Total Distance: 207.7, Total Demand: 68.0, Duration sailing: 20.77, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'DSA', 'OSS', 'MON'], Total Distance: 233.5, Total Demand: 72.0, Duration sailing: 23.35, Duration lossing: 10.0
# Shortest Route: ['MON', 'ASL', 'DSA', 'TENTRB', 'MON'], Total Distance: 205.4, Total Demand: 77.0, Duration sailing: 20.54, Duration lossing: 10.7
# Shortest Route: ['MON', 'ASL', 'DSA', 'TEQTRC', 'MON'], Total Distance: 196.6, Total Demand: 81.0, Duration sailing: 19.66, Duration lossing: 11.25
# Shortest Route: ['MON', 'ASL', 'DSA', 'TRO', 'MON'], Total Distance: 204.4, Total Demand: 65.0, Duration sailing: 20.44, Duration lossing: 9.03
# Shortest Route: ['MON', 'ASL', 'DSA', 'VFB', 'MON'], Total Distance: 203.4, Total Demand: 72.0, Duration sailing: 20.34, Duration lossing: 10.0
# Shortest Route: ['MON', 'ASL', 'DSS', 'KVB', 'MON'], Total Distance: 206.8, Total Demand: 68.0, Duration sailing: 20.68, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'DSS', 'MID', 'MON'], Total Distance: 256.5, Total Demand: 68.0, Duration sailing: 25.65, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'DSS', 'NLNVAL', 'MON'], Total Distance: 214.9, Total Demand: 83.0, Duration sailing: 21.49, Duration lossing: 11.53
# Shortest Route: ['MON', 'ASL', 'DSS', 'OSC', 'MON'], Total Distance: 229.1, Total Demand: 72.0, Duration sailing: 22.91, Duration lossing: 10.0
# Shortest Route: ['MON', 'ASL', 'DSS', 'OSE', 'MON'], Total Distance: 237.4, Total Demand: 90.0, Duration sailing: 23.74, Duration lossing: 12.5
# Shortest Route: ['MON', 'ASL', 'DSS', 'OSO', 'MON'], Total Distance: 219.9, Total Demand: 68.0, Duration sailing: 21.99, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'DSS', 'OSS', 'MON'], Total Distance: 247.3, Total Demand: 72.0, Duration sailing: 24.73, Duration lossing: 10.0
# Shortest Route: ['MON', 'ASL', 'DSS', 'TENTRB', 'MON'], Total Distance: 215.3, Total Demand: 77.0, Duration sailing: 21.53, Duration lossing: 10.7
# Shortest Route: ['MON', 'ASL', 'DSS', 'TEQTRC', 'MON'], Total Distance: 205.3, Total Demand: 81.0, Duration sailing: 20.53, Duration lossing: 11.25
# Shortest Route: ['MON', 'ASL', 'DSS', 'TRO', 'MON'], Total Distance: 214.0, Total Demand: 65.0, Duration sailing: 21.4, Duration lossing: 9.03
# Shortest Route: ['MON', 'ASL', 'DSS', 'VFB', 'MON'], Total Distance: 215.4, Total Demand: 72.0, Duration sailing: 21.54, Duration lossing: 10.0
# Shortest Route: ['MON', 'ASL', 'KVB', 'MID', 'MON'], Total Distance: 214.1, Total Demand: 53.0, Duration sailing: 21.41, Duration lossing: 7.36
# Shortest Route: ['MON', 'ASL', 'KVB', 'NLNVAL', 'MON'], Total Distance: 171.4, Total Demand: 68.0, Duration sailing: 17.14, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'KVB', 'OSC', 'MON'], Total Distance: 182.4, Total Demand: 57.0, Duration sailing: 18.24, Duration lossing: 7.92
# Shortest Route: ['MON', 'ASL', 'KVB', 'OSE', 'MON'], Total Distance: 190.7, Total Demand: 75.0, Duration sailing: 19.07, Duration lossing: 10.42
# Shortest Route: ['MON', 'ASL', 'KVB', 'OSO', 'MON'], Total Distance: 173.4, Total Demand: 53.0, Duration sailing: 17.34, Duration lossing: 7.36
# Shortest Route: ['MON', 'ASL', 'KVB', 'OSS', 'MON'], Total Distance: 200.8, Total Demand: 57.0, Duration sailing: 20.08, Duration lossing: 7.92
# Shortest Route: ['MON', 'ASL', 'KVB', 'TENTRB', 'MON'], Total Distance: 171.9, Total Demand: 62.0, Duration sailing: 17.19, Duration lossing: 8.61
# Shortest Route: ['MON', 'ASL', 'KVB', 'TEQTRC', 'MON'], Total Distance: 164.5, Total Demand: 66.0, Duration sailing: 16.45, Duration lossing: 9.17
# Shortest Route: ['MON', 'ASL', 'KVB', 'TRO', 'MON'], Total Distance: 130.5, Total Demand: 50.0, Duration sailing: 13.05, Duration lossing: 6.95
# Shortest Route: ['MON', 'ASL', 'KVB', 'VFB', 'MON'], Total Distance: 169.1, Total Demand: 57.0, Duration sailing: 16.91, Duration lossing: 7.92
# Shortest Route: ['MON', 'ASL', 'MID', 'NLNVAL', 'MON'], Total Distance: 219.5, Total Demand: 68.0, Duration sailing: 21.95, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'MID', 'OSC', 'MON'], Total Distance: 196.0, Total Demand: 57.0, Duration sailing: 19.6, Duration lossing: 7.92
# Shortest Route: ['MON', 'ASL', 'MID', 'OSE', 'MON'], Total Distance: 197.6, Total Demand: 75.0, Duration sailing: 19.76, Duration lossing: 10.42
# Shortest Route: ['MON', 'ASL', 'MID', 'OSO', 'MON'], Total Distance: 196.4, Total Demand: 53.0, Duration sailing: 19.64, Duration lossing: 7.36
# Shortest Route: ['MON', 'ASL', 'MID', 'OSS', 'MON'], Total Distance: 201.4, Total Demand: 57.0, Duration sailing: 20.14, Duration lossing: 7.92
# Shortest Route: ['MON', 'ASL', 'MID', 'TENTRB', 'MON'], Total Distance: 202.0, Total Demand: 62.0, Duration sailing: 20.2, Duration lossing: 8.61
# Shortest Route: ['MON', 'ASL', 'MID', 'TEQTRC', 'MON'], Total Distance: 201.3, Total Demand: 66.0, Duration sailing: 20.13, Duration lossing: 9.17
# Shortest Route: ['MON', 'ASL', 'MID', 'TRO', 'MON'], Total Distance: 179.9, Total Demand: 50.0, Duration sailing: 17.99, Duration lossing: 6.95
# Shortest Route: ['MON', 'ASL', 'MID', 'VFB', 'MON'], Total Distance: 198.1, Total Demand: 57.0, Duration sailing: 19.81, Duration lossing: 7.92
# Shortest Route: ['MON', 'ASL', 'NLNVAL', 'OSC', 'MON'], Total Distance: 179.5, Total Demand: 72.0, Duration sailing: 17.95, Duration lossing: 10.0
# Shortest Route: ['MON', 'ASL', 'NLNVAL', 'OSE', 'MON'], Total Distance: 187.7, Total Demand: 90.0, Duration sailing: 18.77, Duration lossing: 12.5
# Shortest Route: ['MON', 'ASL', 'NLNVAL', 'OSO', 'MON'], Total Distance: 171.7, Total Demand: 68.0, Duration sailing: 17.17, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'NLNVAL', 'OSS', 'MON'], Total Distance: 197.4, Total Demand: 72.0, Duration sailing: 19.74, Duration lossing: 10.0
# Shortest Route: ['MON', 'ASL', 'NLNVAL', 'TENTRB', 'MON'], Total Distance: 172.3, Total Demand: 77.0, Duration sailing: 17.23, Duration lossing: 10.7
# Shortest Route: ['MON', 'ASL', 'NLNVAL', 'TEQTRC', 'MON'], Total Distance: 165.8, Total Demand: 81.0, Duration sailing: 16.58, Duration lossing: 11.25
# Shortest Route: ['MON', 'ASL', 'NLNVAL', 'TRO', 'MON'], Total Distance: 170.9, Total Demand: 65.0, Duration sailing: 17.09, Duration lossing: 9.03
# ...
# Shortest Route: ['MON', 'OSE', 'OSO', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 212.3, Total Demand: 97.0, Duration sailing: 21.23, Duration lossing: 13.47
# Shortest Route: ['MON', 'OSO', 'OSS', 'TENTRB', 'TEQTRC', 'TRO', 'MON'], Total Distance: 164.3, Total Demand: 93.0, Duration sailing: 16.43, Duration lossing: 12.92
# Shortest Route: ['MON', 'OSO', 'OSS', 'TENTRB', 'TEQTRC', 'VFB', 'MON'], Total Distance: 191.4, Total Demand: 100.0, Duration sailing: 19.14, Duration lossing: 13.89
# Shortest Route: ['MON', 'OSO', 'OSS', 'TENTRB', 'TRO', 'VFB', 'MON'], Total Distance: 194.7, Total Demand: 84.0, Duration sailing: 19.47, Duration lossing: 11.67
# Shortest Route: ['MON', 'OSO', 'OSS', 'TEQTRC', 'TRO', 'VFB', 'MON'], Total Distance: 206.3, Total Demand: 88.0, Duration sailing: 20.63, Duration lossing: 12.22
# Shortest Route: ['MON', 'OSO', 'TENTRB', 'TEQTRC', 'TRO', 'VFB', 'MON'], Total Distance: 178.1, Total Demand: 93.0, Duration sailing: 17.81, Duration lossing: 12.92
# Shortest Route: ['MON', 'OSS', 'TENTRB', 'TEQTRC', 'TRO', 'VFB', 'MON'], Total Distance: 201.9, Total Demand: 97.0, Duration sailing: 20.19, Duration lossing: 13.47
# Shortest Route: ['MON', 'APT', 'ASL', 'KVB', 'MID', 'OSC', 'TRO', 'MON'], Total Distance: 256.2, Total Demand: 100.0, Duration sailing: 25.62, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'ASL', 'KVB', 'MID', 'OSO', 'TRO', 'MON'], Total Distance: 259.9, Total Demand: 96.0, Duration sailing: 25.99, Duration lossing: 13.33
# Shortest Route: ['MON', 'APT', 'ASL', 'KVB', 'MID', 'OSS', 'TRO', 'MON'], Total Distance: 269.8, Total Demand: 100.0, Duration sailing: 26.98, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'ASL', 'KVB', 'MID', 'TRO', 'VFB', 'MON'], Total Distance: 285.3, Total Demand: 100.0, Duration sailing: 28.53, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'ASL', 'KVB', 'OSC', 'OSO', 'TRO', 'MON'], Total Distance: 229.2, Total Demand: 100.0, Duration sailing: 22.92, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'ASL', 'KVB', 'OSO', 'OSS', 'TRO', 'MON'], Total Distance: 253.9, Total Demand: 100.0, Duration sailing: 25.39, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'ASL', 'KVB', 'OSO', 'TRO', 'VFB', 'MON'], Total Distance: 265.6, Total Demand: 100.0, Duration sailing: 26.56, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'ASL', 'MID', 'OSC', 'OSO', 'TRO', 'MON'], Total Distance: 242.8, Total Demand: 100.0, Duration sailing: 24.28, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'ASL', 'MID', 'OSO', 'OSS', 'TRO', 'MON'], Total Distance: 276.9, Total Demand: 100.0, Duration sailing: 27.69, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'ASL', 'MID', 'OSO', 'TRO', 'VFB', 'MON'], Total Distance: 288.6, Total Demand: 100.0, Duration sailing: 28.86, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'DSA', 'KVB', 'MID', 'OSO', 'TRO', 'MON'], Total Distance: 293.2, Total Demand: 100.0, Duration sailing: 29.32, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'DSS', 'KVB', 'MID', 'OSO', 'TRO', 'MON'], Total Distance: 303.2, Total Demand: 100.0, Duration sailing: 30.32, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'NLNVAL', 'OSO', 'TRO', 'MON'], Total Distance: 273.9, Total Demand: 100.0, Duration sailing: 27.39, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSC', 'OSO', 'OSS', 'MON'], Total Distance: 267.9, Total Demand: 96.0, Duration sailing: 26.79, Duration lossing: 13.33
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSC', 'OSO', 'TRO', 'MON'], Total Distance: 242.6, Total Demand: 89.0, Duration sailing: 24.26, Duration lossing: 12.36
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSC', 'OSO', 'VFB', 'MON'], Total Distance: 242.8, Total Demand: 96.0, Duration sailing: 24.28, Duration lossing: 13.33
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSC', 'OSS', 'TRO', 'MON'], Total Distance: 264.8, Total Demand: 93.0, Duration sailing: 26.48, Duration lossing: 12.92
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSC', 'OSS', 'VFB', 'MON'], Total Distance: 268.9, Total Demand: 100.0, Duration sailing: 26.89, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSC', 'TENTRB', 'TRO', 'MON'], Total Distance: 245.3, Total Demand: 98.0, Duration sailing: 24.53, Duration lossing: 13.61
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSC', 'TRO', 'VFB', 'MON'], Total Distance: 284.7, Total Demand: 93.0, Duration sailing: 28.47, Duration lossing: 12.92
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSO', 'OSS', 'TRO', 'MON'], Total Distance: 276.7, Total Demand: 89.0, Duration sailing: 27.67, Duration lossing: 12.36
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSO', 'OSS', 'VFB', 'MON'], Total Distance: 280.8, Total Demand: 96.0, Duration sailing: 28.08, Duration lossing: 13.33
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSO', 'TENTRB', 'TRO', 'MON'], Total Distance: 245.6, Total Demand: 94.0, Duration sailing: 24.56, Duration lossing: 13.06
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSO', 'TEQTRC', 'TRO', 'MON'], Total Distance: 254.4, Total Demand: 98.0, Duration sailing: 25.44, Duration lossing: 13.61
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSO', 'TRO', 'VFB', 'MON'], Total Distance: 288.4, Total Demand: 89.0, Duration sailing: 28.84, Duration lossing: 12.36
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 253.4, Total Demand: 98.0, Duration sailing: 25.34, Duration lossing: 13.61
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 298.3, Total Demand: 93.0, Duration sailing: 29.83, Duration lossing: 12.92
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'TENTRB', 'TRO', 'VFB', 'MON'], Total Distance: 291.9, Total Demand: 98.0, Duration sailing: 29.19, Duration lossing: 13.61
# Shortest Route: ['MON', 'APT', 'KVB', 'OSC', 'OSO', 'OSS', 'TRO', 'MON'], Total Distance: 246.0, Total Demand: 93.0, Duration sailing: 24.6, Duration lossing: 12.92
# Shortest Route: ['MON', 'APT', 'KVB', 'OSC', 'OSO', 'OSS', 'VFB', 'MON'], Total Distance: 250.1, Total Demand: 100.0, Duration sailing: 25.01, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'KVB', 'OSC', 'OSO', 'TENTRB', 'TRO', 'MON'], Total Distance: 214.9, Total Demand: 98.0, Duration sailing: 21.49, Duration lossing: 13.61
# Shortest Route: ['MON', 'APT', 'KVB', 'OSC', 'OSO', 'TRO', 'VFB', 'MON'], Total Distance: 257.7, Total Demand: 93.0, Duration sailing: 25.77, Duration lossing: 12.92
# Shortest Route: ['MON', 'APT', 'KVB', 'OSC', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 279.9, Total Demand: 97.0, Duration sailing: 27.99, Duration lossing: 13.47
# Shortest Route: ['MON', 'APT', 'KVB', 'OSO', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 237.5, Total Demand: 98.0, Duration sailing: 23.75, Duration lossing: 13.61
# Shortest Route: ['MON', 'APT', 'KVB', 'OSO', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 282.4, Total Demand: 93.0, Duration sailing: 28.24, Duration lossing: 12.92
# Shortest Route: ['MON', 'APT', 'KVB', 'OSO', 'TENTRB', 'TRO', 'VFB', 'MON'], Total Distance: 251.3, Total Demand: 98.0, Duration sailing: 25.13, Duration lossing: 13.61
# Shortest Route: ['MON', 'APT', 'MID', 'OSC', 'OSO', 'OSS', 'TRO', 'MON'], Total Distance: 217.3, Total Demand: 93.0, Duration sailing: 21.73, Duration lossing: 12.92
# Shortest Route: ['MON', 'APT', 'MID', 'OSC', 'OSO', 'OSS', 'VFB', 'MON'], Total Distance: 221.4, Total Demand: 100.0, Duration sailing: 22.14, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'MID', 'OSC', 'OSO', 'TENTRB', 'TRO', 'MON'], Total Distance: 186.2, Total Demand: 98.0, Duration sailing: 18.62, Duration lossing: 13.61
# Shortest Route: ['MON', 'APT', 'MID', 'OSC', 'OSO', 'TRO', 'VFB', 'MON'], Total Distance: 229.0, Total Demand: 93.0, Duration sailing: 22.9, Duration lossing: 12.92
# Shortest Route: ['MON', 'APT', 'MID', 'OSC', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 251.2, Total Demand: 97.0, Duration sailing: 25.12, Duration lossing: 13.47
# Shortest Route: ['MON', 'APT', 'MID', 'OSO', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 218.2, Total Demand: 98.0, Duration sailing: 21.82, Duration lossing: 13.61
# Shortest Route: ['MON', 'APT', 'MID', 'OSO', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 263.1, Total Demand: 93.0, Duration sailing: 26.31, Duration lossing: 12.92
# Shortest Route: ['MON', 'APT', 'MID', 'OSO', 'TENTRB', 'TRO', 'VFB', 'MON'], Total Distance: 232.0, Total Demand: 98.0, Duration sailing: 23.2, Duration lossing: 13.61
# Shortest Route: ['MON', 'APT', 'OSC', 'OSO', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 234.5, Total Demand: 97.0, Duration sailing: 23.45, Duration lossing: 13.47
# Shortest Route: ['MON', 'ASL', 'KVB', 'MID', 'OSC', 'OSO', 'TRO', 'MON'], Total Distance: 220.4, Total Demand: 96.0, Duration sailing: 22.04, Duration lossing: 13.33
# Shortest Route: ['MON', 'ASL', 'KVB', 'MID', 'OSC', 'OSS', 'TRO', 'MON'], Total Distance: 242.6, Total Demand: 100.0, Duration sailing: 24.26, Duration lossing: 13.89
# Shortest Route: ['MON', 'ASL', 'KVB', 'MID', 'OSC', 'TRO', 'VFB', 'MON'], Total Distance: 262.5, Total Demand: 100.0, Duration sailing: 26.25, Duration lossing: 13.89
# Shortest Route: ['MON', 'ASL', 'KVB', 'MID', 'OSO', 'OSS', 'TRO', 'MON'], Total Distance: 254.5, Total Demand: 96.0, Duration sailing: 25.45, Duration lossing: 13.33
# Shortest Route: ['MON', 'ASL', 'KVB', 'MID', 'OSO', 'TRO', 'VFB', 'MON'], Total Distance: 266.2, Total Demand: 96.0, Duration sailing: 26.62, Duration lossing: 13.33
# Shortest Route: ['MON', 'ASL', 'KVB', 'MID', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 276.1, Total Demand: 100.0, Duration sailing: 27.61, Duration lossing: 13.89
# Shortest Route: ['MON', 'ASL', 'KVB', 'OSC', 'OSO', 'OSS', 'TRO', 'MON'], Total Distance: 223.8, Total Demand: 100.0, Duration sailing: 22.38, Duration lossing: 13.89
# Shortest Route: ['MON', 'ASL', 'KVB', 'OSC', 'OSO', 'TRO', 'VFB', 'MON'], Total Distance: 235.5, Total Demand: 100.0, Duration sailing: 23.55, Duration lossing: 13.89
# Shortest Route: ['MON', 'ASL', 'KVB', 'OSO', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 260.2, Total Demand: 100.0, Duration sailing: 26.02, Duration lossing: 13.89
# Shortest Route: ['MON', 'ASL', 'MID', 'OSC', 'OSO', 'OSS', 'TRO', 'MON'], Total Distance: 237.4, Total Demand: 100.0, Duration sailing: 23.74, Duration lossing: 13.89
# Shortest Route: ['MON', 'ASL', 'MID', 'OSC', 'OSO', 'TRO', 'VFB', 'MON'], Total Distance: 249.1, Total Demand: 100.0, Duration sailing: 24.91, Duration lossing: 13.89
# Shortest Route: ['MON', 'ASL', 'MID', 'OSO', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 283.2, Total Demand: 100.0, Duration sailing: 28.32, Duration lossing: 13.89
# Shortest Route: ['MON', 'DSA', 'KVB', 'MID', 'OSC', 'OSO', 'TRO', 'MON'], Total Distance: 240.3, Total Demand: 100.0, Duration sailing: 24.03, Duration lossing: 13.89
# Shortest Route: ['MON', 'DSA', 'KVB', 'MID', 'OSO', 'OSS', 'TRO', 'MON'], Total Distance: 274.4, Total Demand: 100.0, Duration sailing: 27.44, Duration lossing: 13.89
# Shortest Route: ['MON', 'DSA', 'KVB', 'MID', 'OSO', 'TRO', 'VFB', 'MON'], Total Distance: 286.1, Total Demand: 100.0, Duration sailing: 28.61, Duration lossing: 13.89
# Shortest Route: ['MON', 'DSS', 'KVB', 'MID', 'OSC', 'OSO', 'TRO', 'MON'], Total Distance: 242.2, Total Demand: 100.0, Duration sailing: 24.22, Duration lossing: 13.89
# Shortest Route: ['MON', 'DSS', 'KVB', 'MID', 'OSO', 'OSS', 'TRO', 'MON'], Total Distance: 276.3, Total Demand: 100.0, Duration sailing: 27.63, Duration lossing: 13.89
# Shortest Route: ['MON', 'DSS', 'KVB', 'MID', 'OSO', 'TRO', 'VFB', 'MON'], Total Distance: 288.0, Total Demand: 100.0, Duration sailing: 28.8, Duration lossing: 13.89
# Shortest Route: ['MON', 'KVB', 'MID', 'NLNVAL', 'OSC', 'OSO', 'TRO', 'MON'], Total Distance: 232.2, Total Demand: 100.0, Duration sailing: 23.22, Duration lossing: 13.89
# Shortest Route: ['MON', 'KVB', 'MID', 'NLNVAL', 'OSO', 'OSS', 'TRO', 'MON'], Total Distance: 258.1, Total Demand: 100.0, Duration sailing: 25.81, Duration lossing: 13.89
# Shortest Route: ['MON', 'KVB', 'MID', 'NLNVAL', 'OSO', 'TRO', 'VFB', 'MON'], Total Distance: 269.8, Total Demand: 100.0, Duration sailing: 26.98, Duration lossing: 13.89
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSO', 'OSS', 'TRO', 'MON'], Total Distance: 226.8, Total Demand: 89.0, Duration sailing: 22.68, Duration lossing: 12.36
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSO', 'OSS', 'VFB', 'MON'], Total Distance: 230.9, Total Demand: 96.0, Duration sailing: 23.09, Duration lossing: 13.33
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSO', 'TENTRB', 'TRO', 'MON'], Total Distance: 195.7, Total Demand: 94.0, Duration sailing: 19.57, Duration lossing: 13.06
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSO', 'TEQTRC', 'TRO', 'MON'], Total Distance: 204.5, Total Demand: 98.0, Duration sailing: 20.45, Duration lossing: 13.61
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSO', 'TRO', 'VFB', 'MON'], Total Distance: 238.5, Total Demand: 89.0, Duration sailing: 23.85, Duration lossing: 12.36
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 215.8, Total Demand: 98.0, Duration sailing: 21.58, Duration lossing: 13.61
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 260.7, Total Demand: 93.0, Duration sailing: 26.07, Duration lossing: 12.92
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'TENTRB', 'TRO', 'VFB', 'MON'], Total Distance: 241.2, Total Demand: 98.0, Duration sailing: 24.12, Duration lossing: 13.61
# Shortest Route: ['MON', 'KVB', 'MID', 'OSO', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 227.7, Total Demand: 94.0, Duration sailing: 22.77, Duration lossing: 13.06
# Shortest Route: ['MON', 'KVB', 'MID', 'OSO', 'OSS', 'TEQTRC', 'TRO', 'MON'], Total Distance: 239.3, Total Demand: 98.0, Duration sailing: 23.93, Duration lossing: 13.61
# Shortest Route: ['MON', 'KVB', 'MID', 'OSO', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 272.6, Total Demand: 89.0, Duration sailing: 27.26, Duration lossing: 12.36
# Shortest Route: ['MON', 'KVB', 'MID', 'OSO', 'TENTRB', 'TRO', 'VFB', 'MON'], Total Distance: 241.5, Total Demand: 94.0, Duration sailing: 24.15, Duration lossing: 13.06
# Shortest Route: ['MON', 'KVB', 'MID', 'OSO', 'TEQTRC', 'TRO', 'VFB', 'MON'], Total Distance: 250.3, Total Demand: 98.0, Duration sailing: 25.03, Duration lossing: 13.61
# Shortest Route: ['MON', 'KVB', 'MID', 'OSS', 'TENTRB', 'TRO', 'VFB', 'MON'], Total Distance: 249.3, Total Demand: 98.0, Duration sailing: 24.93, Duration lossing: 13.61
# Shortest Route: ['MON', 'KVB', 'OSC', 'OSO', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 197.0, Total Demand: 98.0, Duration sailing: 19.7, Duration lossing: 13.61
# Shortest Route: ['MON', 'KVB', 'OSC', 'OSO', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 241.9, Total Demand: 93.0, Duration sailing: 24.19, Duration lossing: 12.92
# Shortest Route: ['MON', 'KVB', 'OSC', 'OSO', 'TENTRB', 'TRO', 'VFB', 'MON'], Total Distance: 210.8, Total Demand: 98.0, Duration sailing: 21.08, Duration lossing: 13.61
# Shortest Route: ['MON', 'KVB', 'OSO', 'OSS', 'TENTRB', 'TRO', 'VFB', 'MON'], Total Distance: 233.4, Total Demand: 98.0, Duration sailing: 23.34, Duration lossing: 13.61
# Shortest Route: ['MON', 'MID', 'OSC', 'OSO', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 207.5, Total Demand: 98.0, Duration sailing: 20.75, Duration lossing: 13.61
# Shortest Route: ['MON', 'MID', 'OSC', 'OSO', 'OSS', 'TRO', 'VFB', 'MON'], Total Distance: 252.4, Total Demand: 93.0, Duration sailing: 25.24, Duration lossing: 12.92
# Shortest Route: ['MON', 'MID', 'OSC', 'OSO', 'TENTRB', 'TRO', 'VFB', 'MON'], Total Distance: 221.3, Total Demand: 98.0, Duration sailing: 22.13, Duration lossing: 13.61
# Shortest Route: ['MON', 'MID', 'OSO', 'OSS', 'TENTRB', 'TRO', 'VFB', 'MON'], Total Distance: 253.3, Total Demand: 98.0, Duration sailing: 25.33, Duration lossing: 13.61
# 3121

# %% [markdown]
# ## Checks the capacity utilization (demand delivered). Removes all routes with capacity utilization below 70%

# %%
count_below_10 = 0
count_below_20 = 0
count_below_30 = 0
count_below_40 = 0
count_below_50 = 0
count_below_60 = 0
count_below_70 = 0
count_below_80 = 0
count_below_90 = 0

for route, distance, demand, duration_sailing, duration_lossing in shortest_routes_dict.values():
    if demand < 10:
        count_below_10 += 1
    if demand < 20:
        count_below_20 += 1
    if demand < 30:
        count_below_30 += 1
    if demand < 40:
        count_below_40 += 1
    if demand < 50:
        count_below_50 += 1
    if demand < 60:
        count_below_60 += 1
    if demand < 70:
        count_below_70 += 1
    if demand < 80:
        count_below_80 += 1
    if demand < 90:
        count_below_90 += 1

print("Number of shortest routes with total demand below 10:", count_below_10)
print("Number of shortest routes with total demand below 20:", count_below_20)
print("Number of shortest routes with total demand below 30:", count_below_30)
print("Number of shortest routes with total demand below 40:", count_below_40)
print("Number of shortest routes with total demand below 50:", count_below_50)
print("Number of shortest routes with total demand below 60:", count_below_60)
print("Number of shortest routes with total demand below 70:", count_below_70)
print("Number of shortest routes with total demand below 80:", count_below_80)
print("Number of shortest routes with total demand below 90:", count_below_90)
# Out:
# '\ncount_below_10 = 0\ncount_below_20 = 0\ncount_below_30 = 0\ncount_below_40 = 0\ncount_below_50 = 0\ncount_below_60 = 0\ncount_below_70 = 0\ncount_below_80 = 0\ncount_below_90 = 0\n\nfor route, distance, demand, duration_sailing, duration_lossing in shortest_routes_dict.values():\n    if demand < 10:\n        count_below_10 += 1\n    if demand < 20:\n        count_below_20 += 1\n    if demand < 30:\n        count_below_30 += 1\n    if demand < 40:\n        count_below_40 += 1\n    if demand < 50:\n        count_below_50 += 1\n    if demand < 60:\n        count_below_60 += 1\n    if demand < 70:\n        count_below_70 += 1\n    if demand < 80:\n        count_below_80 += 1\n    if demand < 90:\n        count_below_90 += 1\n\nprint("Number of shortest routes with total demand below 10:", count_below_10)\nprint("Number of shortest routes with total demand below 20:", count_below_20)\nprint("Number of shortest routes with total demand below 30:", count_below_30)\nprint("Number of shortest routes with total demand below 40:", count_below_40)\nprint("Number of shortest routes with total demand below 50:", count_below_50)\nprint("Number of shortest routes with total demand below 60:", count_below_60)\nprint("Number of shortest routes with total demand below 70:", count_below_70)\nprint("Number of shortest routes with total demand below 80:", count_below_80)\nprint("Number of shortest routes with total demand below 90:", count_below_90)\n'

# %%
shortest_routes_dict_cap = {}

for key, (route, distance, demand, duration_sailing, duration_lossing) in shortest_routes_dict.items():
    if demand > 42 and demand < 71:
        shortest_routes_dict_cap[key] = (route, distance, demand, duration_sailing, duration_lossing)
# Out:
# '\nshortest_routes_dict_cap = {}\n\nfor key, (route, distance, demand, duration_sailing, duration_lossing) in shortest_routes_dict.items():\n    if demand > 42 and demand < 71:\n        shortest_routes_dict_cap[key] = (route, distance, demand, duration_sailing, duration_lossing)\n'

# %%
#print(len(shortest_routes_dict_cap))

# %%
# Initialize counters
count_between_16_and_24 = 0
count_between_40_and_48 = 0

# Iterate through routes in shortest_routes_dict_cap and count routes based on conditions
for route, distance, demand, duration_sailing, duration_lossing in shortest_routes_dict_cap.values():
    total_duration = duration_sailing + duration_lossing
    if 16 < total_duration < 24:
        count_between_16_and_24 += 1
    if 40 < total_duration < 48:
        count_between_40_and_48 += 1

# Print counts
print("Count of routes with duration between 16 and 24:", count_between_16_and_24)
print("Count of routes with duration between 40 and 48:", count_between_40_and_48)
# Out:
# '\n# Initialize counters\ncount_between_16_and_24 = 0\ncount_between_40_and_48 = 0\n\n# Iterate through routes in shortest_routes_dict_cap and count routes based on conditions\nfor route, distance, demand, duration_sailing, duration_lossing in shortest_routes_dict_cap.values():\n    total_duration = duration_sailing + duration_lossing\n    if 16 < total_duration < 24:\n        count_between_16_and_24 += 1\n    if 40 < total_duration < 48:\n        count_between_40_and_48 += 1\n\n# Print counts\nprint("Count of routes with duration between 16 and 24:", count_between_16_and_24)\nprint("Count of routes with duration between 40 and 48:", count_between_40_and_48)\n'

# %%
# Initialize dictionaries to store routes
shortest_routes_dict_cap_idle = {}
routes_to_remove = []

# Iterate through routes in shortest_routes_dict_cap
for key, (route, distance, demand, duration_sailing, duration_lossing) in shortest_routes_dict_cap.items():
    total_duration = duration_sailing + duration_lossing
    if 16 < total_duration < 24 or 40 < total_duration < 48:
        # If the route meets the conditions, add it to the routes_to_remove list
        routes_to_remove.append(key)
    else:
        # If the route does not meet the conditions, add it to shortest_routes_dict_cap_idle
        shortest_routes_dict_cap_idle[key] = (route, distance, demand, duration_sailing, duration_lossing)

# Remove routes that meet the conditions from shortest_routes_dict_cap
for key in routes_to_remove:
    del shortest_routes_dict_cap[key]

# Print counts
print("Count of routes with duration between 16 and 24 removed:", len(routes_to_remove))
print("Count of routes with duration between 40 and 48 removed:", len(routes_to_remove))
# Out:
# '\n# Initialize dictionaries to store routes\nshortest_routes_dict_cap_idle = {}\nroutes_to_remove = []\n\n# Iterate through routes in shortest_routes_dict_cap\nfor key, (route, distance, demand, duration_sailing, duration_lossing) in shortest_routes_dict_cap.items():\n    total_duration = duration_sailing + duration_lossing\n    if 16 < total_duration < 24 or 40 < total_duration < 48:\n        # If the route meets the conditions, add it to the routes_to_remove list\n        routes_to_remove.append(key)\n    else:\n        # If the route does not meet the conditions, add it to shortest_routes_dict_cap_idle\n        shortest_routes_dict_cap_idle[key] = (route, distance, demand, duration_sailing, duration_lossing)\n\n# Remove routes that meet the conditions from shortest_routes_dict_cap\nfor key in routes_to_remove:\n    del shortest_routes_dict_cap[key]\n\n# Print counts\nprint("Count of routes with duration between 16 and 24 removed:", len(routes_to_remove))\nprint("Count of routes with duration between 40 and 48 removed:", len(routes_to_remove))\n'

# %%
#print(len(shortest_routes_dict_cap_idle))

# %% [markdown]
# ## Saves the shortest routes left to csv files in the generated_datafiles folder. In total 2294 routes

# %%
routes_only = [route for route, _, _, _, _ in shortest_routes_dict.values()]
distances_only = [distance for _, distance, _, _, _ in shortest_routes_dict.values()]
demand_only = [demand for _, _, demand, _, _ in shortest_routes_dict.values()]
duration_sailing = [duration_sailing for _, _, _, duration_sailing, _ in shortest_routes_dict.values()]
duration_lossing = [duration_lossing for _, _, _, _, duration_lossing in shortest_routes_dict.values()]

df_distances = pd.DataFrame({'Distance': distances_only})
df_demand = pd.DataFrame({'Demand': demand_only})
df_duration_sailing = pd.DataFrame({'Duration (hours)': duration_sailing})
df_duration_lossing = pd.DataFrame({'Duration (hours)': duration_lossing})

'''
df_distances.to_csv('generated_datafiles/distances_strøm.csv', index=False)
df_demand.to_csv('generated_datafiles/demand_strøm.csv', index=False)
df_duration_sailing.to_csv('generated_datafiles/duration_sailing_strøm.csv', index=False)
df_duration_lossing.to_csv('generated_datafiles/duration_lossing_strøm.csv', index=False)
route_file = "generated_datafiles/routes_strøm.csv"
'''

df_distances.to_csv('generated_datafiles_2239/distances.csv', index=False)
df_demand.to_csv('generated_datafiles_2239/demand.csv', index=False)
df_duration_sailing.to_csv('generated_datafiles_2239/duration_sailing.csv', index=False)
df_duration_lossing.to_csv('generated_datafiles_2239/duration_lossing.csv', index=False)
route_file = "generated_datafiles_2239/routes.csv"

def write_to_csv(filename, data):
    with open(filename, "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerows(data)

write_to_csv(route_file, routes_only)
# Out:
# '\nroutes_only = [route for route, _, _, _, _ in shortest_routes_dict.values()]\ndistances_only = [distance for _, distance, _, _, _ in shortest_routes_dict.values()]\ndemand_only = [demand for _, _, demand, _, _ in shortest_routes_dict.values()]\nduration_sailing = [duration_sailing for _, _, _, duration_sailing, _ in shortest_routes_dict.values()]\nduration_lossing = [duration_lossing for _, _, _, _, duration_lossing in shortest_routes_dict.values()]\n\ndf_distances = pd.DataFrame({\'Distance\': distances_only})\ndf_demand = pd.DataFrame({\'Demand\': demand_only})\ndf_duration_sailing = pd.DataFrame({\'Duration (hours)\': duration_sailing})\ndf_duration_lossing = pd.DataFrame({\'Duration (hours)\': duration_lossing})\n\n\ndf_distances.to_csv(\'generated_datafiles/distances_strøm.csv\', index=False)\ndf_demand.to_csv(\'generated_datafiles/demand_strøm.csv\', index=False)\ndf_duration_sailing.to_csv(\'generated_datafiles/duration_sailing_strøm.csv\', index=False)\ndf_duration_lossing.to_csv(\'generated_datafiles/duration_lossing_strøm.csv\', index=False)\nroute_file = "generated_datafiles/routes_strøm.csv"\n\ndf_distances.to_csv(\'generated_datafiles_3121/distances.csv\', index=False)\ndf_demand.to_csv(\'generated_datafiles_3121/demand.csv\', index=False)\ndf_duration_sailing.to_csv(\'generated_datafiles_3121/duration_sailing.csv\', index=False)\ndf_duration_lossing.to_csv(\'generated_datafiles_3121/duration_lossing.csv\', index=False)\nroute_file = "generated_datafiles_3121/routes.csv"\n\ndef write_to_csv(filename, data):\n    with open(filename, "w", newline="") as file:\n        writer = csv.writer(file)\n        writer.writerows(data)\n\nwrite_to_csv(route_file, routes_only)\n'
