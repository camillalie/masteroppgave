# %%
import pandas as pd
from itertools import permutations
import math
import os
import csv
import time
# Out:
# /var/folders/gp/vqql8_v1253_d8bwfqk_0gb40000gn/T/ipykernel_1705/2693103964.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## INPUT

# %%
cargo_capacity_psv = 100
psv_speed = 10
max_platforms_in_one_voyage = 7

non_cluster = 'general_routes'
mappenavn = 'cluster18_new'

# %% [markdown]
# ## GENERATE ROUTES FOR CLUSTER

# %%
demand = pd.read_csv(f'{mappenavn}/output_platforms_demand.csv', header=0, delimiter=';')
distances = pd.read_csv(f'{mappenavn}/output_distance_matrix_kmeans.csv', header=0, delimiter=';', index_col='from/to')

platforms_demand = dict(zip(demand['platform'], demand['avg_q'].replace(',', '.').astype(float)))
platforms_d = ['MON'] + demand['platform'].tolist() + ['MON']  # Add 'DUS' as start and end platforms

# %%
shortest_routes_dict = {}

def generate_routes(demand, distances):
    cargo_capacity = cargo_capacity_psv
    max_platforms = max_platforms_in_one_voyage + 2

    def dp(platform, cargo_remaining, route, visited):
        if cargo_remaining < 0:
            return
        if len(route) > max_platforms:
            return
        if platform == 'MON' and len(route) > 2:
            total_demand = sum(platforms_demand[p] for p in route[1:-1])
            if total_demand <= cargo_capacity:
                key = tuple(sorted(set(route)))
                total_distance = sum(distances.loc[route[i], route[i+1]] for i in range(len(route)-1))
                if key not in shortest_routes_dict or total_distance < shortest_routes_dict[key][1]:
                    duration_sailing = round((total_distance / psv_speed), 2)
                    duration_lossing = round(((total_demand * 1.389) / psv_speed), 2)
                    duration_sailing = round(duration_sailing, 2)
                    duration_lossing = round(duration_lossing, 2)
                    shortest_routes_dict[key] = (route, total_distance, total_demand, duration_sailing, duration_lossing)
            return

        # Check if the current route is dominated
        current_distance = sum(distances.loc[route[i], route[i+1]] for i in range(len(route)-1))
        current_demand = sum(platforms_demand[p] for p in route[1:-1])
        
        # Check for dominance in existing routes
        for key, (existing_route, existing_distance, existing_demand, _, _) in shortest_routes_dict.items():
            if set(existing_route[1:-1]) == set(route[1:-1]) and existing_demand >= current_demand and existing_distance <= current_distance:
                return
        
        # Check for dominance in subsequent routes starting with the same platforms
        for existing_route in dominated_routes:
            if set(existing_route[1:-1]) == set(route[1:-1]) and existing_demand >= current_demand and existing_distance <= current_distance:
                return

        for next_platform in platforms_demand.keys():
            if next_platform != platform and next_platform not in visited:
                try:
                    distance_to_next = distances.loc[platform, next_platform]
                    new_cargo_remaining = cargo_remaining - platforms_demand[next_platform]
                    dp(next_platform, new_cargo_remaining, route + [next_platform], visited.union({next_platform}))
                except KeyError:
                    print("KeyError occurred for platform:", next_platform)
                    continue

    for r in range(3, min(len(platforms_demand) + 3, max_platforms + 3)):
        for route_combination in permutations(platforms_demand.keys(), r - 2):
            route = ['MON'] + list(route_combination) + ['MON']
            dp('MON', cargo_capacity, route, {'MON'})

            # Add the current route to the dominated routes set
            dominated_routes.add(tuple(route))

    return shortest_routes_dict

# Keep track of dominated routes to skip future routes starting with them
dominated_routes = set()
shortest_routes_dict = generate_routes(demand, distances)

for route, distance, demand, duration_sailing, duration_lossing in shortest_routes_dict.values():
    print(f"Shortest Route: {route}, Total Distance: {round(distance,2)}, Total Demand: {demand}, Duration sailing: {duration_sailing}, Duration lossing: {duration_lossing}")

print(len(shortest_routes_dict))
# Out:
# Shortest Route: ['MON', 'APTOSS', 'MON'], Total Distance: 134.82, Total Demand: 30.0, Duration sailing: 13.48, Duration lossing: 4.17
# Shortest Route: ['MON', 'ASLGFAGFBGFC', 'MON'], Total Distance: 156.56, Total Demand: 86.0, Duration sailing: 15.66, Duration lossing: 11.95
# Shortest Route: ['MON', 'DAB', 'MON'], Total Distance: 85.82, Total Demand: 40.0, Duration sailing: 8.58, Duration lossing: 5.56
# Shortest Route: ['MON', 'DSASTASTBSTC', 'MON'], Total Distance: 183.48, Total Demand: 90.25, Duration sailing: 18.35, Duration lossing: 12.54
# Shortest Route: ['MON', 'DSS', 'MON'], Total Distance: 164.34, Total Demand: 29.0, Duration sailing: 16.43, Duration lossing: 4.03
# Shortest Route: ['MON', 'KVBNLNVAL', 'MON'], Total Distance: 138.2, Total Demand: 38.0, Duration sailing: 13.82, Duration lossing: 5.28
# Shortest Route: ['MON', 'MID', 'MON'], Total Distance: 156.6, Total Demand: 14.0, Duration sailing: 15.66, Duration lossing: 1.94
# Shortest Route: ['MON', 'OSCOSE', 'MON'], Total Distance: 121.04, Total Demand: 43.2, Duration sailing: 12.1, Duration lossing: 6.0
# Shortest Route: ['MON', 'OSOVFB', 'MON'], Total Distance: 107.14, Total Demand: 28.5, Duration sailing: 10.71, Duration lossing: 3.96
# Shortest Route: ['MON', 'TENTEQTRBTRCTRO', 'MON'], Total Distance: 85.62, Total Demand: 56.0, Duration sailing: 8.56, Duration lossing: 7.78
# Shortest Route: ['MON', 'APTOSS', 'DAB', 'MON'], Total Distance: 175.1, Total Demand: 70.0, Duration sailing: 17.51, Duration lossing: 9.72
# Shortest Route: ['MON', 'DSS', 'APTOSS', 'MON'], Total Distance: 232.1, Total Demand: 59.0, Duration sailing: 23.21, Duration lossing: 8.2
# Shortest Route: ['MON', 'APTOSS', 'KVBNLNVAL', 'MON'], Total Distance: 191.61, Total Demand: 68.0, Duration sailing: 19.16, Duration lossing: 9.45
# Shortest Route: ['MON', 'APTOSS', 'MID', 'MON'], Total Distance: 176.21, Total Demand: 44.0, Duration sailing: 17.62, Duration lossing: 6.11
# Shortest Route: ['MON', 'APTOSS', 'OSCOSE', 'MON'], Total Distance: 152.11, Total Demand: 73.2, Duration sailing: 15.21, Duration lossing: 10.17
# Shortest Route: ['MON', 'APTOSS', 'OSOVFB', 'MON'], Total Distance: 155.97, Total Demand: 58.5, Duration sailing: 15.6, Duration lossing: 8.13
# Shortest Route: ['MON', 'APTOSS', 'TENTEQTRBTRCTRO', 'MON'], Total Distance: 164.57, Total Demand: 86.0, Duration sailing: 16.46, Duration lossing: 11.95
# Shortest Route: ['MON', 'MID', 'ASLGFAGFBGFC', 'MON'], Total Distance: 202.1, Total Demand: 100.0, Duration sailing: 20.21, Duration lossing: 13.89
# Shortest Route: ['MON', 'DSS', 'DAB', 'MON'], Total Distance: 164.48, Total Demand: 69.0, Duration sailing: 16.45, Duration lossing: 9.58
# Shortest Route: ['MON', 'DAB', 'KVBNLNVAL', 'MON'], Total Distance: 147.61, Total Demand: 78.0, Duration sailing: 14.76, Duration lossing: 10.83
# Shortest Route: ['MON', 'MID', 'DAB', 'MON'], Total Distance: 181.98, Total Demand: 54.0, Duration sailing: 18.2, Duration lossing: 7.5
# Shortest Route: ['MON', 'DAB', 'OSCOSE', 'MON'], Total Distance: 154.85, Total Demand: 83.2, Duration sailing: 15.48, Duration lossing: 11.56
# Shortest Route: ['MON', 'DAB', 'OSOVFB', 'MON'], Total Distance: 135.22, Total Demand: 68.5, Duration sailing: 13.52, Duration lossing: 9.51
# Shortest Route: ['MON', 'DAB', 'TENTEQTRBTRCTRO', 'MON'], Total Distance: 129.04, Total Demand: 96.0, Duration sailing: 12.9, Duration lossing: 13.33
# Shortest Route: ['MON', 'DSS', 'KVBNLNVAL', 'MON'], Total Distance: 187.97, Total Demand: 67.0, Duration sailing: 18.8, Duration lossing: 9.31
# Shortest Route: ['MON', 'DSS', 'MID', 'MON'], Total Distance: 224.82, Total Demand: 43.0, Duration sailing: 22.48, Duration lossing: 5.97
# Shortest Route: ['MON', 'DSS', 'OSCOSE', 'MON'], Total Distance: 211.97, Total Demand: 72.2, Duration sailing: 21.2, Duration lossing: 10.03
# Shortest Route: ['MON', 'DSS', 'OSOVFB', 'MON'], Total Distance: 194.55, Total Demand: 57.5, Duration sailing: 19.46, Duration lossing: 7.99
# Shortest Route: ['MON', 'DSS', 'TENTEQTRBTRCTRO', 'MON'], Total Distance: 201.13, Total Demand: 85.0, Duration sailing: 20.11, Duration lossing: 11.81
# Shortest Route: ['MON', 'MID', 'KVBNLNVAL', 'MON'], Total Distance: 186.92, Total Demand: 52.0, Duration sailing: 18.69, Duration lossing: 7.22
# Shortest Route: ['MON', 'KVBNLNVAL', 'OSCOSE', 'MON'], Total Distance: 171.65, Total Demand: 81.2, Duration sailing: 17.16, Duration lossing: 11.28
# Shortest Route: ['MON', 'KVBNLNVAL', 'OSOVFB', 'MON'], Total Distance: 155.45, Total Demand: 66.5, Duration sailing: 15.54, Duration lossing: 9.24
# Shortest Route: ['MON', 'KVBNLNVAL', 'TENTEQTRBTRCTRO', 'MON'], Total Distance: 167.63, Total Demand: 94.0, Duration sailing: 16.76, Duration lossing: 13.06
# Shortest Route: ['MON', 'MID', 'OSCOSE', 'MON'], Total Distance: 167.35, Total Demand: 57.2, Duration sailing: 16.74, Duration lossing: 7.95
# Shortest Route: ['MON', 'MID', 'OSOVFB', 'MON'], Total Distance: 166.18, Total Demand: 42.5, Duration sailing: 16.62, Duration lossing: 5.9
# Shortest Route: ['MON', 'MID', 'TENTEQTRBTRCTRO', 'MON'], Total Distance: 182.93, Total Demand: 70.0, Duration sailing: 18.29, Duration lossing: 9.72
# Shortest Route: ['MON', 'OSCOSE', 'OSOVFB', 'MON'], Total Distance: 135.37, Total Demand: 71.7, Duration sailing: 13.54, Duration lossing: 9.96
# Shortest Route: ['MON', 'OSCOSE', 'TENTEQTRBTRCTRO', 'MON'], Total Distance: 148.01, Total Demand: 99.2, Duration sailing: 14.8, Duration lossing: 13.78
# Shortest Route: ['MON', 'OSOVFB', 'TENTEQTRBTRCTRO', 'MON'], Total Distance: 133.27, Total Demand: 84.5, Duration sailing: 13.33, Duration lossing: 11.74
# Shortest Route: ['MON', 'APTOSS', 'DSS', 'DAB', 'MON'], Total Distance: 232.24, Total Demand: 99.0, Duration sailing: 23.22, Duration lossing: 13.75
# Shortest Route: ['MON', 'APTOSS', 'MID', 'DAB', 'MON'], Total Distance: 201.59, Total Demand: 84.0, Duration sailing: 20.16, Duration lossing: 11.67
# Shortest Route: ['MON', 'APTOSS', 'OSOVFB', 'DAB', 'MON'], Total Distance: 184.05, Total Demand: 98.5, Duration sailing: 18.4, Duration lossing: 13.68
# Shortest Route: ['MON', 'APTOSS', 'KVBNLNVAL', 'DSS', 'MON'], Total Distance: 241.38, Total Demand: 97.0, Duration sailing: 24.14, Duration lossing: 13.47
# Shortest Route: ['MON', 'DSS', 'MID', 'APTOSS', 'MON'], Total Distance: 244.43, Total Demand: 73.0, Duration sailing: 24.44, Duration lossing: 10.14
# Shortest Route: ['MON', 'APTOSS', 'OSOVFB', 'DSS', 'MON'], Total Distance: 243.38, Total Demand: 87.5, Duration sailing: 24.34, Duration lossing: 12.15
# Shortest Route: ['MON', 'APTOSS', 'MID', 'KVBNLNVAL', 'MON'], Total Distance: 206.53, Total Demand: 82.0, Duration sailing: 20.65, Duration lossing: 11.39
# Shortest Route: ['MON', 'APTOSS', 'OSOVFB', 'KVBNLNVAL', 'MON'], Total Distance: 204.28, Total Demand: 96.5, Duration sailing: 20.43, Duration lossing: 13.4
# Shortest Route: ['MON', 'APTOSS', 'MID', 'OSCOSE', 'MON'], Total Distance: 186.96, Total Demand: 87.2, Duration sailing: 18.7, Duration lossing: 12.11
# Shortest Route: ['MON', 'APTOSS', 'MID', 'OSOVFB', 'MON'], Total Distance: 185.79, Total Demand: 72.5, Duration sailing: 18.58, Duration lossing: 10.07
# Shortest Route: ['MON', 'TENTEQTRBTRCTRO', 'MID', 'APTOSS', 'MON'], Total Distance: 202.54, Total Demand: 100.0, Duration sailing: 20.25, Duration lossing: 13.89
# Shortest Route: ['MON', 'DAB', 'DSS', 'MID', 'MON'], Total Distance: 224.96, Total Demand: 83.0, Duration sailing: 22.5, Duration lossing: 11.53
# Shortest Route: ['MON', 'DAB', 'DSS', 'OSOVFB', 'MON'], Total Distance: 194.69, Total Demand: 97.5, Duration sailing: 19.47, Duration lossing: 13.54
# Shortest Route: ['MON', 'DAB', 'KVBNLNVAL', 'MID', 'MON'], Total Distance: 196.33, Total Demand: 92.0, Duration sailing: 19.63, Duration lossing: 12.78
# Shortest Route: ['MON', 'DAB', 'MID', 'OSCOSE', 'MON'], Total Distance: 192.73, Total Demand: 97.2, Duration sailing: 19.27, Duration lossing: 13.5
# Shortest Route: ['MON', 'DAB', 'MID', 'OSOVFB', 'MON'], Total Distance: 191.56, Total Demand: 82.5, Duration sailing: 19.16, Duration lossing: 11.46
# Shortest Route: ['MON', 'DSS', 'KVBNLNVAL', 'MID', 'MON'], Total Distance: 236.69, Total Demand: 81.0, Duration sailing: 23.67, Duration lossing: 11.25
# Shortest Route: ['MON', 'DSS', 'KVBNLNVAL', 'OSOVFB', 'MON'], Total Distance: 205.22, Total Demand: 95.5, Duration sailing: 20.52, Duration lossing: 13.26
# Shortest Route: ['MON', 'DSS', 'MID', 'OSCOSE', 'MON'], Total Distance: 235.57, Total Demand: 86.2, Duration sailing: 23.56, Duration lossing: 11.97
# Shortest Route: ['MON', 'DSS', 'MID', 'OSOVFB', 'MON'], Total Distance: 234.4, Total Demand: 71.5, Duration sailing: 23.44, Duration lossing: 9.93
# Shortest Route: ['MON', 'DSS', 'MID', 'TENTEQTRBTRCTRO', 'MON'], Total Distance: 251.15, Total Demand: 99.0, Duration sailing: 25.12, Duration lossing: 13.75
# Shortest Route: ['MON', 'KVBNLNVAL', 'MID', 'OSCOSE', 'MON'], Total Distance: 197.67, Total Demand: 95.2, Duration sailing: 19.77, Duration lossing: 13.22
# Shortest Route: ['MON', 'KVBNLNVAL', 'MID', 'OSOVFB', 'MON'], Total Distance: 196.5, Total Demand: 80.5, Duration sailing: 19.65, Duration lossing: 11.18
# Shortest Route: ['MON', 'OSCOSE', 'MID', 'OSOVFB', 'MON'], Total Distance: 176.93, Total Demand: 85.7, Duration sailing: 17.69, Duration lossing: 11.9
# Shortest Route: ['MON', 'MID', 'OSOVFB', 'TENTEQTRBTRCTRO', 'MON'], Total Distance: 192.31, Total Demand: 98.5, Duration sailing: 19.23, Duration lossing: 13.68
# 64

# %%
routes_only = [route for route, _, _, _, _ in shortest_routes_dict.values()]
route_file = f'{mappenavn}/routes.csv'

def write_to_csv(filename, data):
    with open(filename, "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerows(data)

write_to_csv(route_file, routes_only)

# %% [markdown]
# ## NEW CLUSTERING CALCULATION

# %%
input_filename = f'{mappenavn}/routes.csv'
output_filename = f'{mappenavn}/processed_routes.csv'

def split_into_threes(word):
    if len(word) > 3:
        return ','.join([word[i:i+3] for i in range(0, len(word), 3)])
    else:
        return word

def process_csv_file(input_filename, output_filename):
    with open(input_filename, 'r', newline='') as file, open(output_filename, 'w', newline='') as outfile:
        reader = csv.reader(file)
        writer = csv.writer(outfile)

        for row in reader:
            processed_row = []
            for column in row:
                processed_segments = [split_into_threes(segment) for segment in column.split(',')]
                processed_row.append(','.join(processed_segments))

            outfile.write(','.join(processed_row) + '\n')

process_csv_file(input_filename, output_filename)

with open(output_filename, 'r') as processed_file:
    print(processed_file.read())
# Out:
# MON,APT,OSS,MON
# MON,ASL,MON
# MON,DAB,MON
# MON,DSA,STA,STB,STC,MON
# MON,DSS,MON
# MON,GFA,GFB,GFC,MON
# MON,KVB,MON
# MON,MID,MON
# MON,NLN,VAL,MON
# MON,OSC,OSE,MON
# MON,OSO,VFB,MON
# MON,TEN,TEQ,TRB,TRC,MON
# MON,TRO,MON
# MON,ASL,APT,OSS,MON
# MON,APT,OSS,DAB,MON
# MON,DSS,APT,OSS,MON
# MON,APT,OSS,GFA,GFB,GFC,MON
# MON,APT,OSS,KVB,MON
# MON,APT,OSS,MID,MON
# MON,APT,OSS,NLN,VAL,MON
# MON,APT,OSS,OSC,OSE,MON
# MON,APT,OSS,OSO,VFB,MON
# MON,APT,OSS,TEN,TEQ,TRB,TRC,MON
# MON,APT,OSS,TRO,MON
# MON,ASL,DAB,MON
# MON,ASL,DSS,MON
# MON,ASL,GFA,GFB,GFC,MON
# MON,ASL,KVB,MON
# MON,ASL,MID,MON
# MON,ASL,NLN,VAL,MON
# MON,ASL,OSC,OSE,MON
# MON,ASL,OSO,VFB,MON
# MON,ASL,TEN,TEQ,TRB,TRC,MON
# MON,ASL,TRO,MON
# MON,DSS,DAB,MON
# MON,KVB,DAB,MON
# MON,MID,DAB,MON
# MON,DAB,NLN,VAL,MON
# MON,DAB,OSC,OSE,MON
# MON,DAB,OSO,VFB,MON
# MON,DAB,TEN,TEQ,TRB,TRC,MON
# MON,TRO,DAB,MON
# MON,DSS,GFA,GFB,GFC,MON
# MON,DSS,KVB,MON
# MON,DSS,MID,MON
# MON,DSS,NLN,VAL,MON
# MON,DSS,OSC,OSE,MON
# MON,DSS,OSO,VFB,MON
# MON,DSS,TEN,TEQ,TRB,TRC,MON
# MON,DSS,TRO,MON
# MON,GFA,GFB,GFC,KVB,MON
# MON,GFA,GFB,GFC,MID,MON
# MON,GFA,GFB,GFC,NLN,VAL,MON
# MON,GFA,GFB,GFC,OSO,VFB,MON
# MON,GFA,GFB,GFC,TRO,MON
# MON,KVB,MID,MON
# MON,KVB,NLN,VAL,MON
# MON,KVB,OSC,OSE,MON
# MON,KVB,OSO,VFB,MON
# MON,KVB,TEN,TEQ,TRB,TRC,MON
# MON,KVB,TRO,MON
# MON,MID,NLN,VAL,MON
# MON,MID,OSC,OSE,MON
# MON,MID,OSO,VFB,MON
# MON,MID,TEN,TEQ,TRB,TRC,MON
# MON,MID,TRO,MON
# MON,NLN,VAL,OSC,OSE,MON
# MON,NLN,VAL,OSO,VFB,MON
# MON,NLN,VAL,TEN,TEQ,TRB,TRC,MON
# MON,NLN,VAL,TRO,MON
# MON,OSC,OSE,OSO,VFB,MON
# MON,OSC,OSE,TEN,TEQ,TRB,TRC,MON
# MON,TRO,OSC,OSE,MON
# MON,OSO,VFB,TEN,TEQ,TRB,TRC,MON
# MON,TRO,OSO,VFB,MON
# MON,TEN,TEQ,TRB,TRC,TRO,MON
# MON,APT,OSS,ASL,DAB,MON
# MON,APT,OSS,ASL,DSS,MON
# MON,KVB,ASL,APT,OSS,MON
# MON,APT,OSS,MID,ASL,MON
# MON,APT,OSS,ASL,NLN,VAL,MON
# MON,ASL,OSC,OSE,APT,OSS,MON
# MON,APT,OSS,ASL,OSO,VFB,MON
# MON,ASL,APT,OSS,TRO,MON
# MON,APT,OSS,DSS,DAB,MON
# MON,APT,OSS,KVB,DAB,MON
# MON,APT,OSS,MID,DAB,MON
# MON,APT,OSS,NLN,VAL,DAB,MON
# MON,APT,OSS,OSO,VFB,DAB,MON
# MON,DAB,APT,OSS,TRO,MON
# MON,DSS,KVB,APT,OSS,MON
# MON,DSS,MID,APT,OSS,MON
# MON,APT,OSS,NLN,VAL,DSS,MON
# MON,APT,OSS,OSO,VFB,DSS,MON
# MON,DSS,APT,OSS,TRO,MON
# MON,APT,OSS,MID,KVB,MON
# MON,APT,OSS,NLN,VAL,KVB,MON
# MON,KVB,OSC,OSE,APT,OSS,MON
# MON,APT,OSS,OSO,VFB,KVB,MON
# MON,APT,OSS,KVB,TEN,TEQ,TRB,TRC,MON
# MON,KVB,APT,OSS,TRO,MON
# MON,NLN,VAL,MID,APT,OSS,MON
# MON,APT,OSS,MID,OSC,OSE,MON
# MON,APT,OSS,MID,OSO,VFB,MON
# MON,APT,OSS,MID,TEN,TEQ,TRB,TRC,MON
# MON,MID,APT,OSS,TRO,MON
# MON,APT,OSS,OSO,VFB,NLN,VAL,MON
# MON,NLN,VAL,APT,OSS,TRO,MON
# MON,OSC,OSE,APT,OSS,TRO,MON
# MON,OSO,VFB,APT,OSS,TRO,MON
# MON,TEN,TEQ,TRB,TRC,APT,OSS,TRO,MON
# MON,ASL,DSS,DAB,MON
# MON,KVB,ASL,DAB,MON
# MON,DAB,ASL,MID,MON
# MON,DAB,ASL,NLN,VAL,MON
# MON,DAB,ASL,OSO,VFB,MON
# MON,DAB,ASL,TRO,MON
# MON,DSS,ASL,KVB,MON
# MON,DSS,ASL,MID,MON
# MON,DSS,ASL,NLN,VAL,MON
# MON,DSS,ASL,OSC,OSE,MON
# MON,DSS,ASL,OSO,VFB,MON
# MON,DSS,ASL,TRO,MON
# MON,KVB,ASL,MID,MON
# MON,KVB,ASL,NLN,VAL,MON
# MON,KVB,ASL,OSC,OSE,MON
# MON,KVB,ASL,OSO,VFB,MON
# MON,KVB,ASL,TEN,TEQ,TRB,TRC,MON
# MON,KVB,ASL,TRO,MON
# MON,MID,ASL,NLN,VAL,MON
# MON,OSC,OSE,MID,ASL,MON
# MON,OSO,VFB,MID,ASL,MON
# MON,ASL,MID,TEN,TEQ,TRB,TRC,MON
# MON,ASL,MID,TRO,MON
# MON,NLN,VAL,ASL,OSC,OSE,MON
# MON,NLN,VAL,ASL,OSO,VFB,MON
# MON,NLN,VAL,ASL,TRO,MON
# MON,ASL,OSC,OSE,OSO,VFB,MON
# MON,ASL,OSC,OSE,TRO,MON
# MON,ASL,OSO,VFB,TRO,MON
# MON,TEN,TEQ,TRB,TRC,ASL,TRO,MON
# MON,DAB,DSS,KVB,MON
# MON,DAB,DSS,MID,MON
# MON,DAB,DSS,NLN,VAL,MON
# MON,DAB,DSS,OSO,VFB,MON
# MON,DAB,DSS,TRO,MON
# MON,MID,KVB,DAB,MON
# MON,NLN,VAL,KVB,DAB,MON
# MON,DAB,KVB,OSC,OSE,MON
# MON,DAB,KVB,OSO,VFB,MON
# MON,DAB,KVB,TRO,MON
# MON,DAB,NLN,VAL,MID,MON
# MON,DAB,MID,OSC,OSE,MON
# MON,DAB,MID,OSO,VFB,MON
# MON,DAB,MID,TRO,MON
# MON,DAB,NLN,VAL,OSO,VFB,MON
# MON,DAB,NLN,VAL,TRO,MON
# MON,DAB,OSC,OSE,TRO,MON
# MON,DAB,OSO,VFB,TRO,MON
# MON,DSS,KVB,MID,MON
# MON,DSS,NLN,VAL,KVB,MON
# MON,OSC,OSE,KVB,DSS,MON
# MON,DSS,KVB,OSO,VFB,MON
# MON,DSS,KVB,TEN,TEQ,TRB,TRC,MON
# MON,TRO,KVB,DSS,MON
# MON,DSS,NLN,VAL,MID,MON
# MON,DSS,MID,OSC,OSE,MON
# MON,DSS,MID,OSO,VFB,MON
# MON,DSS,MID,TEN,TEQ,TRB,TRC,MON
# MON,DSS,MID,TRO,MON
# MON,DSS,NLN,VAL,OSO,VFB,MON
# MON,DSS,NLN,VAL,TRO,MON
# MON,DSS,OSC,OSE,TRO,MON
# MON,TRO,OSO,VFB,DSS,MON
# MON,DSS,TEN,TEQ,TRB,TRC,TRO,MON
# MON,KVB,GFA,GFB,GFC,MID,MON
# MON,GFA,GFB,GFC,KVB,TRO,MON
# MON,GFA,GFB,GFC,MID,TRO,MON
# MON,KVB,NLN,VAL,MID,MON
# MON,KVB,MID,OSC,OSE,MON
# MON,KVB,MID,OSO,VFB,MON
# MON,KVB,MID,TEN,TEQ,TRB,TRC,MON
# MON,KVB,MID,TRO,MON
# MON,OSC,OSE,NLN,VAL,KVB,MON
# MON,KVB,NLN,VAL,OSO,VFB,MON
# MON,TEN,TEQ,TRB,TRC,NLN,VAL,KVB,MON
# MON,KVB,NLN,VAL,TRO,MON
# MON,KVB,OSO,VFB,OSC,OSE,MON
# MON,KVB,OSC,OSE,TRO,MON
# MON,KVB,OSO,VFB,TEN,TEQ,TRB,TRC,MON
# MON,KVB,OSO,VFB,TRO,MON
# MON,KVB,TEN,TEQ,TRB,TRC,TRO,MON
# MON,OSC,OSE,MID,NLN,VAL,MON
# MON,NLN,VAL,MID,OSO,VFB,MON
# MON,NLN,VAL,MID,TEN,TEQ,TRB,TRC,MON
# MON,NLN,VAL,MID,TRO,MON
# MON,OSC,OSE,MID,OSO,VFB,MON
# MON,MID,OSC,OSE,TRO,MON
# MON,MID,OSO,VFB,TEN,TEQ,TRB,TRC,MON
# MON,OSO,VFB,MID,TRO,MON
# MON,TEN,TEQ,TRB,TRC,MID,TRO,MON
# MON,NLN,VAL,OSC,OSE,TRO,MON
# MON,NLN,VAL,OSO,VFB,TRO,MON
# MON,TEN,TEQ,TRB,TRC,NLN,VAL,TRO,MON
# MON,OSO,VFB,OSC,OSE,TRO,MON
# MON,TEN,TEQ,TRB,TRC,OSO,VFB,TRO,MON
# MON,DSS,ASL,KVB,APT,OSS,MON
# MON,APT,OSS,MID,ASL,DSS,MON
# MON,DSS,ASL,APT,OSS,TRO,MON
# MON,APT,OSS,MID,ASL,KVB,MON
# MON,KVB,NLN,VAL,ASL,APT,OSS,MON
# MON,KVB,ASL,OSO,VFB,APT,OSS,MON
# MON,KVB,ASL,APT,OSS,TRO,MON
# MON,APT,OSS,MID,ASL,NLN,VAL,MON
# MON,APT,OSS,MID,ASL,OSO,VFB,MON
# MON,TRO,APT,OSS,MID,ASL,MON
# MON,NLN,VAL,ASL,APT,OSS,TRO,MON
# MON,OSO,VFB,ASL,APT,OSS,TRO,MON
# MON,APT,OSS,MID,KVB,DAB,MON
# MON,DAB,KVB,APT,OSS,TRO,MON
# MON,DAB,MID,APT,OSS,TRO,MON
# MON,APT,OSS,MID,KVB,DSS,MON
# MON,DSS,KVB,APT,OSS,TRO,MON
# MON,DSS,MID,APT,OSS,TRO,MON
# MON,DSS,NLN,VAL,APT,OSS,TRO,MON
# MON,DSS,OSO,VFB,APT,OSS,TRO,MON
# MON,KVB,NLN,VAL,MID,APT,OSS,MON
# MON,APT,OSS,MID,KVB,OSO,VFB,MON
# MON,KVB,MID,APT,OSS,TRO,MON
# MON,KVB,NLN,VAL,APT,OSS,TRO,MON
# MON,KVB,OSC,OSE,APT,OSS,TRO,MON
# MON,KVB,OSO,VFB,APT,OSS,TRO,MON
# MON,NLN,VAL,MID,APT,OSS,TRO,MON
# MON,OSC,OSE,MID,APT,OSS,TRO,MON
# MON,OSO,VFB,MID,APT,OSS,TRO,MON
# MON,TRO,APT,OSS,OSO,VFB,NLN,VAL,MON
# MON,DAB,KVB,ASL,MID,MON
# MON,DAB,KVB,ASL,TRO,MON
# MON,DAB,ASL,MID,TRO,MON
# MON,KVB,DSS,ASL,MID,MON
# MON,DSS,ASL,NLN,VAL,KVB,MON
# MON,DSS,ASL,KVB,OSO,VFB,MON
# MON,DSS,ASL,KVB,TRO,MON
# MON,DSS,ASL,NLN,VAL,MID,MON
# MON,DSS,ASL,MID,OSO,VFB,MON
# MON,DSS,ASL,MID,TRO,MON
# MON,DSS,ASL,NLN,VAL,TRO,MON
# MON,DSS,ASL,OSO,VFB,TRO,MON
# MON,KVB,NLN,VAL,ASL,MID,MON
# MON,KVB,ASL,MID,OSC,OSE,MON
# MON,KVB,ASL,MID,OSO,VFB,MON
# MON,KVB,ASL,MID,TRO,MON
# MON,KVB,NLN,VAL,ASL,OSO,VFB,MON
# MON,KVB,ASL,NLN,VAL,TRO,MON
# MON,KVB,ASL,OSC,OSE,TRO,MON
# MON,KVB,ASL,OSO,VFB,TRO,MON
# MON,NLN,VAL,ASL,MID,OSO,VFB,MON
# MON,NLN,VAL,ASL,MID,TRO,MON
# MON,ASL,MID,OSC,OSE,TRO,MON
# MON,ASL,MID,OSO,VFB,TRO,MON
# MON,NLN,VAL,ASL,OSO,VFB,TRO,MON
# MON,DAB,DSS,KVB,MID,MON
# MON,DAB,DSS,KVB,TRO,MON
# MON,DAB,DSS,MID,TRO,MON
# MON,MID,NLN,VAL,KVB,DAB,MON
# MON,DAB,KVB,MID,OSO,VFB,MON
# MON,DAB,KVB,MID,TRO,MON
# MON,DAB,KVB,NLN,VAL,TRO,MON
# MON,DAB,KVB,OSO,VFB,TRO,MON
# MON,DAB,NLN,VAL,MID,TRO,MON
# MON,DAB,MID,OSO,VFB,TRO,MON
# MON,DSS,KVB,NLN,VAL,MID,MON
# MON,OSO,VFB,MID,KVB,DSS,MON
# MON,DSS,KVB,MID,TRO,MON
# MON,DSS,NLN,VAL,KVB,TRO,MON
# MON,DSS,KVB,OSC,OSE,TRO,MON
# MON,DSS,KVB,OSO,VFB,TRO,MON
# MON,DSS,NLN,VAL,MID,TRO,MON
# MON,DSS,MID,OSC,OSE,TRO,MON
# MON,DSS,MID,OSO,VFB,TRO,MON
# MON,DSS,NLN,VAL,OSO,VFB,TRO,MON
# MON,KVB,NLN,VAL,MID,OSC,OSE,MON
# MON,KVB,NLN,VAL,MID,OSO,VFB,MON
# MON,KVB,NLN,VAL,MID,TRO,MON
# MON,KVB,MID,OSC,OSE,OSO,VFB,MON
# MON,KVB,MID,OSC,OSE,TRO,MON
# MON,KVB,MID,OSO,VFB,TRO,MON
# MON,TEN,TEQ,TRB,TRC,KVB,MID,TRO,MON
# MON,KVB,NLN,VAL,OSC,OSE,TRO,MON
# MON,KVB,NLN,VAL,OSO,VFB,TRO,MON
# MON,KVB,OSO,VFB,OSC,OSE,TRO,MON
# MON,NLN,VAL,MID,OSC,OSE,TRO,MON
# MON,NLN,VAL,MID,OSO,VFB,TRO,MON
# MON,OSO,VFB,MID,OSC,OSE,TRO,MON
# MON,KVB,ASL,MID,APT,OSS,TRO,MON
# MON,TRO,APT,OSS,MID,KVB,DSS,MON
# MON,KVB,NLN,VAL,MID,APT,OSS,TRO,MON
# MON,OSO,VFB,KVB,MID,APT,OSS,TRO,MON
# MON,KVB,DSS,ASL,MID,TRO,MON
# MON,KVB,NLN,VAL,ASL,MID,TRO,MON
# MON,KVB,ASL,MID,OSO,VFB,TRO,MON
# MON,DSS,KVB,NLN,VAL,MID,TRO,MON
# MON,DSS,KVB,MID,OSO,VFB,TRO,MON
# MON,KVB,NLN,VAL,MID,OSO,VFB,TRO,MON

# %%
def find_matching_row(csv_file, names):
    with open(csv_file, 'r', newline='') as file:
        reader = csv.reader(file)
        for row_number, row in enumerate(reader, start=1):
            if set(names).issubset(row):
                return row_number, row
    return None, None

def get_platform_visits(platform):
    with open(f'{non_cluster}/output_platforms_visits.csv', 'r', newline='') as file:
        reader = csv.DictReader(file, delimiter=';')
        for row in reader:
            if row['platform'] == platform:
                return int(row['visits'])
    return None

def remove_lowest_demand_platforms(row):
    visits_count = {}
    for platform in row:
        if platform != 'route_number' and platform != 'total_distance':
            visits = get_platform_visits(platform)
            if visits is not None:
                if visits in visits_count:
                    visits_count[visits].append(platform)
                else:
                    visits_count[visits] = [platform]
    
    if visits_count:
        lowest_demand = min(visits_count)
        for platform in visits_count[lowest_demand]:
            row.remove(platform)

def compute_weights(route_data):
    visits = [get_platform_visits(platform) for platform in route_data if platform not in ['route_number', 'total_distance']]
    visits = [v for v in visits if v is not None]  
    if not visits:
        return [0]
    
    min_visit = min(visits)
    max_visit = max(visits)
    if max_visit > 0:
        return min_visit / max_visit
    return 0

def compute_weight_incrementally(current_min, previous_min, max_visit):
    if max_visit > 0:
        return (current_min - previous_min) / max_visit
    return 0

def normalize_weights(weights):
    total = sum(weights)
    return [w / total for w in weights]

def compute_min_visit(row_data):
    visits = [get_platform_visits(platform) for platform in row_data if platform not in ['route_number', 'total_distance']]
    visits = [v for v in visits if v is not None] 
    return min(visits) if visits else float('inf')  

def count_unique_visits(row):
    unique_visits = set()
    for platform in row:
        if platform != 'route_number' and platform != 'total_distance':
            visits = get_platform_visits(platform)
            if visits is not None:
                unique_visits.add(visits)
    return len(unique_visits)

def print_row_and_distance(csv_file, row_number):
    if row_number:
        with open(csv_file, 'r', newline='') as file:
            reader = csv.reader(file)
            for i, row_num in enumerate(reader, start=1):
                if i == row_number:
                    print(f"Row number: {row_number}")
                    print("Row:", row_num)
                    break
        with open(f'{non_cluster}/distances.csv', 'r', newline='') as distance_file:
            reader = csv.reader(distance_file)
            for i, row_dist in enumerate(reader, start=1):
                if i == row_number + 1:  
                    print("Distance Row:", row_dist)
                    break
        with open(f'{non_cluster}/demand.csv', 'r', newline='') as distance_file:
            reader = csv.reader(distance_file)
            for i, row_demand in enumerate(reader, start=1):
                if i == row_number + 1:  
                    print("Demand Row:", row_demand)
                    break
    return row_dist, row_demand

def process_routes():
    with open(f'{mappenavn}/distances.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Distances'])
    with open(f'{mappenavn}/demand.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Demand'])

    non_matching_rows = []
    weighted_distances = []
    weighted_demands = []
    with open(f'{mappenavn}/processed_routes.csv', 'r', newline='') as file:
        reader = csv.reader(file)
        for row in reader:
            total_weighted_distance = 0  
            total_weighted_demand = 0  
            row_number, original_row_data = find_matching_row(f'{non_cluster}/routes.csv', row)
            if row_number is not None:
                print("Processing row:", row)  
                print("Found matching row:", row_number)  
                distance, demand = print_row_and_distance(f'{non_cluster}/routes.csv', row_number)

                visits = [get_platform_visits(platform) for platform in original_row_data if platform not in ['route_number', 'total_distance']]
                visits = [v for v in visits if v is not None]  
                print("Visits:", visits)  

                if visits:
                    max_visit = max(visits)
                    min_visit = min(visits)
                    weights = [min_visit / max_visit if max_visit > 0 else 0]

                    unique_visits_count = count_unique_visits(original_row_data) - 1
                    routes_found = 0
                    row_data = original_row_data[:]
                    previous_min = min_visit

                    weighted_distance = float(distance[0]) * weights[0]  
                    total_weighted_distance += weighted_distance

                    weighted_demand = float(demand[0]) * weights[0]  
                    total_weighted_demand += weighted_demand

                    while len(row_data) > 2 and routes_found < unique_visits_count:
                        remove_lowest_demand_platforms(row_data)
                        row_number, new_row_data = find_matching_row(f'{non_cluster}/routes.csv', row_data)
                        if row_number is not None:
                            print("Found matching row in loop:", row_number)  
                            print_row_and_distance(f'{non_cluster}/routes.csv', row_number)
                            current_min = compute_min_visit(new_row_data)
                            if current_min != float('inf'): 
                                weight = compute_weight_incrementally(current_min, previous_min, max_visit)
                                weights.append(weight)
                                previous_min = current_min
                                with open(f'{non_cluster}/distances.csv', 'r', newline='') as distance_file:
                                    reader = csv.reader(distance_file)
                                    for i, row_distance in enumerate(reader, start=1):
                                        if i == row_number + 1:  
                                            weighted_distance = float(row_distance[0]) * weight  
                                            total_weighted_distance += weighted_distance  
                                            weighted_distances.append(weighted_distance)
                                with open(f'{non_cluster}/demand.csv', 'r', newline='') as demand_file:
                                    reader = csv.reader(demand_file)
                                    for i, row_demand in enumerate(reader, start=1):
                                        if i == row_number + 1:  
                                            weighted_demand = float(row_demand[0]) * weight  
                                            total_weighted_demand += weighted_demand  
                                            weighted_demands.append(weighted_demand)

                            row_data = new_row_data[:]
                            routes_found += 1
                    
                    total_weight = sum(weights)
                    if total_weight > 0:
                        normalized_weights = [weight / total_weight for weight in weights]
                        for route, weight in zip(range(len(normalized_weights)), normalized_weights):
                            print(f"Route {route + 1} Weight: {weight}")
                    
            print(f"Total Weighted Distance for this route: {total_weighted_distance}")
            print(f"Total Weighted Demand for this route: {total_weighted_demand}")

            with open(f'{mappenavn}/distances.csv', 'a', newline='') as file:
                writer = csv.writer(file)
                writer.writerow([total_weighted_distance])

            with open(f'{mappenavn}/demand.csv', 'a', newline='') as file:
                writer = csv.writer(file)
                writer.writerow([total_weighted_demand])

process_routes()
# Out:
# Processing row: ['MON', 'APT', 'OSS', 'MON']
# Found matching row: 1426
# Row number: 1426
# Row: ['MON', 'APT', 'OSS', 'MON']
# Distance Row: ['130.79000000000002']
# Demand Row: ['36.0']
# Visits: [2, 3]
# Found matching row in loop: 1413
# Row number: 1413
# Row: ['MON', 'OSS', 'MON']
# Distance Row: ['64.36']
# Demand Row: ['18.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 108.64666666666668
# Total Weighted Demand for this route: 30.0
# Processing row: ['MON', 'ASL', 'MON']
# Found matching row: 1
# Row number: 1
# Row: ['MON', 'ASL', 'MON']
# Distance Row: ['85.82']
# Demand Row: ['40.0']
# Visits: [3]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 85.82
# Total Weighted Demand for this route: 40.0
# Processing row: ['MON', 'DAB', 'MON']
# Found matching row: 2
# Row number: 2
# Row: ['MON', 'DAB', 'MON']
# Distance Row: ['168.12']
# Demand Row: ['29.0']
# Visits: [4]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 168.12
# Total Weighted Demand for this route: 29.0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'DSS', 'MON']
# Found matching row: 4
# Row number: 4
# Row: ['MON', 'DSS', 'MON']
# Distance Row: ['144.52']
# Demand Row: ['32.0']
# Visits: [3]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 144.52
# Total Weighted Demand for this route: 32.0
# Processing row: ['MON', 'GFA', 'GFB', 'GFC', 'MON']
# Found matching row: 407
# Row number: 407
# Row: ['MON', 'GFA', 'GFB', 'GFC', 'MON']
# Distance Row: ['146.81']
# Demand Row: ['68.0']
# Visits: [4, 3, 3]
# Found matching row in loop: 5
# Row number: 5
# Row: ['MON', 'GFA', 'MON']
# Distance Row: ['144.32']
# Demand Row: ['22.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 146.1875
# Total Weighted Demand for this route: 56.5
# Processing row: ['MON', 'KVB', 'MON']
# Found matching row: 8
# Row number: 8
# Row: ['MON', 'KVB', 'MON']
# Distance Row: ['132.78']
# Demand Row: ['25.0']
# Visits: [2]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 132.78
# Total Weighted Demand for this route: 25.0
# Processing row: ['MON', 'MID', 'MON']
# Found matching row: 1408
# Row number: 1408
# Row: ['MON', 'MID', 'MON']
# Distance Row: ['132.78']
# Demand Row: ['25.0']
# Visits: [2]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 132.78
# Total Weighted Demand for this route: 25.0
# Processing row: ['MON', 'NLN', 'VAL', 'MON']
# Found matching row: 105
# Row number: 105
# Row: ['MON', 'NLN', 'VAL', 'MON']
# Distance Row: ['168.63']
# Demand Row: ['54.0']
# Visits: [3, 1]
# Found matching row in loop: 9
# Row number: 9
# Row: ['MON', 'NLN', 'MON']
# Distance Row: ['165.4']
# Demand Row: ['25.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 166.47666666666666
# Total Weighted Demand for this route: 34.666666666666664
# Processing row: ['MON', 'OSC', 'OSE', 'MON']
# Found matching row: 1474
# Row number: 1474
# Row: ['MON', 'OSC', 'OSE', 'MON']
# Distance Row: ['111.2']
# Demand Row: ['32.0']
# Visits: [2, 5]
# Found matching row in loop: 1411
# Row number: 1411
# Row: ['MON', 'OSE', 'MON']
# Distance Row: ['98.6']
# Demand Row: ['14.0']
# Route 1 Weight: 0.4
# Route 2 Weight: 0.6
# Total Weighted Distance for this route: 103.64
# Total Weighted Demand for this route: 21.200000000000003
# Processing row: ['MON', 'OSO', 'VFB', 'MON']
# Found matching row: 1494
# Row number: 1494
# Row: ['MON', 'OSO', 'VFB', 'MON']
# Distance Row: ['121.95']
# Demand Row: ['36.0']
# Visits: [3, 4]
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 139.78750000000002
# Total Weighted Demand for this route: 37.75
# Processing row: ['MON', 'TEN', 'TEQ', 'TRB', 'TRC', 'MON']
# Found matching row: 6764
# Row number: 6764
# Row: ['MON', 'TEN', 'TRB', 'TEQ', 'TRC', 'MON']
# Distance Row: ['75.42']
# Demand Row: ['69.0']
# Visits: [4, 1, 4, 2]
# Found matching row in loop: 5407
# Row number: 5407
# Row: ['MON', 'TRC', 'TEQ', 'TEN', 'MON']
# Distance Row: ['75.23']
# Demand Row: ['47.0']
# Found matching row in loop: 4965
# Row number: 4965
# Row: ['MON', 'TEN', 'TEQ', 'MON']
# Distance Row: ['67.32']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.5
# Total Weighted Distance for this route: 71.32249999999999
# Total Weighted Demand for this route: 49.0
# Processing row: ['MON', 'TRO', 'MON']
# Found matching row: 1416
# Row number: 1416
# Row: ['MON', 'TRO', 'MON']
# Distance Row: ['130.08']
# Demand Row: ['11.0']
# Visits: [2]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 130.08
# Total Weighted Demand for this route: 11.0
# Processing row: ['MON', 'ASL', 'APT', 'OSS', 'MON']
# Found matching row: 1516
# Row number: 1516
# Row: ['MON', 'APT', 'OSS', 'ASL', 'MON']
# Distance Row: ['196.41000000000003']
# Demand Row: ['61.0']
# Visits: [2, 3, 3]
# Found matching row in loop: 1438
# Row number: 1438
# Row: ['MON', 'ASL', 'OSS', 'MON']
# Distance Row: ['157.51999999999998']
# Demand Row: ['43.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 183.44666666666666
# Total Weighted Demand for this route: 55.0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'APT', 'OSS', 'KVB', 'MON']
# Found matching row: 1527
# Row number: 1527
# Row: ['MON', 'APT', 'OSS', 'KVB', 'MON']
# Distance Row: ['178.29000000000002']
# Demand Row: ['50.0']
# Visits: [2, 3, 2]
# Found matching row in loop: 1413
# Row number: 1413
# Row: ['MON', 'OSS', 'MON']
# Distance Row: ['64.36']
# Demand Row: ['18.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 140.31333333333333
# Total Weighted Demand for this route: 39.33333333333333
# Processing row: ['MON', 'APT', 'OSS', 'MID', 'MON']
# Found matching row: 1537
# Row number: 1537
# Row: ['MON', 'MID', 'APT', 'OSS', 'MON']
# Distance Row: ['168.59']
# Demand Row: ['50.0']
# Visits: [2, 2, 3]
# Found matching row in loop: 1413
# Row number: 1413
# Row: ['MON', 'OSS', 'MON']
# Distance Row: ['64.36']
# Demand Row: ['18.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 133.84666666666666
# Total Weighted Demand for this route: 39.33333333333333
# Processing row: ['MON', 'APT', 'OSS', 'NLN', 'VAL', 'MON']
# Found matching row: 2061
# Row number: 2061
# Row: ['MON', 'APT', 'OSS', 'NLN', 'VAL', 'MON']
# Distance Row: ['183.48000000000002']
# Demand Row: ['79.0']
# Visits: [2, 3, 3, 1]
# Found matching row in loop: 1546
# Row number: 1546
# Row: ['MON', 'APT', 'OSS', 'NLN', 'MON']
# Distance Row: ['180.85000000000002']
# Demand Row: ['61.0']
# Found matching row in loop: 1468
# Row number: 1468
# Row: ['MON', 'NLN', 'OSS', 'MON']
# Distance Row: ['138.01']
# Demand Row: ['43.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 167.44666666666666
# Total Weighted Demand for this route: 61.0
# Processing row: ['MON', 'APT', 'OSS', 'OSC', 'OSE', 'MON']
# Found matching row: 2074
# Row number: 2074
# Row: ['MON', 'APT', 'OSS', 'OSE', 'OSC', 'MON']
# Distance Row: ['139.41']
# Demand Row: ['90.0']
# Visits: [2, 3, 5, 2]
# Found matching row in loop: 1483
# Row number: 1483
# Row: ['MON', 'OSE', 'OSS', 'MON']
# Distance Row: ['112.81']
# Demand Row: ['54.0']
# Found matching row in loop: 1411
# Row number: 1411
# Row: ['MON', 'OSE', 'MON']
# Distance Row: ['98.6']
# Demand Row: ['14.0']
# Route 1 Weight: 0.4
# Route 2 Weight: 0.2
# Route 3 Weight: 0.4
# Total Weighted Distance for this route: 117.766
# Total Weighted Demand for this route: 52.4
# Processing row: ['MON', 'APT', 'OSS', 'OSO', 'VFB', 'MON']
# Found matching row: 2126
# Row number: 2126
# Row: ['MON', 'APT', 'OSS', 'OSO', 'VFB', 'MON']
# Distance Row: ['142.48000000000002']
# Demand Row: ['72.0']
# Visits: [2, 3, 3, 4]
# Found matching row in loop: 1843
# Row number: 1843
# Row: ['MON', 'OSS', 'OSO', 'VFB', 'MON']
# Distance Row: ['98.88']
# Demand Row: ['54.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 144.28500000000003
# Total Weighted Demand for this route: 60.25
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'APT', 'OSS', 'TRO', 'MON']
# Found matching row: 1575
# Row number: 1575
# Row: ['MON', 'APT', 'OSS', 'TRO', 'MON']
# Distance Row: ['176.91000000000003']
# Demand Row: ['47.0']
# Visits: [2, 3, 2]
# Found matching row in loop: 1413
# Row number: 1413
# Row: ['MON', 'OSS', 'MON']
# Distance Row: ['64.36']
# Demand Row: ['18.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 139.39333333333335
# Total Weighted Demand for this route: 37.33333333333333
# Processing row: ['MON', 'ASL', 'DAB', 'MON']
# Found matching row: 16
# Row number: 16
# Row: ['MON', 'ASL', 'DAB', 'MON']
# Distance Row: ['182.0']
# Demand Row: ['54.0']
# Visits: [3, 4]
# Found matching row in loop: 2
# Row number: 2
# Row: ['MON', 'DAB', 'MON']
# Distance Row: ['168.12']
# Demand Row: ['29.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 178.53
# Total Weighted Demand for this route: 47.75
# Processing row: ['MON', 'ASL', 'DSS', 'MON']
# Found matching row: 18
# Row number: 18
# Row: ['MON', 'ASL', 'DSS', 'MON']
# Distance Row: ['156.45']
# Demand Row: ['57.0']
# Visits: [3, 3]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 156.45
# Total Weighted Demand for this route: 57.0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'ASL', 'KVB', 'MON']
# Found matching row: 22
# Row number: 22
# Row: ['MON', 'ASL', 'KVB', 'MON']
# Distance Row: ['152.51']
# Demand Row: ['50.0']
# Visits: [3, 2]
# Found matching row in loop: 1
# Row number: 1
# Row: ['MON', 'ASL', 'MON']
# Distance Row: ['85.82']
# Demand Row: ['40.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 130.27999999999997
# Total Weighted Demand for this route: 46.66666666666666
# Processing row: ['MON', 'ASL', 'MID', 'MON']
# Found matching row: 1433
# Row number: 1433
# Row: ['MON', 'ASL', 'MID', 'MON']
# Distance Row: ['152.51']
# Demand Row: ['50.0']
# Visits: [3, 2]
# Found matching row in loop: 1
# Row number: 1
# Row: ['MON', 'ASL', 'MON']
# Distance Row: ['85.82']
# Demand Row: ['40.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 130.27999999999997
# Total Weighted Demand for this route: 46.66666666666666
# Processing row: ['MON', 'ASL', 'NLN', 'VAL', 'MON']
# Found matching row: 196
# Row number: 196
# Row: ['MON', 'NLN', 'ASL', 'VAL', 'MON']
# Distance Row: ['171.44']
# Demand Row: ['79.0']
# Visits: [3, 3, 1]
# Found matching row in loop: 23
# Row number: 23
# Row: ['MON', 'ASL', 'NLN', 'MON']
# Distance Row: ['170.58']
# Demand Row: ['50.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 170.86666666666667
# Total Weighted Demand for this route: 59.66666666666666
# Processing row: ['MON', 'ASL', 'OSC', 'OSE', 'MON']
# Found matching row: 1618
# Row number: 1618
# Row: ['MON', 'ASL', 'OSC', 'OSE', 'MON']
# Distance Row: ['168.34']
# Demand Row: ['57.0']
# Visits: [3, 2, 5]
# Found matching row in loop: 1436
# Row number: 1436
# Row: ['MON', 'ASL', 'OSE', 'MON']
# Distance Row: ['160.62']
# Demand Row: ['39.0']
# Found matching row in loop: 1411
# Row number: 1411
# Row: ['MON', 'OSE', 'MON']
# Distance Row: ['98.6']
# Demand Row: ['14.0']
# Route 1 Weight: 0.4
# Route 2 Weight: 0.2
# Route 3 Weight: 0.4
# Total Weighted Distance for this route: 138.9
# Total Weighted Demand for this route: 36.2
# Processing row: ['MON', 'ASL', 'OSO', 'VFB', 'MON']
# Found matching row: 1638
# Row number: 1638
# Row: ['MON', 'ASL', 'VFB', 'OSO', 'MON']
# Distance Row: ['185.57']
# Demand Row: ['61.0']
# Visits: [3, 4, 3]
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 187.5025
# Total Weighted Demand for this route: 56.5
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'ASL', 'TRO', 'MON']
# Found matching row: 1441
# Row number: 1441
# Row: ['MON', 'ASL', 'TRO', 'MON']
# Distance Row: ['152.46']
# Demand Row: ['36.0']
# Visits: [3, 2]
# Found matching row in loop: 1
# Row number: 1
# Row: ['MON', 'ASL', 'MON']
# Distance Row: ['85.82']
# Demand Row: ['40.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 130.24666666666667
# Total Weighted Demand for this route: 37.33333333333333
# Processing row: ['MON', 'DSS', 'DAB', 'MON']
# Found matching row: 31
# Row number: 31
# Row: ['MON', 'DSS', 'DAB', 'MON']
# Distance Row: ['150.09']
# Demand Row: ['72.0']
# Visits: [3, 4]
# Found matching row in loop: 2
# Row number: 2
# Row: ['MON', 'DAB', 'MON']
# Distance Row: ['168.12']
# Demand Row: ['29.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 154.5975
# Total Weighted Demand for this route: 61.25
# Processing row: ['MON', 'KVB', 'DAB', 'MON']
# Found matching row: 35
# Row number: 35
# Row: ['MON', 'KVB', 'DAB', 'MON']
# Distance Row: ['142.7']
# Demand Row: ['65.0']
# Visits: [2, 4]
# Found matching row in loop: 2
# Row number: 2
# Row: ['MON', 'DAB', 'MON']
# Distance Row: ['168.12']
# Demand Row: ['29.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.5
# Total Weighted Distance for this route: 155.41
# Total Weighted Demand for this route: 47.0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'DAB', 'NLN', 'VAL', 'MON']
# Found matching row: 270
# Row number: 270
# Row: ['MON', 'DAB', 'VAL', 'NLN', 'MON']
# Distance Row: ['172.74']
# Demand Row: ['94.0']
# Visits: [4, 1, 3]
# Found matching row in loop: 36
# Row number: 36
# Row: ['MON', 'DAB', 'NLN', 'MON']
# Distance Row: ['169.51']
# Demand Row: ['65.0']
# Found matching row in loop: 2
# Row number: 2
# Row: ['MON', 'DAB', 'MON']
# Distance Row: ['168.12']
# Demand Row: ['29.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 169.97
# Total Weighted Demand for this route: 63.25
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'DSS', 'KVB', 'MON']
# Found matching row: 58
# Row number: 58
# Row: ['MON', 'DSS', 'KVB', 'MON']
# Distance Row: ['181.39']
# Demand Row: ['54.0']
# Visits: [3, 2]
# Found matching row in loop: 4
# Row number: 4
# Row: ['MON', 'DSS', 'MON']
# Distance Row: ['144.52']
# Demand Row: ['32.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 169.09999999999997
# Total Weighted Demand for this route: 46.666666666666664
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'DSS', 'NLN', 'VAL', 'MON']
# Found matching row: 391
# Row number: 391
# Row: ['MON', 'DSS', 'NLN', 'VAL', 'MON']
# Distance Row: ['189.16000000000003']
# Demand Row: ['83.0']
# Visits: [3, 3, 1]
# Found matching row in loop: 59
# Row number: 59
# Row: ['MON', 'DSS', 'NLN', 'MON']
# Distance Row: ['185.93']
# Demand Row: ['54.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 187.00666666666666
# Total Weighted Demand for this route: 63.666666666666664
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'GFA', 'GFB', 'GFC', 'KVB', 'MON']
# Found matching row: 1021
# Row number: 1021
# Row: ['MON', 'GFC', 'GFB', 'GFA', 'KVB', 'MON']
# Distance Row: ['147.95999999999998']
# Demand Row: ['97.0']
# Visits: [3, 3, 4, 2]
# Found matching row in loop: 407
# Row number: 407
# Row: ['MON', 'GFA', 'GFB', 'GFC', 'MON']
# Distance Row: ['146.81']
# Demand Row: ['68.0']
# Found matching row in loop: 5
# Row number: 5
# Row: ['MON', 'GFA', 'MON']
# Distance Row: ['144.32']
# Demand Row: ['22.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 146.7625
# Total Weighted Demand for this route: 71.0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'MID', 'MON']
# Found matching row: 1444
# Row number: 1444
# Row: ['MON', 'KVB', 'MID', 'MON']
# Distance Row: ['134.19']
# Demand Row: ['39.0']
# Visits: [2, 2]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 134.19
# Total Weighted Demand for this route: 39.0
# Processing row: ['MON', 'KVB', 'NLN', 'VAL', 'MON']
# Found matching row: 521
# Row number: 521
# Row: ['MON', 'KVB', 'VAL', 'NLN', 'MON']
# Distance Row: ['168.82']
# Demand Row: ['68.0']
# Visits: [2, 1, 3]
# Found matching row in loop: 93
# Row number: 93
# Row: ['MON', 'KVB', 'NLN', 'MON']
# Distance Row: ['166.13']
# Demand Row: ['39.0']
# Found matching row in loop: 9
# Row number: 9
# Row: ['MON', 'NLN', 'MON']
# Distance Row: ['165.4']
# Demand Row: ['25.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 166.78333333333333
# Total Weighted Demand for this route: 44.0
# Processing row: ['MON', 'KVB', 'OSC', 'OSE', 'MON']
# Found matching row: 1673
# Row number: 1673
# Row: ['MON', 'KVB', 'OSC', 'OSE', 'MON']
# Distance Row: ['147.68']
# Demand Row: ['46.0']
# Visits: [2, 2, 5]
# Found matching row in loop: 1411
# Row number: 1411
# Row: ['MON', 'OSE', 'MON']
# Distance Row: ['98.6']
# Demand Row: ['14.0']
# Route 1 Weight: 0.4
# Route 2 Weight: 0.6
# Total Weighted Distance for this route: 118.232
# Total Weighted Demand for this route: 26.800000000000004
# Processing row: ['MON', 'KVB', 'OSO', 'VFB', 'MON']
# Found matching row: 1693
# Row number: 1693
# Row: ['MON', 'KVB', 'VFB', 'OSO', 'MON']
# Distance Row: ['166.76000000000002']
# Demand Row: ['50.0']
# Visits: [2, 4, 3]
# Found matching row in loop: 1494
# Row number: 1494
# Row: ['MON', 'OSO', 'VFB', 'MON']
# Distance Row: ['121.95']
# Demand Row: ['36.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 162.1925
# Total Weighted Demand for this route: 44.75
# Processing row: ['MON', 'KVB', 'TEN', 'TEQ', 'TRB', 'TRC', 'MON']
# Found matching row: 8141
# Row number: 8141
# Row: ['MON', 'TEN', 'TRB', 'KVB', 'TEQ', 'TRC', 'MON']
# Distance Row: ['136.93']
# Demand Row: ['83.0']
# Visits: [4, 1, 2, 4, 2]
# Found matching row in loop: 6056
# Row number: 6056
# Row: ['MON', 'TEN', 'KVB', 'TEQ', 'TRC', 'MON']
# Distance Row: ['136.06']
# Demand Row: ['61.0']
# Found matching row in loop: 4965
# Row number: 4965
# Row: ['MON', 'TEN', 'TEQ', 'MON']
# Distance Row: ['67.32']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.5
# Total Weighted Distance for this route: 101.9075
# Total Weighted Demand for this route: 56.0
# Processing row: ['MON', 'KVB', 'TRO', 'MON']
# Found matching row: 1452
# Row number: 1452
# Row: ['MON', 'KVB', 'TRO', 'MON']
# Distance Row: ['131.29000000000002']
# Demand Row: ['25.0']
# Visits: [2, 2]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 131.29000000000002
# Total Weighted Demand for this route: 25.0
# Processing row: ['MON', 'MID', 'NLN', 'VAL', 'MON']
# Found matching row: 1716
# Row number: 1716
# Row: ['MON', 'MID', 'NLN', 'VAL', 'MON']
# Distance Row: ['179.76999999999998']
# Demand Row: ['57.0']
# Visits: [2, 3, 1]
# Found matching row in loop: 1455
# Row number: 1455
# Row: ['MON', 'MID', 'NLN', 'MON']
# Distance Row: ['156.6']
# Demand Row: ['32.0']
# Found matching row in loop: 9
# Row number: 9
# Row: ['MON', 'NLN', 'MON']
# Distance Row: ['165.4']
# Demand Row: ['25.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 167.25666666666666
# Total Weighted Demand for this route: 38.0
# Processing row: ['MON', 'MID', 'OSC', 'OSE', 'MON']
# Found matching row: 1718
# Row number: 1718
# Row: ['MON', 'OSC', 'MID', 'OSE', 'MON']
# Distance Row: ['156.99']
# Demand Row: ['46.0']
# Visits: [2, 2, 5]
# Found matching row in loop: 1411
# Row number: 1411
# Row: ['MON', 'OSE', 'MON']
# Distance Row: ['98.6']
# Demand Row: ['14.0']
# Route 1 Weight: 0.4
# Route 2 Weight: 0.6
# Total Weighted Distance for this route: 121.956
# Total Weighted Demand for this route: 26.800000000000004
# Processing row: ['MON', 'MID', 'OSO', 'VFB', 'MON']
# Found matching row: 1738
# Row number: 1738
# Row: ['MON', 'OSO', 'MID', 'VFB', 'MON']
# Distance Row: ['162.32']
# Demand Row: ['50.0']
# Visits: [3, 2, 4]
# Found matching row in loop: 1494
# Row number: 1494
# Row: ['MON', 'OSO', 'VFB', 'MON']
# Distance Row: ['121.95']
# Demand Row: ['36.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 159.9725
# Total Weighted Demand for this route: 44.75
# Processing row: ['MON', 'MID', 'TEN', 'TEQ', 'TRB', 'TRC', 'MON']
# Found matching row: 8541
# Row number: 8541
# Row: ['MON', 'TEN', 'MID', 'TRB', 'TEQ', 'TRC', 'MON']
# Distance Row: ['164.81']
# Demand Row: ['83.0']
# Visits: [4, 2, 1, 4, 2]
# Found matching row in loop: 6276
# Row number: 6276
# Row: ['MON', 'TRC', 'TEQ', 'MID', 'TEN', 'MON']
# Distance Row: ['162.47']
# Demand Row: ['61.0']
# Found matching row in loop: 4965
# Row number: 4965
# Row: ['MON', 'TEN', 'TEQ', 'MON']
# Distance Row: ['67.32']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.5
# Total Weighted Distance for this route: 115.47999999999999
# Total Weighted Demand for this route: 56.0
# Processing row: ['MON', 'MID', 'TRO', 'MON']
# Found matching row: 1462
# Row number: 1462
# Row: ['MON', 'MID', 'TRO', 'MON']
# Distance Row: ['177.44']
# Demand Row: ['25.0']
# Visits: [2, 2]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 177.44
# Total Weighted Demand for this route: 25.0
# Processing row: ['MON', 'NLN', 'VAL', 'OSC', 'OSE', 'MON']
# Found matching row: 2657
# Row number: 2657
# Row: ['MON', 'OSE', 'OSC', 'NLN', 'VAL', 'MON']
# Distance Row: ['163.0']
# Demand Row: ['97.0']
# Visits: [5, 2, 3, 1]
# Found matching row in loop: 1754
# Row number: 1754
# Row: ['MON', 'NLN', 'OSC', 'OSE', 'MON']
# Distance Row: ['151.12']
# Demand Row: ['57.0']
# Found matching row in loop: 1466
# Row number: 1466
# Row: ['MON', 'NLN', 'OSE', 'MON']
# Distance Row: ['142.14999999999998']
# Demand Row: ['39.0']
# Found matching row in loop: 1411
# Row number: 1411
# Row: ['MON', 'OSE', 'MON']
# Distance Row: ['98.6']
# Demand Row: ['14.0']
# Route 1 Weight: 0.2
# Route 2 Weight: 0.2
# Route 3 Weight: 0.2
# Route 4 Weight: 0.4
# Total Weighted Distance for this route: 130.69400000000002
# Total Weighted Demand for this route: 44.20000000000001
# Processing row: ['MON', 'NLN', 'VAL', 'OSO', 'VFB', 'MON']
# Found matching row: 2712
# Row number: 2712
# Row: ['MON', 'OSO', 'VFB', 'NLN', 'VAL', 'MON']
# Distance Row: ['172.51']
# Demand Row: ['83.0']
# Visits: [3, 4, 3, 1]
# Found matching row in loop: 1774
# Row number: 1774
# Row: ['MON', 'NLN', 'VFB', 'OSO', 'MON']
# Distance Row: ['169.55']
# Demand Row: ['61.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 176.22750000000002
# Total Weighted Demand for this route: 62.0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'NLN', 'VAL', 'TRO', 'MON']
# Found matching row: 1787
# Row number: 1787
# Row: ['MON', 'TRO', 'NLN', 'VAL', 'MON']
# Distance Row: ['142.79']
# Demand Row: ['54.0']
# Visits: [2, 3, 1]
# Found matching row in loop: 1471
# Row number: 1471
# Row: ['MON', 'NLN', 'TRO', 'MON']
# Distance Row: ['133.0']
# Demand Row: ['36.0']
# Found matching row in loop: 9
# Row number: 9
# Row: ['MON', 'NLN', 'MON']
# Distance Row: ['165.4']
# Demand Row: ['25.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 147.06333333333333
# Total Weighted Demand for this route: 38.33333333333333
# Processing row: ['MON', 'OSC', 'OSE', 'OSO', 'VFB', 'MON']
# Found matching row: 2738
# Row number: 2738
# Row: ['MON', 'OSE', 'OSC', 'OSO', 'VFB', 'MON']
# Distance Row: ['129.07999999999998']
# Demand Row: ['90.0']
# Visits: [5, 2, 3, 4]
# Found matching row in loop: 1823
# Row number: 1823
# Row: ['MON', 'OSE', 'OSO', 'VFB', 'MON']
# Distance Row: ['123.56']
# Demand Row: ['72.0']
# Found matching row in loop: 1488
# Row number: 1488
# Row: ['MON', 'OSE', 'VFB', 'MON']
# Distance Row: ['129.04']
# Demand Row: ['32.0']
# Found matching row in loop: 1411
# Row number: 1411
# Row: ['MON', 'OSE', 'MON']
# Distance Row: ['98.6']
# Demand Row: ['14.0']
# Route 1 Weight: 0.4
# Route 2 Weight: 0.2
# Route 3 Weight: 0.2
# Route 4 Weight: 0.2
# Total Weighted Distance for this route: 121.87199999999999
# Total Weighted Demand for this route: 59.599999999999994
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'TRO', 'OSC', 'OSE', 'MON']
# Found matching row: 1794
# Row number: 1794
# Row: ['MON', 'OSC', 'OSE', 'TRO', 'MON']
# Distance Row: ['156.79000000000002']
# Demand Row: ['65.0']
# Visits: [2, 5, 2]
# Found matching row in loop: 1411
# Row number: 1411
# Row: ['MON', 'OSE', 'MON']
# Distance Row: ['98.6']
# Demand Row: ['14.0']
# Route 1 Weight: 0.4
# Route 2 Weight: 0.6
# Total Weighted Distance for this route: 121.876
# Total Weighted Demand for this route: 34.4
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'TRO', 'OSO', 'VFB', 'MON']
# Found matching row: 1852
# Row number: 1852
# Row: ['MON', 'TRO', 'OSO', 'VFB', 'MON']
# Distance Row: ['140.99']
# Demand Row: ['43.0']
# Visits: [2, 3, 4]
# Found matching row in loop: 1494
# Row number: 1494
# Row: ['MON', 'OSO', 'VFB', 'MON']
# Distance Row: ['121.95']
# Demand Row: ['36.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 149.3075
# Total Weighted Demand for this route: 41.25
# Processing row: ['MON', 'TEN', 'TEQ', 'TRB', 'TRC', 'TRO', 'MON']
# Found matching row: 9056
# Row number: 9056
# Row: ['MON', 'TRC', 'TEQ', 'TRB', 'TEN', 'TRO', 'MON']
# Distance Row: ['137.59']
# Demand Row: ['87.0']
# Visits: [2, 4, 1, 4, 2]
# Found matching row in loop: 6768
# Row number: 6768
# Row: ['MON', 'TRC', 'TEQ', 'TEN', 'TRO', 'MON']
# Distance Row: ['136.48']
# Demand Row: ['65.0']
# Found matching row in loop: 4965
# Row number: 4965
# Row: ['MON', 'TEN', 'TEQ', 'MON']
# Distance Row: ['67.32']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.5
# Total Weighted Distance for this route: 102.1775
# Total Weighted Demand for this route: 58.0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'ASL', 'APT', 'OSS', 'MON']
# Found matching row: 1879
# Row number: 1879
# Row: ['MON', 'APT', 'OSS', 'ASL', 'KVB', 'MON']
# Distance Row: ['196.73000000000002']
# Demand Row: ['75.0']
# Visits: [2, 3, 3, 2]
# Found matching row in loop: 1438
# Row number: 1438
# Row: ['MON', 'ASL', 'OSS', 'MON']
# Distance Row: ['157.51999999999998']
# Demand Row: ['43.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 183.66
# Total Weighted Demand for this route: 64.33333333333333
# Processing row: ['MON', 'APT', 'OSS', 'MID', 'ASL', 'MON']
# Found matching row: 1889
# Row number: 1889
# Row: ['MON', 'ASL', 'MID', 'APT', 'OSS', 'MON']
# Distance Row: ['203.85000000000002']
# Demand Row: ['75.0']
# Visits: [3, 2, 2, 3]
# Found matching row in loop: 1438
# Row number: 1438
# Row: ['MON', 'ASL', 'OSS', 'MON']
# Distance Row: ['157.51999999999998']
# Demand Row: ['43.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 188.40666666666667
# Total Weighted Demand for this route: 64.33333333333333
# Processing row: ['MON', 'APT', 'OSS', 'ASL', 'NLN', 'VAL', 'MON']
# Found matching row: 2947
# Row number: 2947
# Row: ['MON', 'APT', 'OSS', 'ASL', 'NLN', 'VAL', 'MON']
# Distance Row: ['198.82999999999998']
# Demand Row: ['97.0']
# Visits: [2, 3, 3, 3, 1]
# Found matching row in loop: 1897
# Row number: 1897
# Row: ['MON', 'APT', 'OSS', 'ASL', 'NLN', 'MON']
# Distance Row: ['196.45999999999998']
# Demand Row: ['86.0']
# Found matching row in loop: 1612
# Row number: 1612
# Row: ['MON', 'NLN', 'ASL', 'OSS', 'MON']
# Distance Row: ['157.57']
# Demand Row: ['68.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 184.28666666666663
# Total Weighted Demand for this route: 83.66666666666666
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'APT', 'OSS', 'ASL', 'OSO', 'VFB', 'MON']
# Found matching row: 2975
# Row number: 2975
# Row: ['MON', 'APT', 'OSS', 'OSO', 'VFB', 'ASL', 'MON']
# Distance Row: ['204.60000000000002']
# Demand Row: ['97.0']
# Visits: [2, 3, 3, 4, 3]
# Found matching row in loop: 2337
# Row number: 2337
# Row: ['MON', 'ASL', 'VFB', 'OSO', 'OSS', 'MON']
# Distance Row: ['163.81']
# Demand Row: ['79.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 191.5775
# Total Weighted Demand for this route: 79.0
# Processing row: ['MON', 'ASL', 'APT', 'OSS', 'TRO', 'MON']
# Found matching row: 1925
# Row number: 1925
# Row: ['MON', 'ASL', 'OSS', 'APT', 'TRO', 'MON']
# Distance Row: ['194.16000000000003']
# Demand Row: ['72.0']
# Visits: [3, 3, 2, 2]
# Found matching row in loop: 1438
# Row number: 1438
# Row: ['MON', 'ASL', 'OSS', 'MON']
# Distance Row: ['157.51999999999998']
# Demand Row: ['43.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 181.94666666666666
# Total Weighted Demand for this route: 62.33333333333333
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'APT', 'OSS', 'MID', 'KVB', 'MON']
# Found matching row: 1942
# Row number: 1942
# Row: ['MON', 'OSS', 'APT', 'MID', 'KVB', 'MON']
# Distance Row: ['192.97']
# Demand Row: ['64.0']
# Visits: [3, 2, 2, 2]
# Found matching row in loop: 1413
# Row number: 1413
# Row: ['MON', 'OSS', 'MON']
# Distance Row: ['64.36']
# Demand Row: ['18.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 150.09999999999997
# Total Weighted Demand for this route: 48.666666666666664
# Processing row: ['MON', 'APT', 'OSS', 'NLN', 'VAL', 'KVB', 'MON']
# Found matching row: 3062
# Row number: 3062
# Row: ['MON', 'APT', 'OSS', 'NLN', 'VAL', 'KVB', 'MON']
# Distance Row: ['184.89']
# Demand Row: ['93.0']
# Visits: [2, 3, 3, 1, 2]
# Found matching row in loop: 1951
# Row number: 1951
# Row: ['MON', 'APT', 'OSS', 'NLN', 'KVB', 'MON']
# Distance Row: ['182.26000000000002']
# Demand Row: ['75.0']
# Found matching row in loop: 1468
# Row number: 1468
# Row: ['MON', 'NLN', 'OSS', 'MON']
# Distance Row: ['138.01']
# Demand Row: ['43.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 168.38666666666666
# Total Weighted Demand for this route: 70.33333333333333
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'APT', 'OSS', 'OSO', 'VFB', 'KVB', 'MON']
# Found matching row: 3114
# Row number: 3114
# Row: ['MON', 'KVB', 'VFB', 'OSO', 'OSS', 'APT', 'MON']
# Distance Row: ['184.17000000000002']
# Demand Row: ['86.0']
# Visits: [2, 4, 3, 3, 2]
# Found matching row in loop: 1843
# Row number: 1843
# Row: ['MON', 'OSS', 'OSO', 'VFB', 'MON']
# Distance Row: ['98.88']
# Demand Row: ['54.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 165.13
# Total Weighted Demand for this route: 67.25
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'APT', 'OSS', 'TRO', 'MON']
# Found matching row: 1980
# Row number: 1980
# Row: ['MON', 'KVB', 'OSS', 'APT', 'TRO', 'MON']
# Distance Row: ['178.12']
# Demand Row: ['61.0']
# Visits: [2, 3, 2, 2]
# Found matching row in loop: 1413
# Row number: 1413
# Row: ['MON', 'OSS', 'MON']
# Distance Row: ['64.36']
# Demand Row: ['18.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 140.2
# Total Weighted Demand for this route: 46.666666666666664
# Processing row: ['MON', 'NLN', 'VAL', 'MID', 'APT', 'OSS', 'MON']
# Found matching row: 3161
# Row number: 3161
# Row: ['MON', 'OSS', 'APT', 'MID', 'NLN', 'VAL', 'MON']
# Distance Row: ['198.05']
# Demand Row: ['93.0']
# Visits: [3, 2, 2, 3, 1]
# Found matching row in loop: 1996
# Row number: 1996
# Row: ['MON', 'NLN', 'MID', 'APT', 'OSS', 'MON']
# Distance Row: ['192.87']
# Demand Row: ['75.0']
# Found matching row in loop: 1468
# Row number: 1468
# Row: ['MON', 'NLN', 'OSS', 'MON']
# Distance Row: ['138.01']
# Demand Row: ['43.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 176.31
# Total Weighted Demand for this route: 70.33333333333333
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'APT', 'OSS', 'MID', 'OSO', 'VFB', 'MON']
# Found matching row: 3213
# Row number: 3213
# Row: ['MON', 'OSS', 'APT', 'MID', 'OSO', 'VFB', 'MON']
# Distance Row: ['172.11']
# Demand Row: ['86.0']
# Visits: [3, 2, 2, 3, 4]
# Found matching row in loop: 1843
# Row number: 1843
# Row: ['MON', 'OSS', 'OSO', 'VFB', 'MON']
# Distance Row: ['98.88']
# Demand Row: ['54.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 159.10000000000002
# Total Weighted Demand for this route: 67.25
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'MID', 'APT', 'OSS', 'TRO', 'MON']
# Found matching row: 2025
# Row number: 2025
# Row: ['MON', 'MID', 'APT', 'OSS', 'TRO', 'MON']
# Distance Row: ['192.28000000000003']
# Demand Row: ['61.0']
# Visits: [2, 2, 3, 2]
# Found matching row in loop: 1413
# Row number: 1413
# Row: ['MON', 'OSS', 'MON']
# Distance Row: ['64.36']
# Demand Row: ['18.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 149.64
# Total Weighted Demand for this route: 46.666666666666664
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'NLN', 'VAL', 'APT', 'OSS', 'TRO', 'MON']
# Found matching row: 3282
# Row number: 3282
# Row: ['MON', 'VAL', 'NLN', 'OSS', 'APT', 'TRO', 'MON']
# Distance Row: ['183.73']
# Demand Row: ['90.0']
# Visits: [1, 3, 3, 2, 2]
# Found matching row in loop: 2060
# Row number: 2060
# Row: ['MON', 'NLN', 'OSS', 'APT', 'TRO', 'MON']
# Distance Row: ['178.36']
# Demand Row: ['72.0']
# Found matching row in loop: 1468
# Row number: 1468
# Row: ['MON', 'NLN', 'OSS', 'MON']
# Distance Row: ['138.01']
# Demand Row: ['43.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 166.7
# Total Weighted Demand for this route: 68.33333333333333
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'OSO', 'VFB', 'APT', 'OSS', 'TRO', 'MON']
# Found matching row: 3351
# Row number: 3351
# Row: ['MON', 'TRO', 'APT', 'OSS', 'OSO', 'VFB', 'MON']
# Distance Row: ['181.79']
# Demand Row: ['79.0']
# Visits: [2, 2, 3, 3, 4]
# Found matching row in loop: 1843
# Row number: 1843
# Row: ['MON', 'OSS', 'OSO', 'VFB', 'MON']
# Distance Row: ['98.88']
# Demand Row: ['54.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 163.94
# Total Weighted Demand for this route: 63.75
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'ASL', 'DSS', 'DAB', 'MON']
# Found matching row: 122
# Row number: 122
# Row: ['MON', 'ASL', 'DSS', 'DAB', 'MON']
# Distance Row: ['162.01999999999998']
# Demand Row: ['97.0']
# Visits: [3, 3, 4]
# Found matching row in loop: 2
# Row number: 2
# Row: ['MON', 'DAB', 'MON']
# Distance Row: ['168.12']
# Demand Row: ['29.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 163.545
# Total Weighted Demand for this route: 80.0
# Processing row: ['MON', 'KVB', 'ASL', 'DAB', 'MON']
# Found matching row: 126
# Row number: 126
# Row: ['MON', 'KVB', 'ASL', 'DAB', 'MON']
# Distance Row: ['160.63']
# Demand Row: ['90.0']
# Visits: [2, 3, 4]
# Found matching row in loop: 16
# Row number: 16
# Row: ['MON', 'ASL', 'DAB', 'MON']
# Distance Row: ['182.0']
# Demand Row: ['54.0']
# Found matching row in loop: 2
# Row number: 2
# Row: ['MON', 'DAB', 'MON']
# Distance Row: ['168.12']
# Demand Row: ['29.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 167.845
# Total Weighted Demand for this route: 65.75
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'DSS', 'ASL', 'KVB', 'MON']
# Found matching row: 149
# Row number: 149
# Row: ['MON', 'DSS', 'ASL', 'KVB', 'MON']
# Distance Row: ['188.78']
# Demand Row: ['79.0']
# Visits: [3, 3, 2]
# Found matching row in loop: 18
# Row number: 18
# Row: ['MON', 'ASL', 'DSS', 'MON']
# Distance Row: ['156.45']
# Demand Row: ['57.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 178.00333333333333
# Total Weighted Demand for this route: 71.66666666666666
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'DSS', 'ASL', 'NLN', 'VAL', 'MON']
# Found matching row: 627
# Row number: 627
# Row: ['MON', 'DSS', 'ASL', 'NLN', 'VAL', 'MON']
# Distance Row: ['191.72000000000003']
# Demand Row: ['97.0']
# Visits: [3, 3, 3, 1]
# Found matching row in loop: 150
# Row number: 150
# Row: ['MON', 'DSS', 'ASL', 'NLN', 'MON']
# Distance Row: ['191.11']
# Demand Row: ['79.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 191.31333333333333
# Total Weighted Demand for this route: 85.0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'ASL', 'MID', 'MON']
# Found matching row: 1588
# Row number: 1588
# Row: ['MON', 'KVB', 'ASL', 'MID', 'MON']
# Distance Row: ['152.82999999999998']
# Demand Row: ['64.0']
# Visits: [2, 3, 2]
# Found matching row in loop: 1
# Row number: 1
# Row: ['MON', 'ASL', 'MON']
# Distance Row: ['85.82']
# Demand Row: ['40.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 130.4933333333333
# Total Weighted Demand for this route: 56.0
# Processing row: ['MON', 'KVB', 'ASL', 'NLN', 'VAL', 'MON']
# Found matching row: 719
# Row number: 719
# Row: ['MON', 'KVB', 'ASL', 'NLN', 'VAL', 'MON']
# Distance Row: ['171.76']
# Demand Row: ['93.0']
# Visits: [2, 3, 3, 1]
# Found matching row in loop: 184
# Row number: 184
# Row: ['MON', 'KVB', 'ASL', 'NLN', 'MON']
# Distance Row: ['170.9']
# Demand Row: ['64.0']
# Found matching row in loop: 23
# Row number: 23
# Row: ['MON', 'ASL', 'NLN', 'MON']
# Distance Row: ['170.58']
# Demand Row: ['50.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 171.07999999999998
# Total Weighted Demand for this route: 69.0
# Processing row: ['MON', 'KVB', 'ASL', 'OSC', 'OSE', 'MON']
# Found matching row: 2176
# Row number: 2176
# Row: ['MON', 'KVB', 'ASL', 'OSC', 'OSE', 'MON']
# Distance Row: ['168.66']
# Demand Row: ['71.0']
# Visits: [2, 3, 2, 5]
# Found matching row in loop: 1436
# Row number: 1436
# Row: ['MON', 'ASL', 'OSE', 'MON']
# Distance Row: ['160.62']
# Demand Row: ['39.0']
# Found matching row in loop: 1411
# Row number: 1411
# Row: ['MON', 'OSE', 'MON']
# Distance Row: ['98.6']
# Demand Row: ['14.0']
# Route 1 Weight: 0.4
# Route 2 Weight: 0.2
# Route 3 Weight: 0.4
# Total Weighted Distance for this route: 139.028
# Total Weighted Demand for this route: 41.800000000000004
# Processing row: ['MON', 'KVB', 'ASL', 'OSO', 'VFB', 'MON']
# Found matching row: 2196
# Row number: 2196
# Row: ['MON', 'KVB', 'ASL', 'VFB', 'OSO', 'MON']
# Distance Row: ['185.89000000000001']
# Demand Row: ['75.0']
# Visits: [2, 3, 4, 3]
# Found matching row in loop: 1638
# Row number: 1638
# Row: ['MON', 'ASL', 'VFB', 'OSO', 'MON']
# Distance Row: ['185.57']
# Demand Row: ['61.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 187.66250000000002
# Total Weighted Demand for this route: 63.5
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'ASL', 'TRO', 'MON']
# Found matching row: 1596
# Row number: 1596
# Row: ['MON', 'KVB', 'ASL', 'TRO', 'MON']
# Distance Row: ['152.78']
# Demand Row: ['50.0']
# Visits: [2, 3, 2]
# Found matching row in loop: 1
# Row number: 1
# Row: ['MON', 'ASL', 'MON']
# Distance Row: ['85.82']
# Demand Row: ['40.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 130.45999999999998
# Total Weighted Demand for this route: 46.66666666666666
# Processing row: ['MON', 'MID', 'ASL', 'NLN', 'VAL', 'MON']
# Found matching row: 2219
# Row number: 2219
# Row: ['MON', 'VAL', 'NLN', 'ASL', 'MID', 'MON']
# Distance Row: ['190.79999999999998']
# Demand Row: ['82.0']
# Visits: [1, 3, 3, 2]
# Found matching row in loop: 1599
# Row number: 1599
# Row: ['MON', 'MID', 'ASL', 'NLN', 'MON']
# Distance Row: ['188.76']
# Demand Row: ['57.0']
# Found matching row in loop: 23
# Row number: 23
# Row: ['MON', 'ASL', 'NLN', 'MON']
# Distance Row: ['170.58']
# Demand Row: ['50.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 183.38
# Total Weighted Demand for this route: 62.99999999999999
# Processing row: ['MON', 'OSC', 'OSE', 'MID', 'ASL', 'MON']
# Found matching row: 2221
# Row number: 2221
# Row: ['MON', 'ASL', 'MID', 'OSE', 'OSC', 'MON']
# Distance Row: ['190.12']
# Demand Row: ['71.0']
# Visits: [3, 2, 5, 2]
# Found matching row in loop: 1436
# Row number: 1436
# Row: ['MON', 'ASL', 'OSE', 'MON']
# Distance Row: ['160.62']
# Demand Row: ['39.0']
# Found matching row in loop: 1411
# Row number: 1411
# Row: ['MON', 'OSE', 'MON']
# Distance Row: ['98.6']
# Demand Row: ['14.0']
# Route 1 Weight: 0.4
# Route 2 Weight: 0.2
# Route 3 Weight: 0.4
# Total Weighted Distance for this route: 147.612
# Total Weighted Demand for this route: 41.800000000000004
# Processing row: ['MON', 'OSO', 'VFB', 'MID', 'ASL', 'MON']
# Found matching row: 2241
# Row number: 2241
# Row: ['MON', 'OSO', 'MID', 'ASL', 'VFB', 'MON']
# Distance Row: ['196.24']
# Demand Row: ['75.0']
# Visits: [3, 2, 3, 4]
# Found matching row in loop: 1638
# Row number: 1638
# Row: ['MON', 'ASL', 'VFB', 'OSO', 'MON']
# Distance Row: ['185.57']
# Demand Row: ['61.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 192.83749999999998
# Total Weighted Demand for this route: 63.5
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'ASL', 'MID', 'TRO', 'MON']
# Found matching row: 1606
# Row number: 1606
# Row: ['MON', 'ASL', 'MID', 'TRO', 'MON']
# Distance Row: ['188.76']
# Demand Row: ['50.0']
# Visits: [3, 2, 2]
# Found matching row in loop: 1
# Row number: 1
# Row: ['MON', 'ASL', 'MON']
# Distance Row: ['85.82']
# Demand Row: ['40.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 154.44666666666666
# Total Weighted Demand for this route: 46.66666666666666
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'NLN', 'VAL', 'ASL', 'OSO', 'VFB', 'MON']
# Found matching row: 3605
# Row number: 3605
# Row: ['MON', 'OSO', 'VFB', 'ASL', 'NLN', 'VAL', 'MON']
# Distance Row: ['189.07999999999998']
# Demand Row: ['97.0']
# Visits: [3, 4, 3, 3, 1]
# Found matching row in loop: 2272
# Row number: 2272
# Row: ['MON', 'NLN', 'ASL', 'VFB', 'OSO', 'MON']
# Distance Row: ['185.62']
# Demand Row: ['86.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 188.40499999999997
# Total Weighted Demand for this route: 78.0
# Processing row: ['MON', 'NLN', 'VAL', 'ASL', 'TRO', 'MON']
# Found matching row: 2285
# Row number: 2285
# Row: ['MON', 'TRO', 'ASL', 'NLN', 'VAL', 'MON']
# Distance Row: ['161.78']
# Demand Row: ['79.0']
# Visits: [2, 3, 3, 1]
# Found matching row in loop: 1615
# Row number: 1615
# Row: ['MON', 'NLN', 'ASL', 'TRO', 'MON']
# Distance Row: ['152.51']
# Demand Row: ['61.0']
# Found matching row in loop: 23
# Row number: 23
# Row: ['MON', 'ASL', 'NLN', 'MON']
# Distance Row: ['170.58']
# Demand Row: ['50.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# ...
# Distance Row: ['203.19']
# Demand Row: ['93.0']
# Visits: [2, 3, 2, 2, 3, 4]
# Found matching row in loop: 1843
# Row number: 1843
# Row: ['MON', 'OSS', 'OSO', 'VFB', 'MON']
# Distance Row: ['98.88']
# Demand Row: ['54.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 174.64
# Total Weighted Demand for this route: 70.75
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'NLN', 'VAL', 'ASL', 'MID', 'MON']
# Found matching row: 3384
# Row number: 3384
# Row: ['MON', 'KVB', 'VAL', 'NLN', 'ASL', 'MID', 'MON']
# Distance Row: ['192.20999999999998']
# Demand Row: ['96.0']
# Visits: [2, 1, 3, 3, 2]
# Found matching row in loop: 2157
# Row number: 2157
# Row: ['MON', 'KVB', 'NLN', 'ASL', 'MID', 'MON']
# Distance Row: ['189.07999999999998']
# Demand Row: ['71.0']
# Found matching row in loop: 23
# Row number: 23
# Row: ['MON', 'ASL', 'NLN', 'MON']
# Distance Row: ['170.58']
# Demand Row: ['50.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 183.95666666666665
# Total Weighted Demand for this route: 72.33333333333333
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'ASL', 'MID', 'OSO', 'VFB', 'MON']
# Found matching row: 3400
# Row number: 3400
# Row: ['MON', 'KVB', 'ASL', 'MID', 'OSO', 'VFB', 'MON']
# Distance Row: ['196.56']
# Demand Row: ['89.0']
# Visits: [2, 3, 2, 3, 4]
# Found matching row in loop: 1638
# Row number: 1638
# Row: ['MON', 'ASL', 'VFB', 'OSO', 'MON']
# Distance Row: ['185.57']
# Demand Row: ['61.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 192.9975
# Total Weighted Demand for this route: 70.5
# Processing row: ['MON', 'KVB', 'ASL', 'MID', 'TRO', 'MON']
# Found matching row: 2164
# Row number: 2164
# Row: ['MON', 'KVB', 'ASL', 'MID', 'TRO', 'MON']
# Distance Row: ['189.96999999999997']
# Demand Row: ['64.0']
# Visits: [2, 3, 2, 2]
# Found matching row in loop: 1
# Row number: 1
# Row: ['MON', 'ASL', 'MON']
# Distance Row: ['85.82']
# Demand Row: ['40.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 155.2533333333333
# Total Weighted Demand for this route: 56.0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'ASL', 'NLN', 'VAL', 'TRO', 'MON']
# Found matching row: 3437
# Row number: 3437
# Row: ['MON', 'KVB', 'ASL', 'NLN', 'VAL', 'TRO', 'MON']
# Distance Row: ['162.83999999999997']
# Demand Row: ['93.0']
# Visits: [2, 3, 3, 1, 2]
# Found matching row in loop: 2173
# Row number: 2173
# Row: ['MON', 'KVB', 'ASL', 'NLN', 'TRO', 'MON']
# Distance Row: ['153.05']
# Demand Row: ['75.0']
# Found matching row in loop: 23
# Row number: 23
# Row: ['MON', 'ASL', 'NLN', 'MON']
# Distance Row: ['170.58']
# Demand Row: ['50.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 162.15666666666664
# Total Weighted Demand for this route: 72.66666666666666
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'ASL', 'OSO', 'VFB', 'TRO', 'MON']
# Found matching row: 3477
# Row number: 3477
# Row: ['MON', 'KVB', 'ASL', 'VFB', 'OSO', 'TRO', 'MON']
# Distance Row: ['163.13']
# Demand Row: ['82.0']
# Visits: [2, 3, 4, 3, 2]
# Found matching row in loop: 1638
# Row number: 1638
# Row: ['MON', 'ASL', 'VFB', 'OSO', 'MON']
# Distance Row: ['185.57']
# Demand Row: ['61.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 176.2825
# Total Weighted Demand for this route: 67.0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'NLN', 'VAL', 'ASL', 'MID', 'TRO', 'MON']
# Found matching row: 3520
# Row number: 3520
# Row: ['MON', 'VAL', 'NLN', 'ASL', 'MID', 'TRO', 'MON']
# Distance Row: ['195.26999999999998']
# Demand Row: ['93.0']
# Visits: [1, 3, 3, 2, 2]
# Found matching row in loop: 2218
# Row number: 2218
# Row: ['MON', 'NLN', 'ASL', 'MID', 'TRO', 'MON']
# Distance Row: ['189.02999999999997']
# Demand Row: ['75.0']
# Found matching row in loop: 23
# Row number: 23
# Row: ['MON', 'ASL', 'NLN', 'MON']
# Distance Row: ['170.58']
# Demand Row: ['50.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 184.95999999999998
# Total Weighted Demand for this route: 72.66666666666666
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'ASL', 'MID', 'OSO', 'VFB', 'TRO', 'MON']
# Found matching row: 3560
# Row number: 3560
# Row: ['MON', 'TRO', 'OSO', 'MID', 'ASL', 'VFB', 'MON']
# Distance Row: ['194.14']
# Demand Row: ['82.0']
# Visits: [2, 3, 2, 3, 4]
# Found matching row in loop: 1638
# Row number: 1638
# Row: ['MON', 'ASL', 'VFB', 'OSO', 'MON']
# Distance Row: ['185.57']
# Demand Row: ['61.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 191.78749999999997
# Total Weighted Demand for this route: 67.0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'NLN', 'VAL', 'MID', 'OSO', 'VFB', 'MON']
# Found matching row: 4623
# Row number: 4623
# Row: ['MON', 'KVB', 'VAL', 'NLN', 'MID', 'OSO', 'VFB', 'MON']
# Distance Row: ['190.56']
# Demand Row: ['100.0']
# Visits: [2, 1, 3, 2, 3, 4]
# Found matching row in loop: 3697
# Row number: 3697
# Row: ['MON', 'KVB', 'NLN', 'MID', 'OSO', 'VFB', 'MON']
# Distance Row: ['186.67000000000002']
# Demand Row: ['89.0']
# Found matching row in loop: 1774
# Row number: 1774
# Row: ['MON', 'NLN', 'VFB', 'OSO', 'MON']
# Distance Row: ['169.55']
# Demand Row: ['61.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 185.01999999999998
# Total Weighted Demand for this route: 73.25
# Processing row: ['MON', 'KVB', 'NLN', 'VAL', 'MID', 'TRO', 'MON']
# Found matching row: 3710
# Row number: 3710
# Row: ['MON', 'KVB', 'VAL', 'NLN', 'MID', 'TRO', 'MON']
# Distance Row: ['185.76']
# Demand Row: ['82.0']
# Visits: [2, 1, 3, 2, 2]
# Found matching row in loop: 2374
# Row number: 2374
# Row: ['MON', 'KVB', 'NLN', 'MID', 'TRO', 'MON']
# Distance Row: ['179.20999999999998']
# Demand Row: ['64.0']
# Found matching row in loop: 9
# Row number: 9
# Row: ['MON', 'NLN', 'MON']
# Distance Row: ['165.4']
# Demand Row: ['25.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 176.79
# Total Weighted Demand for this route: 57.0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'MID', 'OSC', 'OSE', 'TRO', 'MON']
# Found matching row: 3716
# Row number: 3716
# Row: ['MON', 'KVB', 'MID', 'OSC', 'OSE', 'TRO', 'MON']
# Distance Row: ['186.57999999999998']
# Demand Row: ['93.0']
# Visits: [2, 2, 2, 5, 2]
# Found matching row in loop: 1411
# Row number: 1411
# Row: ['MON', 'OSE', 'MON']
# Distance Row: ['98.6']
# Demand Row: ['14.0']
# Route 1 Weight: 0.4
# Route 2 Weight: 0.6
# Total Weighted Distance for this route: 133.79199999999997
# Total Weighted Demand for this route: 45.6
# Processing row: ['MON', 'KVB', 'MID', 'OSO', 'VFB', 'TRO', 'MON']
# Found matching row: 3771
# Row number: 3771
# Row: ['MON', 'KVB', 'MID', 'VFB', 'OSO', 'TRO', 'MON']
# Distance Row: ['184.03']
# Demand Row: ['71.0']
# Visits: [2, 2, 4, 3, 2]
# Found matching row in loop: 1494
# Row number: 1494
# Row: ['MON', 'OSO', 'VFB', 'MON']
# Distance Row: ['121.95']
# Demand Row: ['36.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 170.8275
# Total Weighted Demand for this route: 55.25
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'NLN', 'VAL', 'OSO', 'VFB', 'TRO', 'MON']
# Found matching row: 4720
# Row number: 4720
# Row: ['MON', 'KVB', 'VAL', 'NLN', 'VFB', 'OSO', 'TRO', 'MON']
# Distance Row: ['174.86999999999998']
# Demand Row: ['97.0']
# Visits: [2, 1, 3, 4, 3, 2]
# Found matching row in loop: 3830
# Row number: 3830
# Row: ['MON', 'KVB', 'NLN', 'VFB', 'OSO', 'TRO', 'MON']
# Distance Row: ['144.40999999999997']
# Demand Row: ['82.0']
# Found matching row in loop: 1774
# Row number: 1774
# Row: ['MON', 'NLN', 'VFB', 'OSO', 'MON']
# Distance Row: ['169.55']
# Demand Row: ['61.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 170.5325
# Total Weighted Demand for this route: 70.75
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'NLN', 'VAL', 'MID', 'OSO', 'VFB', 'TRO', 'MON']
# Found matching row: 4786
# Row number: 4786
# Row: ['MON', 'VFB', 'VAL', 'NLN', 'MID', 'OSO', 'TRO', 'MON']
# Distance Row: ['189.29999999999998']
# Demand Row: ['97.0']
# Visits: [4, 1, 3, 2, 3, 2]
# Found matching row in loop: 3993
# Row number: 3993
# Row: ['MON', 'TRO', 'OSO', 'MID', 'NLN', 'VFB', 'MON']
# Distance Row: ['183.38']
# Demand Row: ['82.0']
# Found matching row in loop: 1774
# Row number: 1774
# Row: ['MON', 'NLN', 'VFB', 'OSO', 'MON']
# Distance Row: ['169.55']
# Demand Row: ['61.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 183.8825
# Total Weighted Demand for this route: 70.75
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'ASL', 'MID', 'APT', 'OSS', 'TRO', 'MON']
# Found matching row: 4273
# Row number: 4273
# Row: ['MON', 'KVB', 'ASL', 'MID', 'APT', 'OSS', 'TRO', 'MON']
# Distance Row: ['204.81']
# Demand Row: ['100.0']
# Visits: [2, 3, 2, 2, 3, 2]
# Found matching row in loop: 1438
# Row number: 1438
# Row: ['MON', 'ASL', 'OSS', 'MON']
# Distance Row: ['157.51999999999998']
# Demand Row: ['43.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 189.04666666666665
# Total Weighted Demand for this route: 80.99999999999999
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['MON', 'KVB', 'NLN', 'VAL', 'ASL', 'MID', 'TRO', 'MON']
# Found matching row: 4523
# Row number: 4523
# Row: ['MON', 'KVB', 'VAL', 'NLN', 'ASL', 'MID', 'TRO', 'MON']
# Distance Row: ['193.12999999999997']
# Demand Row: ['96.0']
# Visits: [2, 1, 3, 3, 2, 2]
# Found matching row in loop: 3383
# Row number: 3383
# Row: ['MON', 'KVB', 'NLN', 'ASL', 'MID', 'TRO', 'MON']
# Distance Row: ['190.24']
# Demand Row: ['89.0']
# Found matching row in loop: 23
# Row number: 23
# Row: ['MON', 'ASL', 'NLN', 'MON']
# Distance Row: ['170.58']
# Demand Row: ['50.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 184.64999999999998
# Total Weighted Demand for this route: 78.33333333333333
# Processing row: ['MON', 'KVB', 'ASL', 'MID', 'OSO', 'VFB', 'TRO', 'MON']
# Found matching row: 4540
# Row number: 4540
# Row: ['MON', 'KVB', 'ASL', 'MID', 'VFB', 'OSO', 'TRO', 'MON']
# Distance Row: ['195.35']
# Demand Row: ['96.0']
# Visits: [2, 3, 2, 4, 3, 2]
# Found matching row in loop: 1638
# Row number: 1638
# Row: ['MON', 'ASL', 'VFB', 'OSO', 'MON']
# Distance Row: ['185.57']
# Demand Row: ['61.0']
# Found matching row in loop: 1418
# Row number: 1418
# Row: ['MON', 'VFB', 'MON']
# Distance Row: ['193.3']
# Demand Row: ['43.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 192.39249999999998
# Total Weighted Demand for this route: 74.0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0

# %%
zero_rows = []
with open(f'{mappenavn}/distances.csv', 'r') as file:
    next(file)  # Skip the header line
    for i, line in enumerate(file, start=1):  # Start enumeration from 1
        if float(line.strip()) == 0:
            zero_rows.append(i)

print("Row numbers with 0 values:", zero_rows)

# Read routes.csv line by line and remove rows based on zero_rows
with open(f'{mappenavn}/routes.csv', 'r') as routes_file:
    routes_data = routes_file.readlines()

# Remove rows from routes_data based on zero_rows
routes_data = [route for i, route in enumerate(routes_data, start=1) if i not in zero_rows]

# Write the updated routes_data back to routes.csv
with open(f'{mappenavn}/routes.csv', 'w') as routes_file:
    routes_file.writelines(routes_data)

demand_df = pd.read_csv(f'{mappenavn}/demand.csv')
demand_df = demand_df[demand_df['Demand'] != 0]
demand_df.to_csv(f'{mappenavn}/demand.csv', index=False)

# Remove rows from distances.csv
distances_df = pd.read_csv(f'{mappenavn}/distances.csv')
distances_df = distances_df[distances_df['Distances'] != 0]
distances_df.to_csv(f'{mappenavn}/distances.csv', index=False)
# Out:
# Row numbers with 0 values: [4, 15, 16, 17, 23, 27, 33, 37, 39, 40, 41, 42, 43, 45, 47, 48, 49, 50, 52, 53, 54, 55, 69, 72, 74, 77, 78, 82, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 98, 100, 103, 105, 107, 109, 111, 114, 115, 116, 117, 119, 121, 122, 123, 128, 133, 135, 138, 141, 143, 144, 145, 146, 147, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 182, 184, 186, 190, 192, 193, 195, 199, 201, 202, 204, 206, 207, 208, 209, 211, 212, 214, 215, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 231, 234, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 250, 253, 255, 257, 259, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 285, 288, 289, 291, 292, 294, 296, 297, 298, 299, 302, 303, 304]

# %%
demand_df = pd.read_csv(f'{mappenavn}/demand.csv')
duration_lossing = round(((demand_df['Demand'] * 1.389) / psv_speed), 2)
duration_loss_df = pd.DataFrame({'Duration (hours)': duration_lossing})
duration_loss_df.to_csv(f'{mappenavn}/duration_lossing.csv', index=False)

distances_df = pd.read_csv(f'{mappenavn}/distances.csv')
duration_sailing = round((distances_df['Distances'] / psv_speed), 2)
duration_sailing_df = pd.DataFrame({'Duration (hours)': duration_sailing})
duration_sailing_df.to_csv(f'{mappenavn}/duration_sailing.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/masteroppgave/masteroppgave/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~/masteroppgave/masteroppgave/lib/python3.11/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~/masteroppgave/masteroppgave/lib/python3.11/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: can't multiply sequence by non-int of type 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 demand_df = pd.read_csv(f'{mappenavn}/demand.csv')
# ----> 2 duration_lossing = round(((demand_df['Demand'] * 1.389) / psv_speed), 2)
#       3 duration_loss_df = pd.DataFrame({'Duration (hours)': duration_lossing})
#       4 duration_loss_df.to_csv(f'{mappenavn}/duration_lossing.csv', index=False)
#
# File ~/masteroppgave/masteroppgave/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/masteroppgave/masteroppgave/lib/python3.11/site-packages/pandas/core/arraylike.py:202, in OpsMixin.__mul__(self, other)
#     200 @unpack_zerodim_and_defer("__mul__")
#     201 def __mul__(self, other):
# --> 202     return self._arith_method(other, operator.mul)
#
# File ~/masteroppgave/masteroppgave/lib/python3.11/site-packages/pandas/core/series.py:6115, in Series._arith_method(self, other, op)
#    6113 def _arith_method(self, other, op):
#    6114     self, other = self._align_for_op(other)
# -> 6115     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/masteroppgave/masteroppgave/lib/python3.11/site-packages/pandas/core/base.py:1382, in IndexOpsMixin._arith_method(self, other, op)
#    1379     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1381 with np.errstate(all="ignore"):
# -> 1382     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1384 return self._construct_result(result, name=res_name)
#
# File ~/masteroppgave/masteroppgave/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File ~/masteroppgave/masteroppgave/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File ~/masteroppgave/masteroppgave/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:182, in _masked_arith_op(x, y, op)
#     179         mask = np.where(y == 1, False, mask)
#     181     if mask.any():
# --> 182         result[mask] = op(xrav[mask], y)
#     184 np.putmask(result, ~mask, np.nan)
#     185 result = result.reshape(x.shape)  # 2D compat
#
# TypeError: can't multiply sequence by non-int of type 'float'
