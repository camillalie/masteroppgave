# %%
import pandas as pd
from itertools import permutations
import math
import os
import csv
import time

# %%
cargo_capacity_psv = 100
psv_speed = 10
max_platforms_in_one_voyage = 7

mappenavn = 'generated_datafiles_allroutes'

# %% [markdown]
# ## Reads input data

# %%
demand = pd.read_csv('clustering/output_platforms_demand.csv', header=0, delimiter=';')
distances = pd.read_csv('clustering/output_distance_matrix_kmeans.csv', header=0, delimiter=';', index_col='from/to')

platforms_demand = dict(zip(demand['platform'], demand['avg_q'].replace(',', '.').astype(float)))
platforms_d = ['MON'] + demand['platform'].tolist() + ['MON']  # Add 'DUS' as start and end platforms

# %% [markdown]
# ## Algorithm for generating the shortest routes

# %%
shortest_routes_dict = {}

def generate_routes(demand, distances):
    cargo_capacity = cargo_capacity_psv
    max_platforms = max_platforms_in_one_voyage + 2

    def dp(platform, cargo_remaining, route, visited):
        if cargo_remaining < 0:
            return
        if len(route) > max_platforms:
            return
        if platform == 'MON' and len(route) > 2:
            total_demand = sum(platforms_demand[p] for p in route[1:-1])
            if total_demand <= cargo_capacity:
                key = tuple(sorted(set(route)))
                total_distance = sum(distances.loc[route[i], route[i+1]] for i in range(len(route)-1))
                if key not in shortest_routes_dict or total_distance < shortest_routes_dict[key][1]:
                    duration_sailing = round((total_distance / psv_speed), 2)
                    duration_lossing = round(((total_demand * 1.389) / psv_speed), 2)
                    duration_sailing = round(duration_sailing, 2)
                    duration_lossing = round(duration_lossing, 2)
                    shortest_routes_dict[key] = (route, total_distance, total_demand, duration_sailing, duration_lossing)
            return

        # Check if the current route is dominated
        current_distance = sum(distances.loc[route[i], route[i+1]] for i in range(len(route)-1))
        current_demand = sum(platforms_demand[p] for p in route[1:-1])
        
        # Check for dominance in existing routes
        for key, (existing_route, existing_distance, existing_demand, _, _) in shortest_routes_dict.items():
            if set(existing_route[1:-1]) == set(route[1:-1]) and existing_demand >= current_demand and existing_distance <= current_distance:
                return
        
        # Check for dominance in subsequent routes starting with the same platforms
        for existing_route in dominated_routes:
            if set(existing_route[1:-1]) == set(route[1:-1]) and existing_demand >= current_demand and existing_distance <= current_distance:
                return

        for next_platform in platforms_demand.keys():
            if next_platform != platform and next_platform not in visited:
                try:
                    distance_to_next = distances.loc[platform, next_platform]
                    new_cargo_remaining = cargo_remaining - platforms_demand[next_platform]
                    dp(next_platform, new_cargo_remaining, route + [next_platform], visited.union({next_platform}))
                except KeyError:
                    print("KeyError occurred for platform:", next_platform)
                    continue

    for r in range(3, min(len(platforms_demand) + 3, max_platforms + 3)):
        for route_combination in permutations(platforms_demand.keys(), r - 2):
            route = ['MON'] + list(route_combination) + ['MON']
            dp('MON', cargo_capacity, route, {'MON'})

            # Add the current route to the dominated routes set
            dominated_routes.add(tuple(route))

    return shortest_routes_dict

# Keep track of dominated routes to skip future routes starting with them
dominated_routes = set()
shortest_routes_dict = generate_routes(demand, distances)

for route, distance, demand, duration_sailing, duration_lossing in shortest_routes_dict.values():
    print(f"Shortest Route: {route}, Total Distance: {round(distance,2)}, Total Demand: {demand}, Duration sailing: {duration_sailing}, Duration lossing: {duration_lossing}")

print(len(shortest_routes_dict))
# Out:
# Shortest Route: ['DUS', 'DAB', 'DUS'], Total Distance: 185.84, Total Demand: 40.0, Duration sailing: 18.58, Duration lossing: 5.56
# Shortest Route: ['DUS', 'DRA', 'DUS'], Total Distance: 205.36, Total Demand: 14.0, Duration sailing: 20.54, Duration lossing: 1.94
# Shortest Route: ['DUS', 'DSA', 'DUS'], Total Distance: 164.4, Total Demand: 29.0, Duration sailing: 16.44, Duration lossing: 4.03
# Shortest Route: ['DUS', 'GKR', 'DUS'], Total Distance: 234.68, Total Demand: 18.0, Duration sailing: 23.47, Duration lossing: 2.5
# Shortest Route: ['DUS', 'GUD', 'DUS'], Total Distance: 226.76, Total Demand: 18.0, Duration sailing: 22.68, Duration lossing: 2.5
# Shortest Route: ['DUS', 'JSF', 'DUS'], Total Distance: 176.18, Total Demand: 40.0, Duration sailing: 17.62, Duration lossing: 5.56
# Shortest Route: ['DUS', 'GRA', 'DUS'], Total Distance: 180.44, Total Demand: 14.0, Duration sailing: 18.04, Duration lossing: 1.94
# Shortest Route: ['DUS', 'HDA', 'DUS'], Total Distance: 206.82, Total Demand: 18.0, Duration sailing: 20.68, Duration lossing: 2.5
# Shortest Route: ['DUS', 'SLA', 'DUS'], Total Distance: 229.48, Total Demand: 4.0, Duration sailing: 22.95, Duration lossing: 0.56
# Shortest Route: ['DUS', 'SLB', 'DUS'], Total Distance: 238.28, Total Demand: 7.0, Duration sailing: 23.83, Duration lossing: 0.97
# Shortest Route: ['DUS', 'TEB', 'DUS'], Total Distance: 250.32, Total Demand: 14.0, Duration sailing: 25.03, Duration lossing: 1.94
# Shortest Route: ['DUS', 'DAB', 'DRA', 'DUS'], Total Distance: 253.28, Total Demand: 54.0, Duration sailing: 25.33, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DAB', 'DSA', 'DUS'], Total Distance: 200.65, Total Demand: 69.0, Duration sailing: 20.07, Duration lossing: 9.58
# Shortest Route: ['DUS', 'DAB', 'GKR', 'DUS'], Total Distance: 251.31, Total Demand: 58.0, Duration sailing: 25.13, Duration lossing: 8.06
# Shortest Route: ['DUS', 'DAB', 'GUD', 'DUS'], Total Distance: 233.52, Total Demand: 58.0, Duration sailing: 23.35, Duration lossing: 8.06
# Shortest Route: ['DUS', 'DAB', 'JSF', 'DUS'], Total Distance: 200.27, Total Demand: 80.0, Duration sailing: 20.03, Duration lossing: 11.11
# Shortest Route: ['DUS', 'DAB', 'GRA', 'DUS'], Total Distance: 185.97, Total Demand: 54.0, Duration sailing: 18.6, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DAB', 'HDA', 'DUS'], Total Distance: 222.08, Total Demand: 58.0, Duration sailing: 22.21, Duration lossing: 8.06
# Shortest Route: ['DUS', 'DAB', 'SLA', 'DUS'], Total Distance: 257.01, Total Demand: 44.0, Duration sailing: 25.7, Duration lossing: 6.11
# Shortest Route: ['DUS', 'DAB', 'SLB', 'DUS'], Total Distance: 260.73, Total Demand: 47.0, Duration sailing: 26.07, Duration lossing: 6.53
# Shortest Route: ['DUS', 'DAB', 'TEB', 'DUS'], Total Distance: 271.87, Total Demand: 54.0, Duration sailing: 27.19, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DRA', 'DSA', 'DUS'], Total Distance: 220.95, Total Demand: 43.0, Duration sailing: 22.1, Duration lossing: 5.97
# Shortest Route: ['DUS', 'DRA', 'GKR', 'DUS'], Total Distance: 253.31, Total Demand: 32.0, Duration sailing: 25.33, Duration lossing: 4.44
# Shortest Route: ['DUS', 'DRA', 'GUD', 'DUS'], Total Distance: 261.82, Total Demand: 32.0, Duration sailing: 26.18, Duration lossing: 4.44
# Shortest Route: ['DUS', 'DRA', 'JSF', 'DUS'], Total Distance: 229.9, Total Demand: 54.0, Duration sailing: 22.99, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DRA', 'GRA', 'DUS'], Total Distance: 251.14, Total Demand: 28.0, Duration sailing: 25.11, Duration lossing: 3.89
# Shortest Route: ['DUS', 'DRA', 'HDA', 'DUS'], Total Distance: 289.28, Total Demand: 32.0, Duration sailing: 28.93, Duration lossing: 4.44
# Shortest Route: ['DUS', 'DRA', 'SLA', 'DUS'], Total Distance: 238.41, Total Demand: 18.0, Duration sailing: 23.84, Duration lossing: 2.5
# Shortest Route: ['DUS', 'DRA', 'SLB', 'DUS'], Total Distance: 249.21, Total Demand: 21.0, Duration sailing: 24.92, Duration lossing: 2.92
# Shortest Route: ['DUS', 'DRA', 'TEB', 'DUS'], Total Distance: 258.83, Total Demand: 28.0, Duration sailing: 25.88, Duration lossing: 3.89
# Shortest Route: ['DUS', 'DSA', 'GKR', 'DUS'], Total Distance: 235.04, Total Demand: 47.0, Duration sailing: 23.5, Duration lossing: 6.53
# Shortest Route: ['DUS', 'GUD', 'DSA', 'DUS'], Total Distance: 227.96, Total Demand: 47.0, Duration sailing: 22.8, Duration lossing: 6.53
# Shortest Route: ['DUS', 'DSA', 'JSF', 'DUS'], Total Distance: 178.06, Total Demand: 69.0, Duration sailing: 17.81, Duration lossing: 9.58
# Shortest Route: ['DUS', 'DSA', 'GRA', 'DUS'], Total Distance: 197.39, Total Demand: 43.0, Duration sailing: 19.74, Duration lossing: 5.97
# Shortest Route: ['DUS', 'DSA', 'HDA', 'DUS'], Total Distance: 236.43, Total Demand: 47.0, Duration sailing: 23.64, Duration lossing: 6.53
# Shortest Route: ['DUS', 'DSA', 'SLA', 'DUS'], Total Distance: 233.25, Total Demand: 33.0, Duration sailing: 23.32, Duration lossing: 4.58
# Shortest Route: ['DUS', 'SLB', 'DSA', 'DUS'], Total Distance: 240.34, Total Demand: 36.0, Duration sailing: 24.03, Duration lossing: 5.0
# Shortest Route: ['DUS', 'DSA', 'TEB', 'DUS'], Total Distance: 252.48, Total Demand: 43.0, Duration sailing: 25.25, Duration lossing: 5.97
# Shortest Route: ['DUS', 'GKR', 'GUD', 'DUS'], Total Distance: 247.58, Total Demand: 36.0, Duration sailing: 24.76, Duration lossing: 5.0
# Shortest Route: ['DUS', 'GKR', 'JSF', 'DUS'], Total Distance: 236.77, Total Demand: 58.0, Duration sailing: 23.68, Duration lossing: 8.06
# Shortest Route: ['DUS', 'GKR', 'GRA', 'DUS'], Total Distance: 250.64, Total Demand: 32.0, Duration sailing: 25.06, Duration lossing: 4.44
# Shortest Route: ['DUS', 'GKR', 'HDA', 'DUS'], Total Distance: 282.98, Total Demand: 36.0, Duration sailing: 28.3, Duration lossing: 5.0
# Shortest Route: ['DUS', 'GKR', 'SLA', 'DUS'], Total Distance: 245.63, Total Demand: 22.0, Duration sailing: 24.56, Duration lossing: 3.06
# Shortest Route: ['DUS', 'GKR', 'SLB', 'DUS'], Total Distance: 245.51, Total Demand: 25.0, Duration sailing: 24.55, Duration lossing: 3.47
# Shortest Route: ['DUS', 'GKR', 'TEB', 'DUS'], Total Distance: 255.4, Total Demand: 32.0, Duration sailing: 25.54, Duration lossing: 4.44
# Shortest Route: ['DUS', 'GUD', 'JSF', 'DUS'], Total Distance: 226.95, Total Demand: 58.0, Duration sailing: 22.7, Duration lossing: 8.06
# Shortest Route: ['DUS', 'GUD', 'GRA', 'DUS'], Total Distance: 233.33, Total Demand: 32.0, Duration sailing: 23.33, Duration lossing: 4.44
# Shortest Route: ['DUS', 'GUD', 'HDA', 'DUS'], Total Distance: 262.57, Total Demand: 36.0, Duration sailing: 26.26, Duration lossing: 5.0
# Shortest Route: ['DUS', 'GUD', 'SLA', 'DUS'], Total Distance: 257.37, Total Demand: 22.0, Duration sailing: 25.74, Duration lossing: 3.06
# Shortest Route: ['DUS', 'GUD', 'SLB', 'DUS'], Total Distance: 258.34, Total Demand: 25.0, Duration sailing: 25.83, Duration lossing: 3.47
# Shortest Route: ['DUS', 'GUD', 'TEB', 'DUS'], Total Distance: 267.97, Total Demand: 32.0, Duration sailing: 26.8, Duration lossing: 4.44
# Shortest Route: ['DUS', 'JSF', 'GRA', 'DUS'], Total Distance: 197.64, Total Demand: 54.0, Duration sailing: 19.76, Duration lossing: 7.5
# Shortest Route: ['DUS', 'JSF', 'HDA', 'DUS'], Total Distance: 236.49, Total Demand: 58.0, Duration sailing: 23.65, Duration lossing: 8.06
# Shortest Route: ['DUS', 'SLA', 'JSF', 'DUS'], Total Distance: 237.79, Total Demand: 44.0, Duration sailing: 23.78, Duration lossing: 6.11
# Shortest Route: ['DUS', 'JSF', 'SLB', 'DUS'], Total Distance: 243.63, Total Demand: 47.0, Duration sailing: 24.36, Duration lossing: 6.53
# Shortest Route: ['DUS', 'JSF', 'TEB', 'DUS'], Total Distance: 255.61, Total Demand: 54.0, Duration sailing: 25.56, Duration lossing: 7.5
# Shortest Route: ['DUS', 'GRA', 'HDA', 'DUS'], Total Distance: 219.5, Total Demand: 32.0, Duration sailing: 21.95, Duration lossing: 4.44
# Shortest Route: ['DUS', 'GRA', 'SLA', 'DUS'], Total Distance: 255.82, Total Demand: 18.0, Duration sailing: 25.58, Duration lossing: 2.5
# Shortest Route: ['DUS', 'GRA', 'SLB', 'DUS'], Total Distance: 259.84, Total Demand: 21.0, Duration sailing: 25.98, Duration lossing: 2.92
# Shortest Route: ['DUS', 'GRA', 'TEB', 'DUS'], Total Distance: 271.11, Total Demand: 28.0, Duration sailing: 27.11, Duration lossing: 3.89
# Shortest Route: ['DUS', 'SLA', 'HDA', 'DUS'], Total Distance: 290.92, Total Demand: 22.0, Duration sailing: 29.09, Duration lossing: 3.06
# Shortest Route: ['DUS', 'HDA', 'SLB', 'DUS'], Total Distance: 293.37, Total Demand: 25.0, Duration sailing: 29.34, Duration lossing: 3.47
# Shortest Route: ['DUS', 'HDA', 'TEB', 'DUS'], Total Distance: 303.63, Total Demand: 32.0, Duration sailing: 30.36, Duration lossing: 4.44
# Shortest Route: ['DUS', 'SLA', 'SLB', 'DUS'], Total Distance: 240.29, Total Demand: 11.0, Duration sailing: 24.03, Duration lossing: 1.53
# Shortest Route: ['DUS', 'SLA', 'TEB', 'DUS'], Total Distance: 250.92, Total Demand: 18.0, Duration sailing: 25.09, Duration lossing: 2.5
# Shortest Route: ['DUS', 'SLB', 'TEB', 'DUS'], Total Distance: 250.43, Total Demand: 21.0, Duration sailing: 25.04, Duration lossing: 2.92
# Shortest Route: ['DUS', 'DRA', 'DSA', 'DAB', 'DUS'], Total Distance: 257.2, Total Demand: 83.0, Duration sailing: 25.72, Duration lossing: 11.53
# Shortest Route: ['DUS', 'DAB', 'GKR', 'DRA', 'DUS'], Total Distance: 269.94, Total Demand: 72.0, Duration sailing: 26.99, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DRA', 'GUD', 'DAB', 'DUS'], Total Distance: 268.58, Total Demand: 72.0, Duration sailing: 26.86, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DAB', 'JSF', 'DRA', 'DUS'], Total Distance: 253.99, Total Demand: 94.0, Duration sailing: 25.4, Duration lossing: 13.06
# Shortest Route: ['DUS', 'GRA', 'DAB', 'DRA', 'DUS'], Total Distance: 253.41, Total Demand: 68.0, Duration sailing: 25.34, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DRA', 'DAB', 'HDA', 'DUS'], Total Distance: 289.52, Total Demand: 72.0, Duration sailing: 28.95, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DRA', 'SLA', 'DAB', 'DUS'], Total Distance: 265.94, Total Demand: 58.0, Duration sailing: 26.59, Duration lossing: 8.06
# Shortest Route: ['DUS', 'DAB', 'SLB', 'DRA', 'DUS'], Total Distance: 271.66, Total Demand: 61.0, Duration sailing: 27.17, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DAB', 'TEB', 'DRA', 'DUS'], Total Distance: 280.38, Total Demand: 68.0, Duration sailing: 28.04, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DAB', 'GKR', 'DSA', 'DUS'], Total Distance: 251.67, Total Demand: 87.0, Duration sailing: 25.17, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DAB', 'GUD', 'DSA', 'DUS'], Total Distance: 234.72, Total Demand: 87.0, Duration sailing: 23.47, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DSA', 'DAB', 'GRA', 'DUS'], Total Distance: 200.78, Total Demand: 83.0, Duration sailing: 20.08, Duration lossing: 11.53
# Shortest Route: ['DUS', 'HDA', 'DAB', 'DSA', 'DUS'], Total Distance: 236.89, Total Demand: 87.0, Duration sailing: 23.69, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DAB', 'SLA', 'DSA', 'DUS'], Total Distance: 260.78, Total Demand: 73.0, Duration sailing: 26.08, Duration lossing: 10.14
# Shortest Route: ['DUS', 'DAB', 'SLB', 'DSA', 'DUS'], Total Distance: 262.79, Total Demand: 76.0, Duration sailing: 26.28, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DSA', 'TEB', 'DAB', 'DUS'], Total Distance: 274.03, Total Demand: 83.0, Duration sailing: 27.4, Duration lossing: 11.53
# Shortest Route: ['DUS', 'GKR', 'GUD', 'DAB', 'DUS'], Total Distance: 254.34, Total Demand: 76.0, Duration sailing: 25.43, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DAB', 'GKR', 'JSF', 'DUS'], Total Distance: 253.4, Total Demand: 98.0, Duration sailing: 25.34, Duration lossing: 13.61
# Shortest Route: ['DUS', 'GKR', 'DAB', 'GRA', 'DUS'], Total Distance: 251.44, Total Demand: 72.0, Duration sailing: 25.14, Duration lossing: 10.0
# Shortest Route: ['DUS', 'GKR', 'DAB', 'HDA', 'DUS'], Total Distance: 287.55, Total Demand: 76.0, Duration sailing: 28.75, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DAB', 'GKR', 'SLA', 'DUS'], Total Distance: 262.26, Total Demand: 62.0, Duration sailing: 26.23, Duration lossing: 8.61
# Shortest Route: ['DUS', 'DAB', 'GKR', 'SLB', 'DUS'], Total Distance: 262.14, Total Demand: 65.0, Duration sailing: 26.21, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DAB', 'GKR', 'TEB', 'DUS'], Total Distance: 272.03, Total Demand: 72.0, Duration sailing: 27.2, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DAB', 'GUD', 'JSF', 'DUS'], Total Distance: 233.71, Total Demand: 98.0, Duration sailing: 23.37, Duration lossing: 13.61
# Shortest Route: ['DUS', 'GRA', 'DAB', 'GUD', 'DUS'], Total Distance: 233.65, Total Demand: 72.0, Duration sailing: 23.36, Duration lossing: 10.0
# Shortest Route: ['DUS', 'HDA', 'GUD', 'DAB', 'DUS'], Total Distance: 269.33, Total Demand: 76.0, Duration sailing: 26.93, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DAB', 'GUD', 'SLA', 'DUS'], Total Distance: 264.13, Total Demand: 62.0, Duration sailing: 26.41, Duration lossing: 8.61
# Shortest Route: ['DUS', 'DAB', 'GUD', 'SLB', 'DUS'], Total Distance: 265.1, Total Demand: 65.0, Duration sailing: 26.51, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DAB', 'GUD', 'TEB', 'DUS'], Total Distance: 274.73, Total Demand: 72.0, Duration sailing: 27.47, Duration lossing: 10.0
# Shortest Route: ['DUS', 'JSF', 'DAB', 'GRA', 'DUS'], Total Distance: 200.4, Total Demand: 94.0, Duration sailing: 20.04, Duration lossing: 13.06
# Shortest Route: ['DUS', 'HDA', 'DAB', 'JSF', 'DUS'], Total Distance: 236.51, Total Demand: 98.0, Duration sailing: 23.65, Duration lossing: 13.61
# Shortest Route: ['DUS', 'DAB', 'JSF', 'SLA', 'DUS'], Total Distance: 261.88, Total Demand: 84.0, Duration sailing: 26.19, Duration lossing: 11.67
# Shortest Route: ['DUS', 'DAB', 'SLB', 'JSF', 'DUS'], Total Distance: 266.08, Total Demand: 87.0, Duration sailing: 26.61, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DAB', 'TEB', 'JSF', 'DUS'], Total Distance: 277.16, Total Demand: 94.0, Duration sailing: 27.72, Duration lossing: 13.06
# Shortest Route: ['DUS', 'GRA', 'DAB', 'HDA', 'DUS'], Total Distance: 222.21, Total Demand: 72.0, Duration sailing: 22.22, Duration lossing: 10.0
# Shortest Route: ['DUS', 'GRA', 'DAB', 'SLA', 'DUS'], Total Distance: 257.14, Total Demand: 58.0, Duration sailing: 25.71, Duration lossing: 8.06
# Shortest Route: ['DUS', 'GRA', 'DAB', 'SLB', 'DUS'], Total Distance: 260.86, Total Demand: 61.0, Duration sailing: 26.09, Duration lossing: 8.47
# Shortest Route: ['DUS', 'GRA', 'DAB', 'TEB', 'DUS'], Total Distance: 272.0, Total Demand: 68.0, Duration sailing: 27.2, Duration lossing: 9.45
# Shortest Route: ['DUS', 'HDA', 'DAB', 'SLA', 'DUS'], Total Distance: 293.25, Total Demand: 62.0, Duration sailing: 29.32, Duration lossing: 8.61
# Shortest Route: ['DUS', 'HDA', 'DAB', 'SLB', 'DUS'], Total Distance: 296.97, Total Demand: 65.0, Duration sailing: 29.7, Duration lossing: 9.03
# Shortest Route: ['DUS', 'HDA', 'DAB', 'TEB', 'DUS'], Total Distance: 308.11, Total Demand: 72.0, Duration sailing: 30.81, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DAB', 'SLB', 'SLA', 'DUS'], Total Distance: 262.74, Total Demand: 51.0, Duration sailing: 26.27, Duration lossing: 7.08
# Shortest Route: ['DUS', 'SLA', 'TEB', 'DAB', 'DUS'], Total Distance: 272.47, Total Demand: 58.0, Duration sailing: 27.25, Duration lossing: 8.06
# Shortest Route: ['DUS', 'DAB', 'TEB', 'SLB', 'DUS'], Total Distance: 271.98, Total Demand: 61.0, Duration sailing: 27.2, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DRA', 'GKR', 'DSA', 'DUS'], Total Distance: 253.67, Total Demand: 61.0, Duration sailing: 25.37, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DRA', 'GUD', 'DSA', 'DUS'], Total Distance: 263.02, Total Demand: 61.0, Duration sailing: 26.3, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DSA', 'JSF', 'DRA', 'DUS'], Total Distance: 231.78, Total Demand: 83.0, Duration sailing: 23.18, Duration lossing: 11.53
# Shortest Route: ['DUS', 'DRA', 'DSA', 'GRA', 'DUS'], Total Distance: 253.94, Total Demand: 57.0, Duration sailing: 25.39, Duration lossing: 7.92
# Shortest Route: ['DUS', 'DRA', 'DSA', 'HDA', 'DUS'], Total Distance: 292.98, Total Demand: 61.0, Duration sailing: 29.3, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'DSA', 'DUS'], Total Distance: 242.18, Total Demand: 47.0, Duration sailing: 24.22, Duration lossing: 6.53
# Shortest Route: ['DUS', 'DRA', 'SLB', 'DSA', 'DUS'], Total Distance: 251.27, Total Demand: 50.0, Duration sailing: 25.13, Duration lossing: 6.95
# Shortest Route: ['DUS', 'DRA', 'TEB', 'DSA', 'DUS'], Total Distance: 260.99, Total Demand: 57.0, Duration sailing: 26.1, Duration lossing: 7.92
# Shortest Route: ['DUS', 'DRA', 'GKR', 'GUD', 'DUS'], Total Distance: 266.21, Total Demand: 50.0, Duration sailing: 26.62, Duration lossing: 6.95
# Shortest Route: ['DUS', 'DRA', 'GKR', 'JSF', 'DUS'], Total Distance: 255.4, Total Demand: 72.0, Duration sailing: 25.54, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DRA', 'GKR', 'GRA', 'DUS'], Total Distance: 269.27, Total Demand: 46.0, Duration sailing: 26.93, Duration lossing: 6.39
# Shortest Route: ['DUS', 'DRA', 'GKR', 'HDA', 'DUS'], Total Distance: 301.61, Total Demand: 50.0, Duration sailing: 30.16, Duration lossing: 6.95
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GKR', 'DUS'], Total Distance: 254.56, Total Demand: 36.0, Duration sailing: 25.46, Duration lossing: 5.0
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GKR', 'DUS'], Total Distance: 256.44, Total Demand: 39.0, Duration sailing: 25.64, Duration lossing: 5.42
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GKR', 'DUS'], Total Distance: 263.91, Total Demand: 46.0, Duration sailing: 26.39, Duration lossing: 6.39
# Shortest Route: ['DUS', 'DRA', 'GUD', 'JSF', 'DUS'], Total Distance: 262.01, Total Demand: 72.0, Duration sailing: 26.2, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DRA', 'GUD', 'GRA', 'DUS'], Total Distance: 268.39, Total Demand: 46.0, Duration sailing: 26.84, Duration lossing: 6.39
# Shortest Route: ['DUS', 'DRA', 'GUD', 'HDA', 'DUS'], Total Distance: 297.63, Total Demand: 50.0, Duration sailing: 29.76, Duration lossing: 6.95
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GUD', 'DUS'], Total Distance: 266.3, Total Demand: 36.0, Duration sailing: 26.63, Duration lossing: 5.0
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GUD', 'DUS'], Total Distance: 269.27, Total Demand: 39.0, Duration sailing: 26.93, Duration lossing: 5.42
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GUD', 'DUS'], Total Distance: 276.48, Total Demand: 46.0, Duration sailing: 27.65, Duration lossing: 6.39
# Shortest Route: ['DUS', 'DRA', 'JSF', 'GRA', 'DUS'], Total Distance: 251.36, Total Demand: 68.0, Duration sailing: 25.14, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DRA', 'JSF', 'HDA', 'DUS'], Total Distance: 290.21, Total Demand: 72.0, Duration sailing: 29.02, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DRA', 'SLA', 'JSF', 'DUS'], Total Distance: 246.72, Total Demand: 58.0, Duration sailing: 24.67, Duration lossing: 8.06
# Shortest Route: ['DUS', 'DRA', 'SLB', 'JSF', 'DUS'], Total Distance: 254.56, Total Demand: 61.0, Duration sailing: 25.46, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DRA', 'TEB', 'JSF', 'DUS'], Total Distance: 264.12, Total Demand: 68.0, Duration sailing: 26.41, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DRA', 'GRA', 'HDA', 'DUS'], Total Distance: 290.2, Total Demand: 46.0, Duration sailing: 29.02, Duration lossing: 6.39
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GRA', 'DUS'], Total Distance: 264.75, Total Demand: 32.0, Duration sailing: 26.48, Duration lossing: 4.44
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GRA', 'DUS'], Total Distance: 270.77, Total Demand: 35.0, Duration sailing: 27.08, Duration lossing: 4.86
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GRA', 'DUS'], Total Distance: 279.62, Total Demand: 42.0, Duration sailing: 27.96, Duration lossing: 5.83
# Shortest Route: ['DUS', 'DRA', 'SLA', 'HDA', 'DUS'], Total Distance: 299.85, Total Demand: 36.0, Duration sailing: 29.99, Duration lossing: 5.0
# Shortest Route: ['DUS', 'DRA', 'SLB', 'HDA', 'DUS'], Total Distance: 304.3, Total Demand: 39.0, Duration sailing: 30.43, Duration lossing: 5.42
# Shortest Route: ['DUS', 'DRA', 'TEB', 'HDA', 'DUS'], Total Distance: 312.14, Total Demand: 46.0, Duration sailing: 31.21, Duration lossing: 6.39
# Shortest Route: ['DUS', 'SLB', 'SLA', 'DRA', 'DUS'], Total Distance: 249.22, Total Demand: 25.0, Duration sailing: 24.92, Duration lossing: 3.47
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLA', 'DUS'], Total Distance: 259.43, Total Demand: 32.0, Duration sailing: 25.94, Duration lossing: 4.44
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'DUS'], Total Distance: 258.94, Total Demand: 35.0, Duration sailing: 25.89, Duration lossing: 4.86
# Shortest Route: ['DUS', 'DSA', 'GKR', 'GUD', 'DUS'], Total Distance: 247.94, Total Demand: 65.0, Duration sailing: 24.79, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DSA', 'GKR', 'JSF', 'DUS'], Total Distance: 237.13, Total Demand: 87.0, Duration sailing: 23.71, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DSA', 'GKR', 'GRA', 'DUS'], Total Distance: 251.0, Total Demand: 61.0, Duration sailing: 25.1, Duration lossing: 8.47
# Shortest Route: ['DUS', 'HDA', 'GKR', 'DSA', 'DUS'], Total Distance: 283.34, Total Demand: 65.0, Duration sailing: 28.33, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DSA', 'GKR', 'SLA', 'DUS'], Total Distance: 245.99, Total Demand: 51.0, Duration sailing: 24.6, Duration lossing: 7.08
# Shortest Route: ['DUS', 'DSA', 'GKR', 'SLB', 'DUS'], Total Distance: 245.87, Total Demand: 54.0, Duration sailing: 24.59, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DSA', 'GKR', 'TEB', 'DUS'], Total Distance: 255.76, Total Demand: 61.0, Duration sailing: 25.58, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DSA', 'GUD', 'JSF', 'DUS'], Total Distance: 228.15, Total Demand: 87.0, Duration sailing: 22.82, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DSA', 'GUD', 'GRA', 'DUS'], Total Distance: 234.53, Total Demand: 61.0, Duration sailing: 23.45, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DSA', 'GUD', 'HDA', 'DUS'], Total Distance: 263.77, Total Demand: 65.0, Duration sailing: 26.38, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DSA', 'GUD', 'SLA', 'DUS'], Total Distance: 258.57, Total Demand: 51.0, Duration sailing: 25.86, Duration lossing: 7.08
# Shortest Route: ['DUS', 'DSA', 'GUD', 'SLB', 'DUS'], Total Distance: 259.54, Total Demand: 54.0, Duration sailing: 25.95, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DSA', 'GUD', 'TEB', 'DUS'], Total Distance: 269.17, Total Demand: 61.0, Duration sailing: 26.92, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DSA', 'JSF', 'GRA', 'DUS'], Total Distance: 199.52, Total Demand: 83.0, Duration sailing: 19.95, Duration lossing: 11.53
# Shortest Route: ['DUS', 'DSA', 'JSF', 'HDA', 'DUS'], Total Distance: 238.37, Total Demand: 87.0, Duration sailing: 23.84, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DSA', 'JSF', 'SLA', 'DUS'], Total Distance: 239.67, Total Demand: 73.0, Duration sailing: 23.97, Duration lossing: 10.14
# Shortest Route: ['DUS', 'DSA', 'JSF', 'SLB', 'DUS'], Total Distance: 245.51, Total Demand: 76.0, Duration sailing: 24.55, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DSA', 'JSF', 'TEB', 'DUS'], Total Distance: 257.49, Total Demand: 83.0, Duration sailing: 25.75, Duration lossing: 11.53
# Shortest Route: ['DUS', 'DSA', 'GRA', 'HDA', 'DUS'], Total Distance: 236.45, Total Demand: 61.0, Duration sailing: 23.64, Duration lossing: 8.47
# Shortest Route: ['DUS', 'GRA', 'SLA', 'DSA', 'DUS'], Total Distance: 259.59, Total Demand: 47.0, Duration sailing: 25.96, Duration lossing: 6.53
# Shortest Route: ['DUS', 'DSA', 'SLB', 'GRA', 'DUS'], Total Distance: 261.9, Total Demand: 50.0, Duration sailing: 26.19, Duration lossing: 6.95
# Shortest Route: ['DUS', 'DSA', 'TEB', 'GRA', 'DUS'], Total Distance: 273.27, Total Demand: 57.0, Duration sailing: 27.33, Duration lossing: 7.92
# Shortest Route: ['DUS', 'DSA', 'SLA', 'HDA', 'DUS'], Total Distance: 294.69, Total Demand: 51.0, Duration sailing: 29.47, Duration lossing: 7.08
# Shortest Route: ['DUS', 'DSA', 'SLB', 'HDA', 'DUS'], Total Distance: 295.43, Total Demand: 54.0, Duration sailing: 29.54, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DSA', 'TEB', 'HDA', 'DUS'], Total Distance: 305.79, Total Demand: 61.0, Duration sailing: 30.58, Duration lossing: 8.47
# Shortest Route: ['DUS', 'SLA', 'SLB', 'DSA', 'DUS'], Total Distance: 242.35, Total Demand: 40.0, Duration sailing: 24.23, Duration lossing: 5.56
# Shortest Route: ['DUS', 'DSA', 'TEB', 'SLA', 'DUS'], Total Distance: 253.08, Total Demand: 47.0, Duration sailing: 25.31, Duration lossing: 6.53
# Shortest Route: ['DUS', 'DSA', 'SLB', 'TEB', 'DUS'], Total Distance: 252.49, Total Demand: 50.0, Duration sailing: 25.25, Duration lossing: 6.95
# Shortest Route: ['DUS', 'GKR', 'GUD', 'JSF', 'DUS'], Total Distance: 247.77, Total Demand: 76.0, Duration sailing: 24.78, Duration lossing: 10.56
# Shortest Route: ['DUS', 'GKR', 'GUD', 'GRA', 'DUS'], Total Distance: 254.15, Total Demand: 50.0, Duration sailing: 25.42, Duration lossing: 6.95
# Shortest Route: ['DUS', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 283.39, Total Demand: 54.0, Duration sailing: 28.34, Duration lossing: 7.5
# Shortest Route: ['DUS', 'SLA', 'GKR', 'GUD', 'DUS'], Total Distance: 258.53, Total Demand: 40.0, Duration sailing: 25.85, Duration lossing: 5.56
# Shortest Route: ['DUS', 'SLB', 'GKR', 'GUD', 'DUS'], Total Distance: 258.41, Total Demand: 43.0, Duration sailing: 25.84, Duration lossing: 5.97
# Shortest Route: ['DUS', 'GUD', 'GKR', 'TEB', 'DUS'], Total Distance: 268.3, Total Demand: 50.0, Duration sailing: 26.83, Duration lossing: 6.95
# Shortest Route: ['DUS', 'JSF', 'GKR', 'GRA', 'DUS'], Total Distance: 252.73, Total Demand: 72.0, Duration sailing: 25.27, Duration lossing: 10.0
# Shortest Route: ['DUS', 'JSF', 'GKR', 'HDA', 'DUS'], Total Distance: 285.07, Total Demand: 76.0, Duration sailing: 28.51, Duration lossing: 10.56
# Shortest Route: ['DUS', 'SLA', 'GKR', 'JSF', 'DUS'], Total Distance: 247.72, Total Demand: 62.0, Duration sailing: 24.77, Duration lossing: 8.61
# Shortest Route: ['DUS', 'SLB', 'GKR', 'JSF', 'DUS'], Total Distance: 247.6, Total Demand: 65.0, Duration sailing: 24.76, Duration lossing: 9.03
# Shortest Route: ['DUS', 'JSF', 'GKR', 'TEB', 'DUS'], Total Distance: 257.49, Total Demand: 72.0, Duration sailing: 25.75, Duration lossing: 10.0
# Shortest Route: ['DUS', 'GKR', 'GRA', 'HDA', 'DUS'], Total Distance: 289.7, Total Demand: 50.0, Duration sailing: 28.97, Duration lossing: 6.95
# Shortest Route: ['DUS', 'GRA', 'GKR', 'SLA', 'DUS'], Total Distance: 261.59, Total Demand: 36.0, Duration sailing: 26.16, Duration lossing: 5.0
# Shortest Route: ['DUS', 'GRA', 'GKR', 'SLB', 'DUS'], Total Distance: 261.47, Total Demand: 39.0, Duration sailing: 26.15, Duration lossing: 5.42
# Shortest Route: ['DUS', 'GRA', 'GKR', 'TEB', 'DUS'], Total Distance: 271.36, Total Demand: 46.0, Duration sailing: 27.14, Duration lossing: 6.39
# Shortest Route: ['DUS', 'SLA', 'GKR', 'HDA', 'DUS'], Total Distance: 293.93, Total Demand: 40.0, Duration sailing: 29.39, Duration lossing: 5.56
# Shortest Route: ['DUS', 'SLB', 'GKR', 'HDA', 'DUS'], Total Distance: 293.81, Total Demand: 43.0, Duration sailing: 29.38, Duration lossing: 5.97
# Shortest Route: ['DUS', 'HDA', 'GKR', 'TEB', 'DUS'], Total Distance: 303.7, Total Demand: 50.0, Duration sailing: 30.37, Duration lossing: 6.95
# Shortest Route: ['DUS', 'GKR', 'SLB', 'SLA', 'DUS'], Total Distance: 247.52, Total Demand: 29.0, Duration sailing: 24.75, Duration lossing: 4.03
# Shortest Route: ['DUS', 'GKR', 'TEB', 'SLA', 'DUS'], Total Distance: 256.0, Total Demand: 36.0, Duration sailing: 25.6, Duration lossing: 5.0
# Shortest Route: ['DUS', 'GKR', 'TEB', 'SLB', 'DUS'], Total Distance: 255.51, Total Demand: 39.0, Duration sailing: 25.55, Duration lossing: 5.42
# Shortest Route: ['DUS', 'JSF', 'GUD', 'GRA', 'DUS'], Total Distance: 233.52, Total Demand: 72.0, Duration sailing: 23.35, Duration lossing: 10.0
# Shortest Route: ['DUS', 'JSF', 'GUD', 'HDA', 'DUS'], Total Distance: 262.76, Total Demand: 76.0, Duration sailing: 26.28, Duration lossing: 10.56
# Shortest Route: ['DUS', 'JSF', 'GUD', 'SLA', 'DUS'], Total Distance: 257.56, Total Demand: 62.0, Duration sailing: 25.76, Duration lossing: 8.61
# Shortest Route: ['DUS', 'SLB', 'GUD', 'JSF', 'DUS'], Total Distance: 258.53, Total Demand: 65.0, Duration sailing: 25.85, Duration lossing: 9.03
# Shortest Route: ['DUS', 'JSF', 'GUD', 'TEB', 'DUS'], Total Distance: 268.16, Total Demand: 72.0, Duration sailing: 26.82, Duration lossing: 10.0
# Shortest Route: ['DUS', 'GRA', 'GUD', 'HDA', 'DUS'], Total Distance: 269.14, Total Demand: 50.0, Duration sailing: 26.91, Duration lossing: 6.95
# Shortest Route: ['DUS', 'GRA', 'GUD', 'SLA', 'DUS'], Total Distance: 263.94, Total Demand: 36.0, Duration sailing: 26.39, Duration lossing: 5.0
# Shortest Route: ['DUS', 'SLB', 'GUD', 'GRA', 'DUS'], Total Distance: 264.91, Total Demand: 39.0, Duration sailing: 26.49, Duration lossing: 5.42
# Shortest Route: ['DUS', 'GRA', 'GUD', 'TEB', 'DUS'], Total Distance: 274.54, Total Demand: 46.0, Duration sailing: 27.45, Duration lossing: 6.39
# Shortest Route: ['DUS', 'HDA', 'GUD', 'SLA', 'DUS'], Total Distance: 293.18, Total Demand: 40.0, Duration sailing: 29.32, Duration lossing: 5.56
# Shortest Route: ['DUS', 'HDA', 'GUD', 'SLB', 'DUS'], Total Distance: 294.15, Total Demand: 43.0, Duration sailing: 29.42, Duration lossing: 5.97
# Shortest Route: ['DUS', 'HDA', 'GUD', 'TEB', 'DUS'], Total Distance: 303.78, Total Demand: 50.0, Duration sailing: 30.38, Duration lossing: 6.95
# Shortest Route: ['DUS', 'GUD', 'SLB', 'SLA', 'DUS'], Total Distance: 260.35, Total Demand: 29.0, Duration sailing: 26.03, Duration lossing: 4.03
# Shortest Route: ['DUS', 'GUD', 'TEB', 'SLA', 'DUS'], Total Distance: 268.57, Total Demand: 36.0, Duration sailing: 26.86, Duration lossing: 5.0
# Shortest Route: ['DUS', 'GUD', 'TEB', 'SLB', 'DUS'], Total Distance: 268.08, Total Demand: 39.0, Duration sailing: 26.81, Duration lossing: 5.42
# Shortest Route: ['DUS', 'JSF', 'GRA', 'HDA', 'DUS'], Total Distance: 236.7, Total Demand: 72.0, Duration sailing: 23.67, Duration lossing: 10.0
# Shortest Route: ['DUS', 'GRA', 'JSF', 'SLA', 'DUS'], Total Distance: 259.25, Total Demand: 58.0, Duration sailing: 25.92, Duration lossing: 8.06
# Shortest Route: ['DUS', 'GRA', 'JSF', 'SLB', 'DUS'], Total Distance: 265.09, Total Demand: 61.0, Duration sailing: 26.51, Duration lossing: 8.47
# Shortest Route: ['DUS', 'JSF', 'TEB', 'GRA', 'DUS'], Total Distance: 276.4, Total Demand: 68.0, Duration sailing: 27.64, Duration lossing: 9.45
# Shortest Route: ['DUS', 'HDA', 'JSF', 'SLA', 'DUS'], Total Distance: 298.1, Total Demand: 62.0, Duration sailing: 29.81, Duration lossing: 8.61
# Shortest Route: ['DUS', 'JSF', 'SLB', 'HDA', 'DUS'], Total Distance: 298.72, Total Demand: 65.0, Duration sailing: 29.87, Duration lossing: 9.03
# Shortest Route: ['DUS', 'JSF', 'TEB', 'HDA', 'DUS'], Total Distance: 308.92, Total Demand: 72.0, Duration sailing: 30.89, Duration lossing: 10.0
# Shortest Route: ['DUS', 'JSF', 'SLB', 'SLA', 'DUS'], Total Distance: 245.64, Total Demand: 51.0, Duration sailing: 24.56, Duration lossing: 7.08
# Shortest Route: ['DUS', 'JSF', 'TEB', 'SLA', 'DUS'], Total Distance: 256.21, Total Demand: 58.0, Duration sailing: 25.62, Duration lossing: 8.06
# Shortest Route: ['DUS', 'JSF', 'TEB', 'SLB', 'DUS'], Total Distance: 255.72, Total Demand: 61.0, Duration sailing: 25.57, Duration lossing: 8.47
# Shortest Route: ['DUS', 'HDA', 'GRA', 'SLA', 'DUS'], Total Distance: 294.88, Total Demand: 36.0, Duration sailing: 29.49, Duration lossing: 5.0
# Shortest Route: ['DUS', 'HDA', 'GRA', 'SLB', 'DUS'], Total Distance: 298.9, Total Demand: 39.0, Duration sailing: 29.89, Duration lossing: 5.42
# Shortest Route: ['DUS', 'HDA', 'GRA', 'TEB', 'DUS'], Total Distance: 310.17, Total Demand: 46.0, Duration sailing: 31.02, Duration lossing: 6.39
# Shortest Route: ['DUS', 'GRA', 'SLB', 'SLA', 'DUS'], Total Distance: 261.85, Total Demand: 25.0, Duration sailing: 26.18, Duration lossing: 3.47
# Shortest Route: ['DUS', 'GRA', 'TEB', 'SLA', 'DUS'], Total Distance: 271.71, Total Demand: 32.0, Duration sailing: 27.17, Duration lossing: 4.44
# Shortest Route: ['DUS', 'GRA', 'TEB', 'SLB', 'DUS'], Total Distance: 271.22, Total Demand: 35.0, Duration sailing: 27.12, Duration lossing: 4.86
# Shortest Route: ['DUS', 'HDA', 'SLB', 'SLA', 'DUS'], Total Distance: 295.38, Total Demand: 29.0, Duration sailing: 29.54, Duration lossing: 4.03
# Shortest Route: ['DUS', 'HDA', 'TEB', 'SLA', 'DUS'], Total Distance: 304.23, Total Demand: 36.0, Duration sailing: 30.42, Duration lossing: 5.0
# Shortest Route: ['DUS', 'HDA', 'TEB', 'SLB', 'DUS'], Total Distance: 303.74, Total Demand: 39.0, Duration sailing: 30.37, Duration lossing: 5.42
# Shortest Route: ['DUS', 'SLA', 'TEB', 'SLB', 'DUS'], Total Distance: 251.03, Total Demand: 25.0, Duration sailing: 25.1, Duration lossing: 3.47
# Shortest Route: ['DUS', 'DRA', 'DSA', 'DAB', 'GRA', 'DUS'], Total Distance: 257.33, Total Demand: 97.0, Duration sailing: 25.73, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DAB', 'DSA', 'SLA', 'DRA', 'DUS'], Total Distance: 278.43, Total Demand: 87.0, Duration sailing: 27.84, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DRA', 'SLB', 'DAB', 'DSA', 'DUS'], Total Distance: 286.47, Total Demand: 90.0, Duration sailing: 28.65, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DRA', 'TEB', 'DAB', 'DSA', 'DUS'], Total Distance: 295.19, Total Demand: 97.0, Duration sailing: 29.52, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'GKR', 'GUD', 'DAB', 'DUS'], Total Distance: 272.97, Total Demand: 90.0, Duration sailing: 27.3, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DRA', 'GKR', 'DAB', 'GRA', 'DUS'], Total Distance: 270.07, Total Demand: 86.0, Duration sailing: 27.01, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'GKR', 'DAB', 'HDA', 'DUS'], Total Distance: 306.18, Total Demand: 90.0, Duration sailing: 30.62, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GKR', 'DAB', 'DUS'], Total Distance: 271.19, Total Demand: 76.0, Duration sailing: 27.12, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DAB', 'GKR', 'SLB', 'DRA', 'DUS'], Total Distance: 273.07, Total Demand: 79.0, Duration sailing: 27.31, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DAB', 'GKR', 'TEB', 'DRA', 'DUS'], Total Distance: 280.54, Total Demand: 86.0, Duration sailing: 28.05, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'GUD', 'DAB', 'GRA', 'DUS'], Total Distance: 268.71, Total Demand: 86.0, Duration sailing: 26.87, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'GUD', 'DAB', 'HDA', 'DUS'], Total Distance: 304.82, Total Demand: 90.0, Duration sailing: 30.48, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DAB', 'GUD', 'SLA', 'DRA', 'DUS'], Total Distance: 273.06, Total Demand: 76.0, Duration sailing: 27.31, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GUD', 'DAB', 'DUS'], Total Distance: 276.03, Total Demand: 79.0, Duration sailing: 27.6, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DAB', 'GUD', 'TEB', 'DRA', 'DUS'], Total Distance: 283.24, Total Demand: 86.0, Duration sailing: 28.32, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'SLA', 'JSF', 'DAB', 'DUS'], Total Distance: 270.81, Total Demand: 98.0, Duration sailing: 27.08, Duration lossing: 13.61
# Shortest Route: ['DUS', 'DRA', 'DAB', 'GRA', 'HDA', 'DUS'], Total Distance: 292.47, Total Demand: 86.0, Duration sailing: 29.25, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'SLA', 'DAB', 'GRA', 'DUS'], Total Distance: 266.07, Total Demand: 72.0, Duration sailing: 26.61, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DRA', 'SLB', 'DAB', 'GRA', 'DUS'], Total Distance: 271.79, Total Demand: 75.0, Duration sailing: 27.18, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'TEB', 'DAB', 'GRA', 'DUS'], Total Distance: 280.51, Total Demand: 82.0, Duration sailing: 28.05, Duration lossing: 11.39
# Shortest Route: ['DUS', 'DRA', 'SLA', 'DAB', 'HDA', 'DUS'], Total Distance: 302.18, Total Demand: 76.0, Duration sailing: 30.22, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DRA', 'SLB', 'DAB', 'HDA', 'DUS'], Total Distance: 307.9, Total Demand: 79.0, Duration sailing: 30.79, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DRA', 'TEB', 'DAB', 'HDA', 'DUS'], Total Distance: 316.62, Total Demand: 86.0, Duration sailing: 31.66, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DAB', 'SLB', 'SLA', 'DRA', 'DUS'], Total Distance: 271.67, Total Demand: 65.0, Duration sailing: 27.17, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'DAB', 'DUS'], Total Distance: 281.4, Total Demand: 72.0, Duration sailing: 28.14, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DAB', 'SLB', 'TEB', 'DRA', 'DUS'], Total Distance: 281.39, Total Demand: 75.0, Duration sailing: 28.14, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DAB', 'GKR', 'SLA', 'DSA', 'DUS'], Total Distance: 266.03, Total Demand: 91.0, Duration sailing: 26.6, Duration lossing: 12.64
# Shortest Route: ['DUS', 'DAB', 'GKR', 'SLB', 'DSA', 'DUS'], Total Distance: 264.2, Total Demand: 94.0, Duration sailing: 26.42, Duration lossing: 13.06
# Shortest Route: ['DUS', 'DAB', 'GUD', 'SLA', 'DSA', 'DUS'], Total Distance: 267.9, Total Demand: 91.0, Duration sailing: 26.79, Duration lossing: 12.64
# Shortest Route: ['DUS', 'DAB', 'GUD', 'SLB', 'DSA', 'DUS'], Total Distance: 267.16, Total Demand: 94.0, Duration sailing: 26.72, Duration lossing: 13.06
# Shortest Route: ['DUS', 'DSA', 'SLA', 'DAB', 'GRA', 'DUS'], Total Distance: 260.91, Total Demand: 87.0, Duration sailing: 26.09, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DSA', 'SLB', 'DAB', 'GRA', 'DUS'], Total Distance: 262.92, Total Demand: 90.0, Duration sailing: 26.29, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'TEB', 'DAB', 'GRA', 'DUS'], Total Distance: 274.16, Total Demand: 97.0, Duration sailing: 27.42, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DSA', 'SLA', 'DAB', 'HDA', 'DUS'], Total Distance: 297.02, Total Demand: 91.0, Duration sailing: 29.7, Duration lossing: 12.64
# Shortest Route: ['DUS', 'DSA', 'SLB', 'DAB', 'HDA', 'DUS'], Total Distance: 299.03, Total Demand: 94.0, Duration sailing: 29.9, Duration lossing: 13.06
# Shortest Route: ['DUS', 'DAB', 'SLB', 'SLA', 'DSA', 'DUS'], Total Distance: 266.51, Total Demand: 80.0, Duration sailing: 26.65, Duration lossing: 11.11
# Shortest Route: ['DUS', 'DAB', 'TEB', 'SLA', 'DSA', 'DUS'], Total Distance: 276.24, Total Demand: 87.0, Duration sailing: 27.62, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DAB', 'TEB', 'SLB', 'DSA', 'DUS'], Total Distance: 274.04, Total Demand: 90.0, Duration sailing: 27.4, Duration lossing: 12.5
# Shortest Route: ['DUS', 'GKR', 'GUD', 'DAB', 'GRA', 'DUS'], Total Distance: 254.47, Total Demand: 90.0, Duration sailing: 25.45, Duration lossing: 12.5
# Shortest Route: ['DUS', 'GKR', 'GUD', 'DAB', 'HDA', 'DUS'], Total Distance: 290.58, Total Demand: 94.0, Duration sailing: 29.06, Duration lossing: 13.06
# Shortest Route: ['DUS', 'SLA', 'GKR', 'GUD', 'DAB', 'DUS'], Total Distance: 265.29, Total Demand: 80.0, Duration sailing: 26.53, Duration lossing: 11.11
# Shortest Route: ['DUS', 'SLB', 'GKR', 'GUD', 'DAB', 'DUS'], Total Distance: 265.17, Total Demand: 83.0, Duration sailing: 26.52, Duration lossing: 11.53
# Shortest Route: ['DUS', 'DAB', 'GUD', 'GKR', 'TEB', 'DUS'], Total Distance: 275.06, Total Demand: 90.0, Duration sailing: 27.51, Duration lossing: 12.5
# Shortest Route: ['DUS', 'GKR', 'DAB', 'GRA', 'HDA', 'DUS'], Total Distance: 290.5, Total Demand: 90.0, Duration sailing: 29.05, Duration lossing: 12.5
# Shortest Route: ['DUS', 'GRA', 'DAB', 'GKR', 'SLA', 'DUS'], Total Distance: 262.39, Total Demand: 76.0, Duration sailing: 26.24, Duration lossing: 10.56
# Shortest Route: ['DUS', 'GRA', 'DAB', 'GKR', 'SLB', 'DUS'], Total Distance: 262.27, Total Demand: 79.0, Duration sailing: 26.23, Duration lossing: 10.97
# Shortest Route: ['DUS', 'GRA', 'DAB', 'GKR', 'TEB', 'DUS'], Total Distance: 272.16, Total Demand: 86.0, Duration sailing: 27.22, Duration lossing: 11.95
# Shortest Route: ['DUS', 'HDA', 'DAB', 'GKR', 'SLA', 'DUS'], Total Distance: 298.5, Total Demand: 80.0, Duration sailing: 29.85, Duration lossing: 11.11
# Shortest Route: ['DUS', 'HDA', 'DAB', 'GKR', 'SLB', 'DUS'], Total Distance: 298.38, Total Demand: 83.0, Duration sailing: 29.84, Duration lossing: 11.53
# Shortest Route: ['DUS', 'HDA', 'DAB', 'GKR', 'TEB', 'DUS'], Total Distance: 308.27, Total Demand: 90.0, Duration sailing: 30.83, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DAB', 'GKR', 'SLB', 'SLA', 'DUS'], Total Distance: 264.15, Total Demand: 69.0, Duration sailing: 26.42, Duration lossing: 9.58
# Shortest Route: ['DUS', 'DAB', 'GKR', 'TEB', 'SLA', 'DUS'], Total Distance: 272.63, Total Demand: 76.0, Duration sailing: 27.26, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DAB', 'GKR', 'TEB', 'SLB', 'DUS'], Total Distance: 272.14, Total Demand: 79.0, Duration sailing: 27.21, Duration lossing: 10.97
# Shortest Route: ['DUS', 'GRA', 'DAB', 'GUD', 'HDA', 'DUS'], Total Distance: 269.46, Total Demand: 90.0, Duration sailing: 26.95, Duration lossing: 12.5
# Shortest Route: ['DUS', 'GRA', 'DAB', 'GUD', 'SLA', 'DUS'], Total Distance: 264.26, Total Demand: 76.0, Duration sailing: 26.43, Duration lossing: 10.56
# Shortest Route: ['DUS', 'GRA', 'DAB', 'GUD', 'SLB', 'DUS'], Total Distance: 265.23, Total Demand: 79.0, Duration sailing: 26.52, Duration lossing: 10.97
# Shortest Route: ['DUS', 'GRA', 'DAB', 'GUD', 'TEB', 'DUS'], Total Distance: 274.86, Total Demand: 86.0, Duration sailing: 27.49, Duration lossing: 11.95
# Shortest Route: ['DUS', 'HDA', 'DAB', 'GUD', 'SLA', 'DUS'], Total Distance: 300.37, Total Demand: 80.0, Duration sailing: 30.04, Duration lossing: 11.11
# Shortest Route: ['DUS', 'HDA', 'DAB', 'GUD', 'SLB', 'DUS'], Total Distance: 301.34, Total Demand: 83.0, Duration sailing: 30.13, Duration lossing: 11.53
# Shortest Route: ['DUS', 'HDA', 'DAB', 'GUD', 'TEB', 'DUS'], Total Distance: 310.97, Total Demand: 90.0, Duration sailing: 31.1, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DAB', 'GUD', 'SLB', 'SLA', 'DUS'], Total Distance: 267.11, Total Demand: 69.0, Duration sailing: 26.71, Duration lossing: 9.58
# Shortest Route: ['DUS', 'DAB', 'GUD', 'TEB', 'SLA', 'DUS'], Total Distance: 275.33, Total Demand: 76.0, Duration sailing: 27.53, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DAB', 'GUD', 'TEB', 'SLB', 'DUS'], Total Distance: 274.84, Total Demand: 79.0, Duration sailing: 27.48, Duration lossing: 10.97
# Shortest Route: ['DUS', 'GRA', 'DAB', 'JSF', 'SLA', 'DUS'], Total Distance: 262.01, Total Demand: 98.0, Duration sailing: 26.2, Duration lossing: 13.61
# Shortest Route: ['DUS', 'SLA', 'SLB', 'JSF', 'DAB', 'DUS'], Total Distance: 269.73, Total Demand: 91.0, Duration sailing: 26.97, Duration lossing: 12.64
# Shortest Route: ['DUS', 'DAB', 'JSF', 'TEB', 'SLA', 'DUS'], Total Distance: 280.3, Total Demand: 98.0, Duration sailing: 28.03, Duration lossing: 13.61
# Shortest Route: ['DUS', 'HDA', 'GRA', 'DAB', 'SLA', 'DUS'], Total Distance: 296.2, Total Demand: 76.0, Duration sailing: 29.62, Duration lossing: 10.56
# Shortest Route: ['DUS', 'HDA', 'GRA', 'DAB', 'SLB', 'DUS'], Total Distance: 299.92, Total Demand: 79.0, Duration sailing: 29.99, Duration lossing: 10.97
# Shortest Route: ['DUS', 'HDA', 'GRA', 'DAB', 'TEB', 'DUS'], Total Distance: 311.06, Total Demand: 86.0, Duration sailing: 31.11, Duration lossing: 11.95
# Shortest Route: ['DUS', 'GRA', 'DAB', 'SLB', 'SLA', 'DUS'], Total Distance: 262.87, Total Demand: 65.0, Duration sailing: 26.29, Duration lossing: 9.03
# Shortest Route: ['DUS', 'GRA', 'DAB', 'TEB', 'SLA', 'DUS'], Total Distance: 272.6, Total Demand: 72.0, Duration sailing: 27.26, Duration lossing: 10.0
# Shortest Route: ['DUS', 'GRA', 'DAB', 'TEB', 'SLB', 'DUS'], Total Distance: 272.11, Total Demand: 75.0, Duration sailing: 27.21, Duration lossing: 10.42
# Shortest Route: ['DUS', 'HDA', 'DAB', 'SLB', 'SLA', 'DUS'], Total Distance: 298.98, Total Demand: 69.0, Duration sailing: 29.9, Duration lossing: 9.58
# Shortest Route: ['DUS', 'HDA', 'DAB', 'TEB', 'SLA', 'DUS'], Total Distance: 308.71, Total Demand: 76.0, Duration sailing: 30.87, Duration lossing: 10.56
# Shortest Route: ['DUS', 'HDA', 'DAB', 'TEB', 'SLB', 'DUS'], Total Distance: 308.22, Total Demand: 79.0, Duration sailing: 30.82, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DAB', 'SLB', 'TEB', 'SLA', 'DUS'], Total Distance: 273.48, Total Demand: 65.0, Duration sailing: 27.35, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DRA', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 267.41, Total Demand: 79.0, Duration sailing: 26.74, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DSA', 'DRA', 'GKR', 'GRA', 'DUS'], Total Distance: 284.86, Total Demand: 75.0, Duration sailing: 28.49, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DSA', 'DRA', 'GKR', 'HDA', 'DUS'], Total Distance: 317.2, Total Demand: 79.0, Duration sailing: 31.72, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GKR', 'DSA', 'DUS'], Total Distance: 254.92, Total Demand: 65.0, Duration sailing: 25.49, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GKR', 'DSA', 'DUS'], Total Distance: 256.8, Total Demand: 68.0, Duration sailing: 25.68, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DSA', 'GKR', 'TEB', 'DRA', 'DUS'], Total Distance: 264.27, Total Demand: 75.0, Duration sailing: 26.43, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DSA', 'DRA', 'GUD', 'GRA', 'DUS'], Total Distance: 283.98, Total Demand: 75.0, Duration sailing: 28.4, Duration lossing: 10.42
# Shortest Route: ['DUS', 'HDA', 'GUD', 'DRA', 'DSA', 'DUS'], Total Distance: 313.22, Total Demand: 79.0, Duration sailing: 31.32, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GUD', 'DSA', 'DUS'], Total Distance: 267.5, Total Demand: 65.0, Duration sailing: 26.75, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GUD', 'DSA', 'DUS'], Total Distance: 270.47, Total Demand: 68.0, Duration sailing: 27.05, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GUD', 'DSA', 'DUS'], Total Distance: 277.68, Total Demand: 75.0, Duration sailing: 27.77, Duration lossing: 10.42
# Shortest Route: ['DUS', 'GRA', 'JSF', 'DSA', 'DRA', 'DUS'], Total Distance: 256.07, Total Demand: 97.0, Duration sailing: 25.61, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'JSF', 'DSA', 'DUS'], Total Distance: 248.6, Total Demand: 87.0, Duration sailing: 24.86, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DRA', 'SLB', 'JSF', 'DSA', 'DUS'], Total Distance: 256.44, Total Demand: 90.0, Duration sailing: 25.64, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'JSF', 'TEB', 'DRA', 'DUS'], Total Distance: 266.0, Total Demand: 97.0, Duration sailing: 26.6, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'DSA', 'GRA', 'HDA', 'DUS'], Total Distance: 293.0, Total Demand: 75.0, Duration sailing: 29.3, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'SLA', 'DSA', 'GRA', 'DUS'], Total Distance: 275.17, Total Demand: 61.0, Duration sailing: 27.52, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DRA', 'SLB', 'DSA', 'GRA', 'DUS'], Total Distance: 284.26, Total Demand: 64.0, Duration sailing: 28.43, Duration lossing: 8.89
# Shortest Route: ['DUS', 'DRA', 'TEB', 'DSA', 'GRA', 'DUS'], Total Distance: 293.98, Total Demand: 71.0, Duration sailing: 29.4, Duration lossing: 9.86
# Shortest Route: ['DUS', 'DRA', 'SLA', 'DSA', 'HDA', 'DUS'], Total Distance: 314.21, Total Demand: 65.0, Duration sailing: 31.42, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLB', 'HDA', 'DUS'], Total Distance: 319.89, Total Demand: 68.0, Duration sailing: 31.99, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DSA', 'DRA', 'TEB', 'HDA', 'DUS'], Total Distance: 327.73, Total Demand: 75.0, Duration sailing: 32.77, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DSA', 'SLB', 'SLA', 'DRA', 'DUS'], Total Distance: 251.28, Total Demand: 54.0, Duration sailing: 25.13, Duration lossing: 7.5
# ...
# Shortest Route: ['DUS', 'GRA', 'DAB', 'GKR', 'TEB', 'SLB', 'SLA', 'DUS'], Total Distance: 274.28, Total Demand: 97.0, Duration sailing: 27.43, Duration lossing: 13.47
# Shortest Route: ['DUS', 'GRA', 'DAB', 'GUD', 'TEB', 'SLB', 'SLA', 'DUS'], Total Distance: 276.98, Total Demand: 97.0, Duration sailing: 27.7, Duration lossing: 13.47
# Shortest Route: ['DUS', 'HDA', 'GRA', 'DAB', 'SLB', 'TEB', 'SLA', 'DUS'], Total Distance: 312.67, Total Demand: 97.0, Duration sailing: 31.27, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'GKR', 'GUD', 'GRA', 'DUS'], Total Distance: 289.62, Total Demand: 97.0, Duration sailing: 28.96, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLB', 'GKR', 'GUD', 'GRA', 'DUS'], Total Distance: 291.5, Total Demand: 100.0, Duration sailing: 29.15, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 270.55, Total Demand: 90.0, Duration sailing: 27.06, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 279.03, Total Demand: 97.0, Duration sailing: 27.9, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 280.27, Total Demand: 100.0, Duration sailing: 28.03, Duration lossing: 13.89
# Shortest Route: ['DUS', 'HDA', 'GRA', 'GKR', 'SLA', 'DRA', 'DSA', 'DUS'], Total Distance: 325.17, Total Demand: 97.0, Duration sailing: 32.52, Duration lossing: 13.47
# Shortest Route: ['DUS', 'HDA', 'GRA', 'GKR', 'SLB', 'DRA', 'DSA', 'DUS'], Total Distance: 327.05, Total Demand: 100.0, Duration sailing: 32.7, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'SLB', 'GKR', 'GRA', 'DUS'], Total Distance: 288.0, Total Demand: 86.0, Duration sailing: 28.8, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'TEB', 'GKR', 'GRA', 'DUS'], Total Distance: 296.48, Total Demand: 93.0, Duration sailing: 29.65, Duration lossing: 12.92
# Shortest Route: ['DUS', 'DSA', 'DRA', 'TEB', 'SLB', 'GKR', 'GRA', 'DUS'], Total Distance: 297.72, Total Demand: 96.0, Duration sailing: 29.77, Duration lossing: 13.33
# Shortest Route: ['DUS', 'HDA', 'GKR', 'SLB', 'SLA', 'DRA', 'DSA', 'DUS'], Total Distance: 320.34, Total Demand: 90.0, Duration sailing: 32.03, Duration lossing: 12.5
# Shortest Route: ['DUS', 'HDA', 'GKR', 'TEB', 'SLA', 'DRA', 'DSA', 'DUS'], Total Distance: 328.82, Total Demand: 97.0, Duration sailing: 32.88, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DSA', 'DRA', 'TEB', 'SLB', 'GKR', 'HDA', 'DUS'], Total Distance: 330.06, Total Demand: 100.0, Duration sailing: 33.01, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'DSA', 'DUS'], Total Distance: 266.81, Total Demand: 86.0, Duration sailing: 26.68, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 327.52, Total Demand: 97.0, Duration sailing: 32.75, Duration lossing: 13.47
# Shortest Route: ['DUS', 'HDA', 'GRA', 'GUD', 'SLB', 'DRA', 'DSA', 'DUS'], Total Distance: 330.49, Total Demand: 100.0, Duration sailing: 33.05, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'SLB', 'GUD', 'GRA', 'DUS'], Total Distance: 291.44, Total Demand: 86.0, Duration sailing: 29.14, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'TEB', 'GUD', 'GRA', 'DUS'], Total Distance: 299.66, Total Demand: 93.0, Duration sailing: 29.97, Duration lossing: 12.92
# Shortest Route: ['DUS', 'DSA', 'DRA', 'TEB', 'SLB', 'GUD', 'GRA', 'DUS'], Total Distance: 301.16, Total Demand: 96.0, Duration sailing: 30.12, Duration lossing: 13.33
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'SLB', 'GUD', 'HDA', 'DUS'], Total Distance: 320.68, Total Demand: 90.0, Duration sailing: 32.07, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 328.9, Total Demand: 97.0, Duration sailing: 32.89, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DSA', 'DRA', 'TEB', 'SLB', 'GUD', 'HDA', 'DUS'], Total Distance: 330.4, Total Demand: 100.0, Duration sailing: 33.04, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'DSA', 'DUS'], Total Distance: 280.22, Total Demand: 86.0, Duration sailing: 28.02, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'DSA', 'GRA', 'HDA', 'DUS'], Total Distance: 323.33, Total Demand: 86.0, Duration sailing: 32.33, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'DSA', 'GRA', 'HDA', 'DUS'], Total Distance: 334.06, Total Demand: 93.0, Duration sailing: 33.41, Duration lossing: 12.92
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'DSA', 'GRA', 'HDA', 'DUS'], Total Distance: 333.05, Total Demand: 96.0, Duration sailing: 33.3, Duration lossing: 13.33
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'SLB', 'DSA', 'GRA', 'DUS'], Total Distance: 295.01, Total Demand: 82.0, Duration sailing: 29.5, Duration lossing: 11.39
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'SLB', 'TEB', 'HDA', 'DUS'], Total Distance: 330.27, Total Demand: 86.0, Duration sailing: 33.03, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GKR', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 313.09, Total Demand: 86.0, Duration sailing: 31.31, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GKR', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 314.97, Total Demand: 89.0, Duration sailing: 31.5, Duration lossing: 12.36
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GKR', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 322.44, Total Demand: 96.0, Duration sailing: 32.24, Duration lossing: 13.33
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'GUD', 'GRA', 'DUS'], Total Distance: 275.92, Total Demand: 75.0, Duration sailing: 27.59, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GKR', 'GUD', 'GRA', 'DUS'], Total Distance: 284.4, Total Demand: 82.0, Duration sailing: 28.44, Duration lossing: 11.39
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GKR', 'GUD', 'GRA', 'DUS'], Total Distance: 285.64, Total Demand: 85.0, Duration sailing: 28.56, Duration lossing: 11.81
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 305.16, Total Demand: 79.0, Duration sailing: 30.52, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 313.64, Total Demand: 86.0, Duration sailing: 31.36, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 314.88, Total Demand: 89.0, Duration sailing: 31.49, Duration lossing: 12.36
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'DUS'], Total Distance: 279.35, Total Demand: 75.0, Duration sailing: 27.94, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'JSF', 'GRA', 'DUS'], Total Distance: 280.0, Total Demand: 97.0, Duration sailing: 28.0, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'JSF', 'DUS'], Total Distance: 268.54, Total Demand: 97.0, Duration sailing: 26.85, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'GRA', 'HDA', 'DUS'], Total Distance: 311.47, Total Demand: 75.0, Duration sailing: 31.15, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GKR', 'GRA', 'HDA', 'DUS'], Total Distance: 319.95, Total Demand: 82.0, Duration sailing: 32.0, Duration lossing: 11.39
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GKR', 'GRA', 'HDA', 'DUS'], Total Distance: 321.19, Total Demand: 85.0, Duration sailing: 32.12, Duration lossing: 11.81
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'GRA', 'DUS'], Total Distance: 282.41, Total Demand: 71.0, Duration sailing: 28.24, Duration lossing: 9.86
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'HDA', 'DUS'], Total Distance: 314.75, Total Demand: 75.0, Duration sailing: 31.48, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GUD', 'JSF', 'GRA', 'DUS'], Total Distance: 290.93, Total Demand: 97.0, Duration sailing: 29.09, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'JSF', 'DUS'], Total Distance: 279.21, Total Demand: 97.0, Duration sailing: 27.92, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 314.91, Total Demand: 75.0, Duration sailing: 31.49, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 323.13, Total Demand: 82.0, Duration sailing: 32.31, Duration lossing: 11.39
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 324.63, Total Demand: 85.0, Duration sailing: 32.46, Duration lossing: 11.81
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'GRA', 'DUS'], Total Distance: 285.59, Total Demand: 71.0, Duration sailing: 28.56, Duration lossing: 9.86
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 314.83, Total Demand: 75.0, Duration sailing: 31.48, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'JSF', 'GRA', 'HDA', 'DUS'], Total Distance: 315.09, Total Demand: 97.0, Duration sailing: 31.51, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'SLB', 'JSF', 'GRA', 'DUS'], Total Distance: 286.77, Total Demand: 93.0, Duration sailing: 28.68, Duration lossing: 12.92
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'SLB', 'JSF', 'HDA', 'DUS'], Total Distance: 325.62, Total Demand: 97.0, Duration sailing: 32.56, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'SLB', 'GRA', 'HDA', 'DUS'], Total Distance: 320.58, Total Demand: 71.0, Duration sailing: 32.06, Duration lossing: 9.86
# Shortest Route: ['DUS', 'DSA', 'SLA', 'SLB', 'GKR', 'GUD', 'GRA', 'DUS'], Total Distance: 270.76, Total Demand: 90.0, Duration sailing: 27.08, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'SLA', 'TEB', 'GKR', 'GUD', 'GRA', 'DUS'], Total Distance: 279.24, Total Demand: 97.0, Duration sailing: 27.92, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DSA', 'SLB', 'TEB', 'GKR', 'GUD', 'GRA', 'DUS'], Total Distance: 277.04, Total Demand: 100.0, Duration sailing: 27.7, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DSA', 'SLA', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 300.0, Total Demand: 94.0, Duration sailing: 30.0, Duration lossing: 13.06
# Shortest Route: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 271.62, Total Demand: 90.0, Duration sailing: 27.16, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'SLA', 'SLB', 'GKR', 'GRA', 'HDA', 'DUS'], Total Distance: 306.31, Total Demand: 90.0, Duration sailing: 30.63, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'SLA', 'TEB', 'GKR', 'GRA', 'HDA', 'DUS'], Total Distance: 314.79, Total Demand: 97.0, Duration sailing: 31.48, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DSA', 'SLB', 'TEB', 'GKR', 'GRA', 'HDA', 'DUS'], Total Distance: 312.59, Total Demand: 100.0, Duration sailing: 31.26, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DSA', 'SLA', 'SLB', 'TEB', 'GKR', 'GRA', 'DUS'], Total Distance: 277.25, Total Demand: 86.0, Duration sailing: 27.72, Duration lossing: 11.95
# Shortest Route: ['DUS', 'HDA', 'GKR', 'TEB', 'SLB', 'SLA', 'DSA', 'DUS'], Total Distance: 309.59, Total Demand: 90.0, Duration sailing: 30.96, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'SLA', 'SLB', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 309.75, Total Demand: 90.0, Duration sailing: 30.98, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'SLA', 'TEB', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 317.97, Total Demand: 97.0, Duration sailing: 31.8, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DSA', 'SLB', 'TEB', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 315.77, Total Demand: 100.0, Duration sailing: 31.58, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DSA', 'SLA', 'SLB', 'TEB', 'GUD', 'GRA', 'DUS'], Total Distance: 280.43, Total Demand: 86.0, Duration sailing: 28.04, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DSA', 'SLA', 'SLB', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 309.67, Total Demand: 90.0, Duration sailing: 30.97, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'SLA', 'TEB', 'SLB', 'GRA', 'HDA', 'DUS'], Total Distance: 315.42, Total Demand: 86.0, Duration sailing: 31.54, Duration lossing: 11.95
# Shortest Route: ['DUS', 'SLA', 'SLB', 'GKR', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 306.05, Total Demand: 79.0, Duration sailing: 30.6, Duration lossing: 10.97
# Shortest Route: ['DUS', 'SLA', 'TEB', 'GKR', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 314.53, Total Demand: 86.0, Duration sailing: 31.45, Duration lossing: 11.95
# Shortest Route: ['DUS', 'SLB', 'TEB', 'GKR', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 314.04, Total Demand: 89.0, Duration sailing: 31.4, Duration lossing: 12.36
# Shortest Route: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'GRA', 'DUS'], Total Distance: 276.99, Total Demand: 75.0, Duration sailing: 27.7, Duration lossing: 10.42
# Shortest Route: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 306.23, Total Demand: 79.0, Duration sailing: 30.62, Duration lossing: 10.97
# Shortest Route: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'JSF', 'GRA', 'DUS'], Total Distance: 281.07, Total Demand: 97.0, Duration sailing: 28.11, Duration lossing: 13.47
# Shortest Route: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'GRA', 'HDA', 'DUS'], Total Distance: 312.54, Total Demand: 75.0, Duration sailing: 31.25, Duration lossing: 10.42
# Shortest Route: ['DUS', 'JSF', 'SLA', 'SLB', 'TEB', 'GUD', 'GRA', 'DUS'], Total Distance: 284.97, Total Demand: 97.0, Duration sailing: 28.5, Duration lossing: 13.47
# Shortest Route: ['DUS', 'HDA', 'GRA', 'GUD', 'TEB', 'SLB', 'SLA', 'DUS'], Total Distance: 315.72, Total Demand: 75.0, Duration sailing: 31.57, Duration lossing: 10.42
# Shortest Route: ['DUS', 'SLA', 'TEB', 'SLB', 'JSF', 'GRA', 'HDA', 'DUS'], Total Distance: 316.9, Total Demand: 97.0, Duration sailing: 31.69, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'GRA', 'DUS'], Total Distance: 298.0, Total Demand: 100.0, Duration sailing: 29.8, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'GRA', 'DUS'], Total Distance: 301.18, Total Demand: 100.0, Duration sailing: 30.12, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'SLB', 'DSA', 'GRA', 'HDA', 'DUS'], Total Distance: 334.07, Total Demand: 100.0, Duration sailing: 33.41, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 314.98, Total Demand: 93.0, Duration sailing: 31.5, Duration lossing: 12.92
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GKR', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 323.46, Total Demand: 100.0, Duration sailing: 32.35, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'GRA', 'DUS'], Total Distance: 285.92, Total Demand: 89.0, Duration sailing: 28.59, Duration lossing: 12.36
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 315.16, Total Demand: 93.0, Duration sailing: 31.52, Duration lossing: 12.92
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'GRA', 'HDA', 'DUS'], Total Distance: 321.47, Total Demand: 89.0, Duration sailing: 32.15, Duration lossing: 12.36
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 324.65, Total Demand: 89.0, Duration sailing: 32.46, Duration lossing: 12.36
# Shortest Route: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'GRA', 'HDA', 'DUS'], Total Distance: 316.05, Total Demand: 93.0, Duration sailing: 31.6, Duration lossing: 12.92
# 858

# %% [markdown]
# ## Saves the shortest routes left to csv files in the generated_datafiles folder. In total 858 routes

# %%
routes_only = [route for route, _, _, _, _ in shortest_routes_dict.values()]
distances_only = [distance for _, distance, _, _, _ in shortest_routes_dict.values()]
demand_only = [demand for _, _, demand, _, _ in shortest_routes_dict.values()]
duration_sailing = [duration_sailing for _, _, _, duration_sailing, _ in shortest_routes_dict.values()]
duration_lossing = [duration_lossing for _, _, _, _, duration_lossing in shortest_routes_dict.values()]

df_distances = pd.DataFrame({'Distance': distances_only})
df_demand = pd.DataFrame({'Demand': demand_only})
df_duration_sailing = pd.DataFrame({'Duration (hours)': duration_sailing})
df_duration_lossing = pd.DataFrame({'Duration (hours)': duration_lossing})

df_distances.to_csv(f'{mappenavn}/distances.csv', index=False)
df_demand.to_csv(f'{mappenavn}/demand.csv', index=False)
df_duration_sailing.to_csv(f'{mappenavn}/duration_sailing.csv', index=False)
df_duration_lossing.to_csv(f'{mappenavn}/duration_lossing.csv', index=False)
route_file = f'{mappenavn}/routes.csv'


def write_to_csv(filename, data):
    with open(filename, "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerows(data)

write_to_csv(route_file, routes_only)

# %% [markdown]
# ## Creating the reduced set of routes

# %%
'''
import csv

def contains_required_routes(route, required_routes):
    return all(required_route in route for required_route in required_routes)

def main():
    hda_additional_routes1 = ["HDA", "SLB"]
    hda_additional_routes2 = ["HDA", "SLA"]
    hda_additional_routes3 = ["HDA", "DRA"]
    hda_additional_routes4 = ["HDA", "TEB"]
    
    dra_additional_routes1 = ["DRA", "DAB"]
    dra_additional_routes2 = ["DRA", "GRA"]

    gkr_additional_routes1 = ["GKR", "HDA"]

    teb_additional_routes1 = ["TEB", "DAB"]
    teb_additional_routes2 = ["TEB", "GRA"]

    sla_additional_routes1 = ["SLA", "DAB"]
    sla_additional_routes2 = ["SLA", "GRA"]

    slb_additional_routes1 = ["SLB", "DAB"]
    slb_additional_routes2 = ["SLB", "GRA"]

    routes_with_hda_slb = []
    routes_with_hda_sla = []
    routes_with_hda_dra = []
    routes_with_hda_teb = []

    routes_with_dra_dab = []
    routes_with_dra_gra = []
    routes_with_gkr_hda = []
    routes_with_teb_dab = []

    routes_with_teb_gra = []
    routes_with_sla_dab = []
    routes_with_sla_gra = []
    routes_with_slb_dab = []
    routes_with_slb_gra = []

    with open('generated_datafiles_allroutes/routes.csv', 'r') as file:
        csv_reader = csv.reader(file)
        for row_number, row in enumerate(csv_reader, start=1):
            if contains_required_routes(row, hda_additional_routes1):
                routes_with_hda_slb.append(row_number)
            if contains_required_routes(row, hda_additional_routes2):
                routes_with_hda_sla.append(row_number)
            if contains_required_routes(row, hda_additional_routes3):
                routes_with_hda_dra.append(row_number)
            if contains_required_routes(row, hda_additional_routes4):
                routes_with_hda_teb.append(row_number)
            if contains_required_routes(row, dra_additional_routes1):
                routes_with_dra_dab.append(row_number)
            if contains_required_routes(row, dra_additional_routes2):
                routes_with_dra_gra.append(row_number)

            if contains_required_routes(row, gkr_additional_routes1):
                routes_with_gkr_hda.append(row_number)

            if contains_required_routes(row, teb_additional_routes1):
                routes_with_teb_dab.append(row_number)
            if contains_required_routes(row, teb_additional_routes2):
                routes_with_teb_gra.append(row_number)
            if contains_required_routes(row, sla_additional_routes1):
                routes_with_sla_dab.append(row_number)
            if contains_required_routes(row, sla_additional_routes2):
                routes_with_sla_gra.append(row_number)
            if contains_required_routes(row, slb_additional_routes1):
                routes_with_slb_dab.append(row_number)
            if contains_required_routes(row, slb_additional_routes2):
                routes_with_slb_gra.append(row_number)
            
    # Finding rows where all combinations occur
    # Combine all lists into one
    all_routes = (
        routes_with_hda_slb + 
        routes_with_hda_sla +
        routes_with_hda_dra +
        routes_with_hda_teb +
        routes_with_dra_dab +
        routes_with_dra_gra +
        routes_with_gkr_hda +
        routes_with_teb_dab +
        routes_with_teb_gra +
        routes_with_sla_dab +
        routes_with_sla_gra +
        routes_with_slb_dab +
        routes_with_slb_gra
    )
    
    # Convert the combined list into a set to remove duplicates
    unique_routes = set(all_routes)

    # Convert the set back into a list if needed
    unique_routes_list = list(unique_routes)
    print((sorted(unique_routes_list)))
    print(len(unique_routes_list))

    def filter_routes(input_file, output_file, exclude_indices):
        with open(input_file, 'r', newline='') as f_in, \
            open(output_file, 'w', newline='') as f_out:
            reader = csv.reader(f_in)
            writer = csv.writer(f_out)

            for i, row in enumerate(reader):
                if i + 1 not in exclude_indices:  # Adjusting for 1-based indexing
                    writer.writerow(row)

    def filter_otherfiles(input_file, output_file, exclude_indices):
        with open(input_file, 'r', newline='') as f_in, \
            open(output_file, 'w', newline='') as f_out:
            reader = csv.reader(f_in)
            writer = csv.writer(f_out)

            for i, row in enumerate(reader):
                if i not in exclude_indices:  
                    writer.writerow(row)

    # Example usage
    input_file = 'generated_datafiles_allroutes/routes.csv'
    output_file = 'generated_datafiles_reducedroutes/routes.csv'

    input_file2 = 'generated_datafiles_allroutes/demand.csv'
    output_file2 = 'generated_datafiles_reducedroutes/demand.csv'

    input_file3 = 'generated_datafiles_allroutes/distances.csv'
    output_file3 = 'generated_datafiles_reducedroutes/distances.csv'

    input_file4 = 'generated_datafiles_allroutes/duration_lossing.csv'
    output_file4 = 'generated_datafiles_reducedroutes/duration_lossing.csv'

    input_file5 = 'generated_datafiles_allroutes/duration_sailing.csv'
    output_file5 = 'generated_datafiles_reducedroutes/duration_sailing.csv'

    filter_routes(input_file, output_file, unique_routes_list)
    filter_otherfiles(input_file2, output_file2, unique_routes_list)
    filter_otherfiles(input_file3, output_file3, unique_routes_list)
    filter_otherfiles(input_file4, output_file4, unique_routes_list)
    filter_otherfiles(input_file5, output_file5, unique_routes_list)

if __name__ == "__main__":
    main()
'''
# Out:
# '\nimport csv\n\ndef contains_required_routes(route, required_routes):\n    return all(required_route in route for required_route in required_routes)\n\ndef main():\n    hda_additional_routes1 = ["HDA", "SLB"]\n    hda_additional_routes2 = ["HDA", "SLA"]\n    hda_additional_routes3 = ["HDA", "DRA"]\n    hda_additional_routes4 = ["HDA", "TEB"]\n    \n    dra_additional_routes1 = ["DRA", "DAB"]\n    dra_additional_routes2 = ["DRA", "GRA"]\n\n    gkr_additional_routes1 = ["GKR", "HDA"]\n\n    teb_additional_routes1 = ["TEB", "DAB"]\n    teb_additional_routes2 = ["TEB", "GRA"]\n\n    sla_additional_routes1 = ["SLA", "DAB"]\n    sla_additional_routes2 = ["SLA", "GRA"]\n\n    slb_additional_routes1 = ["SLB", "DAB"]\n    slb_additional_routes2 = ["SLB", "GRA"]\n\n    routes_with_hda_slb = []\n    routes_with_hda_sla = []\n    routes_with_hda_dra = []\n    routes_with_hda_teb = []\n\n    routes_with_dra_dab = []\n    routes_with_dra_gra = []\n    routes_with_gkr_hda = []\n    routes_with_teb_dab = []\n\n    routes_with_teb_gra = []\n    routes_with_sla_dab = []\n    routes_with_sla_gra = []\n    routes_with_slb_dab = []\n    routes_with_slb_gra = []\n\n    with open(\'generated_datafiles_allroutes/routes.csv\', \'r\') as file:\n        csv_reader = csv.reader(file)\n        for row_number, row in enumerate(csv_reader, start=1):\n            if contains_required_routes(row, hda_additional_routes1):\n                routes_with_hda_slb.append(row_number)\n            if contains_required_routes(row, hda_additional_routes2):\n                routes_with_hda_sla.append(row_number)\n            if contains_required_routes(row, hda_additional_routes3):\n                routes_with_hda_dra.append(row_number)\n            if contains_required_routes(row, hda_additional_routes4):\n                routes_with_hda_teb.append(row_number)\n            if contains_required_routes(row, dra_additional_routes1):\n                routes_with_dra_dab.append(row_number)\n            if contains_required_routes(row, dra_additional_routes2):\n                routes_with_dra_gra.append(row_number)\n\n            if contains_required_routes(row, gkr_additional_routes1):\n                routes_with_gkr_hda.append(row_number)\n\n            if contains_required_routes(row, teb_additional_routes1):\n                routes_with_teb_dab.append(row_number)\n            if contains_required_routes(row, teb_additional_routes2):\n                routes_with_teb_gra.append(row_number)\n            if contains_required_routes(row, sla_additional_routes1):\n                routes_with_sla_dab.append(row_number)\n            if contains_required_routes(row, sla_additional_routes2):\n                routes_with_sla_gra.append(row_number)\n            if contains_required_routes(row, slb_additional_routes1):\n                routes_with_slb_dab.append(row_number)\n            if contains_required_routes(row, slb_additional_routes2):\n                routes_with_slb_gra.append(row_number)\n            \n    # Finding rows where all combinations occur\n    # Combine all lists into one\n    all_routes = (\n        routes_with_hda_slb + \n        routes_with_hda_sla +\n        routes_with_hda_dra +\n        routes_with_hda_teb +\n        routes_with_dra_dab +\n        routes_with_dra_gra +\n        routes_with_gkr_hda +\n        routes_with_teb_dab +\n        routes_with_teb_gra +\n        routes_with_sla_dab +\n        routes_with_sla_gra +\n        routes_with_slb_dab +\n        routes_with_slb_gra\n    )\n    \n    # Convert the combined list into a set to remove duplicates\n    unique_routes = set(all_routes)\n\n    # Convert the set back into a list if needed\n    unique_routes_list = list(unique_routes)\n    print((sorted(unique_routes_list)))\n    print(len(unique_routes_list))\n\n    def filter_routes(input_file, output_file, exclude_indices):\n        with open(input_file, \'r\', newline=\'\') as f_in,             open(output_file, \'w\', newline=\'\') as f_out:\n    ...
