# %%
import pandas as pd
from itertools import permutations
import math
import os
import csv
import time

# %% [markdown]
# ## INPUT

# %%
cargo_capacity_psv = 100
psv_speed = 10 
max_platforms_in_one_voyage = 7

non_cluster = 'cluster11'
mappenavn = 'cluster10_new'

# %% [markdown]
# ## GENERATE ROUTES FOR CLUSTER

# %%
demand = pd.read_csv('clustering/output_platforms_demand.csv', header=0, delimiter=';')
distances = pd.read_csv('clustering/output_distance_matrix_kmeans.csv', header=0, delimiter=';', index_col='from/to')

platforms_demand = dict(zip(demand['platform'], demand['avg_q'].replace(',', '.').astype(float)))
platforms_d = ['DUS'] + demand['platform'].tolist() + ['DUS']  # Add 'DUS' as start and end platforms

# %%
shortest_routes_dict = {}

def generate_routes(demand, distances):
    cargo_capacity = cargo_capacity_psv
    max_platforms = max_platforms_in_one_voyage + 2

    def dp(platform, cargo_remaining, route, visited):
        if cargo_remaining < 0:
            return
        if len(route) > max_platforms:
            return
        if platform == 'DUS' and len(route) > 2:
            total_demand = sum(platforms_demand[p] for p in route[1:-1])
            if total_demand <= cargo_capacity:
                key = tuple(sorted(set(route)))
                total_distance = sum(distances.loc[route[i], route[i+1]] for i in range(len(route)-1))
                if key not in shortest_routes_dict or total_distance < shortest_routes_dict[key][1]:
                    duration_sailing = round((total_distance / psv_speed), 2)
                    duration_lossing = round(((total_demand * 1.389) / psv_speed), 2)
                    duration_sailing = round(duration_sailing, 2)
                    duration_lossing = round(duration_lossing, 2)
                    shortest_routes_dict[key] = (route, total_distance, total_demand, duration_sailing, duration_lossing)
            return

        # Check if the current route is dominated
        current_distance = sum(distances.loc[route[i], route[i+1]] for i in range(len(route)-1))
        current_demand = sum(platforms_demand[p] for p in route[1:-1])
        
        # Check for dominance in existing routes
        for key, (existing_route, existing_distance, existing_demand, _, _) in shortest_routes_dict.items():
            if set(existing_route[1:-1]) == set(route[1:-1]) and existing_demand >= current_demand and existing_distance <= current_distance:
                return
        
        # Check for dominance in subsequent routes starting with the same platforms
        for existing_route in dominated_routes:
            if set(existing_route[1:-1]) == set(route[1:-1]) and existing_demand >= current_demand and existing_distance <= current_distance:
                return

        for next_platform in platforms_demand.keys():
            if next_platform != platform and next_platform not in visited:
                try:
                    distance_to_next = distances.loc[platform, next_platform]
                    new_cargo_remaining = cargo_remaining - platforms_demand[next_platform]
                    dp(next_platform, new_cargo_remaining, route + [next_platform], visited.union({next_platform}))
                except KeyError:
                    print("KeyError occurred for platform:", next_platform)
                    continue

    for r in range(3, min(len(platforms_demand) + 3, max_platforms + 3)):
        for route_combination in permutations(platforms_demand.keys(), r - 2):
            route = ['DUS'] + list(route_combination) + ['DUS']
            dp('DUS', cargo_capacity, route, {'DUS'})

            # Add the current route to the dominated routes set
            dominated_routes.add(tuple(route))

    return shortest_routes_dict

# Keep track of dominated routes to skip future routes starting with them
dominated_routes = set()
shortest_routes_dict = generate_routes(demand, distances)

for route, distance, demand, duration_sailing, duration_lossing in shortest_routes_dict.values():
    print(f"Shortest Route: {route}, Total Distance: {round(distance,2)}, Total Demand: {demand}, Duration sailing: {duration_sailing}, Duration lossing: {duration_lossing}")

print(len(shortest_routes_dict))
# Out:
# Shortest Route: ['DUS', 'DABGRA', 'DUS'], Total Distance: 188.1, Total Demand: 50.5, Duration sailing: 18.81, Duration lossing: 7.01
# Shortest Route: ['DUS', 'DRA', 'DUS'], Total Distance: 205.36, Total Demand: 14.0, Duration sailing: 20.54, Duration lossing: 1.94
# Shortest Route: ['DUS', 'DSA', 'DUS'], Total Distance: 164.4, Total Demand: 29.0, Duration sailing: 16.44, Duration lossing: 4.03
# Shortest Route: ['DUS', 'GKR', 'DUS'], Total Distance: 234.68, Total Demand: 18.0, Duration sailing: 23.47, Duration lossing: 2.5
# Shortest Route: ['DUS', 'GUD', 'DUS'], Total Distance: 226.76, Total Demand: 18.0, Duration sailing: 22.68, Duration lossing: 2.5
# Shortest Route: ['DUS', 'JSF', 'DUS'], Total Distance: 176.18, Total Demand: 40.0, Duration sailing: 17.62, Duration lossing: 5.56
# Shortest Route: ['DUS', 'HDA', 'DUS'], Total Distance: 206.82, Total Demand: 18.0, Duration sailing: 20.68, Duration lossing: 2.5
# Shortest Route: ['DUS', 'SLA', 'DUS'], Total Distance: 229.48, Total Demand: 4.0, Duration sailing: 22.95, Duration lossing: 0.56
# Shortest Route: ['DUS', 'SLB', 'DUS'], Total Distance: 238.28, Total Demand: 7.0, Duration sailing: 23.83, Duration lossing: 0.97
# Shortest Route: ['DUS', 'TEB', 'DUS'], Total Distance: 250.32, Total Demand: 14.0, Duration sailing: 25.03, Duration lossing: 1.94
# Shortest Route: ['DUS', 'DABGRA', 'DRA', 'DUS'], Total Distance: 257.15, Total Demand: 64.5, Duration sailing: 25.71, Duration lossing: 8.96
# Shortest Route: ['DUS', 'DABGRA', 'DSA', 'DUS'], Total Distance: 203.94, Total Demand: 79.5, Duration sailing: 20.39, Duration lossing: 11.04
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'DUS'], Total Distance: 255.92, Total Demand: 68.5, Duration sailing: 25.59, Duration lossing: 9.51
# Shortest Route: ['DUS', 'DABGRA', 'GUD', 'DUS'], Total Distance: 238.38, Total Demand: 68.5, Duration sailing: 23.84, Duration lossing: 9.51
# Shortest Route: ['DUS', 'DABGRA', 'JSF', 'DUS'], Total Distance: 203.86, Total Demand: 90.5, Duration sailing: 20.39, Duration lossing: 12.57
# Shortest Route: ['DUS', 'DABGRA', 'HDA', 'DUS'], Total Distance: 225.71, Total Demand: 68.5, Duration sailing: 22.57, Duration lossing: 9.51
# Shortest Route: ['DUS', 'DABGRA', 'SLA', 'DUS'], Total Distance: 261.36, Total Demand: 54.5, Duration sailing: 26.14, Duration lossing: 7.57
# Shortest Route: ['DUS', 'DABGRA', 'SLB', 'DUS'], Total Distance: 265.23, Total Demand: 57.5, Duration sailing: 26.52, Duration lossing: 7.99
# Shortest Route: ['DUS', 'DABGRA', 'TEB', 'DUS'], Total Distance: 276.44, Total Demand: 64.5, Duration sailing: 27.64, Duration lossing: 8.96
# Shortest Route: ['DUS', 'DRA', 'DSA', 'DUS'], Total Distance: 220.95, Total Demand: 43.0, Duration sailing: 22.1, Duration lossing: 5.97
# Shortest Route: ['DUS', 'DRA', 'GKR', 'DUS'], Total Distance: 253.31, Total Demand: 32.0, Duration sailing: 25.33, Duration lossing: 4.44
# Shortest Route: ['DUS', 'DRA', 'GUD', 'DUS'], Total Distance: 261.82, Total Demand: 32.0, Duration sailing: 26.18, Duration lossing: 4.44
# Shortest Route: ['DUS', 'DRA', 'JSF', 'DUS'], Total Distance: 229.9, Total Demand: 54.0, Duration sailing: 22.99, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DRA', 'HDA', 'DUS'], Total Distance: 289.28, Total Demand: 32.0, Duration sailing: 28.93, Duration lossing: 4.44
# Shortest Route: ['DUS', 'DRA', 'SLA', 'DUS'], Total Distance: 238.41, Total Demand: 18.0, Duration sailing: 23.84, Duration lossing: 2.5
# Shortest Route: ['DUS', 'DRA', 'SLB', 'DUS'], Total Distance: 249.21, Total Demand: 21.0, Duration sailing: 24.92, Duration lossing: 2.92
# Shortest Route: ['DUS', 'DRA', 'TEB', 'DUS'], Total Distance: 258.83, Total Demand: 28.0, Duration sailing: 25.88, Duration lossing: 3.89
# Shortest Route: ['DUS', 'DSA', 'GKR', 'DUS'], Total Distance: 235.04, Total Demand: 47.0, Duration sailing: 23.5, Duration lossing: 6.53
# Shortest Route: ['DUS', 'GUD', 'DSA', 'DUS'], Total Distance: 227.96, Total Demand: 47.0, Duration sailing: 22.8, Duration lossing: 6.53
# Shortest Route: ['DUS', 'DSA', 'JSF', 'DUS'], Total Distance: 178.06, Total Demand: 69.0, Duration sailing: 17.81, Duration lossing: 9.58
# Shortest Route: ['DUS', 'DSA', 'HDA', 'DUS'], Total Distance: 236.43, Total Demand: 47.0, Duration sailing: 23.64, Duration lossing: 6.53
# Shortest Route: ['DUS', 'DSA', 'SLA', 'DUS'], Total Distance: 233.25, Total Demand: 33.0, Duration sailing: 23.32, Duration lossing: 4.58
# Shortest Route: ['DUS', 'SLB', 'DSA', 'DUS'], Total Distance: 240.34, Total Demand: 36.0, Duration sailing: 24.03, Duration lossing: 5.0
# Shortest Route: ['DUS', 'DSA', 'TEB', 'DUS'], Total Distance: 252.48, Total Demand: 43.0, Duration sailing: 25.25, Duration lossing: 5.97
# Shortest Route: ['DUS', 'GKR', 'GUD', 'DUS'], Total Distance: 247.58, Total Demand: 36.0, Duration sailing: 24.76, Duration lossing: 5.0
# Shortest Route: ['DUS', 'GKR', 'JSF', 'DUS'], Total Distance: 236.77, Total Demand: 58.0, Duration sailing: 23.68, Duration lossing: 8.06
# Shortest Route: ['DUS', 'GKR', 'HDA', 'DUS'], Total Distance: 282.98, Total Demand: 36.0, Duration sailing: 28.3, Duration lossing: 5.0
# Shortest Route: ['DUS', 'GKR', 'SLA', 'DUS'], Total Distance: 245.63, Total Demand: 22.0, Duration sailing: 24.56, Duration lossing: 3.06
# Shortest Route: ['DUS', 'GKR', 'SLB', 'DUS'], Total Distance: 245.51, Total Demand: 25.0, Duration sailing: 24.55, Duration lossing: 3.47
# Shortest Route: ['DUS', 'GKR', 'TEB', 'DUS'], Total Distance: 255.4, Total Demand: 32.0, Duration sailing: 25.54, Duration lossing: 4.44
# Shortest Route: ['DUS', 'GUD', 'JSF', 'DUS'], Total Distance: 226.95, Total Demand: 58.0, Duration sailing: 22.7, Duration lossing: 8.06
# Shortest Route: ['DUS', 'GUD', 'HDA', 'DUS'], Total Distance: 262.57, Total Demand: 36.0, Duration sailing: 26.26, Duration lossing: 5.0
# Shortest Route: ['DUS', 'GUD', 'SLA', 'DUS'], Total Distance: 257.37, Total Demand: 22.0, Duration sailing: 25.74, Duration lossing: 3.06
# Shortest Route: ['DUS', 'GUD', 'SLB', 'DUS'], Total Distance: 258.34, Total Demand: 25.0, Duration sailing: 25.83, Duration lossing: 3.47
# Shortest Route: ['DUS', 'GUD', 'TEB', 'DUS'], Total Distance: 267.97, Total Demand: 32.0, Duration sailing: 26.8, Duration lossing: 4.44
# Shortest Route: ['DUS', 'JSF', 'HDA', 'DUS'], Total Distance: 236.49, Total Demand: 58.0, Duration sailing: 23.65, Duration lossing: 8.06
# Shortest Route: ['DUS', 'SLA', 'JSF', 'DUS'], Total Distance: 237.79, Total Demand: 44.0, Duration sailing: 23.78, Duration lossing: 6.11
# Shortest Route: ['DUS', 'JSF', 'SLB', 'DUS'], Total Distance: 243.63, Total Demand: 47.0, Duration sailing: 24.36, Duration lossing: 6.53
# Shortest Route: ['DUS', 'JSF', 'TEB', 'DUS'], Total Distance: 255.61, Total Demand: 54.0, Duration sailing: 25.56, Duration lossing: 7.5
# Shortest Route: ['DUS', 'SLA', 'HDA', 'DUS'], Total Distance: 290.92, Total Demand: 22.0, Duration sailing: 29.09, Duration lossing: 3.06
# Shortest Route: ['DUS', 'HDA', 'SLB', 'DUS'], Total Distance: 293.37, Total Demand: 25.0, Duration sailing: 29.34, Duration lossing: 3.47
# Shortest Route: ['DUS', 'HDA', 'TEB', 'DUS'], Total Distance: 303.63, Total Demand: 32.0, Duration sailing: 30.36, Duration lossing: 4.44
# Shortest Route: ['DUS', 'SLA', 'SLB', 'DUS'], Total Distance: 240.29, Total Demand: 11.0, Duration sailing: 24.03, Duration lossing: 1.53
# Shortest Route: ['DUS', 'SLA', 'TEB', 'DUS'], Total Distance: 250.92, Total Demand: 18.0, Duration sailing: 25.09, Duration lossing: 2.5
# Shortest Route: ['DUS', 'SLB', 'TEB', 'DUS'], Total Distance: 250.43, Total Demand: 21.0, Duration sailing: 25.04, Duration lossing: 2.92
# Shortest Route: ['DUS', 'DABGRA', 'DSA', 'DRA', 'DUS'], Total Distance: 260.49, Total Demand: 93.5, Duration sailing: 26.05, Duration lossing: 12.99
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'DRA', 'DUS'], Total Distance: 274.55, Total Demand: 82.5, Duration sailing: 27.45, Duration lossing: 11.46
# Shortest Route: ['DUS', 'DABGRA', 'GUD', 'DRA', 'DUS'], Total Distance: 273.44, Total Demand: 82.5, Duration sailing: 27.34, Duration lossing: 11.46
# Shortest Route: ['DUS', 'DRA', 'DABGRA', 'HDA', 'DUS'], Total Distance: 294.76, Total Demand: 82.5, Duration sailing: 29.48, Duration lossing: 11.46
# Shortest Route: ['DUS', 'DABGRA', 'SLA', 'DRA', 'DUS'], Total Distance: 270.29, Total Demand: 68.5, Duration sailing: 27.03, Duration lossing: 9.51
# Shortest Route: ['DUS', 'DRA', 'SLB', 'DABGRA', 'DUS'], Total Distance: 276.16, Total Demand: 71.5, Duration sailing: 27.62, Duration lossing: 9.93
# Shortest Route: ['DUS', 'DRA', 'TEB', 'DABGRA', 'DUS'], Total Distance: 284.95, Total Demand: 78.5, Duration sailing: 28.49, Duration lossing: 10.9
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'DSA', 'DUS'], Total Distance: 256.28, Total Demand: 97.5, Duration sailing: 25.63, Duration lossing: 13.54
# Shortest Route: ['DUS', 'DABGRA', 'GUD', 'DSA', 'DUS'], Total Distance: 239.58, Total Demand: 97.5, Duration sailing: 23.96, Duration lossing: 13.54
# Shortest Route: ['DUS', 'DSA', 'DABGRA', 'HDA', 'DUS'], Total Distance: 241.55, Total Demand: 97.5, Duration sailing: 24.15, Duration lossing: 13.54
# Shortest Route: ['DUS', 'DABGRA', 'SLA', 'DSA', 'DUS'], Total Distance: 265.13, Total Demand: 83.5, Duration sailing: 26.51, Duration lossing: 11.6
# Shortest Route: ['DUS', 'DABGRA', 'SLB', 'DSA', 'DUS'], Total Distance: 267.29, Total Demand: 86.5, Duration sailing: 26.73, Duration lossing: 12.01
# Shortest Route: ['DUS', 'DSA', 'TEB', 'DABGRA', 'DUS'], Total Distance: 278.6, Total Demand: 93.5, Duration sailing: 27.86, Duration lossing: 12.99
# Shortest Route: ['DUS', 'GKR', 'GUD', 'DABGRA', 'DUS'], Total Distance: 259.2, Total Demand: 86.5, Duration sailing: 25.92, Duration lossing: 12.01
# Shortest Route: ['DUS', 'GKR', 'DABGRA', 'HDA', 'DUS'], Total Distance: 293.53, Total Demand: 86.5, Duration sailing: 29.35, Duration lossing: 12.01
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'SLA', 'DUS'], Total Distance: 266.87, Total Demand: 72.5, Duration sailing: 26.69, Duration lossing: 10.07
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'SLB', 'DUS'], Total Distance: 266.75, Total Demand: 75.5, Duration sailing: 26.68, Duration lossing: 10.49
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'TEB', 'DUS'], Total Distance: 276.64, Total Demand: 82.5, Duration sailing: 27.66, Duration lossing: 11.46
# Shortest Route: ['DUS', 'DABGRA', 'GUD', 'HDA', 'DUS'], Total Distance: 274.19, Total Demand: 86.5, Duration sailing: 27.42, Duration lossing: 12.01
# Shortest Route: ['DUS', 'DABGRA', 'GUD', 'SLA', 'DUS'], Total Distance: 268.99, Total Demand: 72.5, Duration sailing: 26.9, Duration lossing: 10.07
# Shortest Route: ['DUS', 'DABGRA', 'GUD', 'SLB', 'DUS'], Total Distance: 269.96, Total Demand: 75.5, Duration sailing: 27.0, Duration lossing: 10.49
# Shortest Route: ['DUS', 'TEB', 'GUD', 'DABGRA', 'DUS'], Total Distance: 279.59, Total Demand: 82.5, Duration sailing: 27.96, Duration lossing: 11.46
# Shortest Route: ['DUS', 'DABGRA', 'JSF', 'SLA', 'DUS'], Total Distance: 265.47, Total Demand: 94.5, Duration sailing: 26.55, Duration lossing: 13.13
# Shortest Route: ['DUS', 'JSF', 'SLB', 'DABGRA', 'DUS'], Total Distance: 270.58, Total Demand: 97.5, Duration sailing: 27.06, Duration lossing: 13.54
# Shortest Route: ['DUS', 'HDA', 'DABGRA', 'SLA', 'DUS'], Total Distance: 298.97, Total Demand: 72.5, Duration sailing: 29.9, Duration lossing: 10.07
# Shortest Route: ['DUS', 'HDA', 'DABGRA', 'SLB', 'DUS'], Total Distance: 302.84, Total Demand: 75.5, Duration sailing: 30.28, Duration lossing: 10.49
# Shortest Route: ['DUS', 'HDA', 'DABGRA', 'TEB', 'DUS'], Total Distance: 314.05, Total Demand: 82.5, Duration sailing: 31.4, Duration lossing: 11.46
# Shortest Route: ['DUS', 'DABGRA', 'SLB', 'SLA', 'DUS'], Total Distance: 267.24, Total Demand: 61.5, Duration sailing: 26.72, Duration lossing: 8.54
# Shortest Route: ['DUS', 'SLA', 'TEB', 'DABGRA', 'DUS'], Total Distance: 277.04, Total Demand: 68.5, Duration sailing: 27.7, Duration lossing: 9.51
# Shortest Route: ['DUS', 'DABGRA', 'TEB', 'SLB', 'DUS'], Total Distance: 276.55, Total Demand: 71.5, Duration sailing: 27.66, Duration lossing: 9.93
# Shortest Route: ['DUS', 'DRA', 'GKR', 'DSA', 'DUS'], Total Distance: 253.67, Total Demand: 61.0, Duration sailing: 25.37, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DRA', 'GUD', 'DSA', 'DUS'], Total Distance: 263.02, Total Demand: 61.0, Duration sailing: 26.3, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DSA', 'JSF', 'DRA', 'DUS'], Total Distance: 231.78, Total Demand: 83.0, Duration sailing: 23.18, Duration lossing: 11.53
# Shortest Route: ['DUS', 'DRA', 'DSA', 'HDA', 'DUS'], Total Distance: 292.98, Total Demand: 61.0, Duration sailing: 29.3, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'DSA', 'DUS'], Total Distance: 242.18, Total Demand: 47.0, Duration sailing: 24.22, Duration lossing: 6.53
# Shortest Route: ['DUS', 'DRA', 'SLB', 'DSA', 'DUS'], Total Distance: 251.27, Total Demand: 50.0, Duration sailing: 25.13, Duration lossing: 6.95
# Shortest Route: ['DUS', 'DRA', 'TEB', 'DSA', 'DUS'], Total Distance: 260.99, Total Demand: 57.0, Duration sailing: 26.1, Duration lossing: 7.92
# Shortest Route: ['DUS', 'DRA', 'GKR', 'GUD', 'DUS'], Total Distance: 266.21, Total Demand: 50.0, Duration sailing: 26.62, Duration lossing: 6.95
# Shortest Route: ['DUS', 'DRA', 'GKR', 'JSF', 'DUS'], Total Distance: 255.4, Total Demand: 72.0, Duration sailing: 25.54, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DRA', 'GKR', 'HDA', 'DUS'], Total Distance: 301.61, Total Demand: 50.0, Duration sailing: 30.16, Duration lossing: 6.95
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GKR', 'DUS'], Total Distance: 254.56, Total Demand: 36.0, Duration sailing: 25.46, Duration lossing: 5.0
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GKR', 'DUS'], Total Distance: 256.44, Total Demand: 39.0, Duration sailing: 25.64, Duration lossing: 5.42
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GKR', 'DUS'], Total Distance: 263.91, Total Demand: 46.0, Duration sailing: 26.39, Duration lossing: 6.39
# Shortest Route: ['DUS', 'DRA', 'GUD', 'JSF', 'DUS'], Total Distance: 262.01, Total Demand: 72.0, Duration sailing: 26.2, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DRA', 'GUD', 'HDA', 'DUS'], Total Distance: 297.63, Total Demand: 50.0, Duration sailing: 29.76, Duration lossing: 6.95
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GUD', 'DUS'], Total Distance: 266.3, Total Demand: 36.0, Duration sailing: 26.63, Duration lossing: 5.0
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GUD', 'DUS'], Total Distance: 269.27, Total Demand: 39.0, Duration sailing: 26.93, Duration lossing: 5.42
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GUD', 'DUS'], Total Distance: 276.48, Total Demand: 46.0, Duration sailing: 27.65, Duration lossing: 6.39
# Shortest Route: ['DUS', 'DRA', 'JSF', 'HDA', 'DUS'], Total Distance: 290.21, Total Demand: 72.0, Duration sailing: 29.02, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DRA', 'SLA', 'JSF', 'DUS'], Total Distance: 246.72, Total Demand: 58.0, Duration sailing: 24.67, Duration lossing: 8.06
# Shortest Route: ['DUS', 'DRA', 'SLB', 'JSF', 'DUS'], Total Distance: 254.56, Total Demand: 61.0, Duration sailing: 25.46, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DRA', 'TEB', 'JSF', 'DUS'], Total Distance: 264.12, Total Demand: 68.0, Duration sailing: 26.41, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DRA', 'SLA', 'HDA', 'DUS'], Total Distance: 299.85, Total Demand: 36.0, Duration sailing: 29.99, Duration lossing: 5.0
# Shortest Route: ['DUS', 'DRA', 'SLB', 'HDA', 'DUS'], Total Distance: 304.3, Total Demand: 39.0, Duration sailing: 30.43, Duration lossing: 5.42
# Shortest Route: ['DUS', 'DRA', 'TEB', 'HDA', 'DUS'], Total Distance: 312.14, Total Demand: 46.0, Duration sailing: 31.21, Duration lossing: 6.39
# Shortest Route: ['DUS', 'SLB', 'SLA', 'DRA', 'DUS'], Total Distance: 249.22, Total Demand: 25.0, Duration sailing: 24.92, Duration lossing: 3.47
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLA', 'DUS'], Total Distance: 259.43, Total Demand: 32.0, Duration sailing: 25.94, Duration lossing: 4.44
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'DUS'], Total Distance: 258.94, Total Demand: 35.0, Duration sailing: 25.89, Duration lossing: 4.86
# Shortest Route: ['DUS', 'DSA', 'GKR', 'GUD', 'DUS'], Total Distance: 247.94, Total Demand: 65.0, Duration sailing: 24.79, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DSA', 'GKR', 'JSF', 'DUS'], Total Distance: 237.13, Total Demand: 87.0, Duration sailing: 23.71, Duration lossing: 12.08
# Shortest Route: ['DUS', 'HDA', 'GKR', 'DSA', 'DUS'], Total Distance: 283.34, Total Demand: 65.0, Duration sailing: 28.33, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DSA', 'GKR', 'SLA', 'DUS'], Total Distance: 245.99, Total Demand: 51.0, Duration sailing: 24.6, Duration lossing: 7.08
# Shortest Route: ['DUS', 'DSA', 'GKR', 'SLB', 'DUS'], Total Distance: 245.87, Total Demand: 54.0, Duration sailing: 24.59, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DSA', 'GKR', 'TEB', 'DUS'], Total Distance: 255.76, Total Demand: 61.0, Duration sailing: 25.58, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DSA', 'GUD', 'JSF', 'DUS'], Total Distance: 228.15, Total Demand: 87.0, Duration sailing: 22.82, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DSA', 'GUD', 'HDA', 'DUS'], Total Distance: 263.77, Total Demand: 65.0, Duration sailing: 26.38, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DSA', 'GUD', 'SLA', 'DUS'], Total Distance: 258.57, Total Demand: 51.0, Duration sailing: 25.86, Duration lossing: 7.08
# Shortest Route: ['DUS', 'DSA', 'GUD', 'SLB', 'DUS'], Total Distance: 259.54, Total Demand: 54.0, Duration sailing: 25.95, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DSA', 'GUD', 'TEB', 'DUS'], Total Distance: 269.17, Total Demand: 61.0, Duration sailing: 26.92, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DSA', 'JSF', 'HDA', 'DUS'], Total Distance: 238.37, Total Demand: 87.0, Duration sailing: 23.84, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DSA', 'JSF', 'SLA', 'DUS'], Total Distance: 239.67, Total Demand: 73.0, Duration sailing: 23.97, Duration lossing: 10.14
# Shortest Route: ['DUS', 'DSA', 'JSF', 'SLB', 'DUS'], Total Distance: 245.51, Total Demand: 76.0, Duration sailing: 24.55, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DSA', 'JSF', 'TEB', 'DUS'], Total Distance: 257.49, Total Demand: 83.0, Duration sailing: 25.75, Duration lossing: 11.53
# Shortest Route: ['DUS', 'DSA', 'SLA', 'HDA', 'DUS'], Total Distance: 294.69, Total Demand: 51.0, Duration sailing: 29.47, Duration lossing: 7.08
# Shortest Route: ['DUS', 'DSA', 'SLB', 'HDA', 'DUS'], Total Distance: 295.43, Total Demand: 54.0, Duration sailing: 29.54, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DSA', 'TEB', 'HDA', 'DUS'], Total Distance: 305.79, Total Demand: 61.0, Duration sailing: 30.58, Duration lossing: 8.47
# Shortest Route: ['DUS', 'SLA', 'SLB', 'DSA', 'DUS'], Total Distance: 242.35, Total Demand: 40.0, Duration sailing: 24.23, Duration lossing: 5.56
# Shortest Route: ['DUS', 'DSA', 'TEB', 'SLA', 'DUS'], Total Distance: 253.08, Total Demand: 47.0, Duration sailing: 25.31, Duration lossing: 6.53
# Shortest Route: ['DUS', 'DSA', 'SLB', 'TEB', 'DUS'], Total Distance: 252.49, Total Demand: 50.0, Duration sailing: 25.25, Duration lossing: 6.95
# Shortest Route: ['DUS', 'GKR', 'GUD', 'JSF', 'DUS'], Total Distance: 247.77, Total Demand: 76.0, Duration sailing: 24.78, Duration lossing: 10.56
# Shortest Route: ['DUS', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 283.39, Total Demand: 54.0, Duration sailing: 28.34, Duration lossing: 7.5
# Shortest Route: ['DUS', 'SLA', 'GKR', 'GUD', 'DUS'], Total Distance: 258.53, Total Demand: 40.0, Duration sailing: 25.85, Duration lossing: 5.56
# Shortest Route: ['DUS', 'SLB', 'GKR', 'GUD', 'DUS'], Total Distance: 258.41, Total Demand: 43.0, Duration sailing: 25.84, Duration lossing: 5.97
# Shortest Route: ['DUS', 'GUD', 'GKR', 'TEB', 'DUS'], Total Distance: 268.3, Total Demand: 50.0, Duration sailing: 26.83, Duration lossing: 6.95
# Shortest Route: ['DUS', 'JSF', 'GKR', 'HDA', 'DUS'], Total Distance: 285.07, Total Demand: 76.0, Duration sailing: 28.51, Duration lossing: 10.56
# Shortest Route: ['DUS', 'SLA', 'GKR', 'JSF', 'DUS'], Total Distance: 247.72, Total Demand: 62.0, Duration sailing: 24.77, Duration lossing: 8.61
# Shortest Route: ['DUS', 'SLB', 'GKR', 'JSF', 'DUS'], Total Distance: 247.6, Total Demand: 65.0, Duration sailing: 24.76, Duration lossing: 9.03
# Shortest Route: ['DUS', 'JSF', 'GKR', 'TEB', 'DUS'], Total Distance: 257.49, Total Demand: 72.0, Duration sailing: 25.75, Duration lossing: 10.0
# Shortest Route: ['DUS', 'SLA', 'GKR', 'HDA', 'DUS'], Total Distance: 293.93, Total Demand: 40.0, Duration sailing: 29.39, Duration lossing: 5.56
# Shortest Route: ['DUS', 'SLB', 'GKR', 'HDA', 'DUS'], Total Distance: 293.81, Total Demand: 43.0, Duration sailing: 29.38, Duration lossing: 5.97
# Shortest Route: ['DUS', 'HDA', 'GKR', 'TEB', 'DUS'], Total Distance: 303.7, Total Demand: 50.0, Duration sailing: 30.37, Duration lossing: 6.95
# Shortest Route: ['DUS', 'GKR', 'SLB', 'SLA', 'DUS'], Total Distance: 247.52, Total Demand: 29.0, Duration sailing: 24.75, Duration lossing: 4.03
# Shortest Route: ['DUS', 'GKR', 'TEB', 'SLA', 'DUS'], Total Distance: 256.0, Total Demand: 36.0, Duration sailing: 25.6, Duration lossing: 5.0
# Shortest Route: ['DUS', 'GKR', 'TEB', 'SLB', 'DUS'], Total Distance: 255.51, Total Demand: 39.0, Duration sailing: 25.55, Duration lossing: 5.42
# Shortest Route: ['DUS', 'JSF', 'GUD', 'HDA', 'DUS'], Total Distance: 262.76, Total Demand: 76.0, Duration sailing: 26.28, Duration lossing: 10.56
# Shortest Route: ['DUS', 'JSF', 'GUD', 'SLA', 'DUS'], Total Distance: 257.56, Total Demand: 62.0, Duration sailing: 25.76, Duration lossing: 8.61
# Shortest Route: ['DUS', 'SLB', 'GUD', 'JSF', 'DUS'], Total Distance: 258.53, Total Demand: 65.0, Duration sailing: 25.85, Duration lossing: 9.03
# Shortest Route: ['DUS', 'JSF', 'GUD', 'TEB', 'DUS'], Total Distance: 268.16, Total Demand: 72.0, Duration sailing: 26.82, Duration lossing: 10.0
# Shortest Route: ['DUS', 'HDA', 'GUD', 'SLA', 'DUS'], Total Distance: 293.18, Total Demand: 40.0, Duration sailing: 29.32, Duration lossing: 5.56
# Shortest Route: ['DUS', 'HDA', 'GUD', 'SLB', 'DUS'], Total Distance: 294.15, Total Demand: 43.0, Duration sailing: 29.42, Duration lossing: 5.97
# Shortest Route: ['DUS', 'HDA', 'GUD', 'TEB', 'DUS'], Total Distance: 303.78, Total Demand: 50.0, Duration sailing: 30.38, Duration lossing: 6.95
# Shortest Route: ['DUS', 'GUD', 'SLB', 'SLA', 'DUS'], Total Distance: 260.35, Total Demand: 29.0, Duration sailing: 26.03, Duration lossing: 4.03
# Shortest Route: ['DUS', 'GUD', 'TEB', 'SLA', 'DUS'], Total Distance: 268.57, Total Demand: 36.0, Duration sailing: 26.86, Duration lossing: 5.0
# Shortest Route: ['DUS', 'GUD', 'TEB', 'SLB', 'DUS'], Total Distance: 268.08, Total Demand: 39.0, Duration sailing: 26.81, Duration lossing: 5.42
# Shortest Route: ['DUS', 'HDA', 'JSF', 'SLA', 'DUS'], Total Distance: 298.1, Total Demand: 62.0, Duration sailing: 29.81, Duration lossing: 8.61
# Shortest Route: ['DUS', 'JSF', 'SLB', 'HDA', 'DUS'], Total Distance: 298.72, Total Demand: 65.0, Duration sailing: 29.87, Duration lossing: 9.03
# Shortest Route: ['DUS', 'JSF', 'TEB', 'HDA', 'DUS'], Total Distance: 308.92, Total Demand: 72.0, Duration sailing: 30.89, Duration lossing: 10.0
# Shortest Route: ['DUS', 'JSF', 'SLB', 'SLA', 'DUS'], Total Distance: 245.64, Total Demand: 51.0, Duration sailing: 24.56, Duration lossing: 7.08
# Shortest Route: ['DUS', 'JSF', 'TEB', 'SLA', 'DUS'], Total Distance: 256.21, Total Demand: 58.0, Duration sailing: 25.62, Duration lossing: 8.06
# Shortest Route: ['DUS', 'JSF', 'TEB', 'SLB', 'DUS'], Total Distance: 255.72, Total Demand: 61.0, Duration sailing: 25.57, Duration lossing: 8.47
# Shortest Route: ['DUS', 'HDA', 'SLB', 'SLA', 'DUS'], Total Distance: 295.38, Total Demand: 29.0, Duration sailing: 29.54, Duration lossing: 4.03
# Shortest Route: ['DUS', 'HDA', 'TEB', 'SLA', 'DUS'], Total Distance: 304.23, Total Demand: 36.0, Duration sailing: 30.42, Duration lossing: 5.0
# Shortest Route: ['DUS', 'HDA', 'TEB', 'SLB', 'DUS'], Total Distance: 303.74, Total Demand: 39.0, Duration sailing: 30.37, Duration lossing: 5.42
# Shortest Route: ['DUS', 'SLA', 'TEB', 'SLB', 'DUS'], Total Distance: 251.03, Total Demand: 25.0, Duration sailing: 25.1, Duration lossing: 3.47
# Shortest Route: ['DUS', 'DABGRA', 'DSA', 'SLA', 'DRA', 'DUS'], Total Distance: 281.72, Total Demand: 97.5, Duration sailing: 28.17, Duration lossing: 13.54
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'SLA', 'DRA', 'DUS'], Total Distance: 275.8, Total Demand: 86.5, Duration sailing: 27.58, Duration lossing: 12.01
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'SLB', 'DRA', 'DUS'], Total Distance: 277.68, Total Demand: 89.5, Duration sailing: 27.77, Duration lossing: 12.43
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'TEB', 'DRA', 'DUS'], Total Distance: 285.15, Total Demand: 96.5, Duration sailing: 28.51, Duration lossing: 13.4
# Shortest Route: ['DUS', 'DABGRA', 'GUD', 'SLA', 'DRA', 'DUS'], Total Distance: 277.92, Total Demand: 86.5, Duration sailing: 27.79, Duration lossing: 12.01
# Shortest Route: ['DUS', 'DABGRA', 'GUD', 'SLB', 'DRA', 'DUS'], Total Distance: 280.89, Total Demand: 89.5, Duration sailing: 28.09, Duration lossing: 12.43
# Shortest Route: ['DUS', 'DABGRA', 'GUD', 'TEB', 'DRA', 'DUS'], Total Distance: 288.1, Total Demand: 96.5, Duration sailing: 28.81, Duration lossing: 13.4
# Shortest Route: ['DUS', 'DRA', 'SLA', 'DABGRA', 'HDA', 'DUS'], Total Distance: 307.9, Total Demand: 86.5, Duration sailing: 30.79, Duration lossing: 12.01
# Shortest Route: ['DUS', 'DRA', 'SLB', 'DABGRA', 'HDA', 'DUS'], Total Distance: 313.77, Total Demand: 89.5, Duration sailing: 31.38, Duration lossing: 12.43
# Shortest Route: ['DUS', 'DRA', 'TEB', 'DABGRA', 'HDA', 'DUS'], Total Distance: 322.56, Total Demand: 96.5, Duration sailing: 32.26, Duration lossing: 13.4
# Shortest Route: ['DUS', 'DABGRA', 'SLB', 'SLA', 'DRA', 'DUS'], Total Distance: 276.17, Total Demand: 75.5, Duration sailing: 27.62, Duration lossing: 10.49
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'DABGRA', 'DUS'], Total Distance: 285.97, Total Demand: 82.5, Duration sailing: 28.6, Duration lossing: 11.46
# Shortest Route: ['DUS', 'DABGRA', 'SLB', 'TEB', 'DRA', 'DUS'], Total Distance: 285.89, Total Demand: 85.5, Duration sailing: 28.59, Duration lossing: 11.88
# Shortest Route: ['DUS', 'DABGRA', 'SLB', 'SLA', 'DSA', 'DUS'], Total Distance: 271.01, Total Demand: 90.5, Duration sailing: 27.1, Duration lossing: 12.57
# Shortest Route: ['DUS', 'DABGRA', 'TEB', 'SLA', 'DSA', 'DUS'], Total Distance: 280.81, Total Demand: 97.5, Duration sailing: 28.08, Duration lossing: 13.54
# Shortest Route: ['DUS', 'SLA', 'GKR', 'GUD', 'DABGRA', 'DUS'], Total Distance: 270.15, Total Demand: 90.5, Duration sailing: 27.01, Duration lossing: 12.57
# Shortest Route: ['DUS', 'SLB', 'GKR', 'GUD', 'DABGRA', 'DUS'], Total Distance: 270.03, Total Demand: 93.5, Duration sailing: 27.0, Duration lossing: 12.99
# Shortest Route: ['DUS', 'HDA', 'DABGRA', 'GKR', 'SLA', 'DUS'], Total Distance: 304.48, Total Demand: 90.5, Duration sailing: 30.45, Duration lossing: 12.57
# Shortest Route: ['DUS', 'HDA', 'DABGRA', 'GKR', 'SLB', 'DUS'], Total Distance: 304.36, Total Demand: 93.5, Duration sailing: 30.44, Duration lossing: 12.99
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'SLB', 'SLA', 'DUS'], Total Distance: 268.76, Total Demand: 79.5, Duration sailing: 26.88, Duration lossing: 11.04
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'TEB', 'SLA', 'DUS'], Total Distance: 277.24, Total Demand: 86.5, Duration sailing: 27.72, Duration lossing: 12.01
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'TEB', 'SLB', 'DUS'], Total Distance: 276.75, Total Demand: 89.5, Duration sailing: 27.68, Duration lossing: 12.43
# Shortest Route: ['DUS', 'HDA', 'DABGRA', 'GUD', 'SLA', 'DUS'], Total Distance: 306.6, Total Demand: 90.5, Duration sailing: 30.66, Duration lossing: 12.57
# Shortest Route: ['DUS', 'HDA', 'DABGRA', 'GUD', 'SLB', 'DUS'], Total Distance: 307.57, Total Demand: 93.5, Duration sailing: 30.76, Duration lossing: 12.99
# Shortest Route: ['DUS', 'DABGRA', 'GUD', 'SLB', 'SLA', 'DUS'], Total Distance: 271.97, Total Demand: 79.5, Duration sailing: 27.2, Duration lossing: 11.04
# Shortest Route: ['DUS', 'DABGRA', 'GUD', 'TEB', 'SLA', 'DUS'], Total Distance: 280.19, Total Demand: 86.5, Duration sailing: 28.02, Duration lossing: 12.01
# Shortest Route: ['DUS', 'DABGRA', 'GUD', 'TEB', 'SLB', 'DUS'], Total Distance: 279.7, Total Demand: 89.5, Duration sailing: 27.97, Duration lossing: 12.43
# Shortest Route: ['DUS', 'HDA', 'DABGRA', 'SLB', 'SLA', 'DUS'], Total Distance: 304.85, Total Demand: 79.5, Duration sailing: 30.48, Duration lossing: 11.04
# Shortest Route: ['DUS', 'HDA', 'DABGRA', 'TEB', 'SLA', 'DUS'], Total Distance: 314.65, Total Demand: 86.5, Duration sailing: 31.46, Duration lossing: 12.01
# Shortest Route: ['DUS', 'HDA', 'DABGRA', 'TEB', 'SLB', 'DUS'], Total Distance: 314.16, Total Demand: 89.5, Duration sailing: 31.42, Duration lossing: 12.43
# Shortest Route: ['DUS', 'SLA', 'TEB', 'SLB', 'DABGRA', 'DUS'], Total Distance: 277.98, Total Demand: 75.5, Duration sailing: 27.8, Duration lossing: 10.49
# Shortest Route: ['DUS', 'DRA', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 267.41, Total Demand: 79.0, Duration sailing: 26.74, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DSA', 'DRA', 'GKR', 'HDA', 'DUS'], Total Distance: 317.2, Total Demand: 79.0, Duration sailing: 31.72, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GKR', 'DSA', 'DUS'], Total Distance: 254.92, Total Demand: 65.0, Duration sailing: 25.49, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GKR', 'DSA', 'DUS'], Total Distance: 256.8, Total Demand: 68.0, Duration sailing: 25.68, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DSA', 'GKR', 'TEB', 'DRA', 'DUS'], Total Distance: 264.27, Total Demand: 75.0, Duration sailing: 26.43, Duration lossing: 10.42
# Shortest Route: ['DUS', 'HDA', 'GUD', 'DRA', 'DSA', 'DUS'], Total Distance: 313.22, Total Demand: 79.0, Duration sailing: 31.32, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GUD', 'DSA', 'DUS'], Total Distance: 267.5, Total Demand: 65.0, Duration sailing: 26.75, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GUD', 'DSA', 'DUS'], Total Distance: 270.47, Total Demand: 68.0, Duration sailing: 27.05, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GUD', 'DSA', 'DUS'], Total Distance: 277.68, Total Demand: 75.0, Duration sailing: 27.77, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'SLA', 'JSF', 'DSA', 'DUS'], Total Distance: 248.6, Total Demand: 87.0, Duration sailing: 24.86, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DRA', 'SLB', 'JSF', 'DSA', 'DUS'], Total Distance: 256.44, Total Demand: 90.0, Duration sailing: 25.64, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'JSF', 'TEB', 'DRA', 'DUS'], Total Distance: 266.0, Total Demand: 97.0, Duration sailing: 26.6, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'DSA', 'HDA', 'DUS'], Total Distance: 314.21, Total Demand: 65.0, Duration sailing: 31.42, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLB', 'HDA', 'DUS'], Total Distance: 319.89, Total Demand: 68.0, Duration sailing: 31.99, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DSA', 'DRA', 'TEB', 'HDA', 'DUS'], Total Distance: 327.73, Total Demand: 75.0, Duration sailing: 32.77, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DSA', 'SLB', 'SLA', 'DRA', 'DUS'], Total Distance: 251.28, Total Demand: 54.0, Duration sailing: 25.13, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'DSA', 'DUS'], Total Distance: 262.01, Total Demand: 61.0, Duration sailing: 26.2, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'DSA', 'DUS'], Total Distance: 261.0, Total Demand: 64.0, Duration sailing: 26.1, Duration lossing: 8.89
# Shortest Route: ['DUS', 'DRA', 'GKR', 'GUD', 'JSF', 'DUS'], Total Distance: 266.4, Total Demand: 90.0, Duration sailing: 26.64, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DRA', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 302.02, Total Demand: 68.0, Duration sailing: 30.2, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GKR', 'GUD', 'DUS'], Total Distance: 267.46, Total Demand: 54.0, Duration sailing: 26.75, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GKR', 'GUD', 'DUS'], Total Distance: 269.34, Total Demand: 57.0, Duration sailing: 26.93, Duration lossing: 7.92
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GKR', 'GUD', 'DUS'], Total Distance: 276.81, Total Demand: 64.0, Duration sailing: 27.68, Duration lossing: 8.89
# Shortest Route: ['DUS', 'DRA', 'GKR', 'JSF', 'HDA', 'DUS'], Total Distance: 315.71, Total Demand: 90.0, Duration sailing: 31.57, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GKR', 'JSF', 'DUS'], Total Distance: 256.65, Total Demand: 76.0, Duration sailing: 25.66, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GKR', 'JSF', 'DUS'], Total Distance: 258.53, Total Demand: 79.0, Duration sailing: 25.85, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GKR', 'JSF', 'DUS'], Total Distance: 266.0, Total Demand: 86.0, Duration sailing: 26.6, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GKR', 'HDA', 'DUS'], Total Distance: 302.86, Total Demand: 54.0, Duration sailing: 30.29, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GKR', 'HDA', 'DUS'], Total Distance: 304.74, Total Demand: 57.0, Duration sailing: 30.47, Duration lossing: 7.92
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GKR', 'HDA', 'DUS'], Total Distance: 312.21, Total Demand: 64.0, Duration sailing: 31.22, Duration lossing: 8.89
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'DUS'], Total Distance: 256.45, Total Demand: 43.0, Duration sailing: 25.65, Duration lossing: 5.97
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GKR', 'DUS'], Total Distance: 264.93, Total Demand: 50.0, Duration sailing: 26.49, Duration lossing: 6.95
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GKR', 'DUS'], Total Distance: 266.17, Total Demand: 53.0, Duration sailing: 26.62, Duration lossing: 7.36
# Shortest Route: ['DUS', 'DRA', 'JSF', 'GUD', 'HDA', 'DUS'], Total Distance: 316.48, Total Demand: 90.0, Duration sailing: 31.65, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GUD', 'JSF', 'DUS'], Total Distance: 266.49, Total Demand: 76.0, Duration sailing: 26.65, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GUD', 'JSF', 'DUS'], Total Distance: 269.46, Total Demand: 79.0, Duration sailing: 26.95, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GUD', 'JSF', 'DUS'], Total Distance: 276.67, Total Demand: 86.0, Duration sailing: 27.67, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GUD', 'HDA', 'DUS'], Total Distance: 302.11, Total Demand: 54.0, Duration sailing: 30.21, Duration lossing: 7.5
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GUD', 'HDA', 'DUS'], Total Distance: 305.08, Total Demand: 57.0, Duration sailing: 30.51, Duration lossing: 7.92
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 312.29, Total Demand: 64.0, Duration sailing: 31.23, Duration lossing: 8.89
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GUD', 'DUS'], Total Distance: 269.28, Total Demand: 43.0, Duration sailing: 26.93, Duration lossing: 5.97
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GUD', 'DUS'], Total Distance: 277.5, Total Demand: 50.0, Duration sailing: 27.75, Duration lossing: 6.95
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GUD', 'DUS'], Total Distance: 279.0, Total Demand: 53.0, Duration sailing: 27.9, Duration lossing: 7.36
# Shortest Route: ['DUS', 'DRA', 'SLA', 'JSF', 'HDA', 'DUS'], Total Distance: 307.03, Total Demand: 76.0, Duration sailing: 30.7, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DRA', 'SLB', 'JSF', 'HDA', 'DUS'], Total Distance: 314.87, Total Demand: 79.0, Duration sailing: 31.49, Duration lossing: 10.97
# Shortest Route: ['DUS', 'HDA', 'JSF', 'TEB', 'DRA', 'DUS'], Total Distance: 324.43, Total Demand: 86.0, Duration sailing: 32.44, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'JSF', 'DUS'], Total Distance: 254.57, Total Demand: 65.0, Duration sailing: 25.46, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'JSF', 'DUS'], Total Distance: 265.14, Total Demand: 72.0, Duration sailing: 26.51, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'JSF', 'DUS'], Total Distance: 264.29, Total Demand: 75.0, Duration sailing: 26.43, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'HDA', 'DUS'], Total Distance: 304.31, Total Demand: 43.0, Duration sailing: 30.43, Duration lossing: 5.97
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'HDA', 'DUS'], Total Distance: 313.16, Total Demand: 50.0, Duration sailing: 31.32, Duration lossing: 6.95
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'HDA', 'DUS'], Total Distance: 314.03, Total Demand: 53.0, Duration sailing: 31.4, Duration lossing: 7.36
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'SLB', 'DUS'], Total Distance: 259.96, Total Demand: 39.0, Duration sailing: 26.0, Duration lossing: 5.42
# Shortest Route: ['DUS', 'DSA', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 283.75, Total Demand: 83.0, Duration sailing: 28.38, Duration lossing: 11.53
# Shortest Route: ['DUS', 'SLA', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 259.73, Total Demand: 69.0, Duration sailing: 25.97, Duration lossing: 9.58
# Shortest Route: ['DUS', 'SLB', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 259.61, Total Demand: 72.0, Duration sailing: 25.96, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DSA', 'GUD', 'GKR', 'TEB', 'DUS'], Total Distance: 269.5, Total Demand: 79.0, Duration sailing: 26.95, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DSA', 'JSF', 'GKR', 'SLA', 'DUS'], Total Distance: 249.6, Total Demand: 91.0, Duration sailing: 24.96, Duration lossing: 12.64
# Shortest Route: ['DUS', 'DSA', 'JSF', 'GKR', 'SLB', 'DUS'], Total Distance: 249.48, Total Demand: 94.0, Duration sailing: 24.95, Duration lossing: 13.06
# Shortest Route: ['DUS', 'DSA', 'SLA', 'GKR', 'HDA', 'DUS'], Total Distance: 297.7, Total Demand: 69.0, Duration sailing: 29.77, Duration lossing: 9.58
# Shortest Route: ['DUS', 'DSA', 'SLB', 'GKR', 'HDA', 'DUS'], Total Distance: 295.87, Total Demand: 72.0, Duration sailing: 29.59, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DSA', 'TEB', 'GKR', 'HDA', 'DUS'], Total Distance: 305.86, Total Demand: 79.0, Duration sailing: 30.59, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DSA', 'GKR', 'SLB', 'SLA', 'DUS'], Total Distance: 247.88, Total Demand: 58.0, Duration sailing: 24.79, Duration lossing: 8.06
# Shortest Route: ['DUS', 'DSA', 'GKR', 'TEB', 'SLA', 'DUS'], Total Distance: 256.36, Total Demand: 65.0, Duration sailing: 25.64, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DSA', 'GKR', 'TEB', 'SLB', 'DUS'], Total Distance: 255.87, Total Demand: 68.0, Duration sailing: 25.59, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DSA', 'JSF', 'GUD', 'SLA', 'DUS'], Total Distance: 259.44, Total Demand: 91.0, Duration sailing: 25.94, Duration lossing: 12.64
# Shortest Route: ['DUS', 'DSA', 'JSF', 'GUD', 'SLB', 'DUS'], Total Distance: 260.41, Total Demand: 94.0, Duration sailing: 26.04, Duration lossing: 13.06
# Shortest Route: ['DUS', 'DSA', 'SLA', 'GUD', 'HDA', 'DUS'], Total Distance: 296.95, Total Demand: 69.0, Duration sailing: 29.7, Duration lossing: 9.58
# Shortest Route: ['DUS', 'HDA', 'GUD', 'SLB', 'DSA', 'DUS'], Total Distance: 296.21, Total Demand: 72.0, Duration sailing: 29.62, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DSA', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 305.94, Total Demand: 79.0, Duration sailing: 30.59, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DSA', 'GUD', 'SLB', 'SLA', 'DUS'], Total Distance: 261.55, Total Demand: 58.0, Duration sailing: 26.16, Duration lossing: 8.06
# Shortest Route: ['DUS', 'SLA', 'TEB', 'GUD', 'DSA', 'DUS'], Total Distance: 269.77, Total Demand: 65.0, Duration sailing: 26.98, Duration lossing: 9.03
# Shortest Route: ['DUS', 'SLB', 'TEB', 'GUD', 'DSA', 'DUS'], Total Distance: 269.28, Total Demand: 68.0, Duration sailing: 26.93, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DSA', 'JSF', 'SLA', 'HDA', 'DUS'], Total Distance: 301.11, Total Demand: 91.0, Duration sailing: 30.11, Duration lossing: 12.64
# Shortest Route: ['DUS', 'DSA', 'JSF', 'SLB', 'HDA', 'DUS'], Total Distance: 300.6, Total Demand: 94.0, Duration sailing: 30.06, Duration lossing: 13.06
# Shortest Route: ['DUS', 'DSA', 'JSF', 'SLB', 'SLA', 'DUS'], Total Distance: 247.52, Total Demand: 80.0, Duration sailing: 24.75, Duration lossing: 11.11
# Shortest Route: ['DUS', 'DSA', 'JSF', 'TEB', 'SLA', 'DUS'], Total Distance: 258.09, Total Demand: 87.0, Duration sailing: 25.81, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DSA', 'JSF', 'TEB', 'SLB', 'DUS'], Total Distance: 257.6, Total Demand: 90.0, Duration sailing: 25.76, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'SLA', 'SLB', 'HDA', 'DUS'], Total Distance: 299.15, Total Demand: 58.0, Duration sailing: 29.92, Duration lossing: 8.06
# Shortest Route: ['DUS', 'DSA', 'SLA', 'TEB', 'HDA', 'DUS'], Total Distance: 308.0, Total Demand: 65.0, Duration sailing: 30.8, Duration lossing: 9.03
# Shortest Route: ['DUS', 'DSA', 'SLB', 'TEB', 'HDA', 'DUS'], Total Distance: 305.8, Total Demand: 68.0, Duration sailing: 30.58, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DSA', 'SLB', 'TEB', 'SLA', 'DUS'], Total Distance: 253.09, Total Demand: 54.0, Duration sailing: 25.31, Duration lossing: 7.5
# Shortest Route: ['DUS', 'JSF', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 285.48, Total Demand: 94.0, Duration sailing: 28.55, Duration lossing: 13.06
# Shortest Route: ['DUS', 'SLA', 'GKR', 'GUD', 'JSF', 'DUS'], Total Distance: 258.72, Total Demand: 80.0, Duration sailing: 25.87, Duration lossing: 11.11
# Shortest Route: ['DUS', 'SLB', 'GKR', 'GUD', 'JSF', 'DUS'], Total Distance: 258.6, Total Demand: 83.0, Duration sailing: 25.86, Duration lossing: 11.53
# Shortest Route: ['DUS', 'JSF', 'GUD', 'GKR', 'TEB', 'DUS'], Total Distance: 268.49, Total Demand: 90.0, Duration sailing: 26.85, Duration lossing: 12.5
# Shortest Route: ['DUS', 'SLA', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 294.34, Total Demand: 58.0, Duration sailing: 29.43, Duration lossing: 8.06
# Shortest Route: ['DUS', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 294.22, Total Demand: 61.0, Duration sailing: 29.42, Duration lossing: 8.47
# Shortest Route: ['DUS', 'HDA', 'GUD', 'GKR', 'TEB', 'DUS'], Total Distance: 304.11, Total Demand: 68.0, Duration sailing: 30.41, Duration lossing: 9.45
# Shortest Route: ['DUS', 'SLA', 'SLB', 'GKR', 'GUD', 'DUS'], Total Distance: 260.42, Total Demand: 47.0, Duration sailing: 26.04, Duration lossing: 6.53
# Shortest Route: ['DUS', 'SLA', 'TEB', 'GKR', 'GUD', 'DUS'], Total Distance: 268.9, Total Demand: 54.0, Duration sailing: 26.89, Duration lossing: 7.5
# Shortest Route: ['DUS', 'SLB', 'TEB', 'GKR', 'GUD', 'DUS'], Total Distance: 268.41, Total Demand: 57.0, Duration sailing: 26.84, Duration lossing: 7.92
# Shortest Route: ['DUS', 'JSF', 'SLA', 'GKR', 'HDA', 'DUS'], Total Distance: 302.24, Total Demand: 80.0, Duration sailing: 30.22, Duration lossing: 11.11
# Shortest Route: ['DUS', 'JSF', 'SLB', 'GKR', 'HDA', 'DUS'], Total Distance: 299.16, Total Demand: 83.0, Duration sailing: 29.92, Duration lossing: 11.53
# Shortest Route: ['DUS', 'JSF', 'TEB', 'GKR', 'HDA', 'DUS'], Total Distance: 308.99, Total Demand: 90.0, Duration sailing: 30.9, Duration lossing: 12.5
# Shortest Route: ['DUS', 'SLA', 'SLB', 'GKR', 'JSF', 'DUS'], Total Distance: 249.61, Total Demand: 69.0, Duration sailing: 24.96, Duration lossing: 9.58
# Shortest Route: ['DUS', 'JSF', 'GKR', 'TEB', 'SLA', 'DUS'], Total Distance: 258.09, Total Demand: 76.0, Duration sailing: 25.81, Duration lossing: 10.56
# Shortest Route: ['DUS', 'JSF', 'GKR', 'TEB', 'SLB', 'DUS'], Total Distance: 257.6, Total Demand: 79.0, Duration sailing: 25.76, Duration lossing: 10.97
# Shortest Route: ['DUS', 'SLA', 'SLB', 'GKR', 'HDA', 'DUS'], Total Distance: 295.82, Total Demand: 47.0, Duration sailing: 29.58, Duration lossing: 6.53
# Shortest Route: ['DUS', 'SLA', 'TEB', 'GKR', 'HDA', 'DUS'], Total Distance: 304.3, Total Demand: 54.0, Duration sailing: 30.43, Duration lossing: 7.5
# Shortest Route: ['DUS', 'SLB', 'TEB', 'GKR', 'HDA', 'DUS'], Total Distance: 303.81, Total Demand: 57.0, Duration sailing: 30.38, Duration lossing: 7.92
# Shortest Route: ['DUS', 'GKR', 'TEB', 'SLB', 'SLA', 'DUS'], Total Distance: 257.52, Total Demand: 43.0, Duration sailing: 25.75, Duration lossing: 5.97
# Shortest Route: ['DUS', 'JSF', 'SLA', 'GUD', 'HDA', 'DUS'], Total Distance: 301.49, Total Demand: 80.0, Duration sailing: 30.15, Duration lossing: 11.11
# Shortest Route: ['DUS', 'JSF', 'SLB', 'GUD', 'HDA', 'DUS'], Total Distance: 299.5, Total Demand: 83.0, Duration sailing: 29.95, Duration lossing: 11.53
# Shortest Route: ['DUS', 'JSF', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 309.07, Total Demand: 90.0, Duration sailing: 30.91, Duration lossing: 12.5
# Shortest Route: ['DUS', 'SLA', 'SLB', 'GUD', 'JSF', 'DUS'], Total Distance: 260.54, Total Demand: 69.0, Duration sailing: 26.05, Duration lossing: 9.58
# Shortest Route: ['DUS', 'JSF', 'GUD', 'TEB', 'SLA', 'DUS'], Total Distance: 268.76, Total Demand: 76.0, Duration sailing: 26.88, Duration lossing: 10.56
# Shortest Route: ['DUS', 'JSF', 'GUD', 'TEB', 'SLB', 'DUS'], Total Distance: 268.27, Total Demand: 79.0, Duration sailing: 26.83, Duration lossing: 10.97
# Shortest Route: ['DUS', 'HDA', 'GUD', 'SLB', 'SLA', 'DUS'], Total Distance: 296.16, Total Demand: 47.0, Duration sailing: 29.62, Duration lossing: 6.53
# Shortest Route: ['DUS', 'HDA', 'GUD', 'TEB', 'SLA', 'DUS'], Total Distance: 304.38, Total Demand: 54.0, Duration sailing: 30.44, Duration lossing: 7.5
# Shortest Route: ['DUS', 'HDA', 'GUD', 'TEB', 'SLB', 'DUS'], Total Distance: 303.89, Total Demand: 57.0, Duration sailing: 30.39, Duration lossing: 7.92
# Shortest Route: ['DUS', 'GUD', 'TEB', 'SLB', 'SLA', 'DUS'], Total Distance: 270.09, Total Demand: 43.0, Duration sailing: 27.01, Duration lossing: 5.97
# Shortest Route: ['DUS', 'JSF', 'SLA', 'SLB', 'HDA', 'DUS'], Total Distance: 303.69, Total Demand: 69.0, Duration sailing: 30.37, Duration lossing: 9.58
# Shortest Route: ['DUS', 'JSF', 'SLA', 'TEB', 'HDA', 'DUS'], Total Distance: 312.54, Total Demand: 76.0, Duration sailing: 31.25, Duration lossing: 10.56
# Shortest Route: ['DUS', 'JSF', 'SLB', 'TEB', 'HDA', 'DUS'], Total Distance: 309.09, Total Demand: 79.0, Duration sailing: 30.91, Duration lossing: 10.97
# Shortest Route: ['DUS', 'JSF', 'SLB', 'TEB', 'SLA', 'DUS'], Total Distance: 256.38, Total Demand: 65.0, Duration sailing: 25.64, Duration lossing: 9.03
# Shortest Route: ['DUS', 'HDA', 'TEB', 'SLB', 'SLA', 'DUS'], Total Distance: 305.75, Total Demand: 43.0, Duration sailing: 30.58, Duration lossing: 5.97
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'SLB', 'SLA', 'DRA', 'DUS'], Total Distance: 277.69, Total Demand: 93.5, Duration sailing: 27.77, Duration lossing: 12.99
# Shortest Route: ['DUS', 'DABGRA', 'GUD', 'SLB', 'SLA', 'DRA', 'DUS'], Total Distance: 280.9, Total Demand: 93.5, Duration sailing: 28.09, Duration lossing: 12.99
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'DABGRA', 'HDA', 'DUS'], Total Distance: 313.78, Total Demand: 93.5, Duration sailing: 31.38, Duration lossing: 12.99
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'SLB', 'DABGRA', 'DUS'], Total Distance: 286.91, Total Demand: 89.5, Duration sailing: 28.69, Duration lossing: 12.43
# Shortest Route: ['DUS', 'SLA', 'SLB', 'GKR', 'GUD', 'DABGRA', 'DUS'], Total Distance: 272.04, Total Demand: 97.5, Duration sailing: 27.2, Duration lossing: 13.54
# Shortest Route: ['DUS', 'HDA', 'DABGRA', 'GKR', 'SLB', 'SLA', 'DUS'], Total Distance: 306.37, Total Demand: 97.5, Duration sailing: 30.64, Duration lossing: 13.54
# Shortest Route: ['DUS', 'DABGRA', 'GKR', 'TEB', 'SLB', 'SLA', 'DUS'], Total Distance: 278.76, Total Demand: 93.5, Duration sailing: 27.88, Duration lossing: 12.99
# ...
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'TEB', 'HDA', 'DUS'], Total Distance: 328.75, Total Demand: 79.0, Duration sailing: 32.88, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DSA', 'DRA', 'TEB', 'SLB', 'HDA', 'DUS'], Total Distance: 329.62, Total Demand: 82.0, Duration sailing: 32.96, Duration lossing: 11.39
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'SLB', 'DSA', 'DUS'], Total Distance: 262.02, Total Demand: 68.0, Duration sailing: 26.2, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GKR', 'GUD', 'JSF', 'DUS'], Total Distance: 267.65, Total Demand: 94.0, Duration sailing: 26.76, Duration lossing: 13.06
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GKR', 'GUD', 'JSF', 'DUS'], Total Distance: 269.53, Total Demand: 97.0, Duration sailing: 26.95, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 303.27, Total Demand: 72.0, Duration sailing: 30.33, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 305.15, Total Demand: 75.0, Duration sailing: 30.51, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 312.62, Total Demand: 82.0, Duration sailing: 31.26, Duration lossing: 11.39
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'GUD', 'DUS'], Total Distance: 269.35, Total Demand: 61.0, Duration sailing: 26.94, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GKR', 'GUD', 'DUS'], Total Distance: 277.83, Total Demand: 68.0, Duration sailing: 27.78, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GKR', 'GUD', 'DUS'], Total Distance: 279.07, Total Demand: 71.0, Duration sailing: 27.91, Duration lossing: 9.86
# Shortest Route: ['DUS', 'DRA', 'SLA', 'GKR', 'JSF', 'HDA', 'DUS'], Total Distance: 316.96, Total Demand: 94.0, Duration sailing: 31.7, Duration lossing: 13.06
# Shortest Route: ['DUS', 'DRA', 'SLB', 'GKR', 'JSF', 'HDA', 'DUS'], Total Distance: 318.84, Total Demand: 97.0, Duration sailing: 31.88, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'JSF', 'DUS'], Total Distance: 258.54, Total Demand: 83.0, Duration sailing: 25.85, Duration lossing: 11.53
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GKR', 'JSF', 'DUS'], Total Distance: 267.02, Total Demand: 90.0, Duration sailing: 26.7, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GKR', 'JSF', 'DUS'], Total Distance: 268.26, Total Demand: 93.0, Duration sailing: 26.83, Duration lossing: 12.92
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'HDA', 'DUS'], Total Distance: 304.75, Total Demand: 61.0, Duration sailing: 30.48, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GKR', 'HDA', 'DUS'], Total Distance: 313.23, Total Demand: 68.0, Duration sailing: 31.32, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GKR', 'HDA', 'DUS'], Total Distance: 314.47, Total Demand: 71.0, Duration sailing: 31.45, Duration lossing: 9.86
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'DUS'], Total Distance: 266.45, Total Demand: 57.0, Duration sailing: 26.65, Duration lossing: 7.92
# Shortest Route: ['DUS', 'JSF', 'DRA', 'SLA', 'GUD', 'HDA', 'DUS'], Total Distance: 326.65, Total Demand: 94.0, Duration sailing: 32.66, Duration lossing: 13.06
# Shortest Route: ['DUS', 'JSF', 'DRA', 'SLB', 'GUD', 'HDA', 'DUS'], Total Distance: 329.62, Total Demand: 97.0, Duration sailing: 32.96, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GUD', 'JSF', 'DUS'], Total Distance: 269.47, Total Demand: 83.0, Duration sailing: 26.95, Duration lossing: 11.53
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GUD', 'JSF', 'DUS'], Total Distance: 277.69, Total Demand: 90.0, Duration sailing: 27.77, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GUD', 'JSF', 'DUS'], Total Distance: 279.19, Total Demand: 93.0, Duration sailing: 27.92, Duration lossing: 12.92
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GUD', 'HDA', 'DUS'], Total Distance: 305.09, Total Demand: 61.0, Duration sailing: 30.51, Duration lossing: 8.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 313.31, Total Demand: 68.0, Duration sailing: 31.33, Duration lossing: 9.45
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GUD', 'HDA', 'DUS'], Total Distance: 314.81, Total Demand: 71.0, Duration sailing: 31.48, Duration lossing: 9.86
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'DUS'], Total Distance: 279.02, Total Demand: 57.0, Duration sailing: 27.9, Duration lossing: 7.92
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'JSF', 'HDA', 'DUS'], Total Distance: 314.88, Total Demand: 83.0, Duration sailing: 31.49, Duration lossing: 11.53
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'JSF', 'HDA', 'DUS'], Total Distance: 325.45, Total Demand: 90.0, Duration sailing: 32.54, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'JSF', 'HDA', 'DUS'], Total Distance: 324.6, Total Demand: 93.0, Duration sailing: 32.46, Duration lossing: 12.92
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'SLB', 'JSF', 'DUS'], Total Distance: 265.31, Total Demand: 79.0, Duration sailing: 26.53, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'HDA', 'DUS'], Total Distance: 314.68, Total Demand: 57.0, Duration sailing: 31.47, Duration lossing: 7.92
# Shortest Route: ['DUS', 'DSA', 'SLA', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 298.11, Total Demand: 87.0, Duration sailing: 29.81, Duration lossing: 12.08
# Shortest Route: ['DUS', 'DSA', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 296.28, Total Demand: 90.0, Duration sailing: 29.63, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 306.27, Total Demand: 97.0, Duration sailing: 30.63, Duration lossing: 13.47
# Shortest Route: ['DUS', 'SLA', 'SLB', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 261.62, Total Demand: 76.0, Duration sailing: 26.16, Duration lossing: 10.56
# Shortest Route: ['DUS', 'SLA', 'TEB', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 270.1, Total Demand: 83.0, Duration sailing: 27.01, Duration lossing: 11.53
# Shortest Route: ['DUS', 'SLB', 'TEB', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 269.61, Total Demand: 86.0, Duration sailing: 26.96, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DSA', 'JSF', 'GKR', 'SLB', 'SLA', 'DUS'], Total Distance: 251.49, Total Demand: 98.0, Duration sailing: 25.15, Duration lossing: 13.61
# Shortest Route: ['DUS', 'DSA', 'SLA', 'SLB', 'GKR', 'HDA', 'DUS'], Total Distance: 299.59, Total Demand: 76.0, Duration sailing: 29.96, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DSA', 'SLA', 'TEB', 'GKR', 'HDA', 'DUS'], Total Distance: 308.07, Total Demand: 83.0, Duration sailing: 30.81, Duration lossing: 11.53
# Shortest Route: ['DUS', 'DSA', 'SLB', 'TEB', 'GKR', 'HDA', 'DUS'], Total Distance: 305.87, Total Demand: 86.0, Duration sailing: 30.59, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DSA', 'GKR', 'TEB', 'SLB', 'SLA', 'DUS'], Total Distance: 257.88, Total Demand: 72.0, Duration sailing: 25.79, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DSA', 'JSF', 'GUD', 'SLB', 'SLA', 'DUS'], Total Distance: 262.42, Total Demand: 98.0, Duration sailing: 26.24, Duration lossing: 13.61
# Shortest Route: ['DUS', 'DSA', 'SLA', 'SLB', 'GUD', 'HDA', 'DUS'], Total Distance: 299.93, Total Demand: 76.0, Duration sailing: 29.99, Duration lossing: 10.56
# Shortest Route: ['DUS', 'DSA', 'SLA', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 308.15, Total Demand: 83.0, Duration sailing: 30.82, Duration lossing: 11.53
# Shortest Route: ['DUS', 'DSA', 'SLB', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 305.95, Total Demand: 86.0, Duration sailing: 30.6, Duration lossing: 11.95
# Shortest Route: ['DUS', 'SLA', 'SLB', 'TEB', 'GUD', 'DSA', 'DUS'], Total Distance: 271.29, Total Demand: 72.0, Duration sailing: 27.13, Duration lossing: 10.0
# Shortest Route: ['DUS', 'DSA', 'JSF', 'SLA', 'SLB', 'HDA', 'DUS'], Total Distance: 305.57, Total Demand: 98.0, Duration sailing: 30.56, Duration lossing: 13.61
# Shortest Route: ['DUS', 'DSA', 'JSF', 'SLB', 'TEB', 'SLA', 'DUS'], Total Distance: 258.26, Total Demand: 94.0, Duration sailing: 25.83, Duration lossing: 13.06
# Shortest Route: ['DUS', 'DSA', 'SLA', 'SLB', 'TEB', 'HDA', 'DUS'], Total Distance: 309.52, Total Demand: 72.0, Duration sailing: 30.95, Duration lossing: 10.0
# Shortest Route: ['DUS', 'JSF', 'SLA', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 302.65, Total Demand: 98.0, Duration sailing: 30.27, Duration lossing: 13.61
# Shortest Route: ['DUS', 'SLA', 'SLB', 'GKR', 'GUD', 'JSF', 'DUS'], Total Distance: 260.61, Total Demand: 87.0, Duration sailing: 26.06, Duration lossing: 12.08
# Shortest Route: ['DUS', 'SLA', 'TEB', 'GKR', 'GUD', 'JSF', 'DUS'], Total Distance: 269.09, Total Demand: 94.0, Duration sailing: 26.91, Duration lossing: 13.06
# Shortest Route: ['DUS', 'SLB', 'TEB', 'GKR', 'GUD', 'JSF', 'DUS'], Total Distance: 268.6, Total Demand: 97.0, Duration sailing: 26.86, Duration lossing: 13.47
# Shortest Route: ['DUS', 'SLA', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 296.23, Total Demand: 65.0, Duration sailing: 29.62, Duration lossing: 9.03
# Shortest Route: ['DUS', 'SLA', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 304.71, Total Demand: 72.0, Duration sailing: 30.47, Duration lossing: 10.0
# Shortest Route: ['DUS', 'SLB', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 304.22, Total Demand: 75.0, Duration sailing: 30.42, Duration lossing: 10.42
# Shortest Route: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'DUS'], Total Distance: 270.42, Total Demand: 61.0, Duration sailing: 27.04, Duration lossing: 8.47
# Shortest Route: ['DUS', 'JSF', 'SLA', 'SLB', 'GKR', 'HDA', 'DUS'], Total Distance: 304.13, Total Demand: 87.0, Duration sailing: 30.41, Duration lossing: 12.08
# Shortest Route: ['DUS', 'JSF', 'SLA', 'TEB', 'GKR', 'HDA', 'DUS'], Total Distance: 312.61, Total Demand: 94.0, Duration sailing: 31.26, Duration lossing: 13.06
# Shortest Route: ['DUS', 'JSF', 'SLB', 'TEB', 'GKR', 'HDA', 'DUS'], Total Distance: 309.16, Total Demand: 97.0, Duration sailing: 30.92, Duration lossing: 13.47
# Shortest Route: ['DUS', 'JSF', 'GKR', 'TEB', 'SLB', 'SLA', 'DUS'], Total Distance: 259.61, Total Demand: 83.0, Duration sailing: 25.96, Duration lossing: 11.53
# Shortest Route: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'HDA', 'DUS'], Total Distance: 305.82, Total Demand: 61.0, Duration sailing: 30.58, Duration lossing: 8.47
# Shortest Route: ['DUS', 'JSF', 'SLA', 'SLB', 'GUD', 'HDA', 'DUS'], Total Distance: 304.47, Total Demand: 87.0, Duration sailing: 30.45, Duration lossing: 12.08
# Shortest Route: ['DUS', 'JSF', 'SLA', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 312.69, Total Demand: 94.0, Duration sailing: 31.27, Duration lossing: 13.06
# Shortest Route: ['DUS', 'JSF', 'SLB', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 309.24, Total Demand: 97.0, Duration sailing: 30.92, Duration lossing: 13.47
# Shortest Route: ['DUS', 'JSF', 'GUD', 'TEB', 'SLB', 'SLA', 'DUS'], Total Distance: 270.28, Total Demand: 83.0, Duration sailing: 27.03, Duration lossing: 11.53
# Shortest Route: ['DUS', 'HDA', 'GUD', 'TEB', 'SLB', 'SLA', 'DUS'], Total Distance: 305.9, Total Demand: 61.0, Duration sailing: 30.59, Duration lossing: 8.47
# Shortest Route: ['DUS', 'JSF', 'SLA', 'SLB', 'TEB', 'HDA', 'DUS'], Total Distance: 314.06, Total Demand: 83.0, Duration sailing: 31.41, Duration lossing: 11.53
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 270.55, Total Demand: 90.0, Duration sailing: 27.06, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 279.03, Total Demand: 97.0, Duration sailing: 27.9, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 280.27, Total Demand: 100.0, Duration sailing: 28.03, Duration lossing: 13.89
# Shortest Route: ['DUS', 'HDA', 'GKR', 'SLB', 'SLA', 'DRA', 'DSA', 'DUS'], Total Distance: 320.34, Total Demand: 90.0, Duration sailing: 32.03, Duration lossing: 12.5
# Shortest Route: ['DUS', 'HDA', 'GKR', 'TEB', 'SLA', 'DRA', 'DSA', 'DUS'], Total Distance: 328.82, Total Demand: 97.0, Duration sailing: 32.88, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DSA', 'DRA', 'TEB', 'SLB', 'GKR', 'HDA', 'DUS'], Total Distance: 330.06, Total Demand: 100.0, Duration sailing: 33.01, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'DSA', 'DUS'], Total Distance: 266.81, Total Demand: 86.0, Duration sailing: 26.68, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'SLB', 'GUD', 'HDA', 'DUS'], Total Distance: 320.68, Total Demand: 90.0, Duration sailing: 32.07, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 328.9, Total Demand: 97.0, Duration sailing: 32.89, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DSA', 'DRA', 'TEB', 'SLB', 'GUD', 'HDA', 'DUS'], Total Distance: 330.4, Total Demand: 100.0, Duration sailing: 33.04, Duration lossing: 13.89
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'DSA', 'DUS'], Total Distance: 280.22, Total Demand: 86.0, Duration sailing: 28.02, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DSA', 'DRA', 'SLA', 'SLB', 'TEB', 'HDA', 'DUS'], Total Distance: 330.27, Total Demand: 86.0, Duration sailing: 33.03, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 305.16, Total Demand: 79.0, Duration sailing: 30.52, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 313.64, Total Demand: 86.0, Duration sailing: 31.36, Duration lossing: 11.95
# Shortest Route: ['DUS', 'DRA', 'TEB', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 314.88, Total Demand: 89.0, Duration sailing: 31.49, Duration lossing: 12.36
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'DUS'], Total Distance: 279.35, Total Demand: 75.0, Duration sailing: 27.94, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'JSF', 'DUS'], Total Distance: 268.54, Total Demand: 97.0, Duration sailing: 26.85, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'HDA', 'DUS'], Total Distance: 314.75, Total Demand: 75.0, Duration sailing: 31.48, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'JSF', 'DUS'], Total Distance: 279.21, Total Demand: 97.0, Duration sailing: 27.92, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 314.83, Total Demand: 75.0, Duration sailing: 31.48, Duration lossing: 10.42
# Shortest Route: ['DUS', 'DRA', 'SLA', 'TEB', 'SLB', 'JSF', 'HDA', 'DUS'], Total Distance: 325.62, Total Demand: 97.0, Duration sailing: 32.56, Duration lossing: 13.47
# Shortest Route: ['DUS', 'DSA', 'SLA', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 300.0, Total Demand: 94.0, Duration sailing: 30.0, Duration lossing: 13.06
# Shortest Route: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'DSA', 'DUS'], Total Distance: 271.62, Total Demand: 90.0, Duration sailing: 27.16, Duration lossing: 12.5
# Shortest Route: ['DUS', 'HDA', 'GKR', 'TEB', 'SLB', 'SLA', 'DSA', 'DUS'], Total Distance: 309.59, Total Demand: 90.0, Duration sailing: 30.96, Duration lossing: 12.5
# Shortest Route: ['DUS', 'DSA', 'SLA', 'SLB', 'TEB', 'GUD', 'HDA', 'DUS'], Total Distance: 309.67, Total Demand: 90.0, Duration sailing: 30.97, Duration lossing: 12.5
# Shortest Route: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 306.23, Total Demand: 79.0, Duration sailing: 30.62, Duration lossing: 10.97
# Shortest Route: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS'], Total Distance: 315.16, Total Demand: 93.0, Duration sailing: 31.52, Duration lossing: 12.92
# 444

# %%
routes_only = [route for route, _, _, _, _ in shortest_routes_dict.values()]
route_file = f'{mappenavn}/routes.csv'

def write_to_csv(filename, data):
    with open(filename, "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerows(data)

write_to_csv(route_file, routes_only)

# %% [markdown]
# ## NEW CLUSTERING CALCULATION

# %%
input_filename = f'{mappenavn}/routes.csv'
output_filename = f'{mappenavn}/processed_routes.csv'

def split_into_threes(word):
    if len(word) > 3:
        return ','.join([word[i:i+3] for i in range(0, len(word), 3)])
    else:
        return word

def process_csv_file(input_filename, output_filename):
    with open(input_filename, 'r', newline='') as file, open(output_filename, 'w', newline='') as outfile:
        reader = csv.reader(file)
        writer = csv.writer(outfile)

        for row in reader:
            processed_row = []
            for column in row:
                processed_segments = [split_into_threes(segment) for segment in column.split(',')]
                processed_row.append(','.join(processed_segments))

            outfile.write(','.join(processed_row) + '\n')

process_csv_file(input_filename, output_filename)

with open(output_filename, 'r') as processed_file:
    print(processed_file.read())
# Out:
# DUS,DAB,GRA,DUS
# DUS,DRA,DUS
# DUS,DSA,DUS
# DUS,GKR,DUS
# DUS,GUD,DUS
# DUS,JSF,DUS
# DUS,HDA,DUS
# DUS,SLA,DUS
# DUS,SLB,DUS
# DUS,TEB,DUS
# DUS,DAB,GRA,DRA,DUS
# DUS,DAB,GRA,DSA,DUS
# DUS,DAB,GRA,GKR,DUS
# DUS,DAB,GRA,GUD,DUS
# DUS,DAB,GRA,JSF,DUS
# DUS,DAB,GRA,HDA,DUS
# DUS,DAB,GRA,SLA,DUS
# DUS,DAB,GRA,SLB,DUS
# DUS,DAB,GRA,TEB,DUS
# DUS,DRA,DSA,DUS
# DUS,DRA,GKR,DUS
# DUS,DRA,GUD,DUS
# DUS,DRA,JSF,DUS
# DUS,DRA,HDA,DUS
# DUS,DRA,SLA,DUS
# DUS,DRA,SLB,DUS
# DUS,DRA,TEB,DUS
# DUS,DSA,GKR,DUS
# DUS,GUD,DSA,DUS
# DUS,DSA,JSF,DUS
# DUS,DSA,HDA,DUS
# DUS,DSA,SLA,DUS
# DUS,SLB,DSA,DUS
# DUS,DSA,TEB,DUS
# DUS,GKR,GUD,DUS
# DUS,GKR,JSF,DUS
# DUS,GKR,HDA,DUS
# DUS,GKR,SLA,DUS
# DUS,GKR,SLB,DUS
# DUS,GKR,TEB,DUS
# DUS,GUD,JSF,DUS
# DUS,GUD,HDA,DUS
# DUS,GUD,SLA,DUS
# DUS,GUD,SLB,DUS
# DUS,GUD,TEB,DUS
# DUS,JSF,HDA,DUS
# DUS,SLA,JSF,DUS
# DUS,JSF,SLB,DUS
# DUS,JSF,TEB,DUS
# DUS,SLA,HDA,DUS
# DUS,HDA,SLB,DUS
# DUS,HDA,TEB,DUS
# DUS,SLA,SLB,DUS
# DUS,SLA,TEB,DUS
# DUS,SLB,TEB,DUS
# DUS,DAB,GRA,DSA,DRA,DUS
# DUS,DAB,GRA,GKR,DRA,DUS
# DUS,DAB,GRA,GUD,DRA,DUS
# DUS,DRA,DAB,GRA,HDA,DUS
# DUS,DAB,GRA,SLA,DRA,DUS
# DUS,DRA,SLB,DAB,GRA,DUS
# DUS,DRA,TEB,DAB,GRA,DUS
# DUS,DAB,GRA,GKR,DSA,DUS
# DUS,DAB,GRA,GUD,DSA,DUS
# DUS,DSA,DAB,GRA,HDA,DUS
# DUS,DAB,GRA,SLA,DSA,DUS
# DUS,DAB,GRA,SLB,DSA,DUS
# DUS,DSA,TEB,DAB,GRA,DUS
# DUS,GKR,GUD,DAB,GRA,DUS
# DUS,GKR,DAB,GRA,HDA,DUS
# DUS,DAB,GRA,GKR,SLA,DUS
# DUS,DAB,GRA,GKR,SLB,DUS
# DUS,DAB,GRA,GKR,TEB,DUS
# DUS,DAB,GRA,GUD,HDA,DUS
# DUS,DAB,GRA,GUD,SLA,DUS
# DUS,DAB,GRA,GUD,SLB,DUS
# DUS,TEB,GUD,DAB,GRA,DUS
# DUS,DAB,GRA,JSF,SLA,DUS
# DUS,JSF,SLB,DAB,GRA,DUS
# DUS,HDA,DAB,GRA,SLA,DUS
# DUS,HDA,DAB,GRA,SLB,DUS
# DUS,HDA,DAB,GRA,TEB,DUS
# DUS,DAB,GRA,SLB,SLA,DUS
# DUS,SLA,TEB,DAB,GRA,DUS
# DUS,DAB,GRA,TEB,SLB,DUS
# DUS,DRA,GKR,DSA,DUS
# DUS,DRA,GUD,DSA,DUS
# DUS,DSA,JSF,DRA,DUS
# DUS,DRA,DSA,HDA,DUS
# DUS,DRA,SLA,DSA,DUS
# DUS,DRA,SLB,DSA,DUS
# DUS,DRA,TEB,DSA,DUS
# DUS,DRA,GKR,GUD,DUS
# DUS,DRA,GKR,JSF,DUS
# DUS,DRA,GKR,HDA,DUS
# DUS,DRA,SLA,GKR,DUS
# DUS,DRA,SLB,GKR,DUS
# DUS,DRA,TEB,GKR,DUS
# DUS,DRA,GUD,JSF,DUS
# DUS,DRA,GUD,HDA,DUS
# DUS,DRA,SLA,GUD,DUS
# DUS,DRA,SLB,GUD,DUS
# DUS,DRA,TEB,GUD,DUS
# DUS,DRA,JSF,HDA,DUS
# DUS,DRA,SLA,JSF,DUS
# DUS,DRA,SLB,JSF,DUS
# DUS,DRA,TEB,JSF,DUS
# DUS,DRA,SLA,HDA,DUS
# DUS,DRA,SLB,HDA,DUS
# DUS,DRA,TEB,HDA,DUS
# DUS,SLB,SLA,DRA,DUS
# DUS,DRA,TEB,SLA,DUS
# DUS,DRA,TEB,SLB,DUS
# DUS,DSA,GKR,GUD,DUS
# DUS,DSA,GKR,JSF,DUS
# DUS,HDA,GKR,DSA,DUS
# DUS,DSA,GKR,SLA,DUS
# DUS,DSA,GKR,SLB,DUS
# DUS,DSA,GKR,TEB,DUS
# DUS,DSA,GUD,JSF,DUS
# DUS,DSA,GUD,HDA,DUS
# DUS,DSA,GUD,SLA,DUS
# DUS,DSA,GUD,SLB,DUS
# DUS,DSA,GUD,TEB,DUS
# DUS,DSA,JSF,HDA,DUS
# DUS,DSA,JSF,SLA,DUS
# DUS,DSA,JSF,SLB,DUS
# DUS,DSA,JSF,TEB,DUS
# DUS,DSA,SLA,HDA,DUS
# DUS,DSA,SLB,HDA,DUS
# DUS,DSA,TEB,HDA,DUS
# DUS,SLA,SLB,DSA,DUS
# DUS,DSA,TEB,SLA,DUS
# DUS,DSA,SLB,TEB,DUS
# DUS,GKR,GUD,JSF,DUS
# DUS,GKR,GUD,HDA,DUS
# DUS,SLA,GKR,GUD,DUS
# DUS,SLB,GKR,GUD,DUS
# DUS,GUD,GKR,TEB,DUS
# DUS,JSF,GKR,HDA,DUS
# DUS,SLA,GKR,JSF,DUS
# DUS,SLB,GKR,JSF,DUS
# DUS,JSF,GKR,TEB,DUS
# DUS,SLA,GKR,HDA,DUS
# DUS,SLB,GKR,HDA,DUS
# DUS,HDA,GKR,TEB,DUS
# DUS,GKR,SLB,SLA,DUS
# DUS,GKR,TEB,SLA,DUS
# DUS,GKR,TEB,SLB,DUS
# DUS,JSF,GUD,HDA,DUS
# DUS,JSF,GUD,SLA,DUS
# DUS,SLB,GUD,JSF,DUS
# DUS,JSF,GUD,TEB,DUS
# DUS,HDA,GUD,SLA,DUS
# DUS,HDA,GUD,SLB,DUS
# DUS,HDA,GUD,TEB,DUS
# DUS,GUD,SLB,SLA,DUS
# DUS,GUD,TEB,SLA,DUS
# DUS,GUD,TEB,SLB,DUS
# DUS,HDA,JSF,SLA,DUS
# DUS,JSF,SLB,HDA,DUS
# DUS,JSF,TEB,HDA,DUS
# DUS,JSF,SLB,SLA,DUS
# DUS,JSF,TEB,SLA,DUS
# DUS,JSF,TEB,SLB,DUS
# DUS,HDA,SLB,SLA,DUS
# DUS,HDA,TEB,SLA,DUS
# DUS,HDA,TEB,SLB,DUS
# DUS,SLA,TEB,SLB,DUS
# DUS,DAB,GRA,DSA,SLA,DRA,DUS
# DUS,DAB,GRA,GKR,SLA,DRA,DUS
# DUS,DAB,GRA,GKR,SLB,DRA,DUS
# DUS,DAB,GRA,GKR,TEB,DRA,DUS
# DUS,DAB,GRA,GUD,SLA,DRA,DUS
# DUS,DAB,GRA,GUD,SLB,DRA,DUS
# DUS,DAB,GRA,GUD,TEB,DRA,DUS
# DUS,DRA,SLA,DAB,GRA,HDA,DUS
# DUS,DRA,SLB,DAB,GRA,HDA,DUS
# DUS,DRA,TEB,DAB,GRA,HDA,DUS
# DUS,DAB,GRA,SLB,SLA,DRA,DUS
# DUS,DRA,SLA,TEB,DAB,GRA,DUS
# DUS,DAB,GRA,SLB,TEB,DRA,DUS
# DUS,DAB,GRA,SLB,SLA,DSA,DUS
# DUS,DAB,GRA,TEB,SLA,DSA,DUS
# DUS,SLA,GKR,GUD,DAB,GRA,DUS
# DUS,SLB,GKR,GUD,DAB,GRA,DUS
# DUS,HDA,DAB,GRA,GKR,SLA,DUS
# DUS,HDA,DAB,GRA,GKR,SLB,DUS
# DUS,DAB,GRA,GKR,SLB,SLA,DUS
# DUS,DAB,GRA,GKR,TEB,SLA,DUS
# DUS,DAB,GRA,GKR,TEB,SLB,DUS
# DUS,HDA,DAB,GRA,GUD,SLA,DUS
# DUS,HDA,DAB,GRA,GUD,SLB,DUS
# DUS,DAB,GRA,GUD,SLB,SLA,DUS
# DUS,DAB,GRA,GUD,TEB,SLA,DUS
# DUS,DAB,GRA,GUD,TEB,SLB,DUS
# DUS,HDA,DAB,GRA,SLB,SLA,DUS
# DUS,HDA,DAB,GRA,TEB,SLA,DUS
# DUS,HDA,DAB,GRA,TEB,SLB,DUS
# DUS,SLA,TEB,SLB,DAB,GRA,DUS
# DUS,DRA,GKR,GUD,DSA,DUS
# DUS,DSA,DRA,GKR,HDA,DUS
# DUS,DRA,SLA,GKR,DSA,DUS
# DUS,DRA,SLB,GKR,DSA,DUS
# DUS,DSA,GKR,TEB,DRA,DUS
# DUS,HDA,GUD,DRA,DSA,DUS
# DUS,DRA,SLA,GUD,DSA,DUS
# DUS,DRA,SLB,GUD,DSA,DUS
# DUS,DRA,TEB,GUD,DSA,DUS
# DUS,DRA,SLA,JSF,DSA,DUS
# DUS,DRA,SLB,JSF,DSA,DUS
# DUS,DSA,JSF,TEB,DRA,DUS
# DUS,DRA,SLA,DSA,HDA,DUS
# DUS,DSA,DRA,SLB,HDA,DUS
# DUS,DSA,DRA,TEB,HDA,DUS
# DUS,DSA,SLB,SLA,DRA,DUS
# DUS,DRA,SLA,TEB,DSA,DUS
# DUS,DRA,TEB,SLB,DSA,DUS
# DUS,DRA,GKR,GUD,JSF,DUS
# DUS,DRA,GKR,GUD,HDA,DUS
# DUS,DRA,SLA,GKR,GUD,DUS
# DUS,DRA,SLB,GKR,GUD,DUS
# DUS,DRA,TEB,GKR,GUD,DUS
# DUS,DRA,GKR,JSF,HDA,DUS
# DUS,DRA,SLA,GKR,JSF,DUS
# DUS,DRA,SLB,GKR,JSF,DUS
# DUS,DRA,TEB,GKR,JSF,DUS
# DUS,DRA,SLA,GKR,HDA,DUS
# DUS,DRA,SLB,GKR,HDA,DUS
# DUS,DRA,TEB,GKR,HDA,DUS
# DUS,DRA,SLA,SLB,GKR,DUS
# DUS,DRA,SLA,TEB,GKR,DUS
# DUS,DRA,TEB,SLB,GKR,DUS
# DUS,DRA,JSF,GUD,HDA,DUS
# DUS,DRA,SLA,GUD,JSF,DUS
# DUS,DRA,SLB,GUD,JSF,DUS
# DUS,DRA,TEB,GUD,JSF,DUS
# DUS,DRA,SLA,GUD,HDA,DUS
# DUS,DRA,SLB,GUD,HDA,DUS
# DUS,DRA,TEB,GUD,HDA,DUS
# DUS,DRA,SLA,SLB,GUD,DUS
# DUS,DRA,SLA,TEB,GUD,DUS
# DUS,DRA,TEB,SLB,GUD,DUS
# DUS,DRA,SLA,JSF,HDA,DUS
# DUS,DRA,SLB,JSF,HDA,DUS
# DUS,HDA,JSF,TEB,DRA,DUS
# DUS,DRA,SLA,SLB,JSF,DUS
# DUS,DRA,SLA,TEB,JSF,DUS
# DUS,DRA,TEB,SLB,JSF,DUS
# DUS,DRA,SLA,SLB,HDA,DUS
# DUS,DRA,SLA,TEB,HDA,DUS
# DUS,DRA,TEB,SLB,HDA,DUS
# DUS,DRA,SLA,TEB,SLB,DUS
# DUS,DSA,GKR,GUD,HDA,DUS
# DUS,SLA,GKR,GUD,DSA,DUS
# DUS,SLB,GKR,GUD,DSA,DUS
# DUS,DSA,GUD,GKR,TEB,DUS
# DUS,DSA,JSF,GKR,SLA,DUS
# DUS,DSA,JSF,GKR,SLB,DUS
# DUS,DSA,SLA,GKR,HDA,DUS
# DUS,DSA,SLB,GKR,HDA,DUS
# DUS,DSA,TEB,GKR,HDA,DUS
# DUS,DSA,GKR,SLB,SLA,DUS
# DUS,DSA,GKR,TEB,SLA,DUS
# DUS,DSA,GKR,TEB,SLB,DUS
# DUS,DSA,JSF,GUD,SLA,DUS
# DUS,DSA,JSF,GUD,SLB,DUS
# DUS,DSA,SLA,GUD,HDA,DUS
# DUS,HDA,GUD,SLB,DSA,DUS
# DUS,DSA,TEB,GUD,HDA,DUS
# DUS,DSA,GUD,SLB,SLA,DUS
# DUS,SLA,TEB,GUD,DSA,DUS
# DUS,SLB,TEB,GUD,DSA,DUS
# DUS,DSA,JSF,SLA,HDA,DUS
# DUS,DSA,JSF,SLB,HDA,DUS
# DUS,DSA,JSF,SLB,SLA,DUS
# DUS,DSA,JSF,TEB,SLA,DUS
# DUS,DSA,JSF,TEB,SLB,DUS
# DUS,DSA,SLA,SLB,HDA,DUS
# DUS,DSA,SLA,TEB,HDA,DUS
# DUS,DSA,SLB,TEB,HDA,DUS
# DUS,DSA,SLB,TEB,SLA,DUS
# DUS,JSF,GKR,GUD,HDA,DUS
# DUS,SLA,GKR,GUD,JSF,DUS
# DUS,SLB,GKR,GUD,JSF,DUS
# DUS,JSF,GUD,GKR,TEB,DUS
# DUS,SLA,GKR,GUD,HDA,DUS
# DUS,SLB,GKR,GUD,HDA,DUS
# DUS,HDA,GUD,GKR,TEB,DUS
# DUS,SLA,SLB,GKR,GUD,DUS
# DUS,SLA,TEB,GKR,GUD,DUS
# DUS,SLB,TEB,GKR,GUD,DUS
# DUS,JSF,SLA,GKR,HDA,DUS
# DUS,JSF,SLB,GKR,HDA,DUS
# DUS,JSF,TEB,GKR,HDA,DUS
# DUS,SLA,SLB,GKR,JSF,DUS
# DUS,JSF,GKR,TEB,SLA,DUS
# DUS,JSF,GKR,TEB,SLB,DUS
# DUS,SLA,SLB,GKR,HDA,DUS
# DUS,SLA,TEB,GKR,HDA,DUS
# DUS,SLB,TEB,GKR,HDA,DUS
# DUS,GKR,TEB,SLB,SLA,DUS
# DUS,JSF,SLA,GUD,HDA,DUS
# DUS,JSF,SLB,GUD,HDA,DUS
# DUS,JSF,TEB,GUD,HDA,DUS
# DUS,SLA,SLB,GUD,JSF,DUS
# DUS,JSF,GUD,TEB,SLA,DUS
# DUS,JSF,GUD,TEB,SLB,DUS
# DUS,HDA,GUD,SLB,SLA,DUS
# DUS,HDA,GUD,TEB,SLA,DUS
# DUS,HDA,GUD,TEB,SLB,DUS
# DUS,GUD,TEB,SLB,SLA,DUS
# DUS,JSF,SLA,SLB,HDA,DUS
# DUS,JSF,SLA,TEB,HDA,DUS
# DUS,JSF,SLB,TEB,HDA,DUS
# DUS,JSF,SLB,TEB,SLA,DUS
# DUS,HDA,TEB,SLB,SLA,DUS
# DUS,DAB,GRA,GKR,SLB,SLA,DRA,DUS
# DUS,DAB,GRA,GUD,SLB,SLA,DRA,DUS
# DUS,DRA,SLA,SLB,DAB,GRA,HDA,DUS
# DUS,DRA,SLA,TEB,SLB,DAB,GRA,DUS
# DUS,SLA,SLB,GKR,GUD,DAB,GRA,DUS
# DUS,HDA,DAB,GRA,GKR,SLB,SLA,DUS
# DUS,DAB,GRA,GKR,TEB,SLB,SLA,DUS
# DUS,HDA,DAB,GRA,GUD,SLB,SLA,DUS
# DUS,DAB,GRA,GUD,TEB,SLB,SLA,DUS
# DUS,HDA,DAB,GRA,SLB,TEB,SLA,DUS
# DUS,DSA,DRA,GKR,GUD,HDA,DUS
# DUS,DRA,SLA,GKR,GUD,DSA,DUS
# DUS,DRA,SLB,GKR,GUD,DSA,DUS
# DUS,DRA,TEB,GKR,GUD,DSA,DUS
# DUS,HDA,GKR,SLA,DRA,DSA,DUS
# DUS,HDA,GKR,SLB,DRA,DSA,DUS
# DUS,DSA,DRA,TEB,GKR,HDA,DUS
# DUS,DRA,SLA,SLB,GKR,DSA,DUS
# DUS,DRA,SLA,TEB,GKR,DSA,DUS
# DUS,DRA,TEB,SLB,GKR,DSA,DUS
# DUS,HDA,GUD,SLA,DRA,DSA,DUS
# DUS,HDA,GUD,SLB,DRA,DSA,DUS
# DUS,DSA,DRA,TEB,GUD,HDA,DUS
# DUS,DRA,SLA,SLB,GUD,DSA,DUS
# DUS,DRA,SLA,TEB,GUD,DSA,DUS
# DUS,DRA,TEB,SLB,GUD,DSA,DUS
# DUS,DRA,SLA,SLB,JSF,DSA,DUS
# DUS,DSA,DRA,SLA,SLB,HDA,DUS
# DUS,DSA,DRA,SLA,TEB,HDA,DUS
# DUS,DSA,DRA,TEB,SLB,HDA,DUS
# DUS,DRA,SLA,TEB,SLB,DSA,DUS
# DUS,DRA,SLA,GKR,GUD,JSF,DUS
# DUS,DRA,SLB,GKR,GUD,JSF,DUS
# DUS,DRA,SLA,GKR,GUD,HDA,DUS
# DUS,DRA,SLB,GKR,GUD,HDA,DUS
# DUS,DRA,TEB,GKR,GUD,HDA,DUS
# DUS,DRA,SLA,SLB,GKR,GUD,DUS
# DUS,DRA,SLA,TEB,GKR,GUD,DUS
# DUS,DRA,TEB,SLB,GKR,GUD,DUS
# DUS,DRA,SLA,GKR,JSF,HDA,DUS
# DUS,DRA,SLB,GKR,JSF,HDA,DUS
# DUS,DRA,SLA,SLB,GKR,JSF,DUS
# DUS,DRA,SLA,TEB,GKR,JSF,DUS
# DUS,DRA,TEB,SLB,GKR,JSF,DUS
# DUS,DRA,SLA,SLB,GKR,HDA,DUS
# DUS,DRA,SLA,TEB,GKR,HDA,DUS
# DUS,DRA,TEB,SLB,GKR,HDA,DUS
# DUS,DRA,SLA,SLB,TEB,GKR,DUS
# DUS,JSF,DRA,SLA,GUD,HDA,DUS
# DUS,JSF,DRA,SLB,GUD,HDA,DUS
# DUS,DRA,SLA,SLB,GUD,JSF,DUS
# DUS,DRA,SLA,TEB,GUD,JSF,DUS
# DUS,DRA,TEB,SLB,GUD,JSF,DUS
# DUS,DRA,SLA,SLB,GUD,HDA,DUS
# DUS,DRA,SLA,TEB,GUD,HDA,DUS
# DUS,DRA,TEB,SLB,GUD,HDA,DUS
# DUS,DRA,SLA,SLB,TEB,GUD,DUS
# DUS,DRA,SLA,SLB,JSF,HDA,DUS
# DUS,DRA,SLA,TEB,JSF,HDA,DUS
# DUS,DRA,TEB,SLB,JSF,HDA,DUS
# DUS,DRA,SLA,TEB,SLB,JSF,DUS
# DUS,DRA,SLA,SLB,TEB,HDA,DUS
# DUS,DSA,SLA,GKR,GUD,HDA,DUS
# DUS,DSA,SLB,GKR,GUD,HDA,DUS
# DUS,DSA,TEB,GKR,GUD,HDA,DUS
# DUS,SLA,SLB,GKR,GUD,DSA,DUS
# DUS,SLA,TEB,GKR,GUD,DSA,DUS
# DUS,SLB,TEB,GKR,GUD,DSA,DUS
# DUS,DSA,JSF,GKR,SLB,SLA,DUS
# DUS,DSA,SLA,SLB,GKR,HDA,DUS
# DUS,DSA,SLA,TEB,GKR,HDA,DUS
# DUS,DSA,SLB,TEB,GKR,HDA,DUS
# DUS,DSA,GKR,TEB,SLB,SLA,DUS
# DUS,DSA,JSF,GUD,SLB,SLA,DUS
# DUS,DSA,SLA,SLB,GUD,HDA,DUS
# DUS,DSA,SLA,TEB,GUD,HDA,DUS
# DUS,DSA,SLB,TEB,GUD,HDA,DUS
# DUS,SLA,SLB,TEB,GUD,DSA,DUS
# DUS,DSA,JSF,SLA,SLB,HDA,DUS
# DUS,DSA,JSF,SLB,TEB,SLA,DUS
# DUS,DSA,SLA,SLB,TEB,HDA,DUS
# DUS,JSF,SLA,GKR,GUD,HDA,DUS
# DUS,SLA,SLB,GKR,GUD,JSF,DUS
# DUS,SLA,TEB,GKR,GUD,JSF,DUS
# DUS,SLB,TEB,GKR,GUD,JSF,DUS
# DUS,SLA,SLB,GKR,GUD,HDA,DUS
# DUS,SLA,TEB,GKR,GUD,HDA,DUS
# DUS,SLB,TEB,GKR,GUD,HDA,DUS
# DUS,SLA,SLB,TEB,GKR,GUD,DUS
# DUS,JSF,SLA,SLB,GKR,HDA,DUS
# DUS,JSF,SLA,TEB,GKR,HDA,DUS
# DUS,JSF,SLB,TEB,GKR,HDA,DUS
# DUS,JSF,GKR,TEB,SLB,SLA,DUS
# DUS,SLA,SLB,TEB,GKR,HDA,DUS
# DUS,JSF,SLA,SLB,GUD,HDA,DUS
# DUS,JSF,SLA,TEB,GUD,HDA,DUS
# DUS,JSF,SLB,TEB,GUD,HDA,DUS
# DUS,JSF,GUD,TEB,SLB,SLA,DUS
# DUS,HDA,GUD,TEB,SLB,SLA,DUS
# DUS,JSF,SLA,SLB,TEB,HDA,DUS
# DUS,DRA,SLA,SLB,GKR,GUD,DSA,DUS
# DUS,DRA,SLA,TEB,GKR,GUD,DSA,DUS
# DUS,DRA,TEB,SLB,GKR,GUD,DSA,DUS
# DUS,HDA,GKR,SLB,SLA,DRA,DSA,DUS
# DUS,HDA,GKR,TEB,SLA,DRA,DSA,DUS
# DUS,DSA,DRA,TEB,SLB,GKR,HDA,DUS
# DUS,DRA,SLA,SLB,TEB,GKR,DSA,DUS
# DUS,DSA,DRA,SLA,SLB,GUD,HDA,DUS
# DUS,DSA,DRA,SLA,TEB,GUD,HDA,DUS
# DUS,DSA,DRA,TEB,SLB,GUD,HDA,DUS
# DUS,DRA,SLA,SLB,TEB,GUD,DSA,DUS
# DUS,DSA,DRA,SLA,SLB,TEB,HDA,DUS
# DUS,DRA,SLA,SLB,GKR,GUD,HDA,DUS
# DUS,DRA,SLA,TEB,GKR,GUD,HDA,DUS
# DUS,DRA,TEB,SLB,GKR,GUD,HDA,DUS
# DUS,DRA,SLA,SLB,TEB,GKR,GUD,DUS
# DUS,DRA,SLA,SLB,TEB,GKR,JSF,DUS
# DUS,DRA,SLA,SLB,TEB,GKR,HDA,DUS
# DUS,DRA,SLA,SLB,TEB,GUD,JSF,DUS
# DUS,DRA,SLA,SLB,TEB,GUD,HDA,DUS
# DUS,DRA,SLA,TEB,SLB,JSF,HDA,DUS
# DUS,DSA,SLA,SLB,GKR,GUD,HDA,DUS
# DUS,SLA,SLB,TEB,GKR,GUD,DSA,DUS
# DUS,HDA,GKR,TEB,SLB,SLA,DSA,DUS
# DUS,DSA,SLA,SLB,TEB,GUD,HDA,DUS
# DUS,SLA,SLB,TEB,GKR,GUD,HDA,DUS
# DUS,DRA,SLA,SLB,TEB,GKR,GUD,HDA,DUS

# %%
def find_matching_row(csv_file, names):
    with open(csv_file, 'r', newline='') as file:
        reader = csv.reader(file)
        for row_number, row in enumerate(reader, start=1):
            if set(names).issubset(row):
                return row_number, row
    return None, None

def get_platform_visits(platform):
    with open(f'{non_cluster}/output_platforms_visits.csv', 'r', newline='') as file:
        reader = csv.DictReader(file, delimiter=';')
        for row in reader:
            if row['platform'] == platform:
                return int(row['visits'])
    return None

def remove_lowest_demand_platforms(row):
    visits_count = {}
    for platform in row:
        if platform != 'route_number' and platform != 'total_distance':
            visits = get_platform_visits(platform)
            if visits is not None:
                if visits in visits_count:
                    visits_count[visits].append(platform)
                else:
                    visits_count[visits] = [platform]
    
    if visits_count:
        lowest_demand = min(visits_count)
        for platform in visits_count[lowest_demand]:
            row.remove(platform)

def compute_weights(route_data):
    visits = [get_platform_visits(platform) for platform in route_data if platform not in ['route_number', 'total_distance']]
    visits = [v for v in visits if v is not None]  
    if not visits:
        return [0]
    
    min_visit = min(visits)
    max_visit = max(visits)
    if max_visit > 0:
        return min_visit / max_visit
    return 0

def compute_weight_incrementally(current_min, previous_min, max_visit):
    if max_visit > 0:
        return (current_min - previous_min) / max_visit
    return 0

def normalize_weights(weights):
    total = sum(weights)
    return [w / total for w in weights]

def compute_min_visit(row_data):
    visits = [get_platform_visits(platform) for platform in row_data if platform not in ['route_number', 'total_distance']]
    visits = [v for v in visits if v is not None] 
    return min(visits) if visits else float('inf')  

def count_unique_visits(row):
    unique_visits = set()
    for platform in row:
        if platform != 'route_number' and platform != 'total_distance':
            visits = get_platform_visits(platform)
            if visits is not None:
                unique_visits.add(visits)
    return len(unique_visits)

def print_row_and_distance(csv_file, row_number):
    if row_number:
        with open(csv_file, 'r', newline='') as file:
            reader = csv.reader(file)
            for i, row_num in enumerate(reader, start=1):
                if i == row_number:
                    print(f"Row number: {row_number}")
                    print("Row:", row_num)
                    break
        with open(f'{non_cluster}/distances.csv', 'r', newline='') as distance_file:
            reader = csv.reader(distance_file)
            for i, row_dist in enumerate(reader, start=1):
                if i == row_number + 1:  
                    print("Distance Row:", row_dist)
                    break
        with open(f'{non_cluster}/demand.csv', 'r', newline='') as distance_file:
            reader = csv.reader(distance_file)
            for i, row_demand in enumerate(reader, start=1):
                if i == row_number + 1:  
                    print("Demand Row:", row_demand)
                    break
    return row_dist, row_demand

def process_routes():
    with open(f'{mappenavn}/distances.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Distances'])
    with open(f'{mappenavn}/demand.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Demand'])

    non_matching_rows = []
    weighted_distances = []
    weighted_demands = []
    with open(f'{mappenavn}/processed_routes.csv', 'r', newline='') as file:
        reader = csv.reader(file)
        for row in reader:
            total_weighted_distance = 0  
            total_weighted_demand = 0  
            row_number, original_row_data = find_matching_row(f'{non_cluster}/routes.csv', row)
            if row_number is not None:
                print("Processing row:", row)  
                print("Found matching row:", row_number)  
                distance, demand = print_row_and_distance(f'{non_cluster}/routes.csv', row_number)

                visits = [get_platform_visits(platform) for platform in original_row_data if platform not in ['route_number', 'total_distance']]
                visits = [v for v in visits if v is not None]  
                print("Visits:", visits)  

                if visits:
                    max_visit = max(visits)
                    min_visit = min(visits)
                    weights = [min_visit / max_visit if max_visit > 0 else 0]

                    unique_visits_count = count_unique_visits(original_row_data) - 1
                    routes_found = 0
                    row_data = original_row_data[:]
                    previous_min = min_visit

                    weighted_distance = float(distance[0]) * weights[0]  
                    total_weighted_distance += weighted_distance

                    weighted_demand = float(demand[0]) * weights[0]  
                    total_weighted_demand += weighted_demand

                    while len(row_data) > 2 and routes_found < unique_visits_count:
                        remove_lowest_demand_platforms(row_data)
                        row_number, new_row_data = find_matching_row(f'{non_cluster}/routes.csv', row_data)
                        if row_number is not None:
                            print("Found matching row in loop:", row_number)  
                            print_row_and_distance(f'{non_cluster}/routes.csv', row_number)
                            current_min = compute_min_visit(new_row_data)
                            if current_min != float('inf'): 
                                weight = compute_weight_incrementally(current_min, previous_min, max_visit)
                                weights.append(weight)
                                previous_min = current_min
                                with open(f'{non_cluster}/distances.csv', 'r', newline='') as distance_file:
                                    reader = csv.reader(distance_file)
                                    for i, row_distance in enumerate(reader, start=1):
                                        if i == row_number + 1:  
                                            weighted_distance = float(row_distance[0]) * weight  
                                            total_weighted_distance += weighted_distance  
                                            weighted_distances.append(weighted_distance)
                                with open(f'{non_cluster}/demand.csv', 'r', newline='') as demand_file:
                                    reader = csv.reader(demand_file)
                                    for i, row_demand in enumerate(reader, start=1):
                                        if i == row_number + 1:  
                                            weighted_demand = float(row_demand[0]) * weight  
                                            total_weighted_demand += weighted_demand  
                                            weighted_demands.append(weighted_demand)

                            row_data = new_row_data[:]
                            routes_found += 1
                    
                    total_weight = sum(weights)
                    if total_weight > 0:
                        normalized_weights = [weight / total_weight for weight in weights]
                        for route, weight in zip(range(len(normalized_weights)), normalized_weights):
                            print(f"Route {route + 1} Weight: {weight}")
                    
            print(f"Total Weighted Distance for this route: {total_weighted_distance}")
            print(f"Total Weighted Demand for this route: {total_weighted_demand}")

            with open(f'{mappenavn}/distances.csv', 'a', newline='') as file:
                writer = csv.writer(file)
                writer.writerow([total_weighted_distance])

            with open(f'{mappenavn}/demand.csv', 'a', newline='') as file:
                writer = csv.writer(file)
                writer.writerow([total_weighted_demand])

process_routes()
# Out:
# Processing row: ['DUS', 'DAB', 'GRA', 'DUS']
# Found matching row: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Visits: [4, 3]
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 185.9375
# Total Weighted Demand for this route: 50.5
# Processing row: ['DUS', 'DRA', 'DUS']
# Found matching row: 2
# Row number: 2
# Row: ['DUS', 'DRA', 'DUS']
# Distance Row: ['205.36']
# Demand Row: ['14.0']
# Visits: [1]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 205.36
# Total Weighted Demand for this route: 14.0
# Processing row: ['DUS', 'DSA', 'DUS']
# Found matching row: 3
# Row number: 3
# Row: ['DUS', 'DSA', 'DUS']
# Distance Row: ['164.4']
# Demand Row: ['29.0']
# Visits: [3]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 164.4
# Total Weighted Demand for this route: 29.0
# Processing row: ['DUS', 'GKR', 'DUS']
# Found matching row: 4
# Row number: 4
# Row: ['DUS', 'GKR', 'DUS']
# Distance Row: ['234.68']
# Demand Row: ['18.0']
# Visits: [1]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 234.68
# Total Weighted Demand for this route: 18.0
# Processing row: ['DUS', 'GUD', 'DUS']
# Found matching row: 5
# Row number: 5
# Row: ['DUS', 'GUD', 'DUS']
# Distance Row: ['226.76']
# Demand Row: ['18.0']
# Visits: [1]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 226.76
# Total Weighted Demand for this route: 18.0
# Processing row: ['DUS', 'JSF', 'DUS']
# Found matching row: 6
# Row number: 6
# Row: ['DUS', 'JSF', 'DUS']
# Distance Row: ['176.18']
# Demand Row: ['40.0']
# Visits: [4]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 176.18
# Total Weighted Demand for this route: 40.0
# Processing row: ['DUS', 'HDA', 'DUS']
# Found matching row: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Visits: [4]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 206.82
# Total Weighted Demand for this route: 18.0
# Processing row: ['DUS', 'SLA', 'DUS']
# Found matching row: 9
# Row number: 9
# Row: ['DUS', 'SLA', 'DUS']
# Distance Row: ['229.48']
# Demand Row: ['4.0']
# Visits: [1]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 229.48
# Total Weighted Demand for this route: 4.0
# Processing row: ['DUS', 'SLB', 'DUS']
# Found matching row: 10
# Row number: 10
# Row: ['DUS', 'SLB', 'DUS']
# Distance Row: ['238.28']
# Demand Row: ['7.0']
# Visits: [2]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 238.28
# Total Weighted Demand for this route: 7.0
# Processing row: ['DUS', 'TEB', 'DUS']
# Found matching row: 11
# Row number: 11
# Row: ['DUS', 'TEB', 'DUS']
# Distance Row: ['250.32']
# Demand Row: ['14.0']
# Visits: [3]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 250.32
# Total Weighted Demand for this route: 14.0
# Processing row: ['DUS', 'DAB', 'GRA', 'DRA', 'DUS']
# Found matching row: 71
# Row number: 71
# Row: ['DUS', 'GRA', 'DAB', 'DRA', 'DUS']
# Distance Row: ['253.41']
# Demand Row: ['68.0']
# Visits: [3, 4, 1]
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 202.7975
# Total Weighted Demand for this route: 54.0
# Processing row: ['DUS', 'DAB', 'GRA', 'DSA', 'DUS']
# Found matching row: 78
# Row number: 78
# Row: ['DUS', 'DSA', 'DAB', 'GRA', 'DUS']
# Distance Row: ['200.78']
# Demand Row: ['83.0']
# Visits: [3, 4, 3]
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 197.04500000000002
# Total Weighted Demand for this route: 72.25
# Processing row: ['DUS', 'DAB', 'GRA', 'GKR', 'DUS']
# Found matching row: 85
# Row number: 85
# Row: ['DUS', 'GKR', 'DAB', 'GRA', 'DUS']
# Distance Row: ['251.44']
# Demand Row: ['72.0']
# Visits: [1, 4, 3]
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 202.305
# Total Weighted Demand for this route: 55.0
# Processing row: ['DUS', 'DAB', 'GRA', 'GUD', 'DUS']
# Found matching row: 91
# Row number: 91
# Row: ['DUS', 'GRA', 'DAB', 'GUD', 'DUS']
# Distance Row: ['233.64999999999998']
# Demand Row: ['72.0']
# Visits: [3, 4, 1]
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 197.8575
# Total Weighted Demand for this route: 55.0
# Processing row: ['DUS', 'DAB', 'GRA', 'JSF', 'DUS']
# Found matching row: 96
# Row number: 96
# Row: ['DUS', 'JSF', 'DAB', 'GRA', 'DUS']
# Distance Row: ['200.4']
# Demand Row: ['94.0']
# Visits: [4, 4, 3]
# Found matching row in loop: 16
# Row number: 16
# Row: ['DUS', 'DAB', 'JSF', 'DUS']
# Distance Row: ['200.27']
# Demand Row: ['80.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 200.3675
# Total Weighted Demand for this route: 90.5
# Processing row: ['DUS', 'DAB', 'GRA', 'HDA', 'DUS']
# Found matching row: 101
# Row number: 101
# Row: ['DUS', 'GRA', 'DAB', 'HDA', 'DUS']
# Distance Row: ['222.20999999999998']
# Demand Row: ['72.0']
# Visits: [3, 4, 4]
# Found matching row in loop: 18
# Row number: 18
# Row: ['DUS', 'DAB', 'HDA', 'DUS']
# Distance Row: ['222.07999999999998']
# Demand Row: ['58.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 222.17749999999995
# Total Weighted Demand for this route: 68.5
# Processing row: ['DUS', 'DAB', 'GRA', 'SLA', 'DUS']
# Found matching row: 102
# Row number: 102
# Row: ['DUS', 'GRA', 'DAB', 'SLA', 'DUS']
# Distance Row: ['257.14']
# Demand Row: ['58.0']
# Visits: [3, 4, 1]
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 203.73
# Total Weighted Demand for this route: 51.5
# Processing row: ['DUS', 'DAB', 'GRA', 'SLB', 'DUS']
# Found matching row: 103
# Row number: 103
# Row: ['DUS', 'GRA', 'DAB', 'SLB', 'DUS']
# Distance Row: ['260.86']
# Demand Row: ['61.0']
# Visits: [3, 4, 2]
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 223.38250000000002
# Total Weighted Demand for this route: 54.0
# Processing row: ['DUS', 'DAB', 'GRA', 'TEB', 'DUS']
# Found matching row: 104
# Row number: 104
# Row: ['DUS', 'GRA', 'DAB', 'TEB', 'DUS']
# Distance Row: ['272.0']
# Demand Row: ['68.0']
# Visits: [3, 4, 3]
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 250.46
# Total Weighted Demand for this route: 61.0
# Processing row: ['DUS', 'DRA', 'DSA', 'DUS']
# Found matching row: 22
# Row number: 22
# Row: ['DUS', 'DRA', 'DSA', 'DUS']
# Distance Row: ['220.95']
# Demand Row: ['43.0']
# Visits: [1, 3]
# Found matching row in loop: 3
# Row number: 3
# Row: ['DUS', 'DSA', 'DUS']
# Distance Row: ['164.4']
# Demand Row: ['29.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 183.25
# Total Weighted Demand for this route: 33.666666666666664
# Processing row: ['DUS', 'DRA', 'GKR', 'DUS']
# Found matching row: 23
# Row number: 23
# Row: ['DUS', 'DRA', 'GKR', 'DUS']
# Distance Row: ['253.31']
# Demand Row: ['32.0']
# Visits: [1, 1]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 253.31
# Total Weighted Demand for this route: 32.0
# Processing row: ['DUS', 'DRA', 'GUD', 'DUS']
# Found matching row: 24
# Row number: 24
# Row: ['DUS', 'DRA', 'GUD', 'DUS']
# Distance Row: ['261.82']
# Demand Row: ['32.0']
# Visits: [1, 1]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 261.82
# Total Weighted Demand for this route: 32.0
# Processing row: ['DUS', 'DRA', 'JSF', 'DUS']
# Found matching row: 25
# Row number: 25
# Row: ['DUS', 'DRA', 'JSF', 'DUS']
# Distance Row: ['229.9']
# Demand Row: ['54.0']
# Visits: [1, 4]
# Found matching row in loop: 6
# Row number: 6
# Row: ['DUS', 'JSF', 'DUS']
# Distance Row: ['176.18']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.75
# Total Weighted Distance for this route: 189.60999999999999
# Total Weighted Demand for this route: 43.5
# Processing row: ['DUS', 'DRA', 'HDA', 'DUS']
# Found matching row: 27
# Row number: 27
# Row: ['DUS', 'DRA', 'HDA', 'DUS']
# Distance Row: ['289.28']
# Demand Row: ['32.0']
# Visits: [1, 4]
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.75
# Total Weighted Distance for this route: 227.435
# Total Weighted Demand for this route: 21.5
# Processing row: ['DUS', 'DRA', 'SLA', 'DUS']
# Found matching row: 28
# Row number: 28
# Row: ['DUS', 'DRA', 'SLA', 'DUS']
# Distance Row: ['238.41']
# Demand Row: ['18.0']
# Visits: [1, 1]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 238.41
# Total Weighted Demand for this route: 18.0
# Processing row: ['DUS', 'DRA', 'SLB', 'DUS']
# Found matching row: 29
# Row number: 29
# Row: ['DUS', 'DRA', 'SLB', 'DUS']
# Distance Row: ['249.20999999999998']
# Demand Row: ['21.0']
# Visits: [1, 2]
# Found matching row in loop: 10
# Row number: 10
# Row: ['DUS', 'SLB', 'DUS']
# Distance Row: ['238.28']
# Demand Row: ['7.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.5
# Total Weighted Distance for this route: 243.745
# Total Weighted Demand for this route: 14.0
# Processing row: ['DUS', 'DRA', 'TEB', 'DUS']
# Found matching row: 30
# Row number: 30
# Row: ['DUS', 'DRA', 'TEB', 'DUS']
# Distance Row: ['258.83000000000004']
# Demand Row: ['28.0']
# Visits: [1, 3]
# Found matching row in loop: 11
# Row number: 11
# Row: ['DUS', 'TEB', 'DUS']
# Distance Row: ['250.32']
# Demand Row: ['14.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 253.15666666666667
# Total Weighted Demand for this route: 18.666666666666664
# Processing row: ['DUS', 'DSA', 'GKR', 'DUS']
# Found matching row: 31
# Row number: 31
# Row: ['DUS', 'DSA', 'GKR', 'DUS']
# Distance Row: ['235.04000000000002']
# Demand Row: ['47.0']
# Visits: [3, 1]
# Found matching row in loop: 3
# Row number: 3
# Row: ['DUS', 'DSA', 'DUS']
# Distance Row: ['164.4']
# Demand Row: ['29.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 187.94666666666666
# Total Weighted Demand for this route: 35.0
# Processing row: ['DUS', 'GUD', 'DSA', 'DUS']
# Found matching row: 32
# Row number: 32
# Row: ['DUS', 'GUD', 'DSA', 'DUS']
# Distance Row: ['227.95999999999998']
# Demand Row: ['47.0']
# Visits: [1, 3]
# Found matching row in loop: 3
# Row number: 3
# Row: ['DUS', 'DSA', 'DUS']
# Distance Row: ['164.4']
# Demand Row: ['29.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 185.58666666666664
# Total Weighted Demand for this route: 35.0
# Processing row: ['DUS', 'DSA', 'JSF', 'DUS']
# Found matching row: 33
# Row number: 33
# Row: ['DUS', 'DSA', 'JSF', 'DUS']
# Distance Row: ['178.06']
# Demand Row: ['69.0']
# Visits: [3, 4]
# Found matching row in loop: 6
# Row number: 6
# Row: ['DUS', 'JSF', 'DUS']
# Distance Row: ['176.18']
# Demand Row: ['40.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 177.59000000000003
# Total Weighted Demand for this route: 61.75
# Processing row: ['DUS', 'DSA', 'HDA', 'DUS']
# Found matching row: 35
# Row number: 35
# Row: ['DUS', 'DSA', 'HDA', 'DUS']
# Distance Row: ['236.43']
# Demand Row: ['47.0']
# Visits: [3, 4]
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 229.02749999999997
# Total Weighted Demand for this route: 39.75
# Processing row: ['DUS', 'DSA', 'SLA', 'DUS']
# Found matching row: 36
# Row number: 36
# Row: ['DUS', 'DSA', 'SLA', 'DUS']
# Distance Row: ['233.25']
# Demand Row: ['33.0']
# Visits: [3, 1]
# Found matching row in loop: 3
# Row number: 3
# Row: ['DUS', 'DSA', 'DUS']
# Distance Row: ['164.4']
# Demand Row: ['29.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 187.35
# Total Weighted Demand for this route: 30.333333333333332
# Processing row: ['DUS', 'SLB', 'DSA', 'DUS']
# Found matching row: 37
# Row number: 37
# Row: ['DUS', 'SLB', 'DSA', 'DUS']
# Distance Row: ['240.33999999999997']
# Demand Row: ['36.0']
# Visits: [2, 3]
# Found matching row in loop: 3
# Row number: 3
# Row: ['DUS', 'DSA', 'DUS']
# Distance Row: ['164.4']
# Demand Row: ['29.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 215.02666666666664
# Total Weighted Demand for this route: 33.666666666666664
# Processing row: ['DUS', 'DSA', 'TEB', 'DUS']
# Found matching row: 38
# Row number: 38
# Row: ['DUS', 'DSA', 'TEB', 'DUS']
# Distance Row: ['252.48']
# Demand Row: ['43.0']
# Visits: [3, 3]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 252.48
# Total Weighted Demand for this route: 43.0
# Processing row: ['DUS', 'GKR', 'GUD', 'DUS']
# Found matching row: 39
# Row number: 39
# Row: ['DUS', 'GKR', 'GUD', 'DUS']
# Distance Row: ['247.57999999999998']
# Demand Row: ['36.0']
# Visits: [1, 1]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 247.57999999999998
# Total Weighted Demand for this route: 36.0
# Processing row: ['DUS', 'GKR', 'JSF', 'DUS']
# Found matching row: 40
# Row number: 40
# Row: ['DUS', 'GKR', 'JSF', 'DUS']
# Distance Row: ['236.77']
# Demand Row: ['58.0']
# Visits: [1, 4]
# Found matching row in loop: 6
# Row number: 6
# Row: ['DUS', 'JSF', 'DUS']
# Distance Row: ['176.18']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.75
# Total Weighted Distance for this route: 191.3275
# Total Weighted Demand for this route: 44.5
# Processing row: ['DUS', 'GKR', 'HDA', 'DUS']
# Found matching row: 42
# Row number: 42
# Row: ['DUS', 'GKR', 'HDA', 'DUS']
# Distance Row: ['282.98']
# Demand Row: ['36.0']
# Visits: [1, 4]
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.75
# Total Weighted Distance for this route: 225.86
# Total Weighted Demand for this route: 22.5
# Processing row: ['DUS', 'GKR', 'SLA', 'DUS']
# Found matching row: 43
# Row number: 43
# Row: ['DUS', 'GKR', 'SLA', 'DUS']
# Distance Row: ['245.63']
# Demand Row: ['22.0']
# Visits: [1, 1]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 245.63
# Total Weighted Demand for this route: 22.0
# Processing row: ['DUS', 'GKR', 'SLB', 'DUS']
# Found matching row: 44
# Row number: 44
# Row: ['DUS', 'GKR', 'SLB', 'DUS']
# Distance Row: ['245.51']
# Demand Row: ['25.0']
# Visits: [1, 2]
# Found matching row in loop: 10
# Row number: 10
# Row: ['DUS', 'SLB', 'DUS']
# Distance Row: ['238.28']
# Demand Row: ['7.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.5
# Total Weighted Distance for this route: 241.89499999999998
# Total Weighted Demand for this route: 16.0
# Processing row: ['DUS', 'GKR', 'TEB', 'DUS']
# Found matching row: 45
# Row number: 45
# Row: ['DUS', 'GKR', 'TEB', 'DUS']
# Distance Row: ['255.4']
# Demand Row: ['32.0']
# Visits: [1, 3]
# Found matching row in loop: 11
# Row number: 11
# Row: ['DUS', 'TEB', 'DUS']
# Distance Row: ['250.32']
# Demand Row: ['14.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 252.01333333333332
# Total Weighted Demand for this route: 20.0
# Processing row: ['DUS', 'GUD', 'JSF', 'DUS']
# Found matching row: 46
# Row number: 46
# Row: ['DUS', 'GUD', 'JSF', 'DUS']
# Distance Row: ['226.95']
# Demand Row: ['58.0']
# Visits: [1, 4]
# Found matching row in loop: 6
# Row number: 6
# Row: ['DUS', 'JSF', 'DUS']
# Distance Row: ['176.18']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.75
# Total Weighted Distance for this route: 188.8725
# Total Weighted Demand for this route: 44.5
# Processing row: ['DUS', 'GUD', 'HDA', 'DUS']
# Found matching row: 48
# Row number: 48
# Row: ['DUS', 'GUD', 'HDA', 'DUS']
# Distance Row: ['262.57']
# Demand Row: ['36.0']
# Visits: [1, 4]
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.75
# Total Weighted Distance for this route: 220.7575
# Total Weighted Demand for this route: 22.5
# Processing row: ['DUS', 'GUD', 'SLA', 'DUS']
# Found matching row: 49
# Row number: 49
# Row: ['DUS', 'GUD', 'SLA', 'DUS']
# Distance Row: ['257.37']
# Demand Row: ['22.0']
# Visits: [1, 1]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 257.37
# Total Weighted Demand for this route: 22.0
# Processing row: ['DUS', 'GUD', 'SLB', 'DUS']
# Found matching row: 50
# Row number: 50
# Row: ['DUS', 'GUD', 'SLB', 'DUS']
# Distance Row: ['258.34']
# Demand Row: ['25.0']
# Visits: [1, 2]
# Found matching row in loop: 10
# Row number: 10
# Row: ['DUS', 'SLB', 'DUS']
# Distance Row: ['238.28']
# Demand Row: ['7.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.5
# Total Weighted Distance for this route: 248.31
# Total Weighted Demand for this route: 16.0
# Processing row: ['DUS', 'GUD', 'TEB', 'DUS']
# Found matching row: 51
# Row number: 51
# Row: ['DUS', 'GUD', 'TEB', 'DUS']
# Distance Row: ['267.97']
# Demand Row: ['32.0']
# Visits: [1, 3]
# Found matching row in loop: 11
# Row number: 11
# Row: ['DUS', 'TEB', 'DUS']
# Distance Row: ['250.32']
# Demand Row: ['14.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 256.2033333333333
# Total Weighted Demand for this route: 20.0
# Processing row: ['DUS', 'JSF', 'HDA', 'DUS']
# Found matching row: 53
# Row number: 53
# Row: ['DUS', 'JSF', 'HDA', 'DUS']
# Distance Row: ['236.49']
# Demand Row: ['58.0']
# Visits: [4, 4]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 236.49
# Total Weighted Demand for this route: 58.0
# Processing row: ['DUS', 'SLA', 'JSF', 'DUS']
# Found matching row: 54
# Row number: 54
# Row: ['DUS', 'SLA', 'JSF', 'DUS']
# Distance Row: ['237.79']
# Demand Row: ['44.0']
# Visits: [1, 4]
# Found matching row in loop: 6
# Row number: 6
# Row: ['DUS', 'JSF', 'DUS']
# Distance Row: ['176.18']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.75
# Total Weighted Distance for this route: 191.58249999999998
# Total Weighted Demand for this route: 41.0
# Processing row: ['DUS', 'JSF', 'SLB', 'DUS']
# Found matching row: 55
# Row number: 55
# Row: ['DUS', 'JSF', 'SLB', 'DUS']
# Distance Row: ['243.63']
# Demand Row: ['47.0']
# Visits: [4, 2]
# Found matching row in loop: 6
# Row number: 6
# Row: ['DUS', 'JSF', 'DUS']
# Distance Row: ['176.18']
# Demand Row: ['40.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.5
# Total Weighted Distance for this route: 209.905
# Total Weighted Demand for this route: 43.5
# Processing row: ['DUS', 'JSF', 'TEB', 'DUS']
# Found matching row: 56
# Row number: 56
# Row: ['DUS', 'JSF', 'TEB', 'DUS']
# Distance Row: ['255.60999999999999']
# Demand Row: ['54.0']
# Visits: [4, 3]
# Found matching row in loop: 6
# Row number: 6
# Row: ['DUS', 'JSF', 'DUS']
# Distance Row: ['176.18']
# Demand Row: ['40.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 235.7525
# Total Weighted Demand for this route: 50.5
# Processing row: ['DUS', 'SLA', 'HDA', 'DUS']
# Found matching row: 61
# Row number: 61
# Row: ['DUS', 'SLA', 'HDA', 'DUS']
# Distance Row: ['290.91999999999996']
# Demand Row: ['22.0']
# Visits: [1, 4]
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.75
# Total Weighted Distance for this route: 227.845
# Total Weighted Demand for this route: 19.0
# Processing row: ['DUS', 'HDA', 'SLB', 'DUS']
# Found matching row: 62
# Row number: 62
# Row: ['DUS', 'HDA', 'SLB', 'DUS']
# Distance Row: ['293.37']
# Demand Row: ['25.0']
# Visits: [4, 2]
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.5
# Total Weighted Distance for this route: 250.095
# Total Weighted Demand for this route: 21.5
# Processing row: ['DUS', 'HDA', 'TEB', 'DUS']
# Found matching row: 63
# Row number: 63
# Row: ['DUS', 'HDA', 'TEB', 'DUS']
# Distance Row: ['303.63']
# Demand Row: ['32.0']
# Visits: [4, 3]
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 279.4275
# Total Weighted Demand for this route: 28.5
# Processing row: ['DUS', 'SLA', 'SLB', 'DUS']
# Found matching row: 64
# Row number: 64
# Row: ['DUS', 'SLA', 'SLB', 'DUS']
# Distance Row: ['240.29']
# Demand Row: ['11.0']
# Visits: [1, 2]
# Found matching row in loop: 10
# Row number: 10
# Row: ['DUS', 'SLB', 'DUS']
# Distance Row: ['238.28']
# Demand Row: ['7.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.5
# Total Weighted Distance for this route: 239.285
# Total Weighted Demand for this route: 9.0
# Processing row: ['DUS', 'SLA', 'TEB', 'DUS']
# Found matching row: 65
# Row number: 65
# Row: ['DUS', 'SLA', 'TEB', 'DUS']
# Distance Row: ['250.92']
# Demand Row: ['18.0']
# Visits: [1, 3]
# Found matching row in loop: 11
# Row number: 11
# Row: ['DUS', 'TEB', 'DUS']
# Distance Row: ['250.32']
# Demand Row: ['14.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 250.51999999999998
# Total Weighted Demand for this route: 15.333333333333332
# Processing row: ['DUS', 'SLB', 'TEB', 'DUS']
# Found matching row: 66
# Row number: 66
# Row: ['DUS', 'SLB', 'TEB', 'DUS']
# Distance Row: ['250.43']
# Demand Row: ['21.0']
# Visits: [2, 3]
# Found matching row in loop: 11
# Row number: 11
# Row: ['DUS', 'TEB', 'DUS']
# Distance Row: ['250.32']
# Demand Row: ['14.0']
# Route 1 Weight: 0.6666666666666666
# Route 2 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 250.39333333333332
# Total Weighted Demand for this route: 18.666666666666664
# Processing row: ['DUS', 'DAB', 'GRA', 'DSA', 'DRA', 'DUS']
# Found matching row: 231
# Row number: 231
# Row: ['DUS', 'DRA', 'DSA', 'DAB', 'GRA', 'DUS']
# Distance Row: ['257.33000000000004']
# Demand Row: ['97.0']
# Visits: [1, 3, 4, 3]
# Found matching row in loop: 78
# Row number: 78
# Row: ['DUS', 'DSA', 'DAB', 'GRA', 'DUS']
# Distance Row: ['200.78']
# Demand Row: ['83.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 211.18250000000003
# Total Weighted Demand for this route: 75.75
# Processing row: ['DUS', 'DAB', 'GRA', 'GKR', 'DRA', 'DUS']
# Found matching row: 236
# Row number: 236
# Row: ['DUS', 'DRA', 'GKR', 'DAB', 'GRA', 'DUS']
# Distance Row: ['270.07']
# Demand Row: ['86.0']
# Visits: [1, 1, 4, 3]
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 206.9625
# Total Weighted Demand for this route: 58.5
# Processing row: ['DUS', 'DAB', 'GRA', 'GUD', 'DRA', 'DUS']
# Found matching row: 241
# Row number: 241
# Row: ['DUS', 'DRA', 'GUD', 'DAB', 'GRA', 'DUS']
# Distance Row: ['268.71000000000004']
# Demand Row: ['86.0']
# Visits: [1, 1, 4, 3]
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 206.62250000000003
# Total Weighted Demand for this route: 58.5
# Processing row: ['DUS', 'DRA', 'DAB', 'GRA', 'HDA', 'DUS']
# Found matching row: 247
# Row number: 247
# Row: ['DUS', 'DRA', 'DAB', 'GRA', 'HDA', 'DUS']
# Distance Row: ['292.47']
# Demand Row: ['86.0']
# Visits: [1, 4, 3, 4]
# Found matching row in loop: 101
# Row number: 101
# Row: ['DUS', 'GRA', 'DAB', 'HDA', 'DUS']
# Distance Row: ['222.20999999999998']
# Demand Row: ['72.0']
# Found matching row in loop: 18
# Row number: 18
# Row: ['DUS', 'DAB', 'HDA', 'DUS']
# Distance Row: ['222.07999999999998']
# Demand Row: ['58.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 239.7425
# Total Weighted Demand for this route: 72.0
# Processing row: ['DUS', 'DAB', 'GRA', 'SLA', 'DRA', 'DUS']
# Found matching row: 248
# Row number: 248
# Row: ['DUS', 'DRA', 'SLA', 'DAB', 'GRA', 'DUS']
# Distance Row: ['266.07000000000005']
# Demand Row: ['72.0']
# Visits: [1, 1, 4, 3]
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 205.9625
# Total Weighted Demand for this route: 55.0
# Processing row: ['DUS', 'DRA', 'SLB', 'DAB', 'GRA', 'DUS']
# Found matching row: 249
# Row number: 249
# Row: ['DUS', 'DRA', 'SLB', 'DAB', 'GRA', 'DUS']
# Distance Row: ['271.79']
# Demand Row: ['75.0']
# Visits: [1, 2, 4, 3]
# Found matching row in loop: 103
# Row number: 103
# Row: ['DUS', 'GRA', 'DAB', 'SLB', 'DUS']
# Distance Row: ['260.86']
# Demand Row: ['61.0']
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 226.11500000000004
# Total Weighted Demand for this route: 57.5
# Processing row: ['DUS', 'DRA', 'TEB', 'DAB', 'GRA', 'DUS']
# Found matching row: 250
# Row number: 250
# Row: ['DUS', 'DRA', 'TEB', 'DAB', 'GRA', 'DUS']
# Distance Row: ['280.51']
# Demand Row: ['82.0']
# Visits: [1, 3, 4, 3]
# Found matching row in loop: 104
# Row number: 104
# Row: ['DUS', 'GRA', 'DAB', 'TEB', 'DUS']
# Distance Row: ['272.0']
# Demand Row: ['68.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 252.5875
# Total Weighted Demand for this route: 64.5
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['DUS', 'DAB', 'GRA', 'SLA', 'DSA', 'DUS']
# Found matching row: 261
# Row number: 261
# Row: ['DUS', 'DSA', 'SLA', 'DAB', 'GRA', 'DUS']
# Distance Row: ['260.91']
# Demand Row: ['87.0']
# Visits: [3, 1, 4, 3]
# Found matching row in loop: 78
# Row number: 78
# Row: ['DUS', 'DSA', 'DAB', 'GRA', 'DUS']
# Distance Row: ['200.78']
# Demand Row: ['83.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 212.07750000000001
# Total Weighted Demand for this route: 73.25
# Processing row: ['DUS', 'DAB', 'GRA', 'SLB', 'DSA', 'DUS']
# Found matching row: 262
# Row number: 262
# Row: ['DUS', 'DSA', 'SLB', 'DAB', 'GRA', 'DUS']
# Distance Row: ['262.92']
# Demand Row: ['90.0']
# Visits: [3, 2, 4, 3]
# Found matching row in loop: 78
# Row number: 78
# Row: ['DUS', 'DSA', 'DAB', 'GRA', 'DUS']
# Distance Row: ['200.78']
# Demand Row: ['83.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 228.115
# Total Weighted Demand for this route: 75.75
# Processing row: ['DUS', 'DSA', 'TEB', 'DAB', 'GRA', 'DUS']
# Found matching row: 263
# Row number: 263
# Row: ['DUS', 'DSA', 'TEB', 'DAB', 'GRA', 'DUS']
# Distance Row: ['274.15999999999997']
# Demand Row: ['97.0']
# Visits: [3, 3, 4, 3]
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 252.07999999999998
# Total Weighted Demand for this route: 82.75
# Processing row: ['DUS', 'GKR', 'GUD', 'DAB', 'GRA', 'DUS']
# Found matching row: 269
# Row number: 269
# Row: ['DUS', 'GKR', 'GUD', 'DAB', 'GRA', 'DUS']
# Distance Row: ['254.47']
# Demand Row: ['90.0']
# Visits: [1, 1, 4, 3]
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 203.0625
# Total Weighted Demand for this route: 59.5
# Processing row: ['DUS', 'GKR', 'DAB', 'GRA', 'HDA', 'DUS']
# Found matching row: 274
# Row number: 274
# Row: ['DUS', 'GKR', 'DAB', 'GRA', 'HDA', 'DUS']
# Distance Row: ['290.5']
# Demand Row: ['90.0']
# Visits: [1, 4, 3, 4]
# Found matching row in loop: 101
# Row number: 101
# Row: ['DUS', 'GRA', 'DAB', 'HDA', 'DUS']
# Distance Row: ['222.20999999999998']
# Demand Row: ['72.0']
# Found matching row in loop: 18
# Row number: 18
# Row: ['DUS', 'DAB', 'HDA', 'DUS']
# Distance Row: ['222.07999999999998']
# Demand Row: ['58.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 239.25
# Total Weighted Demand for this route: 73.0
# Processing row: ['DUS', 'DAB', 'GRA', 'GKR', 'SLA', 'DUS']
# Found matching row: 275
# Row number: 275
# Row: ['DUS', 'GRA', 'DAB', 'GKR', 'SLA', 'DUS']
# Distance Row: ['262.39']
# Demand Row: ['76.0']
# Visits: [3, 4, 1, 1]
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 205.0425
# Total Weighted Demand for this route: 56.0
# Processing row: ['DUS', 'DAB', 'GRA', 'GKR', 'SLB', 'DUS']
# Found matching row: 276
# Row number: 276
# Row: ['DUS', 'GRA', 'DAB', 'GKR', 'SLB', 'DUS']
# Distance Row: ['262.27']
# Demand Row: ['79.0']
# Visits: [3, 4, 1, 2]
# Found matching row in loop: 103
# Row number: 103
# Row: ['DUS', 'GRA', 'DAB', 'SLB', 'DUS']
# Distance Row: ['260.86']
# Demand Row: ['61.0']
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 223.735
# Total Weighted Demand for this route: 58.5
# Processing row: ['DUS', 'DAB', 'GRA', 'GKR', 'TEB', 'DUS']
# Found matching row: 277
# Row number: 277
# Row: ['DUS', 'GRA', 'DAB', 'GKR', 'TEB', 'DUS']
# Distance Row: ['272.15999999999997']
# Demand Row: ['86.0']
# Visits: [3, 4, 1, 3]
# Found matching row in loop: 104
# Row number: 104
# Row: ['DUS', 'GRA', 'DAB', 'TEB', 'DUS']
# Distance Row: ['272.0']
# Demand Row: ['68.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 250.5
# Total Weighted Demand for this route: 65.5
# Processing row: ['DUS', 'DAB', 'GRA', 'GUD', 'HDA', 'DUS']
# Found matching row: 284
# Row number: 284
# Row: ['DUS', 'GRA', 'DAB', 'GUD', 'HDA', 'DUS']
# Distance Row: ['269.46000000000004']
# Demand Row: ['90.0']
# Visits: [3, 4, 1, 4]
# Found matching row in loop: 101
# Row number: 101
# Row: ['DUS', 'GRA', 'DAB', 'HDA', 'DUS']
# Distance Row: ['222.20999999999998']
# Demand Row: ['72.0']
# Found matching row in loop: 18
# Row number: 18
# Row: ['DUS', 'DAB', 'HDA', 'DUS']
# Distance Row: ['222.07999999999998']
# Demand Row: ['58.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 233.99
# Total Weighted Demand for this route: 73.0
# Processing row: ['DUS', 'DAB', 'GRA', 'GUD', 'SLA', 'DUS']
# Found matching row: 285
# Row number: 285
# Row: ['DUS', 'GRA', 'DAB', 'GUD', 'SLA', 'DUS']
# Distance Row: ['264.26']
# Demand Row: ['76.0']
# Visits: [3, 4, 1, 1]
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 205.51000000000002
# Total Weighted Demand for this route: 56.0
# Processing row: ['DUS', 'DAB', 'GRA', 'GUD', 'SLB', 'DUS']
# Found matching row: 286
# Row number: 286
# Row: ['DUS', 'GRA', 'DAB', 'GUD', 'SLB', 'DUS']
# Distance Row: ['265.23']
# Demand Row: ['79.0']
# Visits: [3, 4, 1, 2]
# Found matching row in loop: 103
# Row number: 103
# Row: ['DUS', 'GRA', 'DAB', 'SLB', 'DUS']
# Distance Row: ['260.86']
# Demand Row: ['61.0']
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 224.47500000000002
# Total Weighted Demand for this route: 58.5
# Processing row: ['DUS', 'TEB', 'GUD', 'DAB', 'GRA', 'DUS']
# Found matching row: 287
# Row number: 287
# Row: ['DUS', 'GRA', 'DAB', 'GUD', 'TEB', 'DUS']
# Distance Row: ['274.86']
# Demand Row: ['86.0']
# Visits: [3, 4, 1, 3]
# Found matching row in loop: 104
# Row number: 104
# Row: ['DUS', 'GRA', 'DAB', 'TEB', 'DUS']
# Distance Row: ['272.0']
# Demand Row: ['68.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 251.175
# Total Weighted Demand for this route: 65.5
# Processing row: ['DUS', 'DAB', 'GRA', 'JSF', 'SLA', 'DUS']
# Found matching row: 294
# Row number: 294
# Row: ['DUS', 'GRA', 'DAB', 'JSF', 'SLA', 'DUS']
# Distance Row: ['262.01']
# Demand Row: ['98.0']
# Visits: [3, 4, 4, 1]
# Found matching row in loop: 96
# Row number: 96
# Row: ['DUS', 'JSF', 'DAB', 'GRA', 'DUS']
# Distance Row: ['200.4']
# Demand Row: ['94.0']
# Found matching row in loop: 16
# Row number: 16
# Row: ['DUS', 'DAB', 'JSF', 'DUS']
# Distance Row: ['200.27']
# Demand Row: ['80.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 215.76999999999998
# Total Weighted Demand for this route: 91.5
# Total Weighted Distance for this route: 0
# Total Weighted Demand for this route: 0
# Processing row: ['DUS', 'HDA', 'DAB', 'GRA', 'SLA', 'DUS']
# Found matching row: 297
# Row number: 297
# Row: ['DUS', 'HDA', 'GRA', 'DAB', 'SLA', 'DUS']
# Distance Row: ['296.2']
# Demand Row: ['76.0']
# Visits: [4, 3, 4, 1]
# Found matching row in loop: 101
# Row number: 101
# Row: ['DUS', 'GRA', 'DAB', 'HDA', 'DUS']
# Distance Row: ['222.20999999999998']
# Demand Row: ['72.0']
# Found matching row in loop: 18
# Row number: 18
# Row: ['DUS', 'DAB', 'HDA', 'DUS']
# Distance Row: ['222.07999999999998']
# Demand Row: ['58.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 240.67499999999995
# Total Weighted Demand for this route: 69.5
# Processing row: ['DUS', 'HDA', 'DAB', 'GRA', 'SLB', 'DUS']
# Found matching row: 298
# Row number: 298
# Row: ['DUS', 'HDA', 'GRA', 'DAB', 'SLB', 'DUS']
# Distance Row: ['299.92']
# Demand Row: ['79.0']
# Visits: [4, 3, 4, 2]
# Found matching row in loop: 101
# Row number: 101
# Row: ['DUS', 'GRA', 'DAB', 'HDA', 'DUS']
# Distance Row: ['222.20999999999998']
# Demand Row: ['72.0']
# Found matching row in loop: 18
# Row number: 18
# Row: ['DUS', 'DAB', 'HDA', 'DUS']
# Distance Row: ['222.07999999999998']
# Demand Row: ['58.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 261.03249999999997
# Total Weighted Demand for this route: 72.0
# Processing row: ['DUS', 'HDA', 'DAB', 'GRA', 'TEB', 'DUS']
# Found matching row: 299
# Row number: 299
# Row: ['DUS', 'HDA', 'GRA', 'DAB', 'TEB', 'DUS']
# Distance Row: ['311.06']
# Demand Row: ['86.0']
# Visits: [4, 3, 4, 3]
# Found matching row in loop: 18
# Row number: 18
# Row: ['DUS', 'DAB', 'HDA', 'DUS']
# Distance Row: ['222.07999999999998']
# Demand Row: ['58.0']
# Route 1 Weight: 0.75
# Route 2 Weight: 0.25
# Total Weighted Distance for this route: 288.815
# Total Weighted Demand for this route: 79.0
# Processing row: ['DUS', 'DAB', 'GRA', 'SLB', 'SLA', 'DUS']
# Found matching row: 300
# Row number: 300
# Row: ['DUS', 'GRA', 'DAB', 'SLB', 'SLA', 'DUS']
# Distance Row: ['262.87']
# Demand Row: ['65.0']
# Visits: [3, 4, 2, 1]
# Found matching row in loop: 103
# Row number: 103
# Row: ['DUS', 'GRA', 'DAB', 'SLB', 'DUS']
# Distance Row: ['260.86']
# Demand Row: ['61.0']
# Found matching row in loop: 17
# Row number: 17
# Row: ['DUS', 'DAB', 'GRA', 'DUS']
# Distance Row: ['185.97']
# Demand Row: ['54.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 223.88500000000002
# Total Weighted Demand for this route: 55.0
# Processing row: ['DUS', 'SLA', 'TEB', 'DAB', 'GRA', 'DUS']
# Found matching row: 301
# Row number: 301
# Row: ['DUS', 'GRA', 'DAB', 'TEB', 'SLA', 'DUS']
# Distance Row: ['272.6']
# Demand Row: ['72.0']
# Visits: [3, 4, 3, 1]
# Found matching row in loop: 104
# Row number: 104
# Row: ['DUS', 'GRA', 'DAB', 'TEB', 'DUS']
# Distance Row: ['272.0']
# Demand Row: ['68.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 250.61
# Total Weighted Demand for this route: 62.0
# Processing row: ['DUS', 'DAB', 'GRA', 'TEB', 'SLB', 'DUS']
# Found matching row: 302
# Row number: 302
# Row: ['DUS', 'GRA', 'DAB', 'TEB', 'SLB', 'DUS']
# Distance Row: ['272.11']
# Demand Row: ['75.0']
# Visits: [3, 4, 3, 2]
# Found matching row in loop: 104
# Row number: 104
# Row: ['DUS', 'GRA', 'DAB', 'TEB', 'DUS']
# Distance Row: ['272.0']
# Demand Row: ['68.0']
# Found matching row in loop: 1
# Row number: 1
# Row: ['DUS', 'DAB', 'DUS']
# Distance Row: ['185.84']
# Demand Row: ['40.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 250.51500000000001
# Total Weighted Demand for this route: 64.5
# Processing row: ['DUS', 'DRA', 'GKR', 'DSA', 'DUS']
# Found matching row: 111
# Row number: 111
# Row: ['DUS', 'DRA', 'GKR', 'DSA', 'DUS']
# Distance Row: ['253.67000000000002']
# Demand Row: ['61.0']
# Visits: [1, 1, 3]
# Found matching row in loop: 3
# Row number: 3
# Row: ['DUS', 'DSA', 'DUS']
# Distance Row: ['164.4']
# Demand Row: ['29.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 194.15666666666667
# Total Weighted Demand for this route: 39.666666666666664
# Processing row: ['DUS', 'DRA', 'GUD', 'DSA', 'DUS']
# Found matching row: 112
# Row number: 112
# Row: ['DUS', 'DRA', 'GUD', 'DSA', 'DUS']
# Distance Row: ['263.02']
# Demand Row: ['61.0']
# Visits: [1, 1, 3]
# Found matching row in loop: 3
# Row number: 3
# Row: ['DUS', 'DSA', 'DUS']
# Distance Row: ['164.4']
# Demand Row: ['29.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 197.2733333333333
# Total Weighted Demand for this route: 39.666666666666664
# Processing row: ['DUS', 'DSA', 'JSF', 'DRA', 'DUS']
# Found matching row: 113
# Row number: 113
# Row: ['DUS', 'DSA', 'JSF', 'DRA', 'DUS']
# Distance Row: ['231.78']
# Demand Row: ['83.0']
# Visits: [3, 4, 1]
# Found matching row in loop: 33
# Row number: 33
# Row: ['DUS', 'DSA', 'JSF', 'DUS']
# Distance Row: ['178.06']
# Demand Row: ['69.0']
# Found matching row in loop: 6
# Row number: 6
# Row: ['DUS', 'JSF', 'DUS']
# Distance Row: ['176.18']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 191.01999999999998
# Total Weighted Demand for this route: 65.25
# Processing row: ['DUS', 'DRA', 'DSA', 'HDA', 'DUS']
# Found matching row: 115
# Row number: 115
# Row: ['DUS', 'DRA', 'DSA', 'HDA', 'DUS']
# Distance Row: ['292.98']
# Demand Row: ['61.0']
# Visits: [1, 3, 4]
# Found matching row in loop: 35
# Row number: 35
# Row: ['DUS', 'DSA', 'HDA', 'DUS']
# Distance Row: ['236.43']
# Demand Row: ['47.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 243.16500000000002
# Total Weighted Demand for this route: 43.25
# Processing row: ['DUS', 'DRA', 'SLA', 'DSA', 'DUS']
# Found matching row: 116
# Row number: 116
# Row: ['DUS', 'DRA', 'SLA', 'DSA', 'DUS']
# Distance Row: ['242.18']
# Demand Row: ['47.0']
# Visits: [1, 1, 3]
# Found matching row in loop: 3
# Row number: 3
# Row: ['DUS', 'DSA', 'DUS']
# Distance Row: ['164.4']
# Demand Row: ['29.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 190.32666666666665
# Total Weighted Demand for this route: 35.0
# Processing row: ['DUS', 'DRA', 'SLB', 'DSA', 'DUS']
# Found matching row: 117
# Row number: 117
# Row: ['DUS', 'DRA', 'SLB', 'DSA', 'DUS']
# Distance Row: ['251.26999999999998']
# Demand Row: ['50.0']
# Visits: [1, 2, 3]
# Found matching row in loop: 37
# Row number: 37
# Row: ['DUS', 'SLB', 'DSA', 'DUS']
# Distance Row: ['240.33999999999997']
# Demand Row: ['36.0']
# Found matching row in loop: 3
# Row number: 3
# Row: ['DUS', 'DSA', 'DUS']
# Distance Row: ['164.4']
# Demand Row: ['29.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 218.66999999999996
# Total Weighted Demand for this route: 38.33333333333333
# Processing row: ['DUS', 'DRA', 'TEB', 'DSA', 'DUS']
# Found matching row: 118
# Row number: 118
# Row: ['DUS', 'DRA', 'TEB', 'DSA', 'DUS']
# Distance Row: ['260.99']
# Demand Row: ['57.0']
# Visits: [1, 3, 3]
# Found matching row in loop: 38
# Row number: 38
# Row: ['DUS', 'DSA', 'TEB', 'DUS']
# Distance Row: ['252.48']
# Demand Row: ['43.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 255.31666666666666
# Total Weighted Demand for this route: 47.666666666666664
# Processing row: ['DUS', 'DRA', 'GKR', 'GUD', 'DUS']
# Found matching row: 119
# Row number: 119
# Row: ['DUS', 'DRA', 'GKR', 'GUD', 'DUS']
# Distance Row: ['266.21']
# Demand Row: ['50.0']
# Visits: [1, 1, 1]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 266.21
# Total Weighted Demand for this route: 50.0
# Processing row: ['DUS', 'DRA', 'GKR', 'JSF', 'DUS']
# Found matching row: 120
# Row number: 120
# Row: ['DUS', 'DRA', 'GKR', 'JSF', 'DUS']
# Distance Row: ['255.4']
# Demand Row: ['72.0']
# Visits: [1, 1, 4]
# Found matching row in loop: 6
# Row number: 6
# Row: ['DUS', 'JSF', 'DUS']
# Distance Row: ['176.18']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.75
# Total Weighted Distance for this route: 195.98499999999999
# Total Weighted Demand for this route: 48.0
# Processing row: ['DUS', 'DRA', 'GKR', 'HDA', 'DUS']
# Found matching row: 122
# Row number: 122
# Row: ['DUS', 'DRA', 'GKR', 'HDA', 'DUS']
# Distance Row: ['301.61']
# Demand Row: ['50.0']
# Visits: [1, 1, 4]
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.75
# Total Weighted Distance for this route: 230.5175
# Total Weighted Demand for this route: 26.0
# Processing row: ['DUS', 'DRA', 'SLA', 'GKR', 'DUS']
# Found matching row: 123
# Row number: 123
# Row: ['DUS', 'DRA', 'SLA', 'GKR', 'DUS']
# Distance Row: ['254.56']
# Demand Row: ['36.0']
# Visits: [1, 1, 1]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 254.56
# Total Weighted Demand for this route: 36.0
# Processing row: ['DUS', 'DRA', 'SLB', 'GKR', 'DUS']
# Found matching row: 124
# Row number: 124
# Row: ['DUS', 'DRA', 'SLB', 'GKR', 'DUS']
# Distance Row: ['256.44']
# Demand Row: ['39.0']
# Visits: [1, 2, 1]
# Found matching row in loop: 10
# Row number: 10
# Row: ['DUS', 'SLB', 'DUS']
# Distance Row: ['238.28']
# Demand Row: ['7.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.5
# Total Weighted Distance for this route: 247.36
# Total Weighted Demand for this route: 23.0
# Processing row: ['DUS', 'DRA', 'TEB', 'GKR', 'DUS']
# Found matching row: 125
# Row number: 125
# Row: ['DUS', 'DRA', 'TEB', 'GKR', 'DUS']
# Distance Row: ['263.91']
# Demand Row: ['46.0']
# Visits: [1, 3, 1]
# Found matching row in loop: 11
# Row number: 11
# Row: ['DUS', 'TEB', 'DUS']
# Distance Row: ['250.32']
# Demand Row: ['14.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.6666666666666666
# Total Weighted Distance for this route: 254.85
# Total Weighted Demand for this route: 24.666666666666664
# Processing row: ['DUS', 'DRA', 'GUD', 'JSF', 'DUS']
# Found matching row: 126
# Row number: 126
# Row: ['DUS', 'DRA', 'GUD', 'JSF', 'DUS']
# Distance Row: ['262.01']
# Demand Row: ['72.0']
# Visits: [1, 1, 4]
# Found matching row in loop: 6
# Row number: 6
# Row: ['DUS', 'JSF', 'DUS']
# Distance Row: ['176.18']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.75
# Total Weighted Distance for this route: 197.6375
# Total Weighted Demand for this route: 48.0
# Processing row: ['DUS', 'DRA', 'GUD', 'HDA', 'DUS']
# Found matching row: 128
# Row number: 128
# Row: ['DUS', 'DRA', 'GUD', 'HDA', 'DUS']
# Distance Row: ['297.63']
# Demand Row: ['50.0']
# Visits: [1, 1, 4]
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.75
# Total Weighted Distance for this route: 229.5225
# Total Weighted Demand for this route: 26.0
# Processing row: ['DUS', 'DRA', 'SLA', 'GUD', 'DUS']
# Found matching row: 129
# Row number: 129
# Row: ['DUS', 'DRA', 'SLA', 'GUD', 'DUS']
# Distance Row: ['266.3']
# Demand Row: ['36.0']
# Visits: [1, 1, 1]
# Route 1 Weight: 1.0
# Total Weighted Distance for this route: 266.3
# Total Weighted Demand for this route: 36.0
# Processing row: ['DUS', 'DRA', 'SLB', 'GUD', 'DUS']
# Found matching row: 130
# Row number: 130
# Row: ['DUS', 'DRA', 'SLB', 'GUD', 'DUS']
# Distance Row: ['269.27']
# Demand Row: ['39.0']
# Visits: [1, 2, 1]
# Found matching row in loop: 10
# Row number: 10
# Row: ['DUS', 'SLB', 'DUS']
# Distance Row: ['238.28']
# Demand Row: ['7.0']
# Route 1 Weight: 0.5
# Route 2 Weight: 0.5
# Total Weighted Distance for this route: 253.77499999999998
# Total Weighted Demand for this route: 23.0
# Processing row: ['DUS', 'DRA', 'TEB', 'GUD', 'DUS']
# Found matching row: 131
# Row number: 131
# Row: ['DUS', 'DRA', 'TEB', 'GUD', 'DUS']
# Distance Row: ['276.48']
# Demand Row: ['46.0']
# Visits: [1, 3, 1]
# Found matching row in loop: 11
# Row number: 11
# Row: ['DUS', 'TEB', 'DUS']
# Distance Row: ['250.32']
# Demand Row: ['14.0']
# Route 1 Weight: 0.3333333333333333
# ...
# Distance Row: ['252.48']
# Demand Row: ['43.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 257.26
# Total Weighted Demand for this route: 59.66666666666666
# Processing row: ['DUS', 'DSA', 'DRA', 'SLA', 'SLB', 'GUD', 'HDA', 'DUS']
# Found matching row: 786
# Row number: 786
# Row: ['DUS', 'DSA', 'DRA', 'SLA', 'SLB', 'GUD', 'HDA', 'DUS']
# Distance Row: ['320.68']
# Demand Row: ['90.0']
# Visits: [3, 1, 1, 2, 1, 4]
# Found matching row in loop: 170
# Row number: 170
# Row: ['DUS', 'DSA', 'SLB', 'HDA', 'DUS']
# Distance Row: ['295.42999999999995']
# Demand Row: ['54.0']
# Found matching row in loop: 35
# Row number: 35
# Row: ['DUS', 'DSA', 'HDA', 'DUS']
# Distance Row: ['236.43']
# Demand Row: ['47.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 264.84
# Total Weighted Demand for this route: 52.25
# Processing row: ['DUS', 'DSA', 'DRA', 'SLA', 'TEB', 'GUD', 'HDA', 'DUS']
# Found matching row: 787
# Row number: 787
# Row: ['DUS', 'DSA', 'DRA', 'SLA', 'TEB', 'GUD', 'HDA', 'DUS']
# Distance Row: ['328.90000000000003']
# Demand Row: ['97.0']
# Visits: [3, 1, 1, 3, 1, 4]
# Found matching row in loop: 171
# Row number: 171
# Row: ['DUS', 'DSA', 'TEB', 'HDA', 'DUS']
# Distance Row: ['305.78999999999996']
# Demand Row: ['61.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 286.825
# Total Weighted Demand for this route: 59.25
# Processing row: ['DUS', 'DSA', 'DRA', 'TEB', 'SLB', 'GUD', 'HDA', 'DUS']
# Found matching row: 788
# Row number: 788
# Row: ['DUS', 'DSA', 'DRA', 'TEB', 'SLB', 'GUD', 'HDA', 'DUS']
# Distance Row: ['330.4']
# Demand Row: ['100.0']
# Visits: [3, 1, 3, 2, 1, 4]
# Found matching row in loop: 433
# Row number: 433
# Row: ['DUS', 'DSA', 'SLB', 'TEB', 'HDA', 'DUS']
# Distance Row: ['305.79999999999995']
# Demand Row: ['68.0']
# Found matching row in loop: 171
# Row number: 171
# Row: ['DUS', 'DSA', 'TEB', 'HDA', 'DUS']
# Distance Row: ['305.78999999999996']
# Demand Row: ['61.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 287.2025
# Total Weighted Demand for this route: 61.75
# Processing row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'DSA', 'DUS']
# Found matching row: 789
# Row number: 789
# Row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'DSA', 'DUS']
# Distance Row: ['280.22']
# Demand Row: ['86.0']
# Visits: [1, 1, 2, 3, 1, 3]
# Found matching row in loop: 174
# Row number: 174
# Row: ['DUS', 'DSA', 'SLB', 'TEB', 'DUS']
# Distance Row: ['252.49']
# Demand Row: ['50.0']
# Found matching row in loop: 38
# Row number: 38
# Row: ['DUS', 'DSA', 'TEB', 'DUS']
# Distance Row: ['252.48']
# Demand Row: ['43.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 261.73
# Total Weighted Demand for this route: 59.66666666666666
# Processing row: ['DUS', 'DSA', 'DRA', 'SLA', 'SLB', 'TEB', 'HDA', 'DUS']
# Found matching row: 794
# Row number: 794
# Row: ['DUS', 'DSA', 'DRA', 'SLA', 'SLB', 'TEB', 'HDA', 'DUS']
# Distance Row: ['330.27']
# Demand Row: ['86.0']
# Visits: [3, 1, 1, 2, 3, 4]
# Found matching row in loop: 433
# Row number: 433
# Row: ['DUS', 'DSA', 'SLB', 'TEB', 'HDA', 'DUS']
# Distance Row: ['305.79999999999995']
# Demand Row: ['68.0']
# Found matching row in loop: 171
# Row number: 171
# Row: ['DUS', 'DSA', 'TEB', 'HDA', 'DUS']
# Distance Row: ['305.78999999999996']
# Demand Row: ['61.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 287.16999999999996
# Total Weighted Demand for this route: 58.25
# Processing row: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS']
# Found matching row: 801
# Row number: 801
# Row: ['DUS', 'DRA', 'SLA', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS']
# Distance Row: ['305.16']
# Demand Row: ['79.0']
# Visits: [1, 1, 2, 1, 1, 4]
# Found matching row in loop: 62
# Row number: 62
# Row: ['DUS', 'HDA', 'SLB', 'DUS']
# Distance Row: ['293.37']
# Demand Row: ['25.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.5
# Total Weighted Distance for this route: 253.0425
# Total Weighted Demand for this route: 35.0
# Processing row: ['DUS', 'DRA', 'SLA', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS']
# Found matching row: 802
# Row number: 802
# Row: ['DUS', 'DRA', 'SLA', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS']
# Distance Row: ['313.64']
# Demand Row: ['86.0']
# Visits: [1, 1, 3, 1, 1, 4]
# Found matching row in loop: 63
# Row number: 63
# Row: ['DUS', 'HDA', 'TEB', 'DUS']
# Distance Row: ['303.63']
# Demand Row: ['32.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.5
# Route 3 Weight: 0.25
# Total Weighted Distance for this route: 281.93
# Total Weighted Demand for this route: 42.0
# Processing row: ['DUS', 'DRA', 'TEB', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS']
# Found matching row: 803
# Row number: 803
# Row: ['DUS', 'DRA', 'TEB', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS']
# Distance Row: ['314.88']
# Demand Row: ['89.0']
# Visits: [1, 3, 2, 1, 1, 4]
# Found matching row in loop: 229
# Row number: 229
# Row: ['DUS', 'HDA', 'TEB', 'SLB', 'DUS']
# Distance Row: ['303.74']
# Demand Row: ['39.0']
# Found matching row in loop: 63
# Row number: 63
# Row: ['DUS', 'HDA', 'TEB', 'DUS']
# Distance Row: ['303.63']
# Demand Row: ['32.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 282.2675
# Total Weighted Demand for this route: 44.5
# Processing row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'DUS']
# Found matching row: 804
# Row number: 804
# Row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'DUS']
# Distance Row: ['279.35']
# Demand Row: ['75.0']
# Visits: [1, 1, 2, 3, 1, 1]
# Found matching row in loop: 66
# Row number: 66
# Row: ['DUS', 'SLB', 'TEB', 'DUS']
# Distance Row: ['250.43']
# Demand Row: ['21.0']
# Found matching row in loop: 11
# Row number: 11
# Row: ['DUS', 'TEB', 'DUS']
# Distance Row: ['250.32']
# Demand Row: ['14.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 260.0333333333333
# Total Weighted Demand for this route: 36.666666666666664
# Processing row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'JSF', 'DUS']
# Found matching row: 806
# Row number: 806
# Row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'JSF', 'DUS']
# Distance Row: ['268.54']
# Demand Row: ['97.0']
# Visits: [1, 1, 2, 3, 1, 4]
# Found matching row in loop: 220
# Row number: 220
# Row: ['DUS', 'JSF', 'TEB', 'SLB', 'DUS']
# Distance Row: ['255.71999999999997']
# Demand Row: ['61.0']
# Found matching row in loop: 56
# Row number: 56
# Row: ['DUS', 'JSF', 'TEB', 'DUS']
# Distance Row: ['255.60999999999999']
# Demand Row: ['54.0']
# Found matching row in loop: 6
# Row number: 6
# Row: ['DUS', 'JSF', 'DUS']
# Distance Row: ['176.18']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 239.0125
# Total Weighted Demand for this route: 63.0
# Processing row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'HDA', 'DUS']
# Found matching row: 811
# Row number: 811
# Row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'HDA', 'DUS']
# Distance Row: ['314.75']
# Demand Row: ['75.0']
# Visits: [1, 1, 2, 3, 1, 4]
# Found matching row in loop: 229
# Row number: 229
# Row: ['DUS', 'HDA', 'TEB', 'SLB', 'DUS']
# Distance Row: ['303.74']
# Demand Row: ['39.0']
# Found matching row in loop: 63
# Row number: 63
# Row: ['DUS', 'HDA', 'TEB', 'DUS']
# Distance Row: ['303.63']
# Demand Row: ['32.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 282.235
# Total Weighted Demand for this route: 41.0
# Processing row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'JSF', 'DUS']
# Found matching row: 813
# Row number: 813
# Row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'JSF', 'DUS']
# Distance Row: ['279.21000000000004']
# Demand Row: ['97.0']
# Visits: [1, 1, 2, 3, 1, 4]
# Found matching row in loop: 220
# Row number: 220
# Row: ['DUS', 'JSF', 'TEB', 'SLB', 'DUS']
# Distance Row: ['255.71999999999997']
# Demand Row: ['61.0']
# Found matching row in loop: 56
# Row number: 56
# Row: ['DUS', 'JSF', 'TEB', 'DUS']
# Distance Row: ['255.60999999999999']
# Demand Row: ['54.0']
# Found matching row in loop: 6
# Row number: 6
# Row: ['DUS', 'JSF', 'DUS']
# Distance Row: ['176.18']
# Demand Row: ['40.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 241.68
# Total Weighted Demand for this route: 63.0
# Processing row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'HDA', 'DUS']
# Found matching row: 818
# Row number: 818
# Row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GUD', 'HDA', 'DUS']
# Distance Row: ['314.83000000000004']
# Demand Row: ['75.0']
# Visits: [1, 1, 2, 3, 1, 4]
# Found matching row in loop: 229
# Row number: 229
# Row: ['DUS', 'HDA', 'TEB', 'SLB', 'DUS']
# Distance Row: ['303.74']
# Demand Row: ['39.0']
# Found matching row in loop: 63
# Row number: 63
# Row: ['DUS', 'HDA', 'TEB', 'DUS']
# Distance Row: ['303.63']
# Demand Row: ['32.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 282.255
# Total Weighted Demand for this route: 41.0
# Processing row: ['DUS', 'DRA', 'SLA', 'TEB', 'SLB', 'JSF', 'HDA', 'DUS']
# Found matching row: 821
# Row number: 821
# Row: ['DUS', 'DRA', 'SLA', 'TEB', 'SLB', 'JSF', 'HDA', 'DUS']
# Distance Row: ['325.62']
# Demand Row: ['97.0']
# Visits: [1, 1, 3, 2, 4, 4]
# Found matching row in loop: 498
# Row number: 498
# Row: ['DUS', 'JSF', 'SLB', 'TEB', 'HDA', 'DUS']
# Distance Row: ['309.09000000000003']
# Demand Row: ['79.0']
# Found matching row in loop: 217
# Row number: 217
# Row: ['DUS', 'JSF', 'TEB', 'HDA', 'DUS']
# Distance Row: ['308.91999999999996']
# Demand Row: ['72.0']
# Found matching row in loop: 53
# Row number: 53
# Row: ['DUS', 'JSF', 'HDA', 'DUS']
# Distance Row: ['236.49']
# Demand Row: ['58.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 295.03
# Total Weighted Demand for this route: 76.5
# Processing row: ['DUS', 'DSA', 'SLA', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS']
# Found matching row: 826
# Row number: 826
# Row: ['DUS', 'DSA', 'SLA', 'SLB', 'GKR', 'GUD', 'HDA', 'DUS']
# Distance Row: ['300.0']
# Demand Row: ['94.0']
# Visits: [3, 1, 2, 1, 1, 4]
# Found matching row in loop: 170
# Row number: 170
# Row: ['DUS', 'DSA', 'SLB', 'HDA', 'DUS']
# Distance Row: ['295.42999999999995']
# Demand Row: ['54.0']
# Found matching row in loop: 35
# Row number: 35
# Row: ['DUS', 'DSA', 'HDA', 'DUS']
# Distance Row: ['236.43']
# Demand Row: ['47.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 259.66999999999996
# Total Weighted Demand for this route: 53.25
# Processing row: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'DSA', 'DUS']
# Found matching row: 827
# Row number: 827
# Row: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'DSA', 'DUS']
# Distance Row: ['271.61999999999995']
# Demand Row: ['90.0']
# Visits: [1, 2, 3, 1, 1, 3]
# Found matching row in loop: 174
# Row number: 174
# Row: ['DUS', 'DSA', 'SLB', 'TEB', 'DUS']
# Distance Row: ['252.49']
# Demand Row: ['50.0']
# Found matching row in loop: 38
# Row number: 38
# Row: ['DUS', 'DSA', 'TEB', 'DUS']
# Distance Row: ['252.48']
# Demand Row: ['43.0']
# Route 1 Weight: 0.3333333333333333
# Route 2 Weight: 0.3333333333333333
# Route 3 Weight: 0.3333333333333333
# Total Weighted Distance for this route: 258.86333333333334
# Total Weighted Demand for this route: 61.0
# Processing row: ['DUS', 'HDA', 'GKR', 'TEB', 'SLB', 'SLA', 'DSA', 'DUS']
# Found matching row: 832
# Row number: 832
# Row: ['DUS', 'HDA', 'GKR', 'TEB', 'SLB', 'SLA', 'DSA', 'DUS']
# Distance Row: ['309.59']
# Demand Row: ['90.0']
# Visits: [4, 1, 3, 2, 1, 3]
# Found matching row in loop: 433
# Row number: 433
# Row: ['DUS', 'DSA', 'SLB', 'TEB', 'HDA', 'DUS']
# Distance Row: ['305.79999999999995']
# Demand Row: ['68.0']
# Found matching row in loop: 171
# Row number: 171
# Row: ['DUS', 'DSA', 'TEB', 'HDA', 'DUS']
# Distance Row: ['305.78999999999996']
# Demand Row: ['61.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 281.99999999999994
# Total Weighted Demand for this route: 59.25
# Processing row: ['DUS', 'DSA', 'SLA', 'SLB', 'TEB', 'GUD', 'HDA', 'DUS']
# Found matching row: 837
# Row number: 837
# Row: ['DUS', 'DSA', 'SLA', 'SLB', 'TEB', 'GUD', 'HDA', 'DUS']
# Distance Row: ['309.67']
# Demand Row: ['90.0']
# Visits: [3, 1, 2, 3, 1, 4]
# Found matching row in loop: 433
# Row number: 433
# Row: ['DUS', 'DSA', 'SLB', 'TEB', 'HDA', 'DUS']
# Distance Row: ['305.79999999999995']
# Demand Row: ['68.0']
# Found matching row in loop: 171
# Row number: 171
# Row: ['DUS', 'DSA', 'TEB', 'HDA', 'DUS']
# Distance Row: ['305.78999999999996']
# Demand Row: ['61.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 282.02
# Total Weighted Demand for this route: 59.25
# Processing row: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS']
# Found matching row: 843
# Row number: 843
# Row: ['DUS', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS']
# Distance Row: ['306.22999999999996']
# Demand Row: ['79.0']
# Visits: [1, 2, 3, 1, 1, 4]
# Found matching row in loop: 229
# Row number: 229
# Row: ['DUS', 'HDA', 'TEB', 'SLB', 'DUS']
# Distance Row: ['303.74']
# Demand Row: ['39.0']
# Found matching row in loop: 63
# Row number: 63
# Row: ['DUS', 'HDA', 'TEB', 'DUS']
# Distance Row: ['303.63']
# Demand Row: ['32.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 280.105
# Total Weighted Demand for this route: 42.0
# Processing row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS']
# Found matching row: 855
# Row number: 855
# Row: ['DUS', 'DRA', 'SLA', 'SLB', 'TEB', 'GKR', 'GUD', 'HDA', 'DUS']
# Distance Row: ['315.16']
# Demand Row: ['93.0']
# Visits: [1, 1, 2, 3, 1, 1, 4]
# Found matching row in loop: 229
# Row number: 229
# Row: ['DUS', 'HDA', 'TEB', 'SLB', 'DUS']
# Distance Row: ['303.74']
# Demand Row: ['39.0']
# Found matching row in loop: 63
# Row number: 63
# Row: ['DUS', 'HDA', 'TEB', 'DUS']
# Distance Row: ['303.63']
# Demand Row: ['32.0']
# Found matching row in loop: 8
# Row number: 8
# Row: ['DUS', 'HDA', 'DUS']
# Distance Row: ['206.82']
# Demand Row: ['18.0']
# Route 1 Weight: 0.25
# Route 2 Weight: 0.25
# Route 3 Weight: 0.25
# Route 4 Weight: 0.25
# Total Weighted Distance for this route: 282.33750000000003
# Total Weighted Demand for this route: 45.5

# %%
zero_rows = []
with open(f'{mappenavn}/distances.csv', 'r') as file:
    next(file)  # Skip the header line
    for i, line in enumerate(file, start=1):  # Start enumeration from 1
        if float(line.strip()) == 0:
            zero_rows.append(i)

print("Row numbers with 0 values:", zero_rows)

# Read routes.csv line by line and remove rows based on zero_rows
with open(f'{mappenavn}/routes.csv', 'r') as routes_file:
    routes_data = routes_file.readlines()

# Remove rows from routes_data based on zero_rows
routes_data = [route for i, route in enumerate(routes_data, start=1) if i not in zero_rows]

# Write the updated routes_data back to routes.csv
with open(f'{mappenavn}/routes.csv', 'w') as routes_file:
    routes_file.writelines(routes_data)

demand_df = pd.read_csv(f'{mappenavn}/demand.csv')
demand_df = demand_df[demand_df['Demand'] != 0]
demand_df.to_csv(f'{mappenavn}/demand.csv', index=False)

# Remove rows from distances.csv
distances_df = pd.read_csv(f'{mappenavn}/distances.csv')
distances_df = distances_df[distances_df['Distances'] != 0]
distances_df.to_csv(f'{mappenavn}/distances.csv', index=False)
# Out:
# Row numbers with 0 values: [63, 64, 65, 79, 170, 184, 322, 323, 325]

# %%
demand_df = pd.read_csv(f'{mappenavn}/demand.csv')
duration_lossing = round(((demand_df['Demand'] * 1.389) / psv_speed), 2)
duration_loss_df = pd.DataFrame({'Duration (hours)': duration_lossing})
duration_loss_df.to_csv(f'{mappenavn}/duration_lossing.csv', index=False)

distances_df = pd.read_csv(f'{mappenavn}/distances.csv')
duration_sailing = round((distances_df['Distances'] / psv_speed), 2)
duration_sailing_df = pd.DataFrame({'Duration (hours)': duration_sailing})
duration_sailing_df.to_csv(f'{mappenavn}/duration_sailing.csv', index=False)
