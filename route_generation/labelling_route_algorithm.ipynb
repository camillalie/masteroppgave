# %%
import pandas as pd
from itertools import combinations
import math
import os
import csv
import time

# %%
cargo_capacity_psv = 100
psv_speed = 10 #7 for strøm, 10 på resten
max_platforms_in_one_voyage = 6

# %% [markdown]
# ## Reads input data

# %%
demand = pd.read_csv('clustering/output_platforms_demand.csv', header=0, delimiter=';')
distances = pd.read_csv('clustering/output_distance_matrix_kmeans.csv', header=0, delimiter=';', index_col='from/to')

platforms_demand = dict(zip(demand['platform'], demand['avg_q'].replace(',', '.').astype(float)))
platforms_d = ['MON'] + demand['platform'].tolist() + ['MON']  # Add 'Mon' as start and end platforms

# %% [markdown]
# ## Algorithm for generating the shortest routes

# %%
shortest_routes_dict = {}

def generate_routes(demand, distances):
    cargo_capacity = cargo_capacity_psv
    max_platforms = max_platforms_in_one_voyage + 2

    def dp(platform, cargo_remaining, route, visited):
        if cargo_remaining < 0:
            return
        if len(route) > max_platforms:
            return
        if platform == 'MON' and len(route) > 2:
            total_demand = sum(platforms_demand[p] for p in route[1:-1])
            if total_demand <= cargo_capacity:
                key = tuple(sorted(set(route)))
                total_distance = sum(distances.loc[route[i], route[i+1]] for i in range(len(route)-1))
                if key not in shortest_routes_dict or total_distance < shortest_routes_dict[key][1]:
                    duration_sailing = round((total_distance / psv_speed), 2)
                    duration_lossing = round(((total_demand * 1.389) / psv_speed), 2)
                    duration_sailing = round(duration_sailing, 2)
                    duration_lossing = round(duration_lossing, 2)
                    shortest_routes_dict[key] = (route, total_distance, total_demand, duration_sailing, duration_lossing)
            return

        # Check if the current route is dominated
        current_distance = sum(distances.loc[route[i], route[i+1]] for i in range(len(route)-1))
        current_demand = sum(platforms_demand[p] for p in route[1:-1])
        
        # Check for dominance in existing routes
        for key, (existing_route, existing_distance, existing_demand, _, _) in shortest_routes_dict.items():
            if set(existing_route[1:-1]) == set(route[1:-1]) and existing_demand >= current_demand and existing_distance <= current_distance:
                return
        
        # Check for dominance in subsequent routes starting with the same platforms
        for existing_route in dominated_routes:
            if set(existing_route[1:-1]) == set(route[1:-1]) and existing_demand >= current_demand and existing_distance <= current_distance:
                return

        for next_platform in platforms_demand.keys():
            if next_platform != platform and next_platform not in visited:
                try:
                    distance_to_next = distances.loc[platform, next_platform]
                    new_cargo_remaining = cargo_remaining - platforms_demand[next_platform]
                    dp(next_platform, new_cargo_remaining, route + [next_platform], visited.union({next_platform}))
                except KeyError:
                    print("KeyError occurred for platform:", next_platform)
                    continue

    for r in range(3, min(len(platforms_demand) + 3, max_platforms + 3)):
        for route_combination in combinations(platforms_demand.keys(), r - 2):
            route = ['MON'] + list(route_combination) + ['MON']
            dp('MON', cargo_capacity, route, {'MON'})

            # Add the current route to the dominated routes set
            dominated_routes.add(tuple(route))

    return shortest_routes_dict

# Keep track of dominated routes to skip future routes starting with them
dominated_routes = set()
shortest_routes_dict = generate_routes(demand, distances)

for route, distance, demand, duration_sailing, duration_lossing in shortest_routes_dict.values():
    print(f"Shortest Route: {route}, Total Distance: {round(distance,2)}, Total Demand: {demand}, Duration sailing: {duration_sailing}, Duration lossing: {duration_lossing}")

print(len(shortest_routes_dict))
# Out:
# Shortest Route: ['MON', 'APT', 'MON'], Total Distance: 148.32, Total Demand: 18.0, Duration sailing: 14.83, Duration lossing: 2.5
# Shortest Route: ['MON', 'ASL', 'MON'], Total Distance: 179.48, Total Demand: 25.0, Duration sailing: 17.95, Duration lossing: 3.47
# Shortest Route: ['MON', 'DAB', 'MON'], Total Distance: 110.98, Total Demand: 40.0, Duration sailing: 11.1, Duration lossing: 5.56
# Shortest Route: ['MON', 'DSA', 'MON'], Total Distance: 194.44, Total Demand: 29.0, Duration sailing: 19.44, Duration lossing: 4.03
# Shortest Route: ['MON', 'DSS', 'MON'], Total Distance: 189.78, Total Demand: 29.0, Duration sailing: 18.98, Duration lossing: 4.03
# Shortest Route: ['MON', 'GFAGFBGFC', 'MON'], Total Distance: 176.96, Total Demand: 67.25, Duration sailing: 17.7, Duration lossing: 9.34
# Shortest Route: ['MON', 'KVB', 'MON'], Total Distance: 151.06, Total Demand: 14.0, Duration sailing: 15.11, Duration lossing: 1.94
# Shortest Route: ['MON', 'MID', 'MON'], Total Distance: 181.28, Total Demand: 14.0, Duration sailing: 18.13, Duration lossing: 1.94
# Shortest Route: ['MON', 'NLNVAL', 'MON'], Total Distance: 160.56, Total Demand: 28.67, Duration sailing: 16.06, Duration lossing: 3.98
# Shortest Route: ['MON', 'OSC', 'MON'], Total Distance: 134.62, Total Demand: 18.0, Duration sailing: 13.46, Duration lossing: 2.5
# Shortest Route: ['MON', 'OSE', 'MON'], Total Distance: 135.42, Total Demand: 36.0, Duration sailing: 13.54, Duration lossing: 5.0
# Shortest Route: ['MON', 'OSOVFB', 'MON'], Total Distance: 133.04, Total Demand: 28.5, Duration sailing: 13.3, Duration lossing: 3.96
# Shortest Route: ['MON', 'OSS', 'MON'], Total Distance: 142.2, Total Demand: 18.0, Duration sailing: 14.22, Duration lossing: 2.5
# Shortest Route: ['MON', 'STASTB', 'MON'], Total Distance: 197.86, Total Demand: 46.75, Duration sailing: 19.79, Duration lossing: 6.49
# Shortest Route: ['MON', 'STC', 'MON'], Total Distance: 190.76, Total Demand: 29.0, Duration sailing: 19.08, Duration lossing: 4.03
# Shortest Route: ['MON', 'TENTRB', 'MON'], Total Distance: 93.5, Total Demand: 23.5, Duration sailing: 9.35, Duration lossing: 3.26
# Shortest Route: ['MON', 'TEQTRC', 'MON'], Total Distance: 87.94, Total Demand: 27.0, Duration sailing: 8.79, Duration lossing: 3.75
# Shortest Route: ['MON', 'TRO', 'MON'], Total Distance: 79.94, Total Demand: 11.0, Duration sailing: 7.99, Duration lossing: 1.53
# Shortest Route: ['MON', 'APT', 'ASL', 'MON'], Total Distance: 217.13, Total Demand: 43.0, Duration sailing: 21.71, Duration lossing: 5.97
# Shortest Route: ['MON', 'APT', 'DAB', 'MON'], Total Distance: 192.13, Total Demand: 58.0, Duration sailing: 19.21, Duration lossing: 8.06
# Shortest Route: ['MON', 'APT', 'DSA', 'MON'], Total Distance: 245.33, Total Demand: 47.0, Duration sailing: 24.53, Duration lossing: 6.53
# Shortest Route: ['MON', 'APT', 'DSS', 'MON'], Total Distance: 249.24, Total Demand: 47.0, Duration sailing: 24.92, Duration lossing: 6.53
# Shortest Route: ['MON', 'APT', 'GFAGFBGFC', 'MON'], Total Distance: 223.8, Total Demand: 85.25, Duration sailing: 22.38, Duration lossing: 11.84
# Shortest Route: ['MON', 'APT', 'KVB', 'MON'], Total Distance: 199.01, Total Demand: 32.0, Duration sailing: 19.9, Duration lossing: 4.44
# Shortest Route: ['MON', 'APT', 'MID', 'MON'], Total Distance: 191.24, Total Demand: 32.0, Duration sailing: 19.12, Duration lossing: 4.44
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'MON'], Total Distance: 203.09, Total Demand: 46.67, Duration sailing: 20.31, Duration lossing: 6.48
# Shortest Route: ['MON', 'APT', 'OSC', 'MON'], Total Distance: 161.88, Total Demand: 36.0, Duration sailing: 16.19, Duration lossing: 5.0
# Shortest Route: ['MON', 'APT', 'OSE', 'MON'], Total Distance: 155.16, Total Demand: 54.0, Duration sailing: 15.52, Duration lossing: 7.5
# Shortest Route: ['MON', 'APT', 'OSOVFB', 'MON'], Total Distance: 173.45, Total Demand: 46.5, Duration sailing: 17.34, Duration lossing: 6.46
# Shortest Route: ['MON', 'APT', 'OSS', 'MON'], Total Distance: 151.87, Total Demand: 36.0, Duration sailing: 15.19, Duration lossing: 5.0
# Shortest Route: ['MON', 'APT', 'STASTB', 'MON'], Total Distance: 239.51, Total Demand: 64.75, Duration sailing: 23.95, Duration lossing: 8.99
# Shortest Route: ['MON', 'APT', 'STC', 'MON'], Total Distance: 235.99, Total Demand: 47.0, Duration sailing: 23.6, Duration lossing: 6.53
# Shortest Route: ['MON', 'APT', 'TENTRB', 'MON'], Total Distance: 158.58, Total Demand: 41.5, Duration sailing: 15.86, Duration lossing: 5.76
# Shortest Route: ['MON', 'APT', 'TEQTRC', 'MON'], Total Distance: 162.55, Total Demand: 45.0, Duration sailing: 16.26, Duration lossing: 6.25
# Shortest Route: ['MON', 'APT', 'TRO', 'MON'], Total Distance: 149.74, Total Demand: 29.0, Duration sailing: 14.97, Duration lossing: 4.03
# Shortest Route: ['MON', 'ASL', 'DAB', 'MON'], Total Distance: 186.67, Total Demand: 65.0, Duration sailing: 18.67, Duration lossing: 9.03
# Shortest Route: ['MON', 'ASL', 'DSA', 'MON'], Total Distance: 208.67, Total Demand: 54.0, Duration sailing: 20.87, Duration lossing: 7.5
# Shortest Route: ['MON', 'ASL', 'DSS', 'MON'], Total Distance: 214.96, Total Demand: 54.0, Duration sailing: 21.5, Duration lossing: 7.5
# Shortest Route: ['MON', 'ASL', 'GFAGFBGFC', 'MON'], Total Distance: 191.28, Total Demand: 92.25, Duration sailing: 19.13, Duration lossing: 12.81
# Shortest Route: ['MON', 'ASL', 'KVB', 'MON'], Total Distance: 179.8, Total Demand: 39.0, Duration sailing: 17.98, Duration lossing: 5.42
# Shortest Route: ['MON', 'ASL', 'MID', 'MON'], Total Distance: 214.61, Total Demand: 39.0, Duration sailing: 21.46, Duration lossing: 5.42
# Shortest Route: ['MON', 'ASL', 'NLNVAL', 'MON'], Total Distance: 181.6, Total Demand: 53.67, Duration sailing: 18.16, Duration lossing: 7.45
# Shortest Route: ['MON', 'ASL', 'OSC', 'MON'], Total Distance: 192.88, Total Demand: 43.0, Duration sailing: 19.29, Duration lossing: 5.97
# Shortest Route: ['MON', 'ASL', 'OSE', 'MON'], Total Distance: 199.93, Total Demand: 61.0, Duration sailing: 19.99, Duration lossing: 8.47
# Shortest Route: ['MON', 'ASL', 'OSOVFB', 'MON'], Total Distance: 193.79, Total Demand: 53.5, Duration sailing: 19.38, Duration lossing: 7.43
# Shortest Route: ['MON', 'ASL', 'OSS', 'MON'], Total Distance: 208.32, Total Demand: 43.0, Duration sailing: 20.83, Duration lossing: 5.97
# Shortest Route: ['MON', 'ASL', 'STASTB', 'MON'], Total Distance: 201.86, Total Demand: 71.75, Duration sailing: 20.19, Duration lossing: 9.97
# Shortest Route: ['MON', 'ASL', 'STC', 'MON'], Total Distance: 198.64, Total Demand: 54.0, Duration sailing: 19.86, Duration lossing: 7.5
# Shortest Route: ['MON', 'ASL', 'TENTRB', 'MON'], Total Distance: 186.61, Total Demand: 48.5, Duration sailing: 18.66, Duration lossing: 6.74
# Shortest Route: ['MON', 'ASL', 'TEQTRC', 'MON'], Total Distance: 182.24, Total Demand: 52.0, Duration sailing: 18.22, Duration lossing: 7.22
# Shortest Route: ['MON', 'ASL', 'TRO', 'MON'], Total Distance: 186.24, Total Demand: 36.0, Duration sailing: 18.62, Duration lossing: 5.0
# Shortest Route: ['MON', 'DAB', 'DSA', 'MON'], Total Distance: 195.26, Total Demand: 69.0, Duration sailing: 19.53, Duration lossing: 9.58
# Shortest Route: ['MON', 'DAB', 'DSS', 'MON'], Total Distance: 189.78, Total Demand: 69.0, Duration sailing: 18.98, Duration lossing: 9.58
# Shortest Route: ['MON', 'DAB', 'KVB', 'MON'], Total Distance: 158.67, Total Demand: 54.0, Duration sailing: 15.87, Duration lossing: 7.5
# Shortest Route: ['MON', 'DAB', 'MID', 'MON'], Total Distance: 206.9, Total Demand: 54.0, Duration sailing: 20.69, Duration lossing: 7.5
# Shortest Route: ['MON', 'DAB', 'NLNVAL', 'MON'], Total Distance: 169.43, Total Demand: 68.67, Duration sailing: 16.94, Duration lossing: 9.54
# Shortest Route: ['MON', 'DAB', 'OSC', 'MON'], Total Distance: 166.0, Total Demand: 58.0, Duration sailing: 16.6, Duration lossing: 8.06
# Shortest Route: ['MON', 'DAB', 'OSE', 'MON'], Total Distance: 172.62, Total Demand: 76.0, Duration sailing: 17.26, Duration lossing: 10.56
# Shortest Route: ['MON', 'DAB', 'OSOVFB', 'MON'], Total Distance: 160.75, Total Demand: 68.5, Duration sailing: 16.08, Duration lossing: 9.51
# Shortest Route: ['MON', 'DAB', 'OSS', 'MON'], Total Distance: 182.66, Total Demand: 58.0, Duration sailing: 18.27, Duration lossing: 8.06
# Shortest Route: ['MON', 'DAB', 'STASTB', 'MON'], Total Distance: 201.56, Total Demand: 86.75, Duration sailing: 20.16, Duration lossing: 12.05
# Shortest Route: ['MON', 'DAB', 'STC', 'MON'], Total Distance: 193.3, Total Demand: 69.0, Duration sailing: 19.33, Duration lossing: 9.58
# Shortest Route: ['MON', 'DAB', 'TENTRB', 'MON'], Total Distance: 135.93, Total Demand: 63.5, Duration sailing: 13.59, Duration lossing: 8.82
# Shortest Route: ['MON', 'DAB', 'TEQTRC', 'MON'], Total Distance: 125.09, Total Demand: 67.0, Duration sailing: 12.51, Duration lossing: 9.31
# Shortest Route: ['MON', 'DAB', 'TRO', 'MON'], Total Distance: 134.64, Total Demand: 51.0, Duration sailing: 13.46, Duration lossing: 7.08
# Shortest Route: ['MON', 'DSA', 'DSS', 'MON'], Total Distance: 202.62, Total Demand: 58.0, Duration sailing: 20.26, Duration lossing: 8.06
# Shortest Route: ['MON', 'DSA', 'GFAGFBGFC', 'MON'], Total Distance: 205.81, Total Demand: 96.25, Duration sailing: 20.58, Duration lossing: 13.37
# Shortest Route: ['MON', 'DSA', 'KVB', 'MON'], Total Distance: 199.44, Total Demand: 43.0, Duration sailing: 19.94, Duration lossing: 5.97
# Shortest Route: ['MON', 'DSA', 'MID', 'MON'], Total Distance: 243.76, Total Demand: 43.0, Duration sailing: 24.38, Duration lossing: 5.97
# Shortest Route: ['MON', 'DSA', 'NLNVAL', 'MON'], Total Distance: 205.26, Total Demand: 57.67, Duration sailing: 20.53, Duration lossing: 8.01
# Shortest Route: ['MON', 'DSA', 'OSC', 'MON'], Total Distance: 219.62, Total Demand: 47.0, Duration sailing: 21.96, Duration lossing: 6.53
# Shortest Route: ['MON', 'DSA', 'OSE', 'MON'], Total Distance: 227.16, Total Demand: 65.0, Duration sailing: 22.72, Duration lossing: 9.03
# Shortest Route: ['MON', 'DSA', 'OSOVFB', 'MON'], Total Distance: 218.35, Total Demand: 57.5, Duration sailing: 21.83, Duration lossing: 7.99
# Shortest Route: ['MON', 'DSA', 'OSS', 'MON'], Total Distance: 236.18, Total Demand: 47.0, Duration sailing: 23.62, Duration lossing: 6.53
# Shortest Route: ['MON', 'DSA', 'STASTB', 'MON'], Total Distance: 211.49, Total Demand: 75.75, Duration sailing: 21.15, Duration lossing: 10.52
# Shortest Route: ['MON', 'DSA', 'STC', 'MON'], Total Distance: 201.05, Total Demand: 58.0, Duration sailing: 20.1, Duration lossing: 8.06
# Shortest Route: ['MON', 'DSA', 'TENTRB', 'MON'], Total Distance: 207.48, Total Demand: 52.5, Duration sailing: 20.75, Duration lossing: 7.29
# Shortest Route: ['MON', 'DSA', 'TEQTRC', 'MON'], Total Distance: 200.52, Total Demand: 56.0, Duration sailing: 20.05, Duration lossing: 7.78
# Shortest Route: ['MON', 'DSA', 'TRO', 'MON'], Total Distance: 207.6, Total Demand: 40.0, Duration sailing: 20.76, Duration lossing: 5.56
# Shortest Route: ['MON', 'DSS', 'GFAGFBGFC', 'MON'], Total Distance: 209.77, Total Demand: 96.25, Duration sailing: 20.98, Duration lossing: 13.37
# Shortest Route: ['MON', 'DSS', 'KVB', 'MON'], Total Distance: 201.52, Total Demand: 43.0, Duration sailing: 20.15, Duration lossing: 5.97
# Shortest Route: ['MON', 'DSS', 'MID', 'MON'], Total Distance: 249.88, Total Demand: 43.0, Duration sailing: 24.99, Duration lossing: 5.97
# Shortest Route: ['MON', 'DSS', 'NLNVAL', 'MON'], Total Distance: 208.88, Total Demand: 57.67, Duration sailing: 20.89, Duration lossing: 8.01
# Shortest Route: ['MON', 'DSS', 'OSC', 'MON'], Total Distance: 222.67, Total Demand: 47.0, Duration sailing: 22.27, Duration lossing: 6.53
# Shortest Route: ['MON', 'DSS', 'OSE', 'MON'], Total Distance: 230.39, Total Demand: 65.0, Duration sailing: 23.04, Duration lossing: 9.03
# Shortest Route: ['MON', 'DSS', 'OSOVFB', 'MON'], Total Distance: 220.22, Total Demand: 57.5, Duration sailing: 22.02, Duration lossing: 7.99
# Shortest Route: ['MON', 'DSS', 'OSS', 'MON'], Total Distance: 239.83, Total Demand: 47.0, Duration sailing: 23.98, Duration lossing: 6.53
# Shortest Route: ['MON', 'DSS', 'STASTB', 'MON'], Total Distance: 219.16, Total Demand: 75.75, Duration sailing: 21.92, Duration lossing: 10.52
# Shortest Route: ['MON', 'DSS', 'STC', 'MON'], Total Distance: 208.55, Total Demand: 58.0, Duration sailing: 20.86, Duration lossing: 8.06
# Shortest Route: ['MON', 'DSS', 'TENTRB', 'MON'], Total Distance: 206.83, Total Demand: 52.5, Duration sailing: 20.68, Duration lossing: 7.29
# Shortest Route: ['MON', 'DSS', 'TEQTRC', 'MON'], Total Distance: 198.67, Total Demand: 56.0, Duration sailing: 19.87, Duration lossing: 7.78
# Shortest Route: ['MON', 'DSS', 'TRO', 'MON'], Total Distance: 206.92, Total Demand: 40.0, Duration sailing: 20.69, Duration lossing: 5.56
# Shortest Route: ['MON', 'GFAGFBGFC', 'KVB', 'MON'], Total Distance: 178.05, Total Demand: 81.25, Duration sailing: 17.8, Duration lossing: 11.29
# Shortest Route: ['MON', 'GFAGFBGFC', 'MID', 'MON'], Total Distance: 224.45, Total Demand: 81.25, Duration sailing: 22.44, Duration lossing: 11.29
# Shortest Route: ['MON', 'GFAGFBGFC', 'NLNVAL', 'MON'], Total Distance: 183.44, Total Demand: 95.92, Duration sailing: 18.34, Duration lossing: 13.32
# Shortest Route: ['MON', 'GFAGFBGFC', 'OSC', 'MON'], Total Distance: 197.8, Total Demand: 85.25, Duration sailing: 19.78, Duration lossing: 11.84
# Shortest Route: ['MON', 'GFAGFBGFC', 'OSOVFB', 'MON'], Total Distance: 196.59, Total Demand: 95.75, Duration sailing: 19.66, Duration lossing: 13.3
# Shortest Route: ['MON', 'GFAGFBGFC', 'OSS', 'MON'], Total Distance: 214.53, Total Demand: 85.25, Duration sailing: 21.45, Duration lossing: 11.84
# Shortest Route: ['MON', 'GFAGFBGFC', 'STC', 'MON'], Total Distance: 198.3, Total Demand: 96.25, Duration sailing: 19.83, Duration lossing: 13.37
# Shortest Route: ['MON', 'GFAGFBGFC', 'TENTRB', 'MON'], Total Distance: 186.83, Total Demand: 90.75, Duration sailing: 18.68, Duration lossing: 12.61
# Shortest Route: ['MON', 'GFAGFBGFC', 'TEQTRC', 'MON'], Total Distance: 180.92, Total Demand: 94.25, Duration sailing: 18.09, Duration lossing: 13.09
# Shortest Route: ['MON', 'GFAGFBGFC', 'TRO', 'MON'], Total Distance: 186.86, Total Demand: 78.25, Duration sailing: 18.69, Duration lossing: 10.87
# Shortest Route: ['MON', 'KVB', 'MID', 'MON'], Total Distance: 203.73, Total Demand: 28.0, Duration sailing: 20.37, Duration lossing: 3.89
# Shortest Route: ['MON', 'KVB', 'NLNVAL', 'MON'], Total Distance: 161.86, Total Demand: 42.67, Duration sailing: 16.19, Duration lossing: 5.93
# Shortest Route: ['MON', 'KVB', 'OSC', 'MON'], Total Distance: 172.22, Total Demand: 32.0, Duration sailing: 17.22, Duration lossing: 4.44
# Shortest Route: ['MON', 'KVB', 'OSE', 'MON'], Total Distance: 179.96, Total Demand: 50.0, Duration sailing: 18.0, Duration lossing: 6.95
# Shortest Route: ['MON', 'KVB', 'OSOVFB', 'MON'], Total Distance: 170.06, Total Demand: 42.5, Duration sailing: 17.01, Duration lossing: 5.9
# Shortest Route: ['MON', 'KVB', 'OSS', 'MON'], Total Distance: 189.51, Total Demand: 32.0, Duration sailing: 18.95, Duration lossing: 4.44
# Shortest Route: ['MON', 'KVB', 'STASTB', 'MON'], Total Distance: 198.33, Total Demand: 60.75, Duration sailing: 19.83, Duration lossing: 8.44
# Shortest Route: ['MON', 'KVB', 'STC', 'MON'], Total Distance: 192.37, Total Demand: 43.0, Duration sailing: 19.24, Duration lossing: 5.97
# Shortest Route: ['MON', 'KVB', 'TENTRB', 'MON'], Total Distance: 159.88, Total Demand: 37.5, Duration sailing: 15.99, Duration lossing: 5.21
# Shortest Route: ['MON', 'KVB', 'TEQTRC', 'MON'], Total Distance: 154.33, Total Demand: 41.0, Duration sailing: 15.43, Duration lossing: 5.69
# Shortest Route: ['MON', 'KVB', 'TRO', 'MON'], Total Distance: 159.89, Total Demand: 25.0, Duration sailing: 15.99, Duration lossing: 3.47
# Shortest Route: ['MON', 'MID', 'NLNVAL', 'MON'], Total Distance: 205.56, Total Demand: 42.67, Duration sailing: 20.56, Duration lossing: 5.93
# Shortest Route: ['MON', 'MID', 'OSC', 'MON'], Total Distance: 181.33, Total Demand: 32.0, Duration sailing: 18.13, Duration lossing: 4.44
# Shortest Route: ['MON', 'MID', 'OSE', 'MON'], Total Distance: 182.31, Total Demand: 50.0, Duration sailing: 18.23, Duration lossing: 6.95
# Shortest Route: ['MON', 'MID', 'OSOVFB', 'MON'], Total Distance: 191.47, Total Demand: 42.5, Duration sailing: 19.15, Duration lossing: 5.9
# Shortest Route: ['MON', 'MID', 'OSS', 'MON'], Total Distance: 185.66, Total Demand: 32.0, Duration sailing: 18.57, Duration lossing: 4.44
# Shortest Route: ['MON', 'MID', 'STASTB', 'MON'], Total Distance: 236.16, Total Demand: 60.75, Duration sailing: 23.62, Duration lossing: 8.44
# Shortest Route: ['MON', 'MID', 'STC', 'MON'], Total Distance: 233.58, Total Demand: 43.0, Duration sailing: 23.36, Duration lossing: 5.97
# Shortest Route: ['MON', 'MID', 'TENTRB', 'MON'], Total Distance: 185.58, Total Demand: 37.5, Duration sailing: 18.56, Duration lossing: 5.21
# Shortest Route: ['MON', 'MID', 'TEQTRC', 'MON'], Total Distance: 186.74, Total Demand: 41.0, Duration sailing: 18.67, Duration lossing: 5.69
# Shortest Route: ['MON', 'MID', 'TRO', 'MON'], Total Distance: 181.46, Total Demand: 25.0, Duration sailing: 18.15, Duration lossing: 3.47
# Shortest Route: ['MON', 'NLNVAL', 'OSC', 'MON'], Total Distance: 177.03, Total Demand: 46.67, Duration sailing: 17.7, Duration lossing: 6.48
# Shortest Route: ['MON', 'NLNVAL', 'OSE', 'MON'], Total Distance: 184.6, Total Demand: 64.67, Duration sailing: 18.46, Duration lossing: 8.98
# Shortest Route: ['MON', 'NLNVAL', 'OSOVFB', 'MON'], Total Distance: 176.23, Total Demand: 57.17, Duration sailing: 17.62, Duration lossing: 7.94
# Shortest Route: ['MON', 'NLNVAL', 'OSS', 'MON'], Total Distance: 193.78, Total Demand: 46.67, Duration sailing: 19.38, Duration lossing: 6.48
# Shortest Route: ['MON', 'NLNVAL', 'STASTB', 'MON'], Total Distance: 201.89, Total Demand: 75.42, Duration sailing: 20.19, Duration lossing: 10.48
# Shortest Route: ['MON', 'NLNVAL', 'STC', 'MON'], Total Distance: 196.91, Total Demand: 57.67, Duration sailing: 19.69, Duration lossing: 8.01
# Shortest Route: ['MON', 'NLNVAL', 'TENTRB', 'MON'], Total Distance: 167.95, Total Demand: 52.17, Duration sailing: 16.79, Duration lossing: 7.25
# Shortest Route: ['MON', 'NLNVAL', 'TEQTRC', 'MON'], Total Distance: 163.32, Total Demand: 55.67, Duration sailing: 16.33, Duration lossing: 7.73
# Shortest Route: ['MON', 'NLNVAL', 'TRO', 'MON'], Total Distance: 167.75, Total Demand: 39.67, Duration sailing: 16.77, Duration lossing: 5.51
# Shortest Route: ['MON', 'OSC', 'OSE', 'MON'], Total Distance: 142.37, Total Demand: 54.0, Duration sailing: 14.24, Duration lossing: 7.5
# Shortest Route: ['MON', 'OSC', 'OSOVFB', 'MON'], Total Distance: 146.86, Total Demand: 46.5, Duration sailing: 14.69, Duration lossing: 6.46
# Shortest Route: ['MON', 'OSC', 'OSS', 'MON'], Total Distance: 152.22, Total Demand: 36.0, Duration sailing: 15.22, Duration lossing: 5.0
# Shortest Route: ['MON', 'OSC', 'STASTB', 'MON'], Total Distance: 215.06, Total Demand: 64.75, Duration sailing: 21.51, Duration lossing: 8.99
# Shortest Route: ['MON', 'OSC', 'STC', 'MON'], Total Distance: 210.91, Total Demand: 47.0, Duration sailing: 21.09, Duration lossing: 6.53
# Shortest Route: ['MON', 'OSC', 'TENTRB', 'MON'], Total Distance: 138.91, Total Demand: 41.5, Duration sailing: 13.89, Duration lossing: 5.76
# Shortest Route: ['MON', 'OSC', 'TEQTRC', 'MON'], Total Distance: 140.7, Total Demand: 45.0, Duration sailing: 14.07, Duration lossing: 6.25
# Shortest Route: ['MON', 'OSC', 'TRO', 'MON'], Total Distance: 135.02, Total Demand: 29.0, Duration sailing: 13.5, Duration lossing: 4.03
# Shortest Route: ['MON', 'OSE', 'OSOVFB', 'MON'], Total Distance: 153.72, Total Demand: 64.5, Duration sailing: 15.37, Duration lossing: 8.96
# Shortest Route: ['MON', 'OSE', 'OSS', 'MON'], Total Distance: 145.52, Total Demand: 54.0, Duration sailing: 14.55, Duration lossing: 7.5
# Shortest Route: ['MON', 'OSE', 'STASTB', 'MON'], Total Distance: 222.23, Total Demand: 82.75, Duration sailing: 22.22, Duration lossing: 11.49
# Shortest Route: ['MON', 'OSE', 'STC', 'MON'], Total Distance: 218.27, Total Demand: 65.0, Duration sailing: 21.83, Duration lossing: 9.03
# Shortest Route: ['MON', 'OSE', 'TENTRB', 'MON'], Total Distance: 141.58, Total Demand: 59.5, Duration sailing: 14.16, Duration lossing: 8.26
# Shortest Route: ['MON', 'OSE', 'TEQTRC', 'MON'], Total Distance: 144.7, Total Demand: 63.0, Duration sailing: 14.47, Duration lossing: 8.75
# Shortest Route: ['MON', 'OSE', 'TRO', 'MON'], Total Distance: 135.44, Total Demand: 47.0, Duration sailing: 13.54, Duration lossing: 6.53
# Shortest Route: ['MON', 'OSOVFB', 'OSS', 'MON'], Total Distance: 163.82, Total Demand: 46.5, Duration sailing: 16.38, Duration lossing: 6.46
# Shortest Route: ['MON', 'OSOVFB', 'STASTB', 'MON'], Total Distance: 215.31, Total Demand: 75.25, Duration sailing: 21.53, Duration lossing: 10.45
# Shortest Route: ['MON', 'OSOVFB', 'STC', 'MON'], Total Distance: 210.47, Total Demand: 57.5, Duration sailing: 21.05, Duration lossing: 7.99
# Shortest Route: ['MON', 'OSOVFB', 'TENTRB', 'MON'], Total Distance: 136.91, Total Demand: 52.0, Duration sailing: 13.69, Duration lossing: 7.22
# Shortest Route: ['MON', 'OSOVFB', 'TEQTRC', 'MON'], Total Distance: 136.9, Total Demand: 55.5, Duration sailing: 13.69, Duration lossing: 7.71
# Shortest Route: ['MON', 'OSOVFB', 'TRO', 'MON'], Total Distance: 135.17, Total Demand: 39.5, Duration sailing: 13.52, Duration lossing: 5.49
# Shortest Route: ['MON', 'OSS', 'STASTB', 'MON'], Total Distance: 230.69, Total Demand: 64.75, Duration sailing: 23.07, Duration lossing: 8.99
# Shortest Route: ['MON', 'OSS', 'STC', 'MON'], Total Distance: 227.0, Total Demand: 47.0, Duration sailing: 22.7, Duration lossing: 6.53
# Shortest Route: ['MON', 'OSS', 'TENTRB', 'MON'], Total Distance: 150.28, Total Demand: 41.5, Duration sailing: 15.03, Duration lossing: 5.76
# Shortest Route: ['MON', 'OSS', 'TEQTRC', 'MON'], Total Distance: 153.9, Total Demand: 45.0, Duration sailing: 15.39, Duration lossing: 6.25
# Shortest Route: ['MON', 'OSS', 'TRO', 'MON'], Total Distance: 142.68, Total Demand: 29.0, Duration sailing: 14.27, Duration lossing: 4.03
# Shortest Route: ['MON', 'STASTB', 'STC', 'MON'], Total Distance: 201.37, Total Demand: 75.75, Duration sailing: 20.14, Duration lossing: 10.52
# Shortest Route: ['MON', 'STASTB', 'TENTRB', 'MON'], Total Distance: 206.97, Total Demand: 70.25, Duration sailing: 20.7, Duration lossing: 9.76
# Shortest Route: ['MON', 'STASTB', 'TEQTRC', 'MON'], Total Distance: 201.57, Total Demand: 73.75, Duration sailing: 20.16, Duration lossing: 10.24
# Shortest Route: ['MON', 'STASTB', 'TRO', 'MON'], Total Distance: 206.87, Total Demand: 57.75, Duration sailing: 20.69, Duration lossing: 8.02
# Shortest Route: ['MON', 'STC', 'TENTRB', 'MON'], Total Distance: 201.17, Total Demand: 52.5, Duration sailing: 20.12, Duration lossing: 7.29
# Shortest Route: ['MON', 'STC', 'TEQTRC', 'MON'], Total Distance: 195.17, Total Demand: 56.0, Duration sailing: 19.52, Duration lossing: 7.78
# Shortest Route: ['MON', 'STC', 'TRO', 'MON'], Total Distance: 201.19, Total Demand: 40.0, Duration sailing: 20.12, Duration lossing: 5.56
# Shortest Route: ['MON', 'TENTRB', 'TEQTRC', 'MON'], Total Distance: 101.84, Total Demand: 50.5, Duration sailing: 10.18, Duration lossing: 7.01
# Shortest Route: ['MON', 'TENTRB', 'TRO', 'MON'], Total Distance: 97.45, Total Demand: 34.5, Duration sailing: 9.75, Duration lossing: 4.79
# Shortest Route: ['MON', 'TEQTRC', 'TRO', 'MON'], Total Distance: 99.86, Total Demand: 38.0, Duration sailing: 9.99, Duration lossing: 5.28
# Shortest Route: ['MON', 'APT', 'ASL', 'DAB', 'MON'], Total Distance: 224.32, Total Demand: 83.0, Duration sailing: 22.43, Duration lossing: 11.53
# Shortest Route: ['MON', 'APT', 'ASL', 'DSA', 'MON'], Total Distance: 246.32, Total Demand: 72.0, Duration sailing: 24.63, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'ASL', 'DSS', 'MON'], Total Distance: 252.61, Total Demand: 72.0, Duration sailing: 25.26, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'ASL', 'KVB', 'MON'], Total Distance: 217.45, Total Demand: 57.0, Duration sailing: 21.74, Duration lossing: 7.92
# Shortest Route: ['MON', 'APT', 'ASL', 'MID', 'MON'], Total Distance: 252.26, Total Demand: 57.0, Duration sailing: 25.23, Duration lossing: 7.92
# Shortest Route: ['MON', 'APT', 'ASL', 'NLNVAL', 'MON'], Total Distance: 219.25, Total Demand: 71.67, Duration sailing: 21.92, Duration lossing: 9.95
# Shortest Route: ['MON', 'APT', 'ASL', 'OSC', 'MON'], Total Distance: 230.53, Total Demand: 61.0, Duration sailing: 23.05, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'ASL', 'OSE', 'MON'], Total Distance: 237.58, Total Demand: 79.0, Duration sailing: 23.76, Duration lossing: 10.97
# Shortest Route: ['MON', 'APT', 'ASL', 'OSOVFB', 'MON'], Total Distance: 231.44, Total Demand: 71.5, Duration sailing: 23.14, Duration lossing: 9.93
# Shortest Route: ['MON', 'APT', 'ASL', 'OSS', 'MON'], Total Distance: 245.97, Total Demand: 61.0, Duration sailing: 24.6, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'ASL', 'STASTB', 'MON'], Total Distance: 239.51, Total Demand: 89.75, Duration sailing: 23.95, Duration lossing: 12.47
# Shortest Route: ['MON', 'APT', 'ASL', 'STC', 'MON'], Total Distance: 236.29, Total Demand: 72.0, Duration sailing: 23.63, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'ASL', 'TENTRB', 'MON'], Total Distance: 224.26, Total Demand: 66.5, Duration sailing: 22.43, Duration lossing: 9.24
# Shortest Route: ['MON', 'APT', 'ASL', 'TEQTRC', 'MON'], Total Distance: 219.89, Total Demand: 70.0, Duration sailing: 21.99, Duration lossing: 9.72
# Shortest Route: ['MON', 'APT', 'ASL', 'TRO', 'MON'], Total Distance: 223.89, Total Demand: 54.0, Duration sailing: 22.39, Duration lossing: 7.5
# Shortest Route: ['MON', 'APT', 'DAB', 'DSA', 'MON'], Total Distance: 276.41, Total Demand: 87.0, Duration sailing: 27.64, Duration lossing: 12.08
# Shortest Route: ['MON', 'APT', 'DAB', 'DSS', 'MON'], Total Distance: 270.93, Total Demand: 87.0, Duration sailing: 27.09, Duration lossing: 12.08
# Shortest Route: ['MON', 'APT', 'DAB', 'KVB', 'MON'], Total Distance: 239.82, Total Demand: 72.0, Duration sailing: 23.98, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'DAB', 'MID', 'MON'], Total Distance: 288.05, Total Demand: 72.0, Duration sailing: 28.8, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'DAB', 'NLNVAL', 'MON'], Total Distance: 250.58, Total Demand: 86.67, Duration sailing: 25.06, Duration lossing: 12.04
# Shortest Route: ['MON', 'APT', 'DAB', 'OSC', 'MON'], Total Distance: 247.15, Total Demand: 76.0, Duration sailing: 24.71, Duration lossing: 10.56
# Shortest Route: ['MON', 'APT', 'DAB', 'OSE', 'MON'], Total Distance: 253.77, Total Demand: 94.0, Duration sailing: 25.38, Duration lossing: 13.06
# Shortest Route: ['MON', 'APT', 'DAB', 'OSOVFB', 'MON'], Total Distance: 241.9, Total Demand: 86.5, Duration sailing: 24.19, Duration lossing: 12.01
# Shortest Route: ['MON', 'APT', 'DAB', 'OSS', 'MON'], Total Distance: 263.81, Total Demand: 76.0, Duration sailing: 26.38, Duration lossing: 10.56
# Shortest Route: ['MON', 'APT', 'DAB', 'STC', 'MON'], Total Distance: 274.45, Total Demand: 87.0, Duration sailing: 27.44, Duration lossing: 12.08
# Shortest Route: ['MON', 'APT', 'DAB', 'TENTRB', 'MON'], Total Distance: 217.08, Total Demand: 81.5, Duration sailing: 21.71, Duration lossing: 11.32
# Shortest Route: ['MON', 'APT', 'DAB', 'TEQTRC', 'MON'], Total Distance: 206.24, Total Demand: 85.0, Duration sailing: 20.62, Duration lossing: 11.81
# Shortest Route: ['MON', 'APT', 'DAB', 'TRO', 'MON'], Total Distance: 215.79, Total Demand: 69.0, Duration sailing: 21.58, Duration lossing: 9.58
# Shortest Route: ['MON', 'APT', 'DSA', 'DSS', 'MON'], Total Distance: 253.51, Total Demand: 76.0, Duration sailing: 25.35, Duration lossing: 10.56
# Shortest Route: ['MON', 'APT', 'DSA', 'KVB', 'MON'], Total Distance: 250.33, Total Demand: 61.0, Duration sailing: 25.03, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'DSA', 'MID', 'MON'], Total Distance: 294.65, Total Demand: 61.0, Duration sailing: 29.47, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'DSA', 'NLNVAL', 'MON'], Total Distance: 256.15, Total Demand: 75.67, Duration sailing: 25.62, Duration lossing: 10.51
# Shortest Route: ['MON', 'APT', 'DSA', 'OSC', 'MON'], Total Distance: 270.51, Total Demand: 65.0, Duration sailing: 27.05, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'DSA', 'OSE', 'MON'], Total Distance: 278.05, Total Demand: 83.0, Duration sailing: 27.8, Duration lossing: 11.53
# Shortest Route: ['MON', 'APT', 'DSA', 'OSOVFB', 'MON'], Total Distance: 269.24, Total Demand: 75.5, Duration sailing: 26.92, Duration lossing: 10.49
# Shortest Route: ['MON', 'APT', 'DSA', 'OSS', 'MON'], Total Distance: 287.07, Total Demand: 65.0, Duration sailing: 28.71, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'DSA', 'STASTB', 'MON'], Total Distance: 262.38, Total Demand: 93.75, Duration sailing: 26.24, Duration lossing: 13.02
# Shortest Route: ['MON', 'APT', 'DSA', 'STC', 'MON'], Total Distance: 251.94, Total Demand: 76.0, Duration sailing: 25.19, Duration lossing: 10.56
# Shortest Route: ['MON', 'APT', 'DSA', 'TENTRB', 'MON'], Total Distance: 258.37, Total Demand: 70.5, Duration sailing: 25.84, Duration lossing: 9.79
# Shortest Route: ['MON', 'APT', 'DSA', 'TEQTRC', 'MON'], Total Distance: 251.41, Total Demand: 74.0, Duration sailing: 25.14, Duration lossing: 10.28
# Shortest Route: ['MON', 'APT', 'DSA', 'TRO', 'MON'], Total Distance: 258.49, Total Demand: 58.0, Duration sailing: 25.85, Duration lossing: 8.06
# Shortest Route: ['MON', 'APT', 'DSS', 'KVB', 'MON'], Total Distance: 260.98, Total Demand: 61.0, Duration sailing: 26.1, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'DSS', 'MID', 'MON'], Total Distance: 309.34, Total Demand: 61.0, Duration sailing: 30.93, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'DSS', 'NLNVAL', 'MON'], Total Distance: 268.34, Total Demand: 75.67, Duration sailing: 26.83, Duration lossing: 10.51
# Shortest Route: ['MON', 'APT', 'DSS', 'OSC', 'MON'], Total Distance: 282.13, Total Demand: 65.0, Duration sailing: 28.21, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'DSS', 'OSE', 'MON'], Total Distance: 289.85, Total Demand: 83.0, Duration sailing: 28.98, Duration lossing: 11.53
# Shortest Route: ['MON', 'APT', 'DSS', 'OSOVFB', 'MON'], Total Distance: 279.68, Total Demand: 75.5, Duration sailing: 27.97, Duration lossing: 10.49
# Shortest Route: ['MON', 'APT', 'DSS', 'OSS', 'MON'], Total Distance: 299.29, Total Demand: 65.0, Duration sailing: 29.93, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'DSS', 'STASTB', 'MON'], Total Distance: 278.62, Total Demand: 93.75, Duration sailing: 27.86, Duration lossing: 13.02
# Shortest Route: ['MON', 'APT', 'DSS', 'STC', 'MON'], Total Distance: 268.01, Total Demand: 76.0, Duration sailing: 26.8, Duration lossing: 10.56
# Shortest Route: ['MON', 'APT', 'DSS', 'TENTRB', 'MON'], Total Distance: 266.29, Total Demand: 70.5, Duration sailing: 26.63, Duration lossing: 9.79
# Shortest Route: ['MON', 'APT', 'DSS', 'TEQTRC', 'MON'], Total Distance: 258.13, Total Demand: 74.0, Duration sailing: 25.81, Duration lossing: 10.28
# Shortest Route: ['MON', 'APT', 'DSS', 'TRO', 'MON'], Total Distance: 266.38, Total Demand: 58.0, Duration sailing: 26.64, Duration lossing: 8.06
# Shortest Route: ['MON', 'APT', 'GFAGFBGFC', 'KVB', 'MON'], Total Distance: 224.89, Total Demand: 99.25, Duration sailing: 22.49, Duration lossing: 13.79
# Shortest Route: ['MON', 'APT', 'GFAGFBGFC', 'MID', 'MON'], Total Distance: 271.29, Total Demand: 99.25, Duration sailing: 27.13, Duration lossing: 13.79
# Shortest Route: ['MON', 'APT', 'GFAGFBGFC', 'TRO', 'MON'], Total Distance: 233.7, Total Demand: 96.25, Duration sailing: 23.37, Duration lossing: 13.37
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'MON'], Total Distance: 251.68, Total Demand: 46.0, Duration sailing: 25.17, Duration lossing: 6.39
# Shortest Route: ['MON', 'APT', 'KVB', 'NLNVAL', 'MON'], Total Distance: 209.81, Total Demand: 60.67, Duration sailing: 20.98, Duration lossing: 8.43
# Shortest Route: ['MON', 'APT', 'KVB', 'OSC', 'MON'], Total Distance: 220.17, Total Demand: 50.0, Duration sailing: 22.02, Duration lossing: 6.95
# Shortest Route: ['MON', 'APT', 'KVB', 'OSE', 'MON'], Total Distance: 227.91, Total Demand: 68.0, Duration sailing: 22.79, Duration lossing: 9.45
# Shortest Route: ['MON', 'APT', 'KVB', 'OSOVFB', 'MON'], Total Distance: 218.01, Total Demand: 60.5, Duration sailing: 21.8, Duration lossing: 8.4
# Shortest Route: ['MON', 'APT', 'KVB', 'OSS', 'MON'], Total Distance: 237.46, Total Demand: 50.0, Duration sailing: 23.75, Duration lossing: 6.95
# Shortest Route: ['MON', 'APT', 'KVB', 'STASTB', 'MON'], Total Distance: 246.28, Total Demand: 78.75, Duration sailing: 24.63, Duration lossing: 10.94
# Shortest Route: ['MON', 'APT', 'KVB', 'STC', 'MON'], Total Distance: 240.32, Total Demand: 61.0, Duration sailing: 24.03, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'KVB', 'TENTRB', 'MON'], Total Distance: 207.83, Total Demand: 55.5, Duration sailing: 20.78, Duration lossing: 7.71
# Shortest Route: ['MON', 'APT', 'KVB', 'TEQTRC', 'MON'], Total Distance: 202.28, Total Demand: 59.0, Duration sailing: 20.23, Duration lossing: 8.2
# Shortest Route: ['MON', 'APT', 'KVB', 'TRO', 'MON'], Total Distance: 207.84, Total Demand: 43.0, Duration sailing: 20.78, Duration lossing: 5.97
# Shortest Route: ['MON', 'APT', 'MID', 'NLNVAL', 'MON'], Total Distance: 215.52, Total Demand: 60.67, Duration sailing: 21.55, Duration lossing: 8.43
# Shortest Route: ['MON', 'APT', 'MID', 'OSC', 'MON'], Total Distance: 191.29, Total Demand: 50.0, Duration sailing: 19.13, Duration lossing: 6.95
# Shortest Route: ['MON', 'APT', 'MID', 'OSE', 'MON'], Total Distance: 192.27, Total Demand: 68.0, Duration sailing: 19.23, Duration lossing: 9.45
# Shortest Route: ['MON', 'APT', 'MID', 'OSOVFB', 'MON'], Total Distance: 201.43, Total Demand: 60.5, Duration sailing: 20.14, Duration lossing: 8.4
# Shortest Route: ['MON', 'APT', 'MID', 'OSS', 'MON'], Total Distance: 195.62, Total Demand: 50.0, Duration sailing: 19.56, Duration lossing: 6.95
# Shortest Route: ['MON', 'APT', 'MID', 'STASTB', 'MON'], Total Distance: 246.12, Total Demand: 78.75, Duration sailing: 24.61, Duration lossing: 10.94
# Shortest Route: ['MON', 'APT', 'MID', 'STC', 'MON'], Total Distance: 243.54, Total Demand: 61.0, Duration sailing: 24.35, Duration lossing: 8.47
# Shortest Route: ['MON', 'APT', 'MID', 'TENTRB', 'MON'], Total Distance: 195.54, Total Demand: 55.5, Duration sailing: 19.55, Duration lossing: 7.71
# Shortest Route: ['MON', 'APT', 'MID', 'TEQTRC', 'MON'], Total Distance: 196.7, Total Demand: 59.0, Duration sailing: 19.67, Duration lossing: 8.2
# Shortest Route: ['MON', 'APT', 'MID', 'TRO', 'MON'], Total Distance: 191.42, Total Demand: 43.0, Duration sailing: 19.14, Duration lossing: 5.97
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'OSC', 'MON'], Total Distance: 219.56, Total Demand: 64.67, Duration sailing: 21.96, Duration lossing: 8.98
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'OSE', 'MON'], Total Distance: 227.13, Total Demand: 82.67, Duration sailing: 22.71, Duration lossing: 11.48
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'OSOVFB', 'MON'], Total Distance: 218.76, Total Demand: 75.17, Duration sailing: 21.88, Duration lossing: 10.44
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'OSS', 'MON'], Total Distance: 236.31, Total Demand: 64.67, Duration sailing: 23.63, Duration lossing: 8.98
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'STASTB', 'MON'], Total Distance: 244.42, Total Demand: 93.42, Duration sailing: 24.44, Duration lossing: 12.98
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'STC', 'MON'], Total Distance: 239.44, Total Demand: 75.67, Duration sailing: 23.94, Duration lossing: 10.51
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'TENTRB', 'MON'], Total Distance: 210.48, Total Demand: 70.17, Duration sailing: 21.05, Duration lossing: 9.75
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'TEQTRC', 'MON'], Total Distance: 205.85, Total Demand: 73.67, Duration sailing: 20.58, Duration lossing: 10.23
# Shortest Route: ['MON', 'APT', 'NLNVAL', 'TRO', 'MON'], Total Distance: 210.28, Total Demand: 57.67, Duration sailing: 21.03, Duration lossing: 8.01
# Shortest Route: ['MON', 'APT', 'OSC', 'OSE', 'MON'], Total Distance: 169.63, Total Demand: 72.0, Duration sailing: 16.96, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'OSC', 'OSOVFB', 'MON'], Total Distance: 174.12, Total Demand: 64.5, Duration sailing: 17.41, Duration lossing: 8.96
# Shortest Route: ['MON', 'APT', 'OSC', 'OSS', 'MON'], Total Distance: 179.48, Total Demand: 54.0, Duration sailing: 17.95, Duration lossing: 7.5
# Shortest Route: ['MON', 'APT', 'OSC', 'STASTB', 'MON'], Total Distance: 242.32, Total Demand: 82.75, Duration sailing: 24.23, Duration lossing: 11.49
# Shortest Route: ['MON', 'APT', 'OSC', 'STC', 'MON'], Total Distance: 238.17, Total Demand: 65.0, Duration sailing: 23.82, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'OSC', 'TENTRB', 'MON'], Total Distance: 166.17, Total Demand: 59.5, Duration sailing: 16.62, Duration lossing: 8.26
# Shortest Route: ['MON', 'APT', 'OSC', 'TEQTRC', 'MON'], Total Distance: 167.96, Total Demand: 63.0, Duration sailing: 16.8, Duration lossing: 8.75
# Shortest Route: ['MON', 'APT', 'OSC', 'TRO', 'MON'], Total Distance: 162.28, Total Demand: 47.0, Duration sailing: 16.23, Duration lossing: 6.53
# Shortest Route: ['MON', 'APT', 'OSE', 'OSOVFB', 'MON'], Total Distance: 173.46, Total Demand: 82.5, Duration sailing: 17.35, Duration lossing: 11.46
# Shortest Route: ['MON', 'APT', 'OSE', 'OSS', 'MON'], Total Distance: 165.26, Total Demand: 72.0, Duration sailing: 16.53, Duration lossing: 10.0
# Shortest Route: ['MON', 'APT', 'OSE', 'STC', 'MON'], Total Distance: 238.01, Total Demand: 83.0, Duration sailing: 23.8, Duration lossing: 11.53
# Shortest Route: ['MON', 'APT', 'OSE', 'TENTRB', 'MON'], Total Distance: 161.32, Total Demand: 77.5, Duration sailing: 16.13, Duration lossing: 10.76
# Shortest Route: ['MON', 'APT', 'OSE', 'TEQTRC', 'MON'], Total Distance: 164.44, Total Demand: 81.0, Duration sailing: 16.44, Duration lossing: 11.25
# Shortest Route: ['MON', 'APT', 'OSE', 'TRO', 'MON'], Total Distance: 155.18, Total Demand: 65.0, Duration sailing: 15.52, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'OSOVFB', 'OSS', 'MON'], Total Distance: 204.23, Total Demand: 64.5, Duration sailing: 20.42, Duration lossing: 8.96
# Shortest Route: ['MON', 'APT', 'OSOVFB', 'STASTB', 'MON'], Total Distance: 255.72, Total Demand: 93.25, Duration sailing: 25.57, Duration lossing: 12.95
# Shortest Route: ['MON', 'APT', 'OSOVFB', 'STC', 'MON'], Total Distance: 250.88, Total Demand: 75.5, Duration sailing: 25.09, Duration lossing: 10.49
# Shortest Route: ['MON', 'APT', 'OSOVFB', 'TENTRB', 'MON'], Total Distance: 177.32, Total Demand: 70.0, Duration sailing: 17.73, Duration lossing: 9.72
# Shortest Route: ['MON', 'APT', 'OSOVFB', 'TEQTRC', 'MON'], Total Distance: 177.31, Total Demand: 73.5, Duration sailing: 17.73, Duration lossing: 10.21
# Shortest Route: ['MON', 'APT', 'OSOVFB', 'TRO', 'MON'], Total Distance: 175.58, Total Demand: 57.5, Duration sailing: 17.56, Duration lossing: 7.99
# Shortest Route: ['MON', 'APT', 'OSS', 'STASTB', 'MON'], Total Distance: 240.36, Total Demand: 82.75, Duration sailing: 24.04, Duration lossing: 11.49
# Shortest Route: ['MON', 'APT', 'OSS', 'STC', 'MON'], Total Distance: 236.67, Total Demand: 65.0, Duration sailing: 23.67, Duration lossing: 9.03
# Shortest Route: ['MON', 'APT', 'OSS', 'TENTRB', 'MON'], Total Distance: 159.95, Total Demand: 59.5, Duration sailing: 16.0, Duration lossing: 8.26
# Shortest Route: ['MON', 'APT', 'OSS', 'TEQTRC', 'MON'], Total Distance: 163.57, Total Demand: 63.0, Duration sailing: 16.36, Duration lossing: 8.75
# Shortest Route: ['MON', 'APT', 'OSS', 'TRO', 'MON'], Total Distance: 152.35, Total Demand: 47.0, Duration sailing: 15.24, Duration lossing: 6.53
# Shortest Route: ['MON', 'APT', 'STASTB', 'STC', 'MON'], Total Distance: 243.02, Total Demand: 93.75, Duration sailing: 24.3, Duration lossing: 13.02
# Shortest Route: ['MON', 'APT', 'STASTB', 'TENTRB', 'MON'], Total Distance: 248.62, Total Demand: 88.25, Duration sailing: 24.86, Duration lossing: 12.26
# Shortest Route: ['MON', 'APT', 'STASTB', 'TEQTRC', 'MON'], Total Distance: 243.22, Total Demand: 91.75, Duration sailing: 24.32, Duration lossing: 12.74
# Shortest Route: ['MON', 'APT', 'STASTB', 'TRO', 'MON'], Total Distance: 248.52, Total Demand: 75.75, Duration sailing: 24.85, Duration lossing: 10.52
# Shortest Route: ['MON', 'APT', 'STC', 'TENTRB', 'MON'], Total Distance: 246.4, Total Demand: 70.5, Duration sailing: 24.64, Duration lossing: 9.79
# Shortest Route: ['MON', 'APT', 'STC', 'TEQTRC', 'MON'], Total Distance: 240.4, Total Demand: 74.0, Duration sailing: 24.04, Duration lossing: 10.28
# Shortest Route: ['MON', 'APT', 'STC', 'TRO', 'MON'], Total Distance: 246.42, Total Demand: 58.0, Duration sailing: 24.64, Duration lossing: 8.06
# Shortest Route: ['MON', 'APT', 'TENTRB', 'TEQTRC', 'MON'], Total Distance: 166.92, Total Demand: 68.5, Duration sailing: 16.69, Duration lossing: 9.51
# Shortest Route: ['MON', 'APT', 'TENTRB', 'TRO', 'MON'], Total Distance: 162.53, Total Demand: 52.5, Duration sailing: 16.25, Duration lossing: 7.29
# Shortest Route: ['MON', 'APT', 'TEQTRC', 'TRO', 'MON'], Total Distance: 174.47, Total Demand: 56.0, Duration sailing: 17.45, Duration lossing: 7.78
# Shortest Route: ['MON', 'ASL', 'DAB', 'DSA', 'MON'], Total Distance: 270.95, Total Demand: 94.0, Duration sailing: 27.1, Duration lossing: 13.06
# Shortest Route: ['MON', 'ASL', 'DAB', 'DSS', 'MON'], Total Distance: 265.47, Total Demand: 94.0, Duration sailing: 26.55, Duration lossing: 13.06
# Shortest Route: ['MON', 'ASL', 'DAB', 'KVB', 'MON'], Total Distance: 234.36, Total Demand: 79.0, Duration sailing: 23.44, Duration lossing: 10.97
# Shortest Route: ['MON', 'ASL', 'DAB', 'MID', 'MON'], Total Distance: 282.59, Total Demand: 79.0, Duration sailing: 28.26, Duration lossing: 10.97
# Shortest Route: ['MON', 'ASL', 'DAB', 'NLNVAL', 'MON'], Total Distance: 245.12, Total Demand: 93.67, Duration sailing: 24.51, Duration lossing: 13.01
# Shortest Route: ['MON', 'ASL', 'DAB', 'OSC', 'MON'], Total Distance: 241.69, Total Demand: 83.0, Duration sailing: 24.17, Duration lossing: 11.53
# Shortest Route: ['MON', 'ASL', 'DAB', 'OSOVFB', 'MON'], Total Distance: 236.44, Total Demand: 93.5, Duration sailing: 23.64, Duration lossing: 12.99
# Shortest Route: ['MON', 'ASL', 'DAB', 'OSS', 'MON'], Total Distance: 258.35, Total Demand: 83.0, Duration sailing: 25.84, Duration lossing: 11.53
# Shortest Route: ['MON', 'ASL', 'DAB', 'STC', 'MON'], Total Distance: 268.99, Total Demand: 94.0, Duration sailing: 26.9, Duration lossing: 13.06
# Shortest Route: ['MON', 'ASL', 'DAB', 'TENTRB', 'MON'], Total Distance: 211.62, Total Demand: 88.5, Duration sailing: 21.16, Duration lossing: 12.29
# Shortest Route: ['MON', 'ASL', 'DAB', 'TEQTRC', 'MON'], Total Distance: 200.78, Total Demand: 92.0, Duration sailing: 20.08, Duration lossing: 12.78
# Shortest Route: ['MON', 'ASL', 'DAB', 'TRO', 'MON'], Total Distance: 210.33, Total Demand: 76.0, Duration sailing: 21.03, Duration lossing: 10.56
# Shortest Route: ['MON', 'ASL', 'DSA', 'DSS', 'MON'], Total Distance: 216.85, Total Demand: 83.0, Duration sailing: 21.68, Duration lossing: 11.53
# Shortest Route: ['MON', 'ASL', 'DSA', 'KVB', 'MON'], Total Distance: 213.67, Total Demand: 68.0, Duration sailing: 21.37, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'DSA', 'MID', 'MON'], Total Distance: 257.99, Total Demand: 68.0, Duration sailing: 25.8, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'DSA', 'NLNVAL', 'MON'], Total Distance: 219.49, Total Demand: 82.67, Duration sailing: 21.95, Duration lossing: 11.48
# Shortest Route: ['MON', 'ASL', 'DSA', 'OSC', 'MON'], Total Distance: 233.85, Total Demand: 72.0, Duration sailing: 23.38, Duration lossing: 10.0
# Shortest Route: ['MON', 'ASL', 'DSA', 'OSE', 'MON'], Total Distance: 241.39, Total Demand: 90.0, Duration sailing: 24.14, Duration lossing: 12.5
# Shortest Route: ['MON', 'ASL', 'DSA', 'OSOVFB', 'MON'], Total Distance: 232.58, Total Demand: 82.5, Duration sailing: 23.26, Duration lossing: 11.46
# Shortest Route: ['MON', 'ASL', 'DSA', 'OSS', 'MON'], Total Distance: 250.41, Total Demand: 72.0, Duration sailing: 25.04, Duration lossing: 10.0
# Shortest Route: ['MON', 'ASL', 'DSA', 'STC', 'MON'], Total Distance: 215.28, Total Demand: 83.0, Duration sailing: 21.53, Duration lossing: 11.53
# Shortest Route: ['MON', 'ASL', 'DSA', 'TENTRB', 'MON'], Total Distance: 221.71, Total Demand: 77.5, Duration sailing: 22.17, Duration lossing: 10.76
# Shortest Route: ['MON', 'ASL', 'DSA', 'TEQTRC', 'MON'], Total Distance: 214.75, Total Demand: 81.0, Duration sailing: 21.48, Duration lossing: 11.25
# Shortest Route: ['MON', 'ASL', 'DSA', 'TRO', 'MON'], Total Distance: 221.83, Total Demand: 65.0, Duration sailing: 22.18, Duration lossing: 9.03
# Shortest Route: ['MON', 'ASL', 'DSS', 'KVB', 'MON'], Total Distance: 226.7, Total Demand: 68.0, Duration sailing: 22.67, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'DSS', 'MID', 'MON'], Total Distance: 275.06, Total Demand: 68.0, Duration sailing: 27.51, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'DSS', 'NLNVAL', 'MON'], Total Distance: 234.06, Total Demand: 82.67, Duration sailing: 23.41, Duration lossing: 11.48
# Shortest Route: ['MON', 'ASL', 'DSS', 'OSC', 'MON'], Total Distance: 247.85, Total Demand: 72.0, Duration sailing: 24.78, Duration lossing: 10.0
# Shortest Route: ['MON', 'ASL', 'DSS', 'OSE', 'MON'], Total Distance: 255.57, Total Demand: 90.0, Duration sailing: 25.56, Duration lossing: 12.5
# Shortest Route: ['MON', 'ASL', 'DSS', 'OSOVFB', 'MON'], Total Distance: 245.4, Total Demand: 82.5, Duration sailing: 24.54, Duration lossing: 11.46
# Shortest Route: ['MON', 'ASL', 'DSS', 'OSS', 'MON'], Total Distance: 265.01, Total Demand: 72.0, Duration sailing: 26.5, Duration lossing: 10.0
# Shortest Route: ['MON', 'ASL', 'DSS', 'STC', 'MON'], Total Distance: 233.73, Total Demand: 83.0, Duration sailing: 23.37, Duration lossing: 11.53
# Shortest Route: ['MON', 'ASL', 'DSS', 'TENTRB', 'MON'], Total Distance: 232.01, Total Demand: 77.5, Duration sailing: 23.2, Duration lossing: 10.76
# Shortest Route: ['MON', 'ASL', 'DSS', 'TEQTRC', 'MON'], Total Distance: 223.85, Total Demand: 81.0, Duration sailing: 22.38, Duration lossing: 11.25
# Shortest Route: ['MON', 'ASL', 'DSS', 'TRO', 'MON'], Total Distance: 232.1, Total Demand: 65.0, Duration sailing: 23.21, Duration lossing: 9.03
# Shortest Route: ['MON', 'ASL', 'KVB', 'MID', 'MON'], Total Distance: 232.47, Total Demand: 53.0, Duration sailing: 23.25, Duration lossing: 7.36
# Shortest Route: ['MON', 'ASL', 'KVB', 'NLNVAL', 'MON'], Total Distance: 190.6, Total Demand: 67.67, Duration sailing: 19.06, Duration lossing: 9.4
# Shortest Route: ['MON', 'ASL', 'KVB', 'OSC', 'MON'], Total Distance: 200.96, Total Demand: 57.0, Duration sailing: 20.1, Duration lossing: 7.92
# Shortest Route: ['MON', 'ASL', 'KVB', 'OSE', 'MON'], Total Distance: 208.7, Total Demand: 75.0, Duration sailing: 20.87, Duration lossing: 10.42
# Shortest Route: ['MON', 'ASL', 'KVB', 'OSOVFB', 'MON'], Total Distance: 198.8, Total Demand: 67.5, Duration sailing: 19.88, Duration lossing: 9.38
# Shortest Route: ['MON', 'ASL', 'KVB', 'OSS', 'MON'], Total Distance: 218.25, Total Demand: 57.0, Duration sailing: 21.82, Duration lossing: 7.92
# Shortest Route: ['MON', 'ASL', 'KVB', 'STASTB', 'MON'], Total Distance: 227.07, Total Demand: 85.75, Duration sailing: 22.71, Duration lossing: 11.91
# Shortest Route: ['MON', 'ASL', 'KVB', 'STC', 'MON'], Total Distance: 221.11, Total Demand: 68.0, Duration sailing: 22.11, Duration lossing: 9.45
# Shortest Route: ['MON', 'ASL', 'KVB', 'TENTRB', 'MON'], Total Distance: 188.62, Total Demand: 62.5, Duration sailing: 18.86, Duration lossing: 8.68
# Shortest Route: ['MON', 'ASL', 'KVB', 'TEQTRC', 'MON'], Total Distance: 183.07, Total Demand: 66.0, Duration sailing: 18.31, Duration lossing: 9.17
# ...
# Shortest Route: ['MON', 'DSS', 'KVB', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 252.0, Total Demand: 95.5, Duration sailing: 25.2, Duration lossing: 13.26
# Shortest Route: ['MON', 'DSS', 'KVB', 'OSS', 'TEQTRC', 'TRO', 'MON'], Total Distance: 263.59, Total Demand: 99.0, Duration sailing: 26.36, Duration lossing: 13.75
# Shortest Route: ['MON', 'DSS', 'MID', 'OSC', 'OSS', 'TRO', 'MON'], Total Distance: 268.01, Total Demand: 90.0, Duration sailing: 26.8, Duration lossing: 12.5
# Shortest Route: ['MON', 'DSS', 'MID', 'OSC', 'TENTRB', 'TRO', 'MON'], Total Distance: 258.17, Total Demand: 95.5, Duration sailing: 25.82, Duration lossing: 13.26
# Shortest Route: ['MON', 'DSS', 'MID', 'OSC', 'TEQTRC', 'TRO', 'MON'], Total Distance: 267.93, Total Demand: 99.0, Duration sailing: 26.79, Duration lossing: 13.75
# Shortest Route: ['MON', 'DSS', 'MID', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 266.29, Total Demand: 95.5, Duration sailing: 26.63, Duration lossing: 13.26
# Shortest Route: ['MON', 'DSS', 'MID', 'OSS', 'TEQTRC', 'TRO', 'MON'], Total Distance: 277.88, Total Demand: 99.0, Duration sailing: 27.79, Duration lossing: 13.75
# Shortest Route: ['MON', 'DSS', 'OSC', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 252.3, Total Demand: 99.5, Duration sailing: 25.23, Duration lossing: 13.82
# Shortest Route: ['MON', 'KVB', 'MID', 'NLNVAL', 'OSC', 'OSS', 'MON'], Total Distance: 262.08, Total Demand: 92.67, Duration sailing: 26.21, Duration lossing: 12.87
# Shortest Route: ['MON', 'KVB', 'MID', 'NLNVAL', 'OSC', 'TENTRB', 'MON'], Total Distance: 248.77, Total Demand: 98.17, Duration sailing: 24.88, Duration lossing: 13.64
# Shortest Route: ['MON', 'KVB', 'MID', 'NLNVAL', 'OSC', 'TRO', 'MON'], Total Distance: 244.88, Total Demand: 85.67, Duration sailing: 24.49, Duration lossing: 11.9
# Shortest Route: ['MON', 'KVB', 'MID', 'NLNVAL', 'OSOVFB', 'TRO', 'MON'], Total Distance: 245.81, Total Demand: 96.17, Duration sailing: 24.58, Duration lossing: 13.36
# Shortest Route: ['MON', 'KVB', 'MID', 'NLNVAL', 'OSS', 'TENTRB', 'MON'], Total Distance: 269.31, Total Demand: 98.17, Duration sailing: 26.93, Duration lossing: 13.64
# Shortest Route: ['MON', 'KVB', 'MID', 'NLNVAL', 'OSS', 'TRO', 'MON'], Total Distance: 261.71, Total Demand: 85.67, Duration sailing: 26.17, Duration lossing: 11.9
# Shortest Route: ['MON', 'KVB', 'MID', 'NLNVAL', 'STC', 'TRO', 'MON'], Total Distance: 274.79, Total Demand: 96.67, Duration sailing: 27.48, Duration lossing: 13.43
# Shortest Route: ['MON', 'KVB', 'MID', 'NLNVAL', 'TENTRB', 'TRO', 'MON'], Total Distance: 239.35, Total Demand: 91.17, Duration sailing: 23.94, Duration lossing: 12.66
# Shortest Route: ['MON', 'KVB', 'MID', 'NLNVAL', 'TEQTRC', 'TRO', 'MON'], Total Distance: 242.69, Total Demand: 94.67, Duration sailing: 24.27, Duration lossing: 13.15
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSE', 'OSS', 'MON'], Total Distance: 221.63, Total Demand: 100.0, Duration sailing: 22.16, Duration lossing: 13.89
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSE', 'TRO', 'MON'], Total Distance: 211.55, Total Demand: 93.0, Duration sailing: 21.15, Duration lossing: 12.92
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSOVFB', 'OSS', 'MON'], Total Distance: 246.8, Total Demand: 92.5, Duration sailing: 24.68, Duration lossing: 12.85
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSOVFB', 'TENTRB', 'MON'], Total Distance: 219.89, Total Demand: 98.0, Duration sailing: 21.99, Duration lossing: 13.61
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSOVFB', 'TRO', 'MON'], Total Distance: 218.15, Total Demand: 85.5, Duration sailing: 21.82, Duration lossing: 11.88
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSS', 'STC', 'MON'], Total Distance: 306.18, Total Demand: 93.0, Duration sailing: 30.62, Duration lossing: 12.92
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSS', 'TENTRB', 'MON'], Total Distance: 229.46, Total Demand: 87.5, Duration sailing: 22.95, Duration lossing: 12.15
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSS', 'TEQTRC', 'MON'], Total Distance: 233.08, Total Demand: 91.0, Duration sailing: 23.31, Duration lossing: 12.64
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSS', 'TRO', 'MON'], Total Distance: 221.86, Total Demand: 75.0, Duration sailing: 22.19, Duration lossing: 10.42
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'STC', 'TENTRB', 'MON'], Total Distance: 290.48, Total Demand: 98.5, Duration sailing: 29.05, Duration lossing: 13.68
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'STC', 'TRO', 'MON'], Total Distance: 290.5, Total Demand: 86.0, Duration sailing: 29.05, Duration lossing: 11.95
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'TENTRB', 'TEQTRC', 'MON'], Total Distance: 216.41, Total Demand: 96.5, Duration sailing: 21.64, Duration lossing: 13.4
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'TENTRB', 'TRO', 'MON'], Total Distance: 212.02, Total Demand: 80.5, Duration sailing: 21.2, Duration lossing: 11.18
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'TEQTRC', 'TRO', 'MON'], Total Distance: 221.78, Total Demand: 84.0, Duration sailing: 22.18, Duration lossing: 11.67
# Shortest Route: ['MON', 'KVB', 'MID', 'OSE', 'OSS', 'TRO', 'MON'], Total Distance: 215.34, Total Demand: 93.0, Duration sailing: 21.53, Duration lossing: 12.92
# Shortest Route: ['MON', 'KVB', 'MID', 'OSE', 'TENTRB', 'TRO', 'MON'], Total Distance: 214.87, Total Demand: 98.5, Duration sailing: 21.49, Duration lossing: 13.68
# Shortest Route: ['MON', 'KVB', 'MID', 'OSOVFB', 'OSS', 'TENTRB', 'MON'], Total Distance: 252.78, Total Demand: 98.0, Duration sailing: 25.28, Duration lossing: 13.61
# Shortest Route: ['MON', 'KVB', 'MID', 'OSOVFB', 'OSS', 'TRO', 'MON'], Total Distance: 245.18, Total Demand: 85.5, Duration sailing: 24.52, Duration lossing: 11.88
# Shortest Route: ['MON', 'KVB', 'MID', 'OSOVFB', 'STC', 'TRO', 'MON'], Total Distance: 301.78, Total Demand: 96.5, Duration sailing: 30.18, Duration lossing: 13.4
# Shortest Route: ['MON', 'KVB', 'MID', 'OSOVFB', 'TENTRB', 'TRO', 'MON'], Total Distance: 221.74, Total Demand: 91.0, Duration sailing: 22.17, Duration lossing: 12.64
# Shortest Route: ['MON', 'KVB', 'MID', 'OSOVFB', 'TEQTRC', 'TRO', 'MON'], Total Distance: 229.7, Total Demand: 94.5, Duration sailing: 22.97, Duration lossing: 13.13
# Shortest Route: ['MON', 'KVB', 'MID', 'OSS', 'STC', 'TENTRB', 'MON'], Total Distance: 303.32, Total Demand: 98.5, Duration sailing: 30.33, Duration lossing: 13.68
# Shortest Route: ['MON', 'KVB', 'MID', 'OSS', 'STC', 'TRO', 'MON'], Total Distance: 303.34, Total Demand: 86.0, Duration sailing: 30.33, Duration lossing: 11.95
# Shortest Route: ['MON', 'KVB', 'MID', 'OSS', 'TENTRB', 'TEQTRC', 'MON'], Total Distance: 224.53, Total Demand: 96.5, Duration sailing: 22.45, Duration lossing: 13.4
# Shortest Route: ['MON', 'KVB', 'MID', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 220.14, Total Demand: 80.5, Duration sailing: 22.01, Duration lossing: 11.18
# Shortest Route: ['MON', 'KVB', 'MID', 'OSS', 'TEQTRC', 'TRO', 'MON'], Total Distance: 231.73, Total Demand: 84.0, Duration sailing: 23.17, Duration lossing: 11.67
# Shortest Route: ['MON', 'KVB', 'MID', 'STC', 'TENTRB', 'TRO', 'MON'], Total Distance: 270.39, Total Demand: 91.5, Duration sailing: 27.04, Duration lossing: 12.71
# Shortest Route: ['MON', 'KVB', 'MID', 'STC', 'TEQTRC', 'TRO', 'MON'], Total Distance: 272.36, Total Demand: 95.0, Duration sailing: 27.24, Duration lossing: 13.2
# Shortest Route: ['MON', 'KVB', 'MID', 'TENTRB', 'TEQTRC', 'TRO', 'MON'], Total Distance: 228.29, Total Demand: 89.5, Duration sailing: 22.83, Duration lossing: 12.43
# Shortest Route: ['MON', 'KVB', 'NLNVAL', 'OSC', 'OSS', 'TRO', 'MON'], Total Distance: 196.41, Total Demand: 89.67, Duration sailing: 19.64, Duration lossing: 12.46
# Shortest Route: ['MON', 'KVB', 'NLNVAL', 'OSC', 'TENTRB', 'TRO', 'MON'], Total Distance: 186.57, Total Demand: 95.17, Duration sailing: 18.66, Duration lossing: 13.22
# Shortest Route: ['MON', 'KVB', 'NLNVAL', 'OSC', 'TEQTRC', 'TRO', 'MON'], Total Distance: 196.33, Total Demand: 98.67, Duration sailing: 19.63, Duration lossing: 13.71
# Shortest Route: ['MON', 'KVB', 'NLNVAL', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 207.11, Total Demand: 95.17, Duration sailing: 20.71, Duration lossing: 13.22
# Shortest Route: ['MON', 'KVB', 'NLNVAL', 'OSS', 'TEQTRC', 'TRO', 'MON'], Total Distance: 218.7, Total Demand: 98.67, Duration sailing: 21.87, Duration lossing: 13.71
# Shortest Route: ['MON', 'KVB', 'OSC', 'OSE', 'OSS', 'TRO', 'MON'], Total Distance: 190.55, Total Demand: 97.0, Duration sailing: 19.06, Duration lossing: 13.47
# Shortest Route: ['MON', 'KVB', 'OSC', 'OSOVFB', 'OSS', 'TRO', 'MON'], Total Distance: 215.72, Total Demand: 89.5, Duration sailing: 21.57, Duration lossing: 12.43
# Shortest Route: ['MON', 'KVB', 'OSC', 'OSOVFB', 'TENTRB', 'TRO', 'MON'], Total Distance: 192.28, Total Demand: 95.0, Duration sailing: 19.23, Duration lossing: 13.2
# Shortest Route: ['MON', 'KVB', 'OSC', 'OSOVFB', 'TEQTRC', 'TRO', 'MON'], Total Distance: 200.24, Total Demand: 98.5, Duration sailing: 20.02, Duration lossing: 13.68
# Shortest Route: ['MON', 'KVB', 'OSC', 'OSS', 'STC', 'TRO', 'MON'], Total Distance: 285.05, Total Demand: 90.0, Duration sailing: 28.51, Duration lossing: 12.5
# Shortest Route: ['MON', 'KVB', 'OSC', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 201.85, Total Demand: 84.5, Duration sailing: 20.18, Duration lossing: 11.74
# Shortest Route: ['MON', 'KVB', 'OSC', 'OSS', 'TEQTRC', 'TRO', 'MON'], Total Distance: 213.44, Total Demand: 88.0, Duration sailing: 21.34, Duration lossing: 12.22
# Shortest Route: ['MON', 'KVB', 'OSC', 'STC', 'TENTRB', 'TRO', 'MON'], Total Distance: 262.87, Total Demand: 95.5, Duration sailing: 26.29, Duration lossing: 13.26
# Shortest Route: ['MON', 'KVB', 'OSC', 'STC', 'TEQTRC', 'TRO', 'MON'], Total Distance: 264.84, Total Demand: 99.0, Duration sailing: 26.48, Duration lossing: 13.75
# Shortest Route: ['MON', 'KVB', 'OSC', 'TENTRB', 'TEQTRC', 'TRO', 'MON'], Total Distance: 196.77, Total Demand: 93.5, Duration sailing: 19.68, Duration lossing: 12.99
# Shortest Route: ['MON', 'KVB', 'OSOVFB', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 212.87, Total Demand: 95.0, Duration sailing: 21.29, Duration lossing: 13.2
# Shortest Route: ['MON', 'KVB', 'OSOVFB', 'OSS', 'TEQTRC', 'TRO', 'MON'], Total Distance: 224.46, Total Demand: 98.5, Duration sailing: 22.45, Duration lossing: 13.68
# Shortest Route: ['MON', 'KVB', 'OSS', 'STC', 'TENTRB', 'TRO', 'MON'], Total Distance: 288.67, Total Demand: 95.5, Duration sailing: 28.87, Duration lossing: 13.26
# Shortest Route: ['MON', 'KVB', 'OSS', 'STC', 'TEQTRC', 'TRO', 'MON'], Total Distance: 290.64, Total Demand: 99.0, Duration sailing: 29.06, Duration lossing: 13.75
# Shortest Route: ['MON', 'KVB', 'OSS', 'TENTRB', 'TEQTRC', 'TRO', 'MON'], Total Distance: 217.85, Total Demand: 93.5, Duration sailing: 21.78, Duration lossing: 12.99
# Shortest Route: ['MON', 'MID', 'NLNVAL', 'OSC', 'OSS', 'TRO', 'MON'], Total Distance: 240.11, Total Demand: 89.67, Duration sailing: 24.01, Duration lossing: 12.46
# Shortest Route: ['MON', 'MID', 'NLNVAL', 'OSC', 'TENTRB', 'TRO', 'MON'], Total Distance: 230.27, Total Demand: 95.17, Duration sailing: 23.03, Duration lossing: 13.22
# Shortest Route: ['MON', 'MID', 'NLNVAL', 'OSC', 'TEQTRC', 'TRO', 'MON'], Total Distance: 240.03, Total Demand: 98.67, Duration sailing: 24.0, Duration lossing: 13.71
# Shortest Route: ['MON', 'MID', 'NLNVAL', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 250.81, Total Demand: 95.17, Duration sailing: 25.08, Duration lossing: 13.22
# Shortest Route: ['MON', 'MID', 'NLNVAL', 'OSS', 'TEQTRC', 'TRO', 'MON'], Total Distance: 262.4, Total Demand: 98.67, Duration sailing: 26.24, Duration lossing: 13.71
# Shortest Route: ['MON', 'MID', 'OSC', 'OSE', 'OSS', 'TRO', 'MON'], Total Distance: 199.66, Total Demand: 97.0, Duration sailing: 19.97, Duration lossing: 13.47
# Shortest Route: ['MON', 'MID', 'OSC', 'OSOVFB', 'OSS', 'TRO', 'MON'], Total Distance: 224.83, Total Demand: 89.5, Duration sailing: 22.48, Duration lossing: 12.43
# Shortest Route: ['MON', 'MID', 'OSC', 'OSOVFB', 'TENTRB', 'TRO', 'MON'], Total Distance: 201.39, Total Demand: 95.0, Duration sailing: 20.14, Duration lossing: 13.2
# Shortest Route: ['MON', 'MID', 'OSC', 'OSOVFB', 'TEQTRC', 'TRO', 'MON'], Total Distance: 209.35, Total Demand: 98.5, Duration sailing: 20.94, Duration lossing: 13.68
# Shortest Route: ['MON', 'MID', 'OSC', 'OSS', 'STC', 'TRO', 'MON'], Total Distance: 294.16, Total Demand: 90.0, Duration sailing: 29.42, Duration lossing: 12.5
# Shortest Route: ['MON', 'MID', 'OSC', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 210.96, Total Demand: 84.5, Duration sailing: 21.1, Duration lossing: 11.74
# Shortest Route: ['MON', 'MID', 'OSC', 'OSS', 'TEQTRC', 'TRO', 'MON'], Total Distance: 222.55, Total Demand: 88.0, Duration sailing: 22.26, Duration lossing: 12.22
# Shortest Route: ['MON', 'MID', 'OSC', 'STC', 'TENTRB', 'TRO', 'MON'], Total Distance: 271.98, Total Demand: 95.5, Duration sailing: 27.2, Duration lossing: 13.26
# Shortest Route: ['MON', 'MID', 'OSC', 'STC', 'TEQTRC', 'TRO', 'MON'], Total Distance: 273.95, Total Demand: 99.0, Duration sailing: 27.4, Duration lossing: 13.75
# Shortest Route: ['MON', 'MID', 'OSC', 'TENTRB', 'TEQTRC', 'TRO', 'MON'], Total Distance: 205.88, Total Demand: 93.5, Duration sailing: 20.59, Duration lossing: 12.99
# Shortest Route: ['MON', 'MID', 'OSOVFB', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 234.28, Total Demand: 95.0, Duration sailing: 23.43, Duration lossing: 13.2
# Shortest Route: ['MON', 'MID', 'OSOVFB', 'OSS', 'TEQTRC', 'TRO', 'MON'], Total Distance: 245.87, Total Demand: 98.5, Duration sailing: 24.59, Duration lossing: 13.68
# Shortest Route: ['MON', 'MID', 'OSS', 'STC', 'TENTRB', 'TRO', 'MON'], Total Distance: 284.82, Total Demand: 95.5, Duration sailing: 28.48, Duration lossing: 13.26
# Shortest Route: ['MON', 'MID', 'OSS', 'STC', 'TEQTRC', 'TRO', 'MON'], Total Distance: 286.79, Total Demand: 99.0, Duration sailing: 28.68, Duration lossing: 13.75
# Shortest Route: ['MON', 'MID', 'OSS', 'TENTRB', 'TEQTRC', 'TRO', 'MON'], Total Distance: 214.0, Total Demand: 93.5, Duration sailing: 21.4, Duration lossing: 12.99
# Shortest Route: ['MON', 'NLNVAL', 'OSC', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 206.66, Total Demand: 99.17, Duration sailing: 20.67, Duration lossing: 13.77
# Shortest Route: ['MON', 'OSC', 'OSOVFB', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 189.67, Total Demand: 99.0, Duration sailing: 18.97, Duration lossing: 13.75
# Shortest Route: ['MON', 'OSC', 'OSS', 'STC', 'TENTRB', 'TRO', 'MON'], Total Distance: 251.38, Total Demand: 99.5, Duration sailing: 25.14, Duration lossing: 13.82
# Shortest Route: ['MON', 'OSC', 'OSS', 'TENTRB', 'TEQTRC', 'TRO', 'MON'], Total Distance: 180.56, Total Demand: 97.5, Duration sailing: 18.06, Duration lossing: 13.54
# Shortest Route: ['MON', 'APT', 'ASL', 'KVB', 'MID', 'OSC', 'TRO', 'MON'], Total Distance: 270.57, Total Demand: 100.0, Duration sailing: 27.06, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'ASL', 'KVB', 'MID', 'OSS', 'TRO', 'MON'], Total Distance: 274.98, Total Demand: 100.0, Duration sailing: 27.5, Duration lossing: 13.89
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSC', 'OSS', 'TRO', 'MON'], Total Distance: 269.81, Total Demand: 93.0, Duration sailing: 26.98, Duration lossing: 12.92
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSC', 'TENTRB', 'TRO', 'MON'], Total Distance: 259.97, Total Demand: 98.5, Duration sailing: 26.0, Duration lossing: 13.68
# Shortest Route: ['MON', 'APT', 'KVB', 'MID', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 268.09, Total Demand: 98.5, Duration sailing: 26.81, Duration lossing: 13.68
# Shortest Route: ['MON', 'ASL', 'KVB', 'MID', 'OSC', 'OSS', 'TRO', 'MON'], Total Distance: 250.6, Total Demand: 100.0, Duration sailing: 25.06, Duration lossing: 13.89
# Shortest Route: ['MON', 'KVB', 'MID', 'OSC', 'OSS', 'TENTRB', 'TRO', 'MON'], Total Distance: 233.41, Total Demand: 98.5, Duration sailing: 23.34, Duration lossing: 13.68
# 2239

# %% [markdown]
# ## Checks the capacity utilization (demand delivered). Removes all routes with capacity utilization below 70%

# %%
count_below_10 = 0
count_below_20 = 0
count_below_30 = 0
count_below_40 = 0
count_below_50 = 0
count_below_60 = 0
count_below_70 = 0
count_below_80 = 0
count_below_90 = 0

for route, distance, demand, duration_sailing, duration_lossing in shortest_routes_dict.values():
    if demand < 10:
        count_below_10 += 1
    if demand < 20:
        count_below_20 += 1
    if demand < 30:
        count_below_30 += 1
    if demand < 40:
        count_below_40 += 1
    if demand < 50:
        count_below_50 += 1
    if demand < 60:
        count_below_60 += 1
    if demand < 70:
        count_below_70 += 1
    if demand < 80:
        count_below_80 += 1
    if demand < 90:
        count_below_90 += 1

print("Number of shortest routes with total demand below 10:", count_below_10)
print("Number of shortest routes with total demand below 20:", count_below_20)
print("Number of shortest routes with total demand below 30:", count_below_30)
print("Number of shortest routes with total demand below 40:", count_below_40)
print("Number of shortest routes with total demand below 50:", count_below_50)
print("Number of shortest routes with total demand below 60:", count_below_60)
print("Number of shortest routes with total demand below 70:", count_below_70)
print("Number of shortest routes with total demand below 80:", count_below_80)
print("Number of shortest routes with total demand below 90:", count_below_90)
# Out:
# Number of shortest routes with total demand below 10: 0
# Number of shortest routes with total demand below 20: 6
# Number of shortest routes with total demand below 30: 20
# Number of shortest routes with total demand below 40: 40
# Number of shortest routes with total demand below 50: 97
# Number of shortest routes with total demand below 60: 215
# Number of shortest routes with total demand below 70: 403
# Number of shortest routes with total demand below 80: 769
# Number of shortest routes with total demand below 90: 1363

# %%
shortest_routes_dict_cap = {}

for key, (route, distance, demand, duration_sailing, duration_lossing) in shortest_routes_dict.items():
    if demand > 70:
        shortest_routes_dict_cap[key] = (route, distance, demand, duration_sailing, duration_lossing)

# %%
print(len(shortest_routes_dict_cap))
# Out:
# 1818

# %% [markdown]
# ## Removes routes which results in very long idle time

# %%
count_between_16_and_24 = 0
count_between_40_and_48 = 0

for route, distance, demand, duration_sailing, duration_lossing in shortest_routes_dict_cap.values():
    total_duration = duration_sailing + duration_lossing
    if 16 < total_duration < 24:
        count_between_16_and_24 += 1
    if 40 < total_duration < 48:
        count_between_40_and_48 += 1

print("Count of routes with duration between 16 and 24:", count_between_16_and_24)
print("Count of routes with duration between 40 and 48:", count_between_40_and_48)
# Out:
# Count of routes with duration between 16 and 24: 0
# Count of routes with duration between 40 and 48: 344

# %%
shortest_routes_dict_cap_idle = {}
routes_to_remove = []

for key, (route, distance, demand, duration_sailing, duration_lossing) in shortest_routes_dict_cap.items():
    total_duration = duration_sailing + duration_lossing
    if 16 < total_duration < 24 or 40 < total_duration < 48:
        routes_to_remove.append(key)
    else:
        shortest_routes_dict_cap_idle[key] = (route, distance, demand, duration_sailing, duration_lossing)

for key in routes_to_remove:
    del shortest_routes_dict_cap[key]

# %%
print(len(shortest_routes_dict_cap))
# Out:
# 1474

# %% [markdown]
# ## Saves the shortest routes left to csv files in the generated_datafiles folder. In total 2294 routes

# %%
routes_only = [route for route, _, _, _, _ in shortest_routes_dict_cap.values()]
distances_only = [distance for _, distance, _, _, _ in shortest_routes_dict_cap.values()]
demand_only = [demand for _, _, demand, _, _ in shortest_routes_dict_cap.values()]
duration_sailing = [duration_sailing for _, _, _, duration_sailing, _ in shortest_routes_dict_cap.values()]
duration_lossing = [duration_lossing for _, _, _, _, duration_lossing in shortest_routes_dict_cap.values()]

df_distances = pd.DataFrame({'Distance': distances_only})
df_demand = pd.DataFrame({'Demand': demand_only})
df_duration_sailing = pd.DataFrame({'Duration (hours)': duration_sailing})
df_duration_lossing = pd.DataFrame({'Duration (hours)': duration_lossing})

df_distances.to_csv('generated_datafiles/distances_strøm.csv', index=False)
df_demand.to_csv('generated_datafiles/demand_strøm.csv', index=False)
df_duration_sailing.to_csv('generated_datafiles/duration_sailing_strøm.csv', index=False)
df_duration_lossing.to_csv('generated_datafiles/duration_lossing_strøm.csv', index=False)

route_file = "generated_datafiles/routes_strøm.csv"

def write_to_csv(filename, data):
    with open(filename, "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerows(data)

write_to_csv(route_file, routes_only)
